# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

# %%
genius_api_key = '-pbykM_bCOXSjvVaREf3bjLhdv8RaN72lxo-QBZGGURSvVd9andLXAu1c-OvlqRT'

# %%
folder_path = r"Z:\BSDS3002_GP_GIT\BSDS3002\Part3 - Tracks\results"
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path):
        artist_df = pd.read_parquet(file_path)
        break

artist_df
# Out:
#                    album_id                  album_name  total_tracks  \
# 0    2juJczR3qiEKXQqryKDF9u              Let It Be Blue            11
# 1    2juJczR3qiEKXQqryKDF9u              Let It Be Blue            11
# 2    2juJczR3qiEKXQqryKDF9u              Let It Be Blue            11
# 3    2juJczR3qiEKXQqryKDF9u              Let It Be Blue            11
# 4    2juJczR3qiEKXQqryKDF9u              Let It Be Blue            11
# ..                      ...                         ...           ...
# 158  2tJySzsNME9WbfSwSve82T  Strange Weather, Isn't It?            10
# 159  2tJySzsNME9WbfSwSve82T  Strange Weather, Isn't It?            10
# 160  2tJySzsNME9WbfSwSve82T  Strange Weather, Isn't It?            10
# 161  2tJySzsNME9WbfSwSve82T  Strange Weather, Isn't It?            10
# 162  2tJySzsNME9WbfSwSve82T  Strange Weather, Isn't It?            10
#
#     album_type release_date artists  \
# 0        album   2022-05-06   [!!!]
# 1        album   2022-05-06   [!!!]
# ...

# %%
from syrics.api import Spotify
sp = Spotify("AQDNUdw04pOvll6grA-CwnJqomQbNrEu8bnLYzMIDVIIpYhxCR9SnqgBEwcsc18J2IquWtHmIhtZE-TJkwqOtgcs-KPb8eR8mCf3QZ5MOGcRtPloxMW9ShcohEzPQAIP29abxGuTruJ9igSFrvRqVwvRttT8mwe6")
lyrics = sp.get_lyrics("7ICQctvdnGfnvTh2UEq8yT")

# %%
import re
from collections import Counter

# %%
test_lyrics = ""
for x in lyrics['lyrics']['lines']:
    test_lyrics += ' ' + x['words']
    # print(x['words'])
print(test_lyrics)
# Out:
#  It's hard to say what it'll do to me But it's not like it's exactly new to me And if I came up with another excuse, you see Just wouldn't sound like the truth to me Normal people, normal people Normal people tell themselves what they wanna believe Normal people, normal people Normal people, normal people like me I expect what anyone elsе expects Hoping for the bеst to a different effect But I'd like to believe there's something 'round the corner That's never been there before Normal people, normal people Normal people get up in the morning Normal people, normal people Normal people get up in the afternoon Normal people, normal people Normal people, normal people like me

# %%
test_lyrics = test_lyrics.lower()
words = test_lyrics.split()
bag_of_words = Counter(words)
bag_of_words
# Out:
# Counter({"it's": 3,
#          'hard': 1,
#          'to': 6,
#          'say': 1,
#          'what': 3,
#          "it'll": 1,
#          'do': 1,
#          'me': 5,
#          'but': 2,
#          'not': 1,
#          'like': 5,
#          'exactly': 1,
#          'new': 1,
#          'and': 1,
#          'if': 1,
#          'i': 2,
#          'came': 1,
#          'up': 3,
#          'with': 1,
#          'another': 1,
#          'excuse,': 1,
#          'you': 1,
#          'see': 1,
#          'just': 1,
#          "wouldn't": 1,
#          'sound': 1,
#          'the': 5,
#          'truth': 1,
#          'normal': 17,
#          'people,': 7,
#          'people': 10,
#          'tell': 1,
#          'themselves': 1,
#          'they': 1,
#          'wanna': 1,
#          'believe': 2,
#          'expect': 1,
#          'anyone': 1,
#          'elsе': 1,
#          'expects': 1,
#          'hoping': 1,
#          'for': 1,
#          'bеst': 1,
#          'a': 1,
# ...

# %%
test_artist = artist_df.copy(deep=True)

# %%
test_artist['bag_of_words'] = None
for i, r in test_artist.iterrows():
    print(r['track_name'])
    test_artist.at[0, 'bag_of_words'] = bag_of_words
# Out:
# Normal People
# A Little Bit (More)
# Storm Around The World
# Un Puente
# Here's What I Need To Know
# Panama Canal
# Man On The Moon
# Let It Be Blue
# It's Grey, It's Grey (It's Grey)
# Crazy Talk
# This Is Pop 2
# Do The Dial Tone
# Maybe You Can’t Make It
# Tighten the Grip
# Let It Fall
# Wonderful Life
# Take It Easy
# Walk It Off
# Let It Change U
# Couldn't Have Known
# Off The Grid
# In The Grid
# Serbia Drums
# My Fault
# Slow Motion
# Slo Mo
# $50 Million
# Domino
# Rhythm Of The Gravity
# UR Paranoid
# This Is The Door
# This Is The Dub
# Kim, Thurston and Me (Intro)
# Kim, Thurston and Me (Intro)
# Charlotte All The Time
# Charlotte All The Time
# Pair Of Dice
# Pair Of Dice
# I Came Here To Be (Yogi's Jam)
# I Came Here To Be (Yogi's Jam)
# I Know It's True
# I Know It's True
# What U Do 2 Me
# What U Do 2 Me
# Stuck In My Heart
# Stuck In My Heart
# Say It (Say It)
# Say It (Say It)
# Happiness Is A Warm Yes (It Is)
# Happiness Is A Warm Yes (It Is)
# The Long Walk
# ...

# %%
test_artist
# Out:
#                    album_id                  album_name  total_tracks  \
# 0    2juJczR3qiEKXQqryKDF9u              Let It Be Blue            11
# 1    2juJczR3qiEKXQqryKDF9u              Let It Be Blue            11
# 2    2juJczR3qiEKXQqryKDF9u              Let It Be Blue            11
# 3    2juJczR3qiEKXQqryKDF9u              Let It Be Blue            11
# 4    2juJczR3qiEKXQqryKDF9u              Let It Be Blue            11
# ..                      ...                         ...           ...
# 158  2tJySzsNME9WbfSwSve82T  Strange Weather, Isn't It?            10
# 159  2tJySzsNME9WbfSwSve82T  Strange Weather, Isn't It?            10
# 160  2tJySzsNME9WbfSwSve82T  Strange Weather, Isn't It?            10
# 161  2tJySzsNME9WbfSwSve82T  Strange Weather, Isn't It?            10
# 162  2tJySzsNME9WbfSwSve82T  Strange Weather, Isn't It?            10
#
#     album_type release_date artists  \
# 0        album   2022-05-06   [!!!]
# 1        album   2022-05-06   [!!!]
# ...

# %%
seesee = pd.read_parquet(r"Z:\BSDS3002_GP_GIT\BSDS3002\Part3 - Lyrics\results\Tamia_tracks.parquet.parquet")

# %%
seesee
# Out:
#                    album_id                                album_name  \
# 0    3l6sId23asoJVjAdNbJAqi                                  Into You
# 1    3l6sId23asoJVjAdNbJAqi                                  Into You
# 2    3l6sId23asoJVjAdNbJAqi                                  Into You
# 3    3l6sId23asoJVjAdNbJAqi                                  Into You
# 4    3l6sId23asoJVjAdNbJAqi                                  Into You
# ..                      ...                                       ...
# 115  616KEcxuONu7C8I6yX64WL                         Cuore di farfalla
# 116  4kfDG41cBfuYsnQCHMgXU7  Leave It Smokin' (remixed by Moon Boots)
# 117  3iqKZM5TUCOkri7aooId5O     Leave It Smokin’ (Remix) [feat. Wale]
# 118  3eoaDBdgObp2e6wxMgWdai                                    Deeper
# 119  0rOPCzZAW5llib3ISGGQRc                                Today I Do
#
#      total_tracks album_type release_date              artists  \
# ...
