# %%
import pandas as pd

# %%
df = pd.read_parquet(r"Z:\BSDS3002_GP_GIT\BSDS3002\Part2 - Results\filtered_artists_with_relations.parquet")
df
# Out:
#                                        Artist                    Spotify Name  \
# 0                                   Motörhead                       Motörhead
# 1                               Color Me Badd                   Color Me Badd
# 2                               Trumans Water                   Trumans Water
# 3                             Cliff Eberhardt                 Cliff Eberhardt
# 4                              The Waitresses                  The Waitresses
# ...                                       ...                             ...
# 9117              Diana Ross and the Supremes       Diana Ross & The Supremes
# 9128                      Frank Black Francis     Frank Black & The Catholics
# 9184  Louis Armstrong - Itinéraire d'un génie  Louis Armstrong & His Hot Five
# 9454                             Steve Harley                    Steve Harley
# 9847           Georgie Fame & The Blue Flames  Georgie Fame & The Blue Flames
#
# ...
