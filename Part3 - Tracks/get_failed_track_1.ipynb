# %%
import os
import base64
import requests
from requests import post, get
import json
from tqdm import tqdm
import pandas as pd
import time
import math
import re

# %%
client_credentials = [
('ef58993d4fbe446ca6a6edd303a56c80', '3fe8edaf5c8147ff9e81ea858b410102'),
('e857908311cd436abed7fe2b1dc99bd5', '56411c35c3874b9ebbaf3f3fe80a811c'),
('470adf495fd548298483dc4d1a38b1e2', 'c16d7144415946028ae38b6d635f6bfd'),
('adafeb81352e4bddb7d5f3be5956ada8', 'a09dbec853264e94a0a5f61eb6df67ed'),
('4c42335d9dc74a36a48cee122449c9d6', '7b0c7b87143d4051b0e3891e70e83da9'),
('ed1bfedbe22244fdbc9f9a592bb8b153', '50585f3a59364e48980e5f576ec9d719'),
('dc3085808e9e490a8426ec00952e12c9', '4b9c26457b034c79b8363ed19ebd9e30'),
('af8d0d58749e48c19ac32f47a8089e31', 'c021220c33f94bd6bceec431617564c8'),
('200886fa3780485faa62b4e89034f7b8', '0deb41f8c0684e619ebceff7e7160d44'),
('46a05bf1cd064188a47c2ec88aca1aeb', 'ca9ce67a39a44b81854d64c9a6acb2bd')

]



credential_index = 0

def get_token(client_id, client_secret):
    auth_string = client_id + ":" + client_secret
    auth_bytes = auth_string.encode("utf-8")
    auth_base64 = str(base64.b64encode(auth_bytes), "utf-8")

    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": "Basic " + auth_base64,
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"grant_type": "client_credentials"}

    response = requests.post(url, headers=headers, data=data)
    json_result = json.loads(response.content)

    if "access_token" in json_result:
        token = json_result["access_token"]
        return token
    else:
        print("Error: Failed to get access token")
        print(json_result)
        return None

def get_auth_header(token):
    return {"Authorization": "Bearer " + token}

def get_albums_for_artist(token, artist_id):
    url = f"https://api.spotify.com/v1/artists/{artist_id}/albums"
    headers = get_auth_header(token)
    params = {"include_groups": "album"}
    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        albums = json.loads(response.text)["items"]
        album_dict = {}
        for album in albums:
            album_id = album["id"]
            album_name = album["name"]
            album_tracks = album["total_tracks"]
            album_type = album["album_type"]
            album_release_date = album["release_date"]
            album_artists = [artist["name"] for artist in album["artists"]]
            album_images = album["images"]

            if album_name in album_dict:
                existing_tracks = album_dict[album_name]["total_tracks"]
                if album_tracks > existing_tracks:
                    album_dict[album_name] = {
                        "album_id": album_id,
                        "album_name": album_name,
                        "total_tracks": album_tracks,
                        "album_type": album_type,
                        "release_date": album_release_date,
                        "artists": album_artists,
                        "images": album_images
                    }
            else:
                album_dict[album_name] = {
                    "album_id": album_id,
                    "album_name": album_name,
                    "total_tracks": album_tracks,
                    "album_type": album_type,
                    "release_date": album_release_date,
                    "artists": album_artists,
                    "images": album_images
                }
        return album_dict
    else:
        print("Error: Failed to get albums for artist")
        print(response.content)
        return None
    
def get_tracks_for_album(token, album_id):
    url = f"https://api.spotify.com/v1/albums/{album_id}/tracks"
    headers = get_auth_header(token)
    params = {"market": "US"}
    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        tracks = json.loads(response.text)["items"]
        track_list = []
        for track in tracks:
            track_name = track["name"]
            track_id = track["id"]
            track_number = track["track_number"]
            track_explicit = track["explicit"]
            track_artists = [artist["name"] for artist in track["artists"]]
            track_dict = {
                "track_name": track_name,
                "track_id": track_id,
                "track_number": track_number,
                "track_explicit": track_explicit,
                "track_artists": track_artists,
            }
            track_list.append(track_dict)
        return track_list
    else:
        print("Error: Failed to get tracks for album")
        print(response.content)
        return None
    
def get_audio_features(token, track_ids):
    audio_features = []

    for i in range(0, len(track_ids), 50):
        chunk = track_ids[i:i + 50]
        ids = ','.join(chunk)
        url = f"https://api.spotify.com/v1/audio-features?ids={ids}"
        headers = {"Authorization": f"Bearer {token}"}
        r = requests.get(url, headers=headers)
        if r.status_code != 200:
            print(f"Error getting audio features for tracks: {r.status_code}")
            return None

        try:
            features = r.json()["audio_features"]
        except KeyError:
            features = []

        audio_features.extend(features)

    audio_features_filtered = []
    for feature in audio_features:
        if feature is not None:
            audio_features_filtered.append(feature)

    return pd.DataFrame(audio_features_filtered)

def load_checkpoint():
    if os.path.exists('checkpoint_f1.json'):
        with open('checkpoint_f1.json', 'r') as f:
            return json.load(f)
    else:
        return {"artist_id": "", "progress": 0}

def save_checkpoint(artist_id, progress):
    with open('checkpoint_f1.json', 'w') as f:
        json.dump({"artist_id": artist_id, "progress": progress}, f)

def load_failed_requests():
    if os.path.exists('failed_requests_f1.parquet'):
        return pd.read_parquet('failed_requests_f1.parquet')
    else:
        return pd.DataFrame(columns=['Spotify ID'])

def save_failed_requests(df):
    df.to_parquet('failed_requests_f1.parquet')

def refresh_token(token_start_time):
    global credential_index
    current_time = time.time()
    elapsed_time = current_time - token_start_time
    if elapsed_time >= 1800:
        credential_index = (credential_index + 1) % len(client_credentials)
        client_id, client_secret = client_credentials[credential_index]
        return get_token(client_id, client_secret), current_time
    return None, token_start_time

def sanitize_filename(filename):
    return re.sub(r'[\\/:"*?<>|]+', '_', filename)

# %%
with open('lost_artist_ids_sub_dict_1.json', 'r') as f:
    artist_ids = json.load(f)
len(artist_ids)
# Out:
# 3202

# %%
token = get_token(client_credentials[0][0], client_credentials[0][1])
token_start_time = time.time()

checkpoint = load_checkpoint()
failed_requests = load_failed_requests()

start_from = checkpoint["artist_id"] if checkpoint["artist_id"] else list(artist_ids.keys())[0]
start_index = list(artist_ids.keys()).index(start_from)


iteration_counter = 0
sleep_interval = 50

for artist_id, artist_name in list(artist_ids.items())[start_index:]:
    sanitized_artist_name = sanitize_filename(artist_name)
    parquet_file_path = f'results/{sanitized_artist_name}_tracks.parquet'
    if os.path.exists(parquet_file_path):
        print(f"Parquet file already exists for {artist_name}, skipping...")
        continue
    try:
        refreshed_token, new_token_start_time = refresh_token(token_start_time)
        if refreshed_token:
            token = refreshed_token
            token_start_time = new_token_start_time

        albums = get_albums_for_artist(token, artist_id)

        if albums is None:
            failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
            save_failed_requests(failed_requests)
            continue

        album_df = pd.DataFrame.from_dict(albums, orient="index")
        album_df.index.name = "album_name"

        all_tracks_df = pd.DataFrame()
        for album_id in tqdm(album_df['album_id'], desc=f"Processing {artist_name}"):
            time.sleep(1)
            tracks = get_tracks_for_album(token, album_id)
            if tracks is None:
                failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
                save_failed_requests(failed_requests)
                continue

            tracks = pd.DataFrame(tracks)
            tracks['album_id'] = album_id
            all_tracks_df = pd.concat([all_tracks_df, tracks], axis=0)

        af_df = get_audio_features(token, all_tracks_df['track_id'].tolist())
        af_df = af_df.rename(columns={'id': 'track_id'})
        all_aftracks_df = pd.merge(all_tracks_df, af_df, on='track_id')
        album_all_aftracks_df = pd.merge(album_df, all_aftracks_df, on='album_id')
        sanitized_artist_name = sanitize_filename(artist_name)
        album_all_aftracks_df.to_parquet(f'results/{sanitized_artist_name}_tracks.parquet')

        save_checkpoint(artist_id, artist_name)
        iteration_counter += 1
        if iteration_counter % sleep_interval == 0:
            time.sleep(10)
            
    except Exception as e:
        print(f"Error processing {artist_name}: {e}")
        failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
        save_failed_requests(failed_requests)
        continue

print("Completed processing all artists.")
# Out:
# Parquet file already exists for The Radiators, skipping...
# Parquet file already exists for Hungry Lucy, skipping...
# Parquet file already exists for Judy Kuhn, skipping...
# Parquet file already exists for Melanie Fiona, skipping...
# Parquet file already exists for Michael Hurley, skipping...
# Parquet file already exists for Louise Goffin, skipping...
# Parquet file already exists for Candi Staton, skipping...
# Parquet file already exists for California X, skipping...
# Parquet file already exists for Archie Fisher, skipping...
# Parquet file already exists for Roadkill Ghost Choir, skipping...
# Parquet file already exists for Josh Roseman Unit, skipping...
# Parquet file already exists for Roger Waters, skipping...
# Parquet file already exists for Rogue Wave, skipping...
# Parquet file already exists for Phil Collins, skipping...
# Parquet file already exists for Nashville Pussy, skipping...
# Parquet file already exists for Imani Coppola, skipping...
# Parquet file already exists for The Beguiled, skipping...
# Parquet file already exists for Mitchell Akiyama, skipping...
# Parquet file already exists for Bob Gibson, skipping...
# Parquet file already exists for The Living End, skipping...
# Parquet file already exists for Port O'Brien, skipping...
# Parquet file already exists for Crippled Black Phoenix, skipping...
# Parquet file already exists for Bobby Brown, skipping...
# Parquet file already exists for Death Cab for Cutie, skipping...
# Parquet file already exists for Leah Andreone, skipping...
# Parquet file already exists for Canibus, skipping...
# Parquet file already exists for Neneh Cherry, skipping...
# Parquet file already exists for Entombed, skipping...
# Parquet file already exists for Blowfly, skipping...
# Parquet file already exists for Armin van Buuren, skipping...
# Parquet file already exists for Crowbar, skipping...
# Parquet file already exists for Fontanelle, skipping...
# Parquet file already exists for The Rats, skipping...
# Parquet file already exists for Ruth Brown, skipping...
# Parquet file already exists for Lief Sorbye, skipping...
# Parquet file already exists for Curtis Amy, skipping...
# Parquet file already exists for Steve Marriott, skipping...
# Parquet file already exists for Karsh Kale, skipping...
# Parquet file already exists for Gogol Bordello, skipping...
# Parquet file already exists for Adventures Of Jet, skipping...
# Parquet file already exists for Larry Harlow, skipping...
# Parquet file already exists for Dream Wife, skipping...
# Parquet file already exists for Elevation Worship, skipping...
# Parquet file already exists for Ruby Braff, skipping...
# Parquet file already exists for Major Stars, skipping...
# Parquet file already exists for Arizona Dranes, skipping...
# Parquet file already exists for Salaam Remi, skipping...
# Parquet file already exists for Johnny Farmer, skipping...
# Parquet file already exists for Angela Johnson, skipping...
# Parquet file already exists for Pinetop Perkins, skipping...
# Parquet file already exists for 50 Foot Wave, skipping...
# Parquet file already exists for Tierney Sutton, skipping...
# Parquet file already exists for Emily Remler, skipping...
# Parquet file already exists for Kree Harrison, skipping...
# Error processing Pendragon: 'album_id'
# Parquet file already exists for Pete Namlook, skipping...
# Parquet file already exists for Whodini, skipping...
# Parquet file already exists for Bellusira, skipping...
# Parquet file already exists for Sister Hazel, skipping...
# Parquet file already exists for Ramblin' Jack Elliott, skipping...
# Parquet file already exists for Chris Rea, skipping...
# Parquet file already exists for Biz Markie, skipping...
# Parquet file already exists for Helmet, skipping...
# Parquet file already exists for Boulevards, skipping...
# Parquet file already exists for Patrick Sky, skipping...
# Parquet file already exists for Prefab Sprout, skipping...
# Parquet file already exists for John Mellencamp, skipping...
# Parquet file already exists for Don Cherry, skipping...
# Parquet file already exists for Terry Jennings, skipping...
# Parquet file already exists for Buck-O-Nine, skipping...
# Parquet file already exists for Skream, skipping...
# Parquet file already exists for Steve Jones, skipping...
# Parquet file already exists for Gal Costa, skipping...
# Parquet file already exists for Natalie Imbruglia, skipping...
# Parquet file already exists for Eddie Durham, skipping...
# Parquet file already exists for Linton Kwesi Johnson, skipping...
# Parquet file already exists for Powerman 5000, skipping...
# Parquet file already exists for Shirley Caesar, skipping...
# Parquet file already exists for Shinehead, skipping...
# Parquet file already exists for Snail Mail, skipping...
# Parquet file already exists for Tuscadero, skipping...
# Parquet file already exists for Jimmy Durante, skipping...
# Parquet file already exists for Phil Woods, skipping...
# Parquet file already exists for Duncan Browne, skipping...
# Parquet file already exists for Silverstein, skipping...
# Parquet file already exists for Pham, skipping...
# Parquet file already exists for Jon Brion, skipping...
# Parquet file already exists for CeeLo Green, skipping...
# Parquet file already exists for The Posies, skipping...
# Parquet file already exists for Ed Thigpen, skipping...
# Parquet file already exists for Salt-N-Pepa, skipping...
# Parquet file already exists for Ben Bernie, skipping...
# Parquet file already exists for Vivian Green, skipping...
# Parquet file already exists for Robert Cray, skipping...
# Parquet file already exists for Slipknot, skipping...
# Parquet file already exists for Troye Sivan, skipping...
# Parquet file already exists for Motorpsycho, skipping...
# Parquet file already exists for Blake Baxter, skipping...
# Parquet file already exists for Zurdok, skipping...
# Parquet file already exists for Zeni Geva, skipping...
# Parquet file already exists for The Shilohs, skipping...
# Parquet file already exists for Shyheim, skipping...
# Parquet file already exists for The Disposable Heroes Of Hiphoprisy, skipping...
# Parquet file already exists for Ambitious Lovers, skipping...
# Parquet file already exists for Gene Autry, skipping...
# Parquet file already exists for Cher, skipping...
# Parquet file already exists for Hatebreed, skipping...
# Parquet file already exists for Cousin Emmy, skipping...
# Parquet file already exists for Ricky Ford, skipping...
# Parquet file already exists for Aceyalone, skipping...
# Parquet file already exists for Donny Hathaway, skipping...
# Parquet file already exists for Die Krupps, skipping...
# Parquet file already exists for Aloa Input, skipping...
# Parquet file already exists for Matt Nathanson, skipping...
# Parquet file already exists for Happy Mondays, skipping...
# Parquet file already exists for Macklemore, skipping...
# Parquet file already exists for Jerry Goldsmith, skipping...
# Parquet file already exists for Victoria Williams, skipping...
# Parquet file already exists for Roberto Torres, skipping...
# Parquet file already exists for Hal Ketchum, skipping...
# Parquet file already exists for Kirk Kelly, skipping...
# Parquet file already exists for The Incredible String Band, skipping...
# Parquet file already exists for Kitaro, skipping...
# Parquet file already exists for The Oh Hellos, skipping...
# Parquet file already exists for Possum Dixon, skipping...
# Parquet file already exists for Secret Affair, skipping...
# Parquet file already exists for Erasure, skipping...
# Parquet file already exists for The Most Serene Republic, skipping...
# Parquet file already exists for New American Shame, skipping...
# Parquet file already exists for Drake Bell, skipping...
# Parquet file already exists for Jimmy Martin, skipping...
# Parquet file already exists for Shelleyan Orphan, skipping...
# Parquet file already exists for Kenny G, skipping...
# Parquet file already exists for Daughter, skipping...
# Parquet file already exists for Black Uhuru, skipping...
# Parquet file already exists for Kelly Harrell, skipping...
# Error processing Felicia Temple: 'album_id'
# Parquet file already exists for Liam Lynch, skipping...
# Parquet file already exists for Ultimate Fakebook, skipping...
# Parquet file already exists for Giuffria, skipping...
# Parquet file already exists for The Flashbulb, skipping...
# Error processing Breathless: 'album_id'
# Parquet file already exists for Bowery Electric, skipping...
# Error processing Kim Deal: 'album_id'
# Parquet file already exists for Peetie Wheatstraw, skipping...
# Parquet file already exists for The Guess Who, skipping...
# Parquet file already exists for The Runaways, skipping...
# Parquet file already exists for Odd Nosdam, skipping...
# Parquet file already exists for The Osmonds, skipping...
# Parquet file already exists for Paul Desmond, skipping...
# Parquet file already exists for Memphis Jug Band, skipping...
# Parquet file already exists for John Hartford, skipping...
# Parquet file already exists for Grant-Lee Phillips, skipping...
# Parquet file already exists for Vanilla Fudge, skipping...
# Parquet file already exists for Global Communication, skipping...
# Parquet file already exists for Ebba Forsberg, skipping...
# Parquet file already exists for Kajagoogoo, skipping...
# Parquet file already exists for The Concretes, skipping...
# Parquet file already exists for Jupiter One, skipping...
# Parquet file already exists for Lumidee, skipping...
# Parquet file already exists for Chuck Strong, skipping...
# Parquet file already exists for Goody Grace, skipping...
# Parquet file already exists for Commodores, skipping...
# Parquet file already exists for Rah Rah, skipping...
# Parquet file already exists for Gridlock, skipping...
# Parquet file already exists for Da Brat, skipping...
# Parquet file already exists for Chevelle, skipping...
# Parquet file already exists for Steven Wilson, skipping...
# Parquet file already exists for Stray Cats, skipping...
# Parquet file already exists for Tedo Stone, skipping...
# Parquet file already exists for Shocking Pinks, skipping...
# Error processing Sallie Martin: 'album_id'
# Parquet file already exists for Juan Gabriel, skipping...
# Parquet file already exists for Slim Harpo, skipping...
# Parquet file already exists for Tom Rush, skipping...
# Parquet file already exists for Pete Steele, skipping...
# Parquet file already exists for Yashin, skipping...
# Error processing Trenchmouth: 'album_id'
# Parquet file already exists for Zion I, skipping...
# Parquet file already exists for Camila Cabello, skipping...
# Parquet file already exists for Annie Lennox, skipping...
# Parquet file already exists for Chris Lane, skipping...
# Parquet file already exists for The Walkabouts, skipping...
# Parquet file already exists for John Prine, skipping...
# Parquet file already exists for Faye Adams, skipping...
# Parquet file already exists for Dan Croll, skipping...
# Parquet file already exists for Zony Mash, skipping...
# Parquet file already exists for Fictionist, skipping...
# Parquet file already exists for Delays, skipping...
# Parquet file already exists for Dave Meder, skipping...
# Parquet file already exists for MC Lyte, skipping...
# Parquet file already exists for Richard Addinsell, skipping...
# Parquet file already exists for Mindless Self Indulgence, skipping...
# Parquet file already exists for Djivan Gasparyan, skipping...
# Parquet file already exists for Guadalcanal Diary, skipping...
# Parquet file already exists for Pansy Division, skipping...
# Parquet file already exists for Nicola Alesini, skipping...
# Parquet file already exists for Will Jay, skipping...
# Parquet file already exists for Bon Iver, skipping...
# Parquet file already exists for Bennie Maupin, skipping...
# Parquet file already exists for Billy Taylor, skipping...
# Parquet file already exists for Destroy All Monsters, skipping...
# Parquet file already exists for Bully, skipping...
# Parquet file already exists for Samara Lubelski, skipping...
# Parquet file already exists for William Michael Morgan, skipping...
# Parquet file already exists for Erin Boheme, skipping...
# Parquet file already exists for Flyleaf, skipping...
# Parquet file already exists for Cabas, skipping...
# Parquet file already exists for P.F. Sloan, skipping...
# Parquet file already exists for Ancient Future, skipping...
# Parquet file already exists for Travie McCoy, skipping...
# Parquet file already exists for Roy Rogers, skipping...
# Parquet file already exists for Ciara, skipping...
# Parquet file already exists for Zingaia, skipping...
# Parquet file already exists for Phebe Starr, skipping...
# Parquet file already exists for State Champs, skipping...
# Parquet file already exists for Tony Williams, skipping...
# Parquet file already exists for Tish Hinojosa, skipping...
# Parquet file already exists for Jamie Lawson, skipping...
# Parquet file already exists for Richard Elliot, skipping...
# Parquet file already exists for The Police, skipping...
# Parquet file already exists for Krokus, skipping...
# Error processing Lagbaja: 'album_id'
# Parquet file already exists for Myracle Brah, skipping...
# Parquet file already exists for Stevie Wonder, skipping...
# Parquet file already exists for Engelbert Humperdinck, skipping...
# Parquet file already exists for Dodgy, skipping...
# Parquet file already exists for Peter Blegvad, skipping...
# Parquet file already exists for The La's, skipping...
# Parquet file already exists for Dweezil Zappa, skipping...
# Parquet file already exists for Total Babes, skipping...
# Parquet file already exists for Air Supply, skipping...
# Error processing Present: 'album_id'
# Parquet file already exists for Remy Ma, skipping...
# Parquet file already exists for Glee Cast, skipping...
# Parquet file already exists for Leaf Hound, skipping...
# Parquet file already exists for Guns N' Roses, skipping...
# Parquet file already exists for Band Of Susans, skipping...
# Parquet file already exists for JamisonParker, skipping...
# Parquet file already exists for Maurice Jarre, skipping...
# Parquet file already exists for Dagmar Krause, skipping...
# Parquet file already exists for Joe Liggins, skipping...
# Parquet file already exists for Dino Valente, skipping...
# Error processing Boymerang: 'album_id'
# Parquet file already exists for Brass Construction, skipping...
# Parquet file already exists for The Band, skipping...
# Error processing Christina Carter: 'album_id'
# Parquet file already exists for Daphne Loves Derby, skipping...
# Parquet file already exists for Calvin Richardson, skipping...
# Error processing Vince Trombetta: 'album_id'
# Parquet file already exists for From Indian Lakes, skipping...
# Parquet file already exists for Babyshambles, skipping...
# Parquet file already exists for Exuma, skipping...
# Parquet file already exists for The Wild Swans, skipping...
# Parquet file already exists for Arcwelder, skipping...
# Parquet file already exists for Twisted Sister, skipping...
# Parquet file already exists for John Coltrane Quartet, skipping...
# Error processing Young Killer: 'album_id'
# Parquet file already exists for The Cool Kids, skipping...
# Parquet file already exists for The Pharaohs, skipping...
# Parquet file already exists for Helen Love, skipping...
# Parquet file already exists for Dwele, skipping...
# Parquet file already exists for Hampton Grease Band, skipping...
# Parquet file already exists for The Moments, skipping...
# Parquet file already exists for Ethan Gruska, skipping...
# Parquet file already exists for Christopher Cross, skipping...
# Parquet file already exists for Sleigh Bells, skipping...
# Parquet file already exists for Roy Hamilton, skipping...
# Parquet file already exists for Klara Lewis, skipping...
# Parquet file already exists for Urban Rescue, skipping...
# Parquet file already exists for Better Than Ezra, skipping...
# Parquet file already exists for The Piano Guys, skipping...
# Parquet file already exists for BMX Bandits, skipping...
# Parquet file already exists for Any Trouble, skipping...
# Parquet file already exists for Mugison, skipping...
# Parquet file already exists for The Blackout Pact, skipping...
# Parquet file already exists for Renaissance, skipping...
# Parquet file already exists for Brenda Russell, skipping...
# Parquet file already exists for Izzy Bizu, skipping...
# Parquet file already exists for Dr. Jeffrey Thompson, skipping...
# Parquet file already exists for Jewel, skipping...
# Parquet file already exists for The Skatalites, skipping...
# Parquet file already exists for Our Lady Peace, skipping...
# Parquet file already exists for Ted Hawkins, skipping...
# Parquet file already exists for George Hodos, skipping...
# Error processing Gary Valente: 'album_id'
# Parquet file already exists for The Fleetwoods, skipping...
# Parquet file already exists for Ben Vaughn, skipping...
# Parquet file already exists for Guy Davis, skipping...
# Parquet file already exists for Soulive, skipping...
# Parquet file already exists for The Roots, skipping...
# Parquet file already exists for Chicken Lips, skipping...
# Parquet file already exists for Sara Bareilles, skipping...
# Parquet file already exists for Violent Femmes, skipping...
# Parquet file already exists for Active Child, skipping...
# Error processing The Normal: 'album_id'
# Parquet file already exists for Dean Martin, skipping...
# Parquet file already exists for Drive Like Jehu, skipping...
# Parquet file already exists for Greg Graffin, skipping...
# Parquet file already exists for Eddie Hazel, skipping...
# Parquet file already exists for Fat Nick, skipping...
# Parquet file already exists for Shyne, skipping...
# Error processing AudioDamn!: 'album_id'
# Parquet file already exists for Sarah Borges, skipping...
# Parquet file already exists for Death of Samantha, skipping...
# Parquet file already exists for Joey Beltram, skipping...
# Parquet file already exists for Nikki Yanofsky, skipping...
# Parquet file already exists for La Muerte, skipping...
# Parquet file already exists for Poco, skipping...
# Parquet file already exists for Cyndi Lauper, skipping...
# Parquet file already exists for Great White, skipping...
# Parquet file already exists for John Klemmer, skipping...
# Parquet file already exists for Pop Will Eat Itself, skipping...
# Parquet file already exists for Jon Jang, skipping...
# Parquet file already exists for FaltyDL, skipping...
# Parquet file already exists for Whistle, skipping...
# Parquet file already exists for Rick James, skipping...
# Parquet file already exists for Cheri Knight, skipping...
# Parquet file already exists for Shenandoah, skipping...
# Parquet file already exists for Taking Back Sunday, skipping...
# Parquet file already exists for Lefty Frizzell, skipping...
# Parquet file already exists for Teisco Del Rey, skipping...
# Parquet file already exists for The Tornadoes, skipping...
# Parquet file already exists for The Outfield, skipping...
# Parquet file already exists for Edward Sharpe & The Magnetic Zeros, skipping...
# Error processing Matthew Koma: 'album_id'
# Parquet file already exists for deadmau5, skipping...
# Parquet file already exists for The Heliocentrics, skipping...
# Parquet file already exists for The Music Machine, skipping...
# Parquet file already exists for Crime Mob, skipping...
# Parquet file already exists for Crumb, skipping...
# Parquet file already exists for Michael Carpenter, skipping...
# Parquet file already exists for Egg, skipping...
# Parquet file already exists for Shirley Collins, skipping...
# Parquet file already exists for Johnnie Ray, skipping...
# Parquet file already exists for Go West, skipping...
# Parquet file already exists for Tin Huey, skipping...
# Error processing Oswego: 'album_id'
# Parquet file already exists for The Midnight, skipping...
# Parquet file already exists for Francine Reed, skipping...
# Parquet file already exists for Otep, skipping...
# Parquet file already exists for Psychic TV, skipping...
# Parquet file already exists for King's X, skipping...
# Parquet file already exists for Pan Sonic, skipping...
# Parquet file already exists for Dan Auerbach, skipping...
# Parquet file already exists for Donna The Buffalo, skipping...
# Parquet file already exists for Mark Erelli, skipping...
# Parquet file already exists for Rachele Lynae, skipping...
# Parquet file already exists for Cibo Matto, skipping...
# Parquet file already exists for Nas, skipping...
# Parquet file already exists for Jazzyfatnastees, skipping...
# Parquet file already exists for Mavis Staples, skipping...
# Parquet file already exists for The McCoury Brothers, skipping...
# Parquet file already exists for Kate McGarry, skipping...
# Parquet file already exists for As One, skipping...
# Parquet file already exists for Omni Trio, skipping...
# Parquet file already exists for Mike Stern, skipping...
# Parquet file already exists for Gay Dad, skipping...
# Parquet file already exists for Superdrag, skipping...
# Parquet file already exists for Fever Ray, skipping...
# Parquet file already exists for Television, skipping...
# Parquet file already exists for Beatallica, skipping...
# Parquet file already exists for Point Of Grace, skipping...
# Parquet file already exists for Nellie McKay, skipping...
# Parquet file already exists for Della Reese, skipping...
# Parquet file already exists for Sandy Bull, skipping...
# Parquet file already exists for David Toop, skipping...
# Parquet file already exists for Donnie McClurkin, skipping...
# Parquet file already exists for Ken Colyer, skipping...
# Parquet file already exists for Andy Williams, skipping...
# Error processing Scott 4: 'album_id'
# Parquet file already exists for Chris Ardoin, skipping...
# Parquet file already exists for Third Eye Blind, skipping...
# Parquet file already exists for The Sweet Inspirations, skipping...
# Parquet file already exists for Murphy's Law, skipping...
# Parquet file already exists for Triumvirat, skipping...
# Parquet file already exists for Black Strobe, skipping...
# Parquet file already exists for Blue States, skipping...
# Parquet file already exists for David Clavijo, skipping...
# Parquet file already exists for Jimmy Dorsey, skipping...
# Parquet file already exists for Miriam Makeba, skipping...
# Parquet file already exists for The Flower Kings, skipping...
# Parquet file already exists for T. Texas Tyler, skipping...
# Parquet file already exists for George W. Johnson, skipping...
# Parquet file already exists for Ani DiFranco, skipping...
# Parquet file already exists for Aretha Franklin, skipping...
# Parquet file already exists for Raoul Björkenheim, skipping...
# Parquet file already exists for Travis Mills, skipping...
# Parquet file already exists for The Gap Band, skipping...
# Parquet file already exists for The Byrds, skipping...
# Parquet file already exists for Was (Not Was), skipping...
# Parquet file already exists for Bobby Rydell, skipping...
# Parquet file already exists for Aaron Parks, skipping...
# Parquet file already exists for Bill Laswell, skipping...
# Parquet file already exists for George Gershwin, skipping...
# Parquet file already exists for The Clash, skipping...
# Parquet file already exists for Céu, skipping...
# Parquet file already exists for Girls Aloud, skipping...
# Parquet file already exists for Stephen Sondheim, skipping...
# Error processing Samhain: 'album_id'
# Parquet file already exists for DC Talk, skipping...
# Parquet file already exists for Fig Dish, skipping...
# Parquet file already exists for Maisie Peters, skipping...
# Parquet file already exists for Jessica Andrews, skipping...
# Parquet file already exists for Holger Czukay, skipping...
# Parquet file already exists for Charles Bukowski, skipping...
# Parquet file already exists for The High Llamas, skipping...
# Parquet file already exists for Paul Brady, skipping...
# Parquet file already exists for Soilwork, skipping...
# Parquet file already exists for Kurtis Blow, skipping...
# Parquet file already exists for Marcus Canty, skipping...
# Parquet file already exists for Major Lance, skipping...
# Parquet file already exists for Shawn Lane, skipping...
# Parquet file already exists for Azure Ray, skipping...
# Parquet file already exists for Pixies, skipping...
# Parquet file already exists for The Ivy League, skipping...
# Parquet file already exists for The Falcons, skipping...
# Parquet file already exists for Foetus, skipping...
# Parquet file already exists for Dire Straits, skipping...
# Parquet file already exists for Tokyo Police Club, skipping...
# Parquet file already exists for Jackie Paris, skipping...
# Parquet file already exists for Metallica, skipping...
# Parquet file already exists for Harry Chapin, skipping...
# Parquet file already exists for Robin Holcomb, skipping...
# Parquet file already exists for 90 Day Men, skipping...
# Parquet file already exists for The Dorsey Brothers, skipping...
# Parquet file already exists for Orbital, skipping...
# Parquet file already exists for Clancy Eccles, skipping...
# Parquet file already exists for Susie Ibarra, skipping...
# Parquet file already exists for Damien Jurado, skipping...
# Error processing Leon Sylvers III: 'album_id'
# Parquet file already exists for Jeffree Star, skipping...
# Parquet file already exists for Chris Montez, skipping...
# Parquet file already exists for Zoot Woman, skipping...
# Parquet file already exists for The Chainsmokers, skipping...
# Parquet file already exists for Stylusboy, skipping...
# Parquet file already exists for Bob Dylan, skipping...
# Parquet file already exists for Erik Norlander, skipping...
# Parquet file already exists for Imperial Drag, skipping...
# Parquet file already exists for Carlos Vives, skipping...
# Parquet file already exists for New Order, skipping...
# Parquet file already exists for Bassholes, skipping...
# Parquet file already exists for Indigenous, skipping...
# Parquet file already exists for Candlebox, skipping...
# Parquet file already exists for Newsboys, skipping...
# Parquet file already exists for Allan Sherman, skipping...
# Parquet file already exists for Barely Civil, skipping...
# Parquet file already exists for Chris Cagle, skipping...
# Parquet file already exists for Har Mar Superstar, skipping...
# Parquet file already exists for Spinal Tap, skipping...
# Parquet file already exists for October London, skipping...
# Parquet file already exists for Earl Hines, skipping...
# Parquet file already exists for No Doubt, skipping...
# Parquet file already exists for Julian Lennon, skipping...
# Parquet file already exists for Boyz II Men, skipping...
# Parquet file already exists for Green Velvet, skipping...
# Parquet file already exists for Boukman Eksperyans, skipping...
# Parquet file already exists for Bill Withers, skipping...
# Parquet file already exists for The Congos, skipping...
# Parquet file already exists for Preoccupations, skipping...
# Parquet file already exists for Hardfloor, skipping...
# Error processing Rodan: 'album_id'
# Parquet file already exists for Doug Keith, skipping...
# Parquet file already exists for Trembling Blue Stars, skipping...
# Parquet file already exists for These Arms Are Snakes, skipping...
# Parquet file already exists for Billy Idol, skipping...
# Parquet file already exists for Dirty Three, skipping...
# Parquet file already exists for Madball, skipping...
# Error processing Levi Dexter: 'album_id'
# Parquet file already exists for Jackie Mittoo, skipping...
# Parquet file already exists for John Lewis, skipping...
# Parquet file already exists for The 1900s, skipping...
# Parquet file already exists for Jackson C. Frank, skipping...
# Parquet file already exists for Balzac, skipping...
# Parquet file already exists for Enrique Iglesias, skipping...
# Parquet file already exists for Todd Edwards, skipping...
# Parquet file already exists for L.V., skipping...
# Parquet file already exists for Atlanta Rhythm Section, skipping...
# Parquet file already exists for Miri Ben-Ari, skipping...
# Parquet file already exists for Skillet, skipping...
# Parquet file already exists for Smoke City, skipping...
# Parquet file already exists for Joe Bonamassa, skipping...
# Parquet file already exists for High Sunn, skipping...
# Parquet file already exists for Vladimir Horowitz, skipping...
# Parquet file already exists for Holly Cole, skipping...
# Parquet file already exists for Rob Thomas, skipping...
# Parquet file already exists for Duane Eddy, skipping...
# Parquet file already exists for Peter La Farge, skipping...
# Parquet file already exists for Two Dollar Pistols, skipping...
# Parquet file already exists for Broken Bells, skipping...
# Parquet file already exists for Brigitte Fontaine, skipping...
# Parquet file already exists for Adrian Lux, skipping...
# Parquet file already exists for Steve Vai, skipping...
# Parquet file already exists for Forrest Fang, skipping...
# Parquet file already exists for Gabrielle Roth & The Mirrors, skipping...
# Parquet file already exists for YOURCODENAMEIS:MILO, skipping...
# Parquet file already exists for Theophilus Beckford, skipping...
# Parquet file already exists for In Flames, skipping...
# Parquet file already exists for The Muckrakers, skipping...
# Parquet file already exists for John Holt, skipping...
# Parquet file already exists for Apollo Sunshine, skipping...
# Parquet file already exists for Eddie Jefferson, skipping...
# Parquet file already exists for Darius Milhaud, skipping...
# Parquet file already exists for Ariana Grande, skipping...
# Parquet file already exists for Eels, skipping...
# Parquet file already exists for Branford Marsalis, skipping...
# Parquet file already exists for Baha Men, skipping...
# Parquet file already exists for Shiraz Lane, skipping...
# Parquet file already exists for The Stanley Brothers, skipping...
# Parquet file already exists for Silicon Teens, skipping...
# Parquet file already exists for Prurient, skipping...
# Parquet file already exists for Courtney Pine, skipping...
# Parquet file already exists for Salif Keita, skipping...
# Parquet file already exists for World Trade, skipping...
# Parquet file already exists for Colbie Caillat, skipping...
# Parquet file already exists for Marmozets, skipping...
# Parquet file already exists for George McCrae, skipping...
# Parquet file already exists for Bobby Timmons, skipping...
# Parquet file already exists for Anal Cunt, skipping...
# Parquet file already exists for Charles Lloyd, skipping...
# Parquet file already exists for The Exploding Hearts, skipping...
# Parquet file already exists for Ron Miles, skipping...
# Parquet file already exists for Nina Hagen, skipping...
# Parquet file already exists for Havoc, skipping...
# Parquet file already exists for Eric Burdon, skipping...
# Parquet file already exists for Trinidad Cardona, skipping...
# Parquet file already exists for Lady Sovereign, skipping...
# Parquet file already exists for Pennywise, skipping...
# Parquet file already exists for James Morrison, skipping...
# Parquet file already exists for MC Lars, skipping...
# Parquet file already exists for Gym Class Heroes, skipping...
# Parquet file already exists for Comets On Fire, skipping...
# Parquet file already exists for Bill Bruford, skipping...
# Parquet file already exists for John Simon, skipping...
# Parquet file already exists for Charlie Barnet, skipping...
# Parquet file already exists for Jimmy Reed, skipping...
# Parquet file already exists for Kameron Marlowe, skipping...
# Parquet file already exists for Extreme Noise Terror, skipping...
# Parquet file already exists for Sid Vicious, skipping...
# Parquet file already exists for Rosemary Clooney, skipping...
# Parquet file already exists for Autograph, skipping...
# Parquet file already exists for China Drum, skipping...
# Error processing Rob Henke: 'album_id'
# Parquet file already exists for Ripley Caine, skipping...
# Parquet file already exists for Ja Rule, skipping...
# Parquet file already exists for Megan Reilly, skipping...
# Error processing Duke Bootee: 'album_id'
# Parquet file already exists for Gang Starr, skipping...
# Parquet file already exists for Digable Planets, skipping...
# Parquet file already exists for Let's Active, skipping...
# Parquet file already exists for Christopher Lawrence, skipping...
# Parquet file already exists for Stephen Malkmus, skipping...
# Parquet file already exists for Rory Block, skipping...
# Parquet file already exists for Unearth, skipping...
# Parquet file already exists for Arnett Cobb, skipping...
# Error processing The Royal Wylds: 'album_id'
# Parquet file already exists for Dread Zeppelin, skipping...
# Error processing Jim Dandy: 'album_id'
# Parquet file already exists for Queen, skipping...
# Parquet file already exists for Acid King, skipping...
# Parquet file already exists for Petra, skipping...
# Parquet file already exists for Roxy Music, skipping...
# Parquet file already exists for Sprung Monkey, skipping...
# Parquet file already exists for Lindsay Fuller, skipping...
# Parquet file already exists for Atari Teenage Riot, skipping...
# Parquet file already exists for Ant Banks, skipping...
# Parquet file already exists for Fischerspooner, skipping...
# Parquet file already exists for Annie Gallup, skipping...
# Parquet file already exists for Metro Station, skipping...
# Parquet file already exists for Ollabelle, skipping...
# Parquet file already exists for Ken Nordine, skipping...
# Parquet file already exists for Colin Meloy, skipping...
# Parquet file already exists for Muggsy Spanier, skipping...
# Parquet file already exists for Dubstar, skipping...
# Parquet file already exists for Silversun Pickups, skipping...
# Parquet file already exists for Caribou, skipping...
# Parquet file already exists for Blossoms, skipping...
# Parquet file already exists for Emma Townshend, skipping...
# Parquet file already exists for Across The Sky, skipping...
# Parquet file already exists for Sun Kil Moon, skipping...
# Parquet file already exists for Diane Schuur, skipping...
# Parquet file already exists for Darkhouse Family, skipping...
# Parquet file already exists for Ryan Kisor, skipping...
# Parquet file already exists for Thomas Dolby, skipping...
# Parquet file already exists for Glassjaw, skipping...
# Parquet file already exists for The Pioneers, skipping...
# Parquet file already exists for Steve Bug, skipping...
# Parquet file already exists for Fats Navarro, skipping...
# Parquet file already exists for Mary Jane Girls, skipping...
# Parquet file already exists for Animotion, skipping...
# Parquet file already exists for Alexander von Zemlinsky, skipping...
# Parquet file already exists for Barbara Dennerlein, skipping...
# Parquet file already exists for Wolfmother, skipping...
# Parquet file already exists for Body Count, skipping...
# Parquet file already exists for The Plimsouls, skipping...
# Parquet file already exists for Danny Elfman, skipping...
# Parquet file already exists for Geddy Lee, skipping...
# Parquet file already exists for Poor Righteous Teachers, skipping...
# Parquet file already exists for John Cohen, skipping...
# Parquet file already exists for Operation Ivy, skipping...
# Parquet file already exists for Urge Overkill, skipping...
# Parquet file already exists for The Used, skipping...
# Parquet file already exists for Them Crooked Vultures, skipping...
# Parquet file already exists for Patty Smyth, skipping...
# Parquet file already exists for Deniece Williams, skipping...
# Parquet file already exists for A$AP Ferg, skipping...
# Parquet file already exists for Ronnie Milsap, skipping...
# Parquet file already exists for The Ladybug Transistor, skipping...
# Parquet file already exists for Robbie Fulks, skipping...
# Parquet file already exists for Andreas Moe, skipping...
# Parquet file already exists for Great Big Sea, skipping...
# Parquet file already exists for Chumbawamba, skipping...
# Parquet file already exists for Henry Cow, skipping...
# Parquet file already exists for Post Malone, skipping...
# Parquet file already exists for Model 500, skipping...
# Parquet file already exists for Youth Code, skipping...
# Parquet file already exists for Jody Watley, skipping...
# Parquet file already exists for Nerf Herder, skipping...
# Parquet file already exists for T.I., skipping...
# Parquet file already exists for Carl Perkins, skipping...
# Parquet file already exists for Christopher Owens, skipping...
# Parquet file already exists for Groove Collective, skipping...
# Parquet file already exists for Morris Albert, skipping...
# Parquet file already exists for Adam Guettel, skipping...
# Parquet file already exists for The Datsuns, skipping...
# Parquet file already exists for Linda Perry, skipping...
# Parquet file already exists for Tift Merritt, skipping...
# Parquet file already exists for American Hi-Fi, skipping...
# Parquet file already exists for Swans, skipping...
# Parquet file already exists for Grace Jones, skipping...
# Parquet file already exists for Derroll Adams, skipping...
# Parquet file already exists for The Golden Dogs, skipping...
# Parquet file already exists for Dan Baird, skipping...
# Parquet file already exists for The Adverts, skipping...
# Parquet file already exists for Allstar Weekend, skipping...
# Parquet file already exists for Jim O'Rourke, skipping...
# Parquet file already exists for Anton Webern, skipping...
# Parquet file already exists for Nelly Furtado, skipping...
# Parquet file already exists for Elliott Sharp, skipping...
# Parquet file already exists for Rev. Claude Jeter, skipping...
# Parquet file already exists for Chris Butler, skipping...
# Parquet file already exists for Lionrock, skipping...
# Parquet file already exists for Bloodhound Gang, skipping...
# Parquet file already exists for Hubert Sumlin, skipping...
# Parquet file already exists for Liz Story, skipping...
# Parquet file already exists for Mark O'Connor, skipping...
# Parquet file already exists for Country Joe McDonald, skipping...
# Parquet file already exists for Dave Navarro, skipping...
# Parquet file already exists for Rick Wakeman, skipping...
# Parquet file already exists for The Wonder Years, skipping...
# Parquet file already exists for Slapp Happy, skipping...
# Parquet file already exists for The Black Maria, skipping...
# Parquet file already exists for Downchild Blues Band, skipping...
# Parquet file already exists for Viva L'American Death Ray Music, skipping...
# Parquet file already exists for Michael Krassner, skipping...
# Parquet file already exists for Hate Dept., skipping...
# Parquet file already exists for The Partridge Family, skipping...
# Parquet file already exists for Jake E. Lee, skipping...
# Parquet file already exists for The Flesh Eaters, skipping...
# Parquet file already exists for Tamia, skipping...
# Parquet file already exists for Charlie Palmieri, skipping...
# Parquet file already exists for Dallas Wayne, skipping...
# Parquet file already exists for Castlecomer, skipping...
# Parquet file already exists for Keane, skipping...
# Parquet file already exists for the everybodyfields, skipping...
# Parquet file already exists for A Thorn For Every Heart, skipping...
# Parquet file already exists for Magnolia Electric Co., skipping...
# Parquet file already exists for Ela Orleans, skipping...
# Parquet file already exists for Blondie, skipping...
# Parquet file already exists for Nick Mulvey, skipping...
# Parquet file already exists for Syd Straw, skipping...
# Parquet file already exists for John Pizzarelli, skipping...
# Parquet file already exists for Tom Vek, skipping...
# Parquet file already exists for Bill Anderson, skipping...
# Parquet file already exists for Gary Stewart, skipping...
# Parquet file already exists for Nicki Minaj, skipping...
# Parquet file already exists for Volbeat, skipping...
# Parquet file already exists for The Mighty Imperials, skipping...
# Parquet file already exists for Andrew W.K., skipping...
# Parquet file already exists for Melvins, skipping...
# Parquet file already exists for Upchurch, skipping...
# Parquet file already exists for Mal Waldron, skipping...
# Error processing Garfield Akers: 'album_id'
# Parquet file already exists for Whiskeytown, skipping...
# Parquet file already exists for Cave In, skipping...
# Parquet file already exists for Venom, skipping...
# Parquet file already exists for Demdike Stare, skipping...
# Parquet file already exists for MF DOOM, skipping...
# Parquet file already exists for Todd Rhodes, skipping...
# Parquet file already exists for Julie Doiron, skipping...
# Parquet file already exists for Larry Young, skipping...
# Parquet file already exists for Glasser, skipping...
# Parquet file already exists for Silje Nes, skipping...
# Parquet file already exists for Dro Carey, skipping...
# Parquet file already exists for Everything Everything, skipping...
# Parquet file already exists for Margaret Glaspy, skipping...
# Parquet file already exists for Kenny Barron, skipping...
# Parquet file already exists for Judy Henske, skipping...
# Parquet file already exists for Gallon Drunk, skipping...
# Parquet file already exists for Marcia Ball, skipping...
# Parquet file already exists for Orchestra Baobab, skipping...
# Parquet file already exists for Pig Destroyer, skipping...
# Parquet file already exists for The Kentucky Headhunters, skipping...
# Parquet file already exists for Carla Bley, skipping...
# Parquet file already exists for Room 5, skipping...
# Parquet file already exists for Mastodon, skipping...
# Parquet file already exists for Eagulls, skipping...
# Parquet file already exists for Company Flow, skipping...
# Parquet file already exists for Dr. Strangely Strange, skipping...
# Parquet file already exists for Pete Seeger, skipping...
# Error processing Bill Chase: 'album_id'
# Parquet file already exists for Charlie Peacock, skipping...
# Parquet file already exists for Brooks & Dunn, skipping...
# Parquet file already exists for Afroman, skipping...
# Parquet file already exists for The Godfathers, skipping...
# Parquet file already exists for Clogs, skipping...
# Parquet file already exists for Casualty Park, skipping...
# Parquet file already exists for Placebo, skipping...
# Parquet file already exists for Shooter Jennings, skipping...
# Parquet file already exists for Vic Damone, skipping...
# Parquet file already exists for Eagles, skipping...
# Parquet file already exists for Semisonic, skipping...
# Parquet file already exists for Warren G, skipping...
# Parquet file already exists for Cedar Walton, skipping...
# Parquet file already exists for Senser, skipping...
# Parquet file already exists for Bronski Beat, skipping...
# Error processing James Hetfield: 'album_id'
# Parquet file already exists for Little Sammy Davis, skipping...
# Parquet file already exists for Luke Combs, skipping...
# Parquet file already exists for Sarah Ross, skipping...
# Parquet file already exists for Thee Headcoatees, skipping...
# Error processing Bluff City: 'album_id'
# Parquet file already exists for Langston Hughes, skipping...
# Parquet file already exists for Tony MacAlpine, skipping...
# Parquet file already exists for El-P, skipping...
# Parquet file already exists for Chris Brown, skipping...
# Parquet file already exists for Bloc Party, skipping...
# Parquet file already exists for Young Statues, skipping...
# Parquet file already exists for Mike Scott, skipping...
# Parquet file already exists for Blind John Davis, skipping...
# Parquet file already exists for Smoking Popes, skipping...
# Parquet file already exists for Kalmah, skipping...
# Parquet file already exists for Les Rythmes Digitales, skipping...
# Parquet file already exists for Grim Reaper, skipping...
# Parquet file already exists for Bobby Bare, skipping...
# Parquet file already exists for Tina Turner, skipping...
# Parquet file already exists for '68 Comeback, skipping...
# Parquet file already exists for Frantz Casseus, skipping...
# Parquet file already exists for Kellie Pickler, skipping...
# Parquet file already exists for Simon Joyner, skipping...
# Parquet file already exists for Bob Brookmeyer, skipping...
# Parquet file already exists for The Crucifucks, skipping...
# Parquet file already exists for Norma Jean, skipping...
# Parquet file already exists for The Hi-Lo's, skipping...
# Parquet file already exists for Eat Static, skipping...
# Parquet file already exists for Cardinals Pride, skipping...
# Parquet file already exists for The Roosevelts, skipping...
# Parquet file already exists for Blitzen Trapper, skipping...
# Parquet file already exists for Busta Rhymes, skipping...
# Parquet file already exists for Adam Green, skipping...
# Parquet file already exists for Laurent Garnier, skipping...
# Parquet file already exists for Alex Gopher, skipping...
# Parquet file already exists for Gary Hoey, skipping...
# Parquet file already exists for Tall Black Guy, skipping...
# Parquet file already exists for Charlie Feathers, skipping...
# Parquet file already exists for Hanne Hukkelberg, skipping...
# Parquet file already exists for The Nightcrawlers, skipping...
# Parquet file already exists for Lindsey Buckingham, skipping...
# Parquet file already exists for Luscious Jackson, skipping...
# Parquet file already exists for NRBQ, skipping...
# Parquet file already exists for Lou Barlow, skipping...
# Parquet file already exists for Snooks Eaglin, skipping...
# Parquet file already exists for Tahiti 80, skipping...
# Parquet file already exists for Winterpills, skipping...
# Parquet file already exists for James Blunt, skipping...
# Parquet file already exists for Cabbage, skipping...
# Parquet file already exists for Street Dogs, skipping...
# Parquet file already exists for Ann Hampton Callaway, skipping...
# Parquet file already exists for Black Mountain, skipping...
# Parquet file already exists for Frou Frou, skipping...
# Parquet file already exists for William Prince, skipping...
# Parquet file already exists for The Minders, skipping...
# Parquet file already exists for Fréhel, skipping...
# Parquet file already exists for Rod Bernard, skipping...
# Parquet file already exists for Boredoms, skipping...
# Parquet file already exists for Mandy Moore, skipping...
# Parquet file already exists for Hot Tuna, skipping...
# Parquet file already exists for John Gilmore, skipping...
# Parquet file already exists for Jimmy Bryant, skipping...
# Parquet file already exists for Big Brother & The Holding Company, skipping...
# Parquet file already exists for Little Milton, skipping...
# Parquet file already exists for Carolina Chocolate Drops, skipping...
# Parquet file already exists for D.R.I., skipping...
# Parquet file already exists for Rahzel, skipping...
# Parquet file already exists for Nosferatu, skipping...
# Parquet file already exists for Sturgill Simpson, skipping...
# Error processing Axl Rose: 'album_id'
# Parquet file already exists for The Marcels, skipping...
# Parquet file already exists for Deanna Kirk, skipping...
# Parquet file already exists for Bo Diddley, skipping...
# Parquet file already exists for Mabel Mercer, skipping...
# Parquet file already exists for Pulseprogramming, skipping...
# Parquet file already exists for John Patitucci, skipping...
# Parquet file already exists for India.Arie, skipping...
# Parquet file already exists for Anti-Flag, skipping...
# Parquet file already exists for San Serac, skipping...
# Parquet file already exists for Boy George, skipping...
# Parquet file already exists for Zero Boys, skipping...
# Parquet file already exists for Madcon, skipping...
# Parquet file already exists for Mayer Hawthorne, skipping...
# Parquet file already exists for Air Waves, skipping...
# Parquet file already exists for Les Claypool, skipping...
# Parquet file already exists for The Juliana Theory, skipping...
# Parquet file already exists for Orthrelm, skipping...
# Parquet file already exists for Lou Donaldson, skipping...
# Parquet file already exists for Lily Allen, skipping...
# Parquet file already exists for Bob Hope, skipping...
# Parquet file already exists for Dokken, skipping...
# Parquet file already exists for Gojira, skipping...
# Parquet file already exists for Jamila Woods, skipping...
# Parquet file already exists for The Deadly Snakes, skipping...
# Parquet file already exists for Greg Davis, skipping...
# Parquet file already exists for The Chieftains, skipping...
# Parquet file already exists for Honeymoon Suite, skipping...
# Parquet file already exists for Alexander von Schlippenbach, skipping...
# Parquet file already exists for Joe Walsh, skipping...
# Parquet file already exists for Das EFX, skipping...
# Parquet file already exists for The Sonora Pine, skipping...
# Parquet file already exists for The Funk Brothers, skipping...
# Parquet file already exists for KRS-One, skipping...
# Parquet file already exists for Eric Bogosian, skipping...
# Parquet file already exists for Joe Henderson, skipping...
# Parquet file already exists for Univers Zero, skipping...
# Parquet file already exists for TRUSTcompany, skipping...
# Parquet file already exists for Tadd Dameron, skipping...
# Parquet file already exists for Salad Boys, skipping...
# ...
# Parquet file already exists for Portishead, skipping...
# Parquet file already exists for Wynn Stewart, skipping...
# Parquet file already exists for BackWordz, skipping...
# Parquet file already exists for Leroy Gibbons, skipping...
# Parquet file already exists for Eric Alexander, skipping...
# Parquet file already exists for John Surman, skipping...
# Parquet file already exists for Josey Wales, skipping...
# Parquet file already exists for The Tripwires, skipping...
# Parquet file already exists for The Now Time Delegation, skipping...
# Parquet file already exists for Pyotr Ilyich Tchaikovsky, skipping...
# Parquet file already exists for Beach House, skipping...
# Parquet file already exists for Hot Chocolate, skipping...
# Parquet file already exists for Danni Nicholls, skipping...
# Parquet file already exists for Madina Lake, skipping...
# Parquet file already exists for Orange 9mm, skipping...
# Parquet file already exists for Chromeo, skipping...
# Parquet file already exists for Norman Blake, skipping...
# Error: Failed to get albums for artist
# b'{\n  "error": {\n    "status": 429,\n    "message": "API rate limit exceeded"\n  }\n}'
# Parquet file already exists for Skepta, skipping...
# Parquet file already exists for Cut Chemist, skipping...
# Parquet file already exists for Dan Tyminski, skipping...
# Parquet file already exists for God Bullies, skipping...
# Parquet file already exists for Alternative TV, skipping...
# Parquet file already exists for Seasons After, skipping...
# Parquet file already exists for DJ Screw, skipping...
# Parquet file already exists for Ayreon, skipping...
# Parquet file already exists for Richie Havens, skipping...
# Parquet file already exists for Gerald Wilson, skipping...
# Parquet file already exists for Pete Droge, skipping...
# Parquet file already exists for North Mississippi Allstars, skipping...
# Parquet file already exists for Sara Evans, skipping...
# Parquet file already exists for Scrufizzer, skipping...
# Parquet file already exists for Bill Morrissey, skipping...
# Parquet file already exists for Peter Murphy, skipping...
# Parquet file already exists for Montell Jordan, skipping...
# Parquet file already exists for The Happenings, skipping...
# Parquet file already exists for Comus, skipping...
# Parquet file already exists for Original Dixieland Jazz Band, skipping...
# Parquet file already exists for Patty Waters, skipping...
# Parquet file already exists for Geto Boys, skipping...
# Parquet file already exists for Mikey Wax, skipping...
# Parquet file already exists for Seeing Stars, skipping...
# Parquet file already exists for Karunesh, skipping...
# Parquet file already exists for Ma Rainey, skipping...
# Parquet file already exists for Seamus Egan, skipping...
# Parquet file already exists for The Chemical Brothers, skipping...
# Parquet file already exists for Crash Kelly, skipping...
# Parquet file already exists for Conan Gray, skipping...
# Parquet file already exists for En Vogue, skipping...
# Parquet file already exists for Death Valley High, skipping...
# Parquet file already exists for Ronnie Dawson, skipping...
# Parquet file already exists for The Toms, skipping...
# Parquet file already exists for Belle Barth, skipping...
# Parquet file already exists for Spooky Tooth, skipping...
# Parquet file already exists for Kacey Musgraves, skipping...
# Parquet file already exists for Andy Bey, skipping...
# Parquet file already exists for Mercy Drive, skipping...
# Error: Failed to get albums for artist
# b'{\n  "error": {\n    "status": 429,\n    "message": "API rate limit exceeded"\n  }\n}'
# Parquet file already exists for Alkaline Trio, skipping...
# Parquet file already exists for Ensign, skipping...
# Parquet file already exists for Fuzzbox, skipping...
# Parquet file already exists for LCD Soundsystem, skipping...
# Parquet file already exists for Eisley, skipping...
# Parquet file already exists for Uncle Sam, skipping...
# Parquet file already exists for Rhonda Vincent, skipping...
# Parquet file already exists for Firefall, skipping...
# Parquet file already exists for Grinspoon, skipping...
# Parquet file already exists for Freakwater, skipping...
# Parquet file already exists for Breakaway, skipping...
# Parquet file already exists for Steven Halpern, skipping...
# Parquet file already exists for Sky Ferreira, skipping...
# Parquet file already exists for Reatards, skipping...
# Parquet file already exists for Jean Ritchie, skipping...
# Parquet file already exists for Grant Lee Buffalo, skipping...
# Parquet file already exists for Bernie Worrell, skipping...
# Parquet file already exists for Hey Colossus, skipping...
# Parquet file already exists for Joe Louis Walker, skipping...
# Parquet file already exists for Red Mitchell, skipping...
# Parquet file already exists for Carla Bruni, skipping...
# Parquet file already exists for Steppenwolf, skipping...
# Parquet file already exists for Rich Aucoin, skipping...
# Parquet file already exists for Rico Nasty, skipping...
# Parquet file already exists for Aaron Goldberg, skipping...
# Parquet file already exists for Conrad Sewell, skipping...
# Parquet file already exists for Elmer Snowden, skipping...
# Parquet file already exists for Sonic Avenues, skipping...
# Parquet file already exists for Rocket Scientists, skipping...
# Parquet file already exists for Jesse Stone, skipping...
# Parquet file already exists for Your Old Droog, skipping...
# Parquet file already exists for Adrian Utley, skipping...
# Parquet file already exists for Ellery Eskelin, skipping...
# Parquet file already exists for Demi Lovato, skipping...
# Parquet file already exists for The Flaming Sideburns, skipping...
# Error: Failed to get albums for artist
# b'{\n  "error": {\n    "status": 429,\n    "message": "API rate limit exceeded"\n  }\n}'
# Parquet file already exists for Brand Nubian, skipping...
# Parquet file already exists for Chase Bryant, skipping...
# Parquet file already exists for Immature, skipping...
# Parquet file already exists for Andy Griggs, skipping...
# Parquet file already exists for Monty Python, skipping...
# Parquet file already exists for Nellie Tiger Travis, skipping...
# Parquet file already exists for Johnny Hodges, skipping...
# Parquet file already exists for Joseph Spence, skipping...
# Parquet file already exists for Sweetback, skipping...
# Parquet file already exists for Roy Brown, skipping...
# Parquet file already exists for Momus, skipping...
# Parquet file already exists for Arturo Sandoval, skipping...
# Parquet file already exists for Royal Crown Revue, skipping...
# Parquet file already exists for Kid Congo Powers, skipping...
# Parquet file already exists for Manu Chao, skipping...
# Parquet file already exists for Tom Coster, skipping...
# Parquet file already exists for Kurt Cobain, skipping...
# Parquet file already exists for Hothouse Flowers, skipping...
# Parquet file already exists for Milt Hinton, skipping...
# Parquet file already exists for Clint Black, skipping...
# Parquet file already exists for The Beach Boys, skipping...
# Parquet file already exists for The Sea and Cake, skipping...
# Parquet file already exists for Highway 13, skipping...
# Parquet file already exists for Lakim Shabazz, skipping...
# Parquet file already exists for Portastatic, skipping...
# Parquet file already exists for The Box Tops, skipping...
# Parquet file already exists for Matrimony, skipping...
# Parquet file already exists for Doria D, skipping...
# Parquet file already exists for Tom Petty, skipping...
# Parquet file already exists for Psychedelic Horseshit, skipping...
# Parquet file already exists for Werly Fairburn, skipping...
# Parquet file already exists for T-Connection, skipping...
# Parquet file already exists for The Whitlams, skipping...
# Parquet file already exists for Aaron Tippin, skipping...
# Parquet file already exists for Arthur Alexander, skipping...
# Parquet file already exists for Everlast, skipping...
# Parquet file already exists for Charles Gounod, skipping...
# Parquet file already exists for Hozier, skipping...
# Parquet file already exists for Money Mark, skipping...
# Parquet file already exists for Con Funk Shun, skipping...
# Error: Failed to get albums for artist
# b'{\n  "error": {\n    "status": 429,\n    "message": "API rate limit exceeded"\n  }\n}'
# Parquet file already exists for Jesse Harris, skipping...
# Parquet file already exists for Creedence Clearwater Revival, skipping...
# Parquet file already exists for Kevn Kinney, skipping...
# Parquet file already exists for Bascom Lamar Lunsford, skipping...
# Parquet file already exists for Enon, skipping...
# Parquet file already exists for Marc Broussard, skipping...
# Parquet file already exists for Dntel, skipping...
# Parquet file already exists for Thelma Houston, skipping...
# Error processing Computer Games: 'album_id'
# Parquet file already exists for Missing Persons, skipping...
# Parquet file already exists for Hell Is For Heroes, skipping...
# Parquet file already exists for Perry Farrell, skipping...
# Parquet file already exists for Trummy Young, skipping...
# Parquet file already exists for Olivia Chaney, skipping...
# Parquet file already exists for Mind Brains, skipping...
# Parquet file already exists for Roy Orbison, skipping...
# Error: Failed to get albums for artist
# b'{\n  "error": {\n    "status": 429,\n    "message": "API rate limit exceeded"\n  }\n}'
# Parquet file already exists for Shaliek, skipping...
# Parquet file already exists for Brandy, skipping...
# Parquet file already exists for Ad Infinitum, skipping...
# Parquet file already exists for Ultravox, skipping...
# Parquet file already exists for Tha Dogg Pound, skipping...
# Parquet file already exists for Humble Pie, skipping...
# Parquet file already exists for K.T. Oslin, skipping...
# Parquet file already exists for Bill Nelson, skipping...
# Parquet file already exists for Jeff Mills, skipping...
# Parquet file already exists for Albert King, skipping...
# Parquet file already exists for O Yuki Conjugate, skipping...
# Parquet file already exists for Buddy Emmons, skipping...
# Parquet file already exists for Rick Astley, skipping...
# Parquet file already exists for Melba Moore, skipping...
# Parquet file already exists for Shy Child, skipping...
# Parquet file already exists for Daniel Ash, skipping...
# Parquet file already exists for Dinah Shore, skipping...
# Error: Failed to get albums for artist
# b'{\n  "error": {\n    "status": 429,\n    "message": "API rate limit exceeded"\n  }\n}'
# Parquet file already exists for Styx, skipping...
# Parquet file already exists for Vangelis, skipping...
# Parquet file already exists for Chantal Kreviazuk, skipping...
# Parquet file already exists for Marty Friedman, skipping...
# Parquet file already exists for Ken Peplowski, skipping...
# Parquet file already exists for Mogwai, skipping...
# Parquet file already exists for Si Zentner, skipping...
# Parquet file already exists for Midland, skipping...
# Parquet file already exists for Brunning Sunflower Blues Band, skipping...
# Parquet file already exists for Anugama, skipping...
# Parquet file already exists for Chico DeBarge, skipping...
# Parquet file already exists for The Candyskins, skipping...
# Parquet file already exists for Aimee Mann, skipping...
# Parquet file already exists for Shriekback, skipping...
# Parquet file already exists for Stephanie Mills, skipping...
# Parquet file already exists for The Hollies, skipping...
# Parquet file already exists for The Uniques, skipping...
# Parquet file already exists for El Michels Affair, skipping...
# Parquet file already exists for The Dead 60s, skipping...
# Parquet file already exists for David S. Ware, skipping...
# Parquet file already exists for Jimmy Cobb, skipping...
# Parquet file already exists for Babybird, skipping...
# Parquet file already exists for The Brecker Brothers, skipping...
# Parquet file already exists for One Dove, skipping...
# Parquet file already exists for Pierce Edens, skipping...
# Parquet file already exists for Rockpile, skipping...
# Parquet file already exists for Badlands, skipping...
# Parquet file already exists for Randy Travis, skipping...
# Parquet file already exists for Lexie Mountain Boys, skipping...
# Parquet file already exists for Jerome Kern, skipping...
# Parquet file already exists for William S. Burroughs, skipping...
# Parquet file already exists for Owl City, skipping...
# Parquet file already exists for Frankie Lee Sims, skipping...
# Parquet file already exists for Max Frost, skipping...
# Parquet file already exists for Compound Red, skipping...
# Parquet file already exists for Giacomo Puccini, skipping...
# Parquet file already exists for The Nazz, skipping...
# Parquet file already exists for Candy Butchers, skipping...
# Parquet file already exists for The Tea Party, skipping...
# Parquet file already exists for Matthias Lupri, skipping...
# Parquet file already exists for John Bickerton, skipping...
# Parquet file already exists for Palehound, skipping...
# Parquet file already exists for Damian Marley, skipping...
# Parquet file already exists for Scrapper Blackwell, skipping...
# Parquet file already exists for Boyz N Da Hood, skipping...
# Parquet file already exists for Broken Social Scene, skipping...
# Parquet file already exists for Diamond Rio, skipping...
# Error: Failed to get albums for artist
# b'{\n  "error": {\n    "status": 429,\n    "message": "API rate limit exceeded"\n  }\n}'
# Parquet file already exists for Boards of Canada, skipping...
# Parquet file already exists for Gene Watson, skipping...
# Parquet file already exists for Allen Ginsberg, skipping...
# Parquet file already exists for Kruder & Dorfmeister, skipping...
# Parquet file already exists for Bound Stems, skipping...
# Parquet file already exists for Michael Nesmith, skipping...
# Parquet file already exists for Sonny Fortune, skipping...
# Parquet file already exists for Rebecca Moore, skipping...
# Parquet file already exists for Richard Strauss, skipping...
# Parquet file already exists for Rancid, skipping...
# Parquet file already exists for Harry "Sweets" Edison, skipping...
# Parquet file already exists for The Revelers, skipping...
# Parquet file already exists for Graeme Revell, skipping...
# Parquet file already exists for Sha Na Na, skipping...
# Parquet file already exists for Khruangbin, skipping...
# Parquet file already exists for Carl Stalling, skipping...
# Parquet file already exists for Lionel Cartwright, skipping...
# Parquet file already exists for The Vandermark 5, skipping...
# Parquet file already exists for Kim Gordon, skipping...
# Parquet file already exists for Max Corbacho, skipping...
# Parquet file already exists for Stone Temple Pilots, skipping...
# Parquet file already exists for Tinashe, skipping...
# Parquet file already exists for Crooked Fingers, skipping...
# Parquet file already exists for Tilt, skipping...
# Parquet file already exists for Timi Yuro, skipping...
# Parquet file already exists for BØRNS, skipping...
# Parquet file already exists for Thomas Mapfumo, skipping...
# Parquet file already exists for Cherrywine, skipping...
# Parquet file already exists for Hoodoo Gurus, skipping...
# Parquet file already exists for Thom Yorke, skipping...
# Parquet file already exists for Kraftwelt, skipping...
# Parquet file already exists for Mark Whitfield, skipping...
# Parquet file already exists for Yma Sumac, skipping...
# Parquet file already exists for The Flashcubes, skipping...
# Parquet file already exists for Keri Hilson, skipping...
# Parquet file already exists for Mary Martin, skipping...
# Parquet file already exists for Mungo Jerry, skipping...
# Error: Failed to get albums for artist
# b'{\n  "error": {\n    "status": 429,\n    "message": "API rate limit exceeded"\n  }\n}'
# Parquet file already exists for The Cardigans, skipping...
# Parquet file already exists for Beach Baby, skipping...
# Parquet file already exists for Combustible Edison, skipping...
# Parquet file already exists for Usher, skipping...
# Parquet file already exists for Elvin Jones, skipping...
# Parquet file already exists for 13th Floor Elevators, skipping...
# Parquet file already exists for The Merton Parkas, skipping...
# Parquet file already exists for Jonathan Richman, skipping...
# Parquet file already exists for Roy Clark, skipping...
# Completed processing all artists.
