# %%
import os
import base64
import requests
from requests import post, get
import json
from tqdm import tqdm
import pandas as pd
import time
import math
import re

# %%
client_credentials = [
('f6356c32c5d64ce58e5624880dea1cd2', 'f6647dac2371449bbc9bc73c3d63cbf5'),
('0adb80f0b55b4b10b07f44a71a4ad5c3', 'a02540682d5a4db78c3745f4d0d8dc87'),
('71347be4f4d54b7196da33f91abace42', 'c2d2e66a56ab4aeaaab4a4fd7a68cf3f'),
('fd07762e0b094ed18b8826b874015a9c', 'e473f5a900ce43c8b0dc801ac93917a6'),
('7833d0cfc3ab44cbb9d775ffadd68ccd', '1cb2c8364a464bab9dc7c16e3d3ed5ff'),
('c2430e5c53e143f1803314a53a761b82', '21f5f48be50f40f5b8c39f78f6aa295a'),
('60207ceb346044cab376d2adb22c3eeb', 'e4a9c82de61f4d56978528a19677a4af'),
('3936a486020342e2b19ec1db051936a2', '1e7120d22519427086f803396069b78d'),
('ccb70e707a4345dbaa187e029e9d3ba0', '49beb62c20da4c5993e91fc86fc7f4b5'),
('a0a12dcead224744985b3e437ac5ca6c', '0e3bea02d16f43da983786c8a5b1f6a7')

]



credential_index = 0

def get_token(client_id, client_secret):
    auth_string = client_id + ":" + client_secret
    auth_bytes = auth_string.encode("utf-8")
    auth_base64 = str(base64.b64encode(auth_bytes), "utf-8")

    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": "Basic " + auth_base64,
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"grant_type": "client_credentials"}

    response = requests.post(url, headers=headers, data=data)
    json_result = json.loads(response.content)

    if "access_token" in json_result:
        token = json_result["access_token"]
        return token
    else:
        print("Error: Failed to get access token")
        print(json_result)
        return None

def get_auth_header(token):
    return {"Authorization": "Bearer " + token}

def get_albums_for_artist(token, artist_id):
    url = f"https://api.spotify.com/v1/artists/{artist_id}/albums"
    headers = get_auth_header(token)
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        albums = json.loads(response.text)["items"]
        album_dict = {}
        for album in albums:
            album_id = album["id"]
            album_name = album["name"]
            album_tracks = album["total_tracks"]
            album_type = album["album_type"]
            album_release_date = album["release_date"]
            album_artists = [artist["name"] for artist in album["artists"]]
            album_images = album["images"]

            if album_name in album_dict:
                existing_tracks = album_dict[album_name]["total_tracks"]
                if album_tracks > existing_tracks:
                    album_dict[album_name] = {
                        "album_id": album_id,
                        "album_name": album_name,
                        "total_tracks": album_tracks,
                        "album_type": album_type,
                        "release_date": album_release_date,
                        "artists": album_artists,
                        "images": album_images
                    }
            else:
                album_dict[album_name] = {
                    "album_id": album_id,
                    "album_name": album_name,
                    "total_tracks": album_tracks,
                    "album_type": album_type,
                    "release_date": album_release_date,
                    "artists": album_artists,
                    "images": album_images
                }
        return album_dict
    else:
        print("Error: Failed to get albums for artist")
        print(response.content)
        return None
    
def get_tracks_for_album(token, album_id):
    url = f"https://api.spotify.com/v1/albums/{album_id}/tracks"
    headers = get_auth_header(token)
    params = {"market": "US"}
    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        tracks = json.loads(response.text)["items"]
        track_list = []
        for track in tracks:
            track_name = track["name"]
            track_id = track["id"]
            track_number = track["track_number"]
            track_explicit = track["explicit"]
            track_artists = [artist["name"] for artist in track["artists"]]
            track_dict = {
                "track_name": track_name,
                "track_id": track_id,
                "track_number": track_number,
                "track_explicit": track_explicit,
                "track_artists": track_artists,
            }
            track_list.append(track_dict)
        return track_list
    else:
        print("Error: Failed to get tracks for album")
        print(response.content)
        return None

# def get_audio_features(token, track_ids):
#     headers = {"Authorization": f"Bearer {token}"}
#     url = "https://api.spotify.com/v1/audio-features"
    
#     id_chunks = [track_ids[i:i+100] for i in range(0, len(track_ids), 100)]
    
#     dfs = []
#     for chunk in id_chunks:
#         params = {"ids": ",".join(chunk)}
#         response = requests.get(url, headers=headers, params=params)
#         data = response.json()["audio_features"]
#         features = pd.DataFrame(data)
#         features = features.drop(["type", "uri", "track_href", "analysis_url"], axis=1)
#         dfs.append(features)
    
#     features = pd.concat(dfs, ignore_index=True)
#     return features

def get_audio_features(token, track_ids):
    audio_features = []

    for i in range(0, len(track_ids), 50):
        chunk = track_ids[i:i + 50]
        ids = ','.join(chunk)
        url = f"https://api.spotify.com/v1/audio-features?ids={ids}"
        headers = {"Authorization": f"Bearer {token}"}
        r = requests.get(url, headers=headers)
        if r.status_code != 200:
            print(f"Error getting audio features for tracks: {r.status_code}")
            return None

        try:
            features = r.json()["audio_features"]
        except KeyError:
            features = []

        audio_features.extend(features)

    audio_features_filtered = []
    for feature in audio_features:
        if feature is not None:
            audio_features_filtered.append(feature)

    return pd.DataFrame(audio_features_filtered)



def load_checkpoint():
    if os.path.exists('checkpoint_4.json'):
        with open('checkpoint_4.json', 'r') as f:
            return json.load(f)
    else:
        return {"artist_id": "", "progress": 0}

def save_checkpoint(artist_id, progress):
    with open('checkpoint_4.json', 'w') as f:
        json.dump({"artist_id": artist_id, "progress": progress}, f)

def load_failed_requests():
    if os.path.exists('failed_requests_4.parquet'):
        return pd.read_parquet('failed_requests_4.parquet')
    else:
        return pd.DataFrame(columns=['Spotify ID'])

def save_failed_requests(df):
    df.to_parquet('failed_requests_4.parquet')

def refresh_token(token_start_time):
    global credential_index
    current_time = time.time()
    elapsed_time = current_time - token_start_time
    if elapsed_time >= 1800:
        credential_index = (credential_index + 1) % len(client_credentials)
        client_id, client_secret = client_credentials[credential_index]
        return get_token(client_id, client_secret), current_time
    return None, token_start_time

def sanitize_filename(filename):
    return re.sub(r'[\\/:"*?<>|]+', '_', filename)

# %%
with open('artist_ids_sub_dict_4.json', 'r') as f:
    artist_ids = json.load(f)
len(artist_ids)
# Out:
# 1201

# %%
token = get_token(client_credentials[0][0], client_credentials[0][1])
token_start_time = time.time()

checkpoint = load_checkpoint()
failed_requests = load_failed_requests()

start_from = checkpoint["artist_id"] if checkpoint["artist_id"] else list(artist_ids.keys())[0]
start_index = list(artist_ids.keys()).index(start_from)


iteration_counter = 0
sleep_interval = 50

for artist_id, artist_name in list(artist_ids.items())[start_index:]:
    sanitized_artist_name = sanitize_filename(artist_name)
    parquet_file_path = f'results/{sanitized_artist_name}_tracks.parquet'
    if os.path.exists(parquet_file_path):
        print(f"Parquet file already exists for {artist_name}, skipping...")
        continue
    try:
        refreshed_token, new_token_start_time = refresh_token(token_start_time)
        if refreshed_token:
            token = refreshed_token
            token_start_time = new_token_start_time

        albums = get_albums_for_artist(token, artist_id)

        if albums is None:
            failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
            save_failed_requests(failed_requests)
            continue

        album_df = pd.DataFrame.from_dict(albums, orient="index")
        album_df.index.name = "album_name"

        all_tracks_df = pd.DataFrame()
        for album_id in tqdm(album_df['album_id'], desc=f"Processing {artist_name}"):
            time.sleep(1)
            tracks = get_tracks_for_album(token, album_id)
            if tracks is None:
                failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
                save_failed_requests(failed_requests)
                continue

            tracks = pd.DataFrame(tracks)
            tracks['album_id'] = album_id
            all_tracks_df = pd.concat([all_tracks_df, tracks], axis=0)

        af_df = get_audio_features(token, all_tracks_df['track_id'].tolist())
        af_df = af_df.rename(columns={'id': 'track_id'})
        all_aftracks_df = pd.merge(all_tracks_df, af_df, on='track_id')
        album_all_aftracks_df = pd.merge(album_df, all_aftracks_df, on='album_id')
        sanitized_artist_name = sanitize_filename(artist_name)
        album_all_aftracks_df.to_parquet(f'results/{sanitized_artist_name}_tracks.parquet')

        save_checkpoint(artist_id, artist_name)
        iteration_counter += 1
        if iteration_counter % sleep_interval == 0:
            time.sleep(10)
            
    except Exception as e:
        print(f"Error processing {artist_name}: {e}")
        failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
        save_failed_requests(failed_requests)
        continue

print("Completed processing all artists.")
# Out:
# Parquet file already exists for Alexander Scriabin, skipping...
# Parquet file already exists for Hiromi, skipping...
# Parquet file already exists for Sade, skipping...
# Parquet file already exists for Train, skipping...
# Parquet file already exists for Unrest, skipping...
# Parquet file already exists for Little Brother, skipping...
# Parquet file already exists for Life Without Buildings, skipping...
# Parquet file already exists for Fuzz Townshend, skipping...
# Parquet file already exists for The Knocks, skipping...
# Parquet file already exists for Cruel Youth, skipping...
# Parquet file already exists for Here We Go Magic, skipping...
# Parquet file already exists for Arne Nordheim, skipping...
# Parquet file already exists for Dale Watson, skipping...
# Parquet file already exists for Raging Slab, skipping...
# Parquet file already exists for Lisa Carbon, skipping...
# Parquet file already exists for Clifford Brown, skipping...
# Parquet file already exists for Vitamin C, skipping...
# Parquet file already exists for The Edwin Hawkins Singers, skipping...
# Parquet file already exists for Burial Chamber Trio, skipping...
# Parquet file already exists for King Crimson, skipping...
# Parquet file already exists for Shaboozey, skipping...
# Parquet file already exists for Simon Steensland, skipping...
# Parquet file already exists for Storyhill, skipping...
# Parquet file already exists for A.A. Bondy, skipping...
# Parquet file already exists for Diamond Nights, skipping...
# Parquet file already exists for Chris Squire, skipping...
# Parquet file already exists for Fear Factory, skipping...
# Parquet file already exists for Cuong Vu, skipping...
# Parquet file already exists for Peter Frampton, skipping...
# Parquet file already exists for Pusha T, skipping...
# Parquet file already exists for Charles McPherson, skipping...
# Parquet file already exists for Deanna Durbin, skipping...
# Parquet file already exists for Zen Tricksters, skipping...
# Parquet file already exists for The So So Glos, skipping...
# Parquet file already exists for The Rembrandts, skipping...
# Parquet file already exists for The Rural Alberta Advantage, skipping...
# Parquet file already exists for Libbi Bosworth, skipping...
# Parquet file already exists for Dream Theater, skipping...
# Parquet file already exists for Razorlight, skipping...
# Parquet file already exists for Echobelly, skipping...
# Parquet file already exists for Man Parrish, skipping...
# Parquet file already exists for Ben Christophers, skipping...
# Parquet file already exists for Appendix Out, skipping...
# Parquet file already exists for Eliane Elias, skipping...
# Parquet file already exists for Ed Harcourt, skipping...
# Parquet file already exists for Jonezetta, skipping...
# Parquet file already exists for The Pietasters, skipping...
# Parquet file already exists for White Zombie, skipping...
# Parquet file already exists for Blu Mar Ten, skipping...
# Parquet file already exists for Big Dumb Face, skipping...
# Parquet file already exists for Hamiet Bluiett, skipping...
# Parquet file already exists for Herb Jeffries, skipping...
# Parquet file already exists for Teen Idols, skipping...
# Parquet file already exists for Cleopatra, skipping...
# Parquet file already exists for Matthew Halsall, skipping...
# Parquet file already exists for Little Johnny Taylor, skipping...
# Parquet file already exists for Joe Allard, skipping...
# Parquet file already exists for Kendra Smith, skipping...
# Parquet file already exists for Bardo Pond, skipping...
# Parquet file already exists for Lola Black, skipping...
# Parquet file already exists for EMF, skipping...
# Parquet file already exists for Morse Code, skipping...
# Parquet file already exists for The June Brides, skipping...
# Parquet file already exists for The Dixie Cups, skipping...
# Parquet file already exists for William Hung, skipping...
# Parquet file already exists for Rihanna, skipping...
# Parquet file already exists for Gary Windo, skipping...
# Parquet file already exists for Penelope Isles, skipping...
# Parquet file already exists for Ray Miller, skipping...
# Parquet file already exists for Patti Page, skipping...
# Parquet file already exists for Megadeth, skipping...
# Parquet file already exists for Dock Boggs, skipping...
# Parquet file already exists for Build An Ark, skipping...
# Parquet file already exists for Naked Eyes, skipping...
# Parquet file already exists for Darren Hanlon, skipping...
# Parquet file already exists for Yumi Zouma, skipping...
# Parquet file already exists for Ronnie Gilbert, skipping...
# Parquet file already exists for Five Star, skipping...
# Parquet file already exists for Garth Brooks, skipping...
# Parquet file already exists for King Buzzo, skipping...
# Parquet file already exists for Ben Kweller, skipping...
# Parquet file already exists for Karla Bonoff, skipping...
# Parquet file already exists for Glenn Gould, skipping...
# Parquet file already exists for Isildurs Bane, skipping...
# Parquet file already exists for Adrian Belew, skipping...
# Parquet file already exists for The Butterscotch Cathedral, skipping...
# Parquet file already exists for Nara Leão, skipping...
# Parquet file already exists for Tyke T, skipping...
# Parquet file already exists for The Bees, skipping...
# Parquet file already exists for Crossfade, skipping...
# Parquet file already exists for Saliva, skipping...
# Parquet file already exists for Comeback Kid, skipping...
# Parquet file already exists for Strawberry Alarm Clock, skipping...
# Parquet file already exists for Ghetts, skipping...
# Parquet file already exists for DD/MM/YYYY, skipping...
# Parquet file already exists for Cannibal Ox, skipping...
# Parquet file already exists for Jack Off Jill, skipping...
# Parquet file already exists for Elliott Carter, skipping...
# Parquet file already exists for Shearwater, skipping...
# Parquet file already exists for Evan Lurie, skipping...
# Parquet file already exists for Leela James, skipping...
# Parquet file already exists for Chalee Tennison, skipping...
# Parquet file already exists for Shadows Fall, skipping...
# Parquet file already exists for Cherish, skipping...
# Parquet file already exists for Bonnie Owens, skipping...
# Parquet file already exists for The Inbreds, skipping...
# Parquet file already exists for Joey Ramone, skipping...
# Parquet file already exists for J-Live, skipping...
# Parquet file already exists for Wretch 32, skipping...
# Parquet file already exists for Lilly Hiatt, skipping...
# Parquet file already exists for Orange Goblin, skipping...
# Parquet file already exists for Nat Pierce, skipping...
# Parquet file already exists for Marc Bolan, skipping...
# Parquet file already exists for The Forty-Fives, skipping...
# Parquet file already exists for William Walton, skipping...
# Parquet file already exists for The Equals, skipping...
# Parquet file already exists for Divinyls, skipping...
# Parquet file already exists for Bruce Haack, skipping...
# Parquet file already exists for Michael Martin Murphey, skipping...
# Parquet file already exists for Nine Inch Nails, skipping...
# Parquet file already exists for Save Ferris, skipping...
# Parquet file already exists for Robert Pollard, skipping...
# Parquet file already exists for Black Rebel Motorcycle Club, skipping...
# Parquet file already exists for DJ Bone, skipping...
# Parquet file already exists for Jimmie Noone, skipping...
# Parquet file already exists for Adam Holzman, skipping...
# Parquet file already exists for Bunk Johnson, skipping...
# Parquet file already exists for Jimmy Buffett, skipping...
# Parquet file already exists for Alcatrazz, skipping...
# Parquet file already exists for Au Pairs, skipping...
# Parquet file already exists for Sugar Boy Crawford, skipping...
# Parquet file already exists for Nick Brewer, skipping...
# Parquet file already exists for Eugenia Leon, skipping...
# Parquet file already exists for The Notorious B.I.G., skipping...
# Parquet file already exists for Laura Welsh, skipping...
# Parquet file already exists for The Moving Sidewalks, skipping...
# Parquet file already exists for Mychael Danna, skipping...
# Parquet file already exists for Camp Lo, skipping...
# Parquet file already exists for Buffalo Tom, skipping...
# Parquet file already exists for The dB's, skipping...
# Parquet file already exists for Rachel Stevens, skipping...
# Parquet file already exists for Henry Mancini, skipping...
# Parquet file already exists for Project Pat, skipping...
# Parquet file already exists for Alannah Myles, skipping...
# Parquet file already exists for Confidence Man, skipping...
# Parquet file already exists for Psarantonis, skipping...
# Parquet file already exists for The Murmurs, skipping...
# Parquet file already exists for Jon Secada, skipping...
# Parquet file already exists for Passenger, skipping...
# Parquet file already exists for Midnight Oil, skipping...
# Parquet file already exists for Eric Lindell, skipping...
# Parquet file already exists for Cause Co-Motion!, skipping...
# Parquet file already exists for Mongo Santamaria, skipping...
# Parquet file already exists for AFI, skipping...
# Parquet file already exists for Lisette Melendez, skipping...
# Parquet file already exists for Johnny Flynn, skipping...
# Parquet file already exists for The Fratellis, skipping...
# Parquet file already exists for Brian May, skipping...
# Parquet file already exists for Eliza Gilkyson, skipping...
# Parquet file already exists for Deleted Scenes, skipping...
# Parquet file already exists for The Sugar Stems, skipping...
# Parquet file already exists for Slam Stewart, skipping...
# Parquet file already exists for TLC, skipping...
# Parquet file already exists for Annette Hanshaw, skipping...
# Parquet file already exists for Cheater Slicks, skipping...
# Parquet file already exists for The Cab, skipping...
# Parquet file already exists for Lil Scrappy, skipping...
# Parquet file already exists for Ad Frank, skipping...
# Parquet file already exists for Blue Highway, skipping...
# Parquet file already exists for Clara Ward, skipping...
# Parquet file already exists for Phil Vassar, skipping...
# Parquet file already exists for Light Asylum, skipping...
# Parquet file already exists for Arcade Fire, skipping...
# Parquet file already exists for Electrik Red, skipping...
# Parquet file already exists for Black Velvet Flag, skipping...
# Parquet file already exists for St. Vincent, skipping...
# Parquet file already exists for Road Rage, skipping...
# Parquet file already exists for The 1975, skipping...
# Parquet file already exists for John Brim, skipping...
# Parquet file already exists for Rawyals, skipping...
# Parquet file already exists for Lykke Li, skipping...
# Parquet file already exists for Harpers Bizarre, skipping...
# Parquet file already exists for L.A. Salami, skipping...
# Parquet file already exists for B-Movie, skipping...
# Parquet file already exists for Ron Asheton, skipping...
# Parquet file already exists for Jethro Burns, skipping...
# Parquet file already exists for Antonio Salieri, skipping...
# Parquet file already exists for Cliff Barrows, skipping...
# Parquet file already exists for Monte Warden, skipping...
# Parquet file already exists for Flaco Jimenez, skipping...
# Parquet file already exists for Ben Allison, skipping...
# Parquet file already exists for Elizabeth Cotten, skipping...
# Parquet file already exists for Bobby Marchan, skipping...
# Parquet file already exists for Stuff Smith, skipping...
# Parquet file already exists for Odonis Odonis, skipping...
# Parquet file already exists for No Age, skipping...
# Parquet file already exists for Kid Koala, skipping...
# Parquet file already exists for The Red Krayola, skipping...
# Parquet file already exists for Wildest Dreams, skipping...
# Parquet file already exists for Josh Rouse, skipping...
# Parquet file already exists for Johnny Bush, skipping...
# Parquet file already exists for Helen Sung, skipping...
# Parquet file already exists for Dimebag Darrell, skipping...
# Parquet file already exists for Masta Ace, skipping...
# Parquet file already exists for Lenny Bruce, skipping...
# Parquet file already exists for Butcher Babies, skipping...
# Parquet file already exists for The Last Shadow Puppets, skipping...
# Parquet file already exists for Katy Perry, skipping...
# Parquet file already exists for Delbert McClinton, skipping...
# Parquet file already exists for Jega, skipping...
# Parquet file already exists for Mikey General, skipping...
# Parquet file already exists for Chimera, skipping...
# Parquet file already exists for Caetano Veloso, skipping...
# Parquet file already exists for The Fiery Furnaces, skipping...
# Parquet file already exists for Wolfgang Amadeus Mozart, skipping...
# Parquet file already exists for The Beths, skipping...
# Parquet file already exists for Arlo Guthrie, skipping...
# Parquet file already exists for Micachu, skipping...
# Parquet file already exists for The Dears, skipping...
# Parquet file already exists for The Merry Thoughts, skipping...
# Parquet file already exists for Surface To Air Missive, skipping...
# Parquet file already exists for Phil Spector, skipping...
# Parquet file already exists for Halestorm, skipping...
# Parquet file already exists for Cipriano de Rore, skipping...
# Parquet file already exists for Ferruccio Busoni, skipping...
# Parquet file already exists for John Petrucci, skipping...
# Parquet file already exists for Chris Cornell, skipping...
# Parquet file already exists for Less Than Jake, skipping...
# Parquet file already exists for Bobby Previte, skipping...
# Parquet file already exists for Tex Beneke, skipping...
# Parquet file already exists for Green River, skipping...
# Parquet file already exists for Rachel Ries, skipping...
# Parquet file already exists for ERAAS, skipping...
# Parquet file already exists for Juanes, skipping...
# Parquet file already exists for The Model Rockets, skipping...
# Parquet file already exists for Wynton Marsalis, skipping...
# Parquet file already exists for Parkway Drive, skipping...
# Parquet file already exists for Emily Barker, skipping...
# Parquet file already exists for The Jim Carroll Band, skipping...
# Parquet file already exists for Ronald Shannon Jackson, skipping...
# Parquet file already exists for Peter Criss, skipping...
# Parquet file already exists for Pandit Pran Nath, skipping...
# Parquet file already exists for Cecil Gant, skipping...
# Parquet file already exists for MFSB, skipping...
# Parquet file already exists for Weather Report, skipping...
# Parquet file already exists for Boogie Down Productions, skipping...
# Parquet file already exists for Wayne Watson, skipping...
# Parquet file already exists for New Politics, skipping...
# Parquet file already exists for Scotty Moore, skipping...
# Parquet file already exists for Mirwais, skipping...
# Parquet file already exists for Gordon Gano, skipping...
# Parquet file already exists for Cory Branan, skipping...
# Parquet file already exists for Amparo Sandino, skipping...
# Parquet file already exists for Sheek Louch, skipping...
# Parquet file already exists for Marconi Union, skipping...
# Parquet file already exists for Taio Cruz, skipping...
# Parquet file already exists for The Devil Dogs, skipping...
# Parquet file already exists for Lamont Dozier, skipping...
# Parquet file already exists for The Queers, skipping...
# Parquet file already exists for Bush Tetras, skipping...
# Parquet file already exists for Benny Goodman, skipping...
# Parquet file already exists for Enya, skipping...
# Parquet file already exists for Ray Keith, skipping...
# Parquet file already exists for Brigitte DeMeyer, skipping...
# Parquet file already exists for Primus, skipping...
# Parquet file already exists for Kirk Hammett, skipping...
# Parquet file already exists for Ladysmith Black Mambazo, skipping...
# Parquet file already exists for The Appleseed Cast, skipping...
# Parquet file already exists for Amon Amarth, skipping...
# Parquet file already exists for Nookie, skipping...
# Parquet file already exists for Brutal Truth, skipping...
# Parquet file already exists for INXS, skipping...
# Parquet file already exists for Trouble Funk, skipping...
# Parquet file already exists for Graham Coxon, skipping...
# Parquet file already exists for Lynyrd Skynyrd, skipping...
# Parquet file already exists for Parlet, skipping...
# Parquet file already exists for The Seahorses, skipping...
# Parquet file already exists for Neil Finn, skipping...
# Parquet file already exists for Tiny Ruins, skipping...
# Parquet file already exists for Tiny Grimes, skipping...
# Parquet file already exists for Nat Adderley, skipping...
# Parquet file already exists for Michel Legrand, skipping...
# Parquet file already exists for Age Of Evil, skipping...
# Parquet file already exists for Adrian Smith, skipping...
# Parquet file already exists for Piero Piccioni, skipping...
# Parquet file already exists for The Chills, skipping...
# Parquet file already exists for Tropic of Cancer, skipping...
# Parquet file already exists for Marty Ehrlich, skipping...
# Parquet file already exists for Steve Burns, skipping...
# Parquet file already exists for Señor Coconut, skipping...
# Parquet file already exists for The New Lost City Ramblers, skipping...
# Parquet file already exists for Rufus Crisp, skipping...
# Parquet file already exists for Cissy Houston, skipping...
# Parquet file already exists for Scott LaFaro, skipping...
# Parquet file already exists for Hurt, skipping...
# Parquet file already exists for Annihilator, skipping...
# Parquet file already exists for Mike Vax, skipping...
# Parquet file already exists for Gary Burton, skipping...
# Parquet file already exists for Jade Alston, skipping...
# Parquet file already exists for Earth Crisis, skipping...
# Parquet file already exists for Adelitas Way, skipping...
# Parquet file already exists for Quicksilver Messenger Service, skipping...
# Parquet file already exists for Nitzer Ebb, skipping...
# Parquet file already exists for The New Mendicants, skipping...
# Parquet file already exists for Randy Brecker, skipping...
# Parquet file already exists for Magazine, skipping...
# Parquet file already exists for Tony Furtado, skipping...
# Parquet file already exists for The Slip, skipping...
# Parquet file already exists for Fetty Wap, skipping...
# Parquet file already exists for Kim Burrell, skipping...
# Parquet file already exists for Longpigs, skipping...
# Parquet file already exists for Lee Dorsey, skipping...
# Parquet file already exists for James Ray, skipping...
# Parquet file already exists for Def Leppard, skipping...
# Parquet file already exists for Don Williams, skipping...
# Parquet file already exists for Donna Summer, skipping...
# Parquet file already exists for Zola Jesus, skipping...
# Parquet file already exists for Vetiver, skipping...
# Parquet file already exists for Deicide, skipping...
# Parquet file already exists for Dakota Staton, skipping...
# Parquet file already exists for Bernie Mac, skipping...
# Parquet file already exists for Tammy Wynette, skipping...
# Parquet file already exists for Paul Kelly, skipping...
# Parquet file already exists for Diego Torres, skipping...
# Parquet file already exists for Delphic, skipping...
# Parquet file already exists for Lem Winchester, skipping...
# Parquet file already exists for Scissor Sisters, skipping...
# Parquet file already exists for Shaquille O'Neal, skipping...
# Parquet file already exists for 4 Non Blondes, skipping...
# Parquet file already exists for Admiral Bailey, skipping...
# Parquet file already exists for Soledad Brothers, skipping...
# Parquet file already exists for The Wilburn Brothers, skipping...
# Parquet file already exists for Rob Swift, skipping...
# Parquet file already exists for M People, skipping...
# Parquet file already exists for The Brilliant Mistakes, skipping...
# Parquet file already exists for Luke Kaufman, skipping...
# Parquet file already exists for Uh Huh Her, skipping...
# Parquet file already exists for Divine Heresy, skipping...
# Parquet file already exists for Timo Maas, skipping...
# Parquet file already exists for Angie Fisher, skipping...
# Parquet file already exists for Disco Doom, skipping...
# Parquet file already exists for Cannon's Jug Stompers, skipping...
# Parquet file already exists for Photay, skipping...
# Parquet file already exists for Front 242, skipping...
# Parquet file already exists for Stephen Schwartz, skipping...
# Parquet file already exists for Kapanga, skipping...
# Parquet file already exists for Boss Hogg Outlawz, skipping...
# Parquet file already exists for Bill Easley, skipping...
# Parquet file already exists for Aurelio Valle, skipping...
# Parquet file already exists for Twin Peaks, skipping...
# Parquet file already exists for David Houston, skipping...
# Parquet file already exists for Derrick Morgan, skipping...
# Parquet file already exists for Killswitch Engage, skipping...
# Parquet file already exists for Ray Bonneville, skipping...
# Parquet file already exists for Kurt Elling, skipping...
# Parquet file already exists for Vic Juris, skipping...
# Parquet file already exists for Tourniquet, skipping...
# Parquet file already exists for The Tuesdays, skipping...
# Parquet file already exists for Willis Earl Beal, skipping...
# Parquet file already exists for Sully Erna, skipping...
# Parquet file already exists for Minus the Bear, skipping...
# Parquet file already exists for Black Rob, skipping...
# Parquet file already exists for Nancy Wilson, skipping...
# Parquet file already exists for Zap Mama, skipping...
# Parquet file already exists for Mory Kanté, skipping...
# Parquet file already exists for Super Cat, skipping...
# Parquet file already exists for Sonny Emory, skipping...
# Parquet file already exists for Kero Kero Bonito, skipping...
# Parquet file already exists for Dali's Dilemma, skipping...
# Parquet file already exists for Illinois Jacquet, skipping...
# Parquet file already exists for Wayne Hancock, skipping...
# Parquet file already exists for The Grease Band, skipping...
# Parquet file already exists for Debi Nova, skipping...
# Parquet file already exists for Susan Werner, skipping...
# Parquet file already exists for Damien Rice, skipping...
# Parquet file already exists for In Camera, skipping...
# Parquet file already exists for Rob Zombie, skipping...
# Parquet file already exists for Charlotte Church, skipping...
# Parquet file already exists for Weepin' Willie Robinson, skipping...
# Parquet file already exists for Austin Brown, skipping...
# Parquet file already exists for The Cave Singers, skipping...
# Parquet file already exists for Howard Devoto, skipping...
# Parquet file already exists for Scavenger Hunt, skipping...
# Parquet file already exists for Industrial Tepee, skipping...
# Parquet file already exists for Mark Kozelek, skipping...
# Parquet file already exists for Larry Wallis, skipping...
# Parquet file already exists for GospelbeacH, skipping...
# Parquet file already exists for Mndsgn, skipping...
# Parquet file already exists for Rachel Goswell, skipping...
# Parquet file already exists for Led Zeppelin, skipping...
# Parquet file already exists for Babs Gonzales, skipping...
# Parquet file already exists for Willie "The Lion" Smith, skipping...
# Parquet file already exists for Baaba Maal, skipping...
# Parquet file already exists for Eddy Grant, skipping...
# Parquet file already exists for Avril Lavigne, skipping...
# Parquet file already exists for Lustmord, skipping...
# Parquet file already exists for The Winans, skipping...
# Parquet file already exists for Big Bill Morganfield, skipping...
# Parquet file already exists for Iron Butterfly, skipping...
# Parquet file already exists for Cornershop, skipping...
# Parquet file already exists for Mother Love Bone, skipping...
# Parquet file already exists for Blackstreet, skipping...
# Parquet file already exists for Mickey Guyton, skipping...
# Parquet file already exists for Emily Rodgers, skipping...
# Parquet file already exists for Hot Hot Heat, skipping...
# Parquet file already exists for Silver Apples, skipping...
# Parquet file already exists for Lauren Shera, skipping...
# Parquet file already exists for Ian McLagan, skipping...
# Parquet file already exists for Kelley Stoltz, skipping...
# Parquet file already exists for Plaid, skipping...
# Parquet file already exists for The Districts, skipping...
# Parquet file already exists for Joy Electric, skipping...
# Parquet file already exists for Geri Allen, skipping...
# Parquet file already exists for Backyard Babies, skipping...
# Parquet file already exists for Rick Rubin, skipping...
# Parquet file already exists for Godspeed You! Black Emperor, skipping...
# Parquet file already exists for Wizz Jones, skipping...
# Parquet file already exists for Greg Phillinganes, skipping...
# Parquet file already exists for Wesla Whitfield, skipping...
# Parquet file already exists for Bikeride, skipping...
# Parquet file already exists for Amos Milburn, skipping...
# Parquet file already exists for Kurupt, skipping...
# Parquet file already exists for Aaron Carter, skipping...
# Parquet file already exists for Genghis Tron, skipping...
# Parquet file already exists for Kylie Minogue, skipping...
# Parquet file already exists for Eve's Plum, skipping...
# Parquet file already exists for Lee Alexander, skipping...
# Parquet file already exists for Ringo Starr, skipping...
# Parquet file already exists for Nils Lofgren, skipping...
# Parquet file already exists for Sacred Spirits, skipping...
# Parquet file already exists for Ralph McTell, skipping...
# Parquet file already exists for Kenny Chesney, skipping...
# Parquet file already exists for Jhelisa, skipping...
# Parquet file already exists for Department S, skipping...
# Parquet file already exists for Black Milk, skipping...
# Parquet file already exists for Sheila Jordan, skipping...
# Parquet file already exists for Orchestra Of Spheres, skipping...
# Parquet file already exists for Rhys Chatham, skipping...
# Parquet file already exists for Accept, skipping...
# Parquet file already exists for Jon Faddis, skipping...
# Parquet file already exists for Joseph Arthur, skipping...
# Parquet file already exists for Da Lench Mob, skipping...
# Parquet file already exists for Victor Bailey, skipping...
# Parquet file already exists for Mass Production, skipping...
# Parquet file already exists for Chick Corea Akoustic Band, skipping...
# Parquet file already exists for Beauty Pill, skipping...
# Parquet file already exists for Rita Coolidge, skipping...
# Parquet file already exists for Silver Snakes, skipping...
# Parquet file already exists for Jack Sheldon, skipping...
# Parquet file already exists for Vivian Girls, skipping...
# Parquet file already exists for Amiri Baraka, skipping...
# Parquet file already exists for Deacon Blue, skipping...
# Parquet file already exists for Water Borders, skipping...
# Parquet file already exists for Juliette Gréco, skipping...
# Parquet file already exists for Klangstof, skipping...
# Parquet file already exists for Fernando Saunders, skipping...
# Parquet file already exists for Penny and Sparrow, skipping...
# Parquet file already exists for John Adams, skipping...
# Parquet file already exists for We Are Scientists, skipping...
# Parquet file already exists for Mushroomhead, skipping...
# Parquet file already exists for Duff McKagan, skipping...
# Parquet file already exists for The Prom Kings, skipping...
# Parquet file already exists for Baauer, skipping...
# Parquet file already exists for Westside Connection, skipping...
# Parquet file already exists for Ray Brown, skipping...
# Parquet file already exists for Corey Hart, skipping...
# Parquet file already exists for Big Bill Broonzy, skipping...
# Parquet file already exists for Bob Berg, skipping...
# Parquet file already exists for Disappears, skipping...
# Parquet file already exists for Five Horse Johnson, skipping...
# Parquet file already exists for Finish Ticket, skipping...
# Parquet file already exists for Odetta, skipping...
# Parquet file already exists for Marianne Faithfull, skipping...
# Parquet file already exists for Trailer Bride, skipping...
# Parquet file already exists for Kokomo Arnold, skipping...
# Parquet file already exists for Menswear, skipping...
# Parquet file already exists for Chamillionaire, skipping...
# Parquet file already exists for The Flying Burrito Brothers, skipping...
# Parquet file already exists for Twin Twin, skipping...
# Parquet file already exists for Eliot Sumner, skipping...
# Parquet file already exists for Kashif, skipping...
# Parquet file already exists for Sevyn Streeter, skipping...
# Parquet file already exists for Mating Ritual, skipping...
# Parquet file already exists for Wavves, skipping...
# Parquet file already exists for Mecca Normal, skipping...
# Parquet file already exists for Leftfield, skipping...
# Parquet file already exists for Cold War Kids, skipping...
# Parquet file already exists for Bebel Gilberto, skipping...
# Parquet file already exists for Morgan Saint, skipping...
# Parquet file already exists for Godzuki, skipping...
# Parquet file already exists for Suburban Studs, skipping...
# Parquet file already exists for Edwin Starr, skipping...
# Parquet file already exists for General Echo, skipping...
# Parquet file already exists for Young Rebel Set, skipping...
# Parquet file already exists for Horace Parlan, skipping...
# Parquet file already exists for Mary Chapin Carpenter, skipping...
# Parquet file already exists for Elle Varner, skipping...
# Parquet file already exists for Gang of Youths, skipping...
# Parquet file already exists for The Primary 5, skipping...
# Parquet file already exists for Wang Chung, skipping...
# Parquet file already exists for Tania Maria, skipping...
# Parquet file already exists for Colin Hay, skipping...
# Parquet file already exists for Matraca Berg, skipping...
# Parquet file already exists for The Nude Party, skipping...
# Parquet file already exists for Wiz Khalifa, skipping...
# Parquet file already exists for Papas Fritas, skipping...
# Parquet file already exists for The Clark Sisters, skipping...
# Parquet file already exists for Eat Skull, skipping...
# Parquet file already exists for Niall Horan, skipping...
# Parquet file already exists for Blind Boy Fuller, skipping...
# Parquet file already exists for Mayhem, skipping...
# Parquet file already exists for Janis Martin, skipping...
# Parquet file already exists for 5ive Style, skipping...
# Parquet file already exists for The Greenberry Woods, skipping...
# Parquet file already exists for Sia, skipping...
# Parquet file already exists for Fucked Up, skipping...
# Parquet file already exists for Ivo Perelman, skipping...
# Parquet file already exists for Ellie Goulding, skipping...
# Parquet file already exists for Deaf Wish, skipping...
# Parquet file already exists for Main Source, skipping...
# Parquet file already exists for The Iguanas, skipping...
# Parquet file already exists for Carl Thomas, skipping...
# Parquet file already exists for Yellow Days, skipping...
# Parquet file already exists for Tommy Lee, skipping...
# Parquet file already exists for Surgeon, skipping...
# Parquet file already exists for Johnny Winter, skipping...
# Parquet file already exists for Dia Frampton, skipping...
# Parquet file already exists for Peppermint Harris, skipping...
# Parquet file already exists for Flaw, skipping...
# Parquet file already exists for Neon Trees, skipping...
# Parquet file already exists for Pat Benatar, skipping...
# Parquet file already exists for Nicholas McDonald, skipping...
# Parquet file already exists for Hot Cross, skipping...
# Parquet file already exists for Steve Reich, skipping...
# Parquet file already exists for Anthony Braxton, skipping...
# Parquet file already exists for Jay Sean, skipping...
# Parquet file already exists for Tony Bourge, skipping...
# Parquet file already exists for Father John Misty, skipping...
# Parquet file already exists for Withered Hand, skipping...
# Parquet file already exists for Honcho Da Savage, skipping...
# Parquet file already exists for Ram Jam, skipping...
# Parquet file already exists for Coldcut, skipping...
# Parquet file already exists for The Lonely Island, skipping...
# Parquet file already exists for Isolée, skipping...
# Parquet file already exists for Goldrush, skipping...
# Parquet file already exists for E-40, skipping...
# Parquet file already exists for Two Friends, skipping...
# Parquet file already exists for Ballet School, skipping...
# Parquet file already exists for Wingy Manone, skipping...
# Parquet file already exists for Bill Cosby, skipping...
# Parquet file already exists for Aaliyah, skipping...
# Parquet file already exists for Calamity Jane, skipping...
# Parquet file already exists for Velocity Girl, skipping...
# Parquet file already exists for Trippie Redd, skipping...
# Parquet file already exists for Audra McDonald, skipping...
# Parquet file already exists for Oblivians, skipping...
# Parquet file already exists for Jethro Tull, skipping...
# Parquet file already exists for JT Hodges, skipping...
# Parquet file already exists for Barbecue Bob, skipping...
# Parquet file already exists for Sir Shina Peters, skipping...
# Parquet file already exists for Dee Clark, skipping...
# Parquet file already exists for Populäre Mechanik, skipping...
# Parquet file already exists for Silver Jews, skipping...
# Parquet file already exists for L. Ron Hubbard, skipping...
# Parquet file already exists for Aubrey Haynie, skipping...
# Parquet file already exists for The Fuzztones, skipping...
# Parquet file already exists for Rosanne Cash, skipping...
# Parquet file already exists for Master Shortie, skipping...
# Parquet file already exists for Nebula, skipping...
# Parquet file already exists for The Four Lads, skipping...
# Parquet file already exists for Folksongs for the Afterlife, skipping...
# Parquet file already exists for Randall Thompson, skipping...
# Parquet file already exists for Jacobites, skipping...
# Parquet file already exists for Albert Lee, skipping...
# Parquet file already exists for Mollie King, skipping...
# Parquet file already exists for Mick Taylor, skipping...
# Parquet file already exists for Ralph Vaughan Williams, skipping...
# Parquet file already exists for Kelleigh Bannen, skipping...
# Parquet file already exists for George Adams, skipping...
# Parquet file already exists for Van Morrison, skipping...
# Parquet file already exists for Elk City, skipping...
# Parquet file already exists for The Ettes, skipping...
# Parquet file already exists for David Kikoski, skipping...
# Parquet file already exists for Blue Merle, skipping...
# Parquet file already exists for Red Prysock, skipping...
# Parquet file already exists for Khan Jamal, skipping...
# Parquet file already exists for Jean-Paul Bourelly, skipping...
# Parquet file already exists for Thin Lizzy, skipping...
# Parquet file already exists for Billy Boy Arnold, skipping...
# Parquet file already exists for Fairport Convention, skipping...
# Parquet file already exists for Engineers, skipping...
# Parquet file already exists for Robbie McIntosh Band, skipping...
# Parquet file already exists for Secret Someones, skipping...
# Parquet file already exists for Black Eyed Peas, skipping...
# Parquet file already exists for The Dream Syndicate, skipping...
# Parquet file already exists for Cursive, skipping...
# Parquet file already exists for Dave Greenslade, skipping...
# Parquet file already exists for Miranda Lee Richards, skipping...
# Parquet file already exists for Kari Faux, skipping...
# Parquet file already exists for Rova Saxophone Quartet, skipping...
# Parquet file already exists for Mance Lipscomb, skipping...
# Parquet file already exists for Tyrese, skipping...
# Parquet file already exists for Bob Luman, skipping...
# Parquet file already exists for Sugarland, skipping...
# Parquet file already exists for Howard McGhee, skipping...
# Parquet file already exists for Wilf Carter, skipping...
# Parquet file already exists for Rebecca Pidgeon, skipping...
# Parquet file already exists for George Bedard, skipping...
# Parquet file already exists for The Human League, skipping...
# Parquet file already exists for Booker T. Laury, skipping...
# Parquet file already exists for Peter White, skipping...
# Parquet file already exists for Kwanza Jones, skipping...
# Parquet file already exists for Dan Parsons, skipping...
# Parquet file already exists for Beirut, skipping...
# Parquet file already exists for Jimmie Vaughan, skipping...
# Parquet file already exists for Goldfinger, skipping...
# Parquet file already exists for Martha Wainwright, skipping...
# Parquet file already exists for Claw Hammer, skipping...
# Parquet file already exists for Nausea, skipping...
# Parquet file already exists for Forfun, skipping...
# Parquet file already exists for Naomi Shelton, skipping...
# Parquet file already exists for Girlschool, skipping...
# Parquet file already exists for Lord Infamous, skipping...
# Parquet file already exists for Mayo Thompson, skipping...
# Parquet file already exists for Bishop Nehru, skipping...
# Parquet file already exists for The Rakes, skipping...
# Parquet file already exists for The Stills, skipping...
# Parquet file already exists for Tom Waits, skipping...
# Parquet file already exists for The Fray, skipping...
# Parquet file already exists for Local Natives, skipping...
# Parquet file already exists for Scorpions, skipping...
# Parquet file already exists for Don Henley, skipping...
# Parquet file already exists for All Hail The Silence, skipping...
# Parquet file already exists for Robert Hood, skipping...
# Parquet file already exists for Trash Kit, skipping...
# Parquet file already exists for Diana Darby, skipping...
# Parquet file already exists for Horslips, skipping...
# Parquet file already exists for Julia Fordham, skipping...
# Parquet file already exists for Boys Like Girls, skipping...
# Parquet file already exists for The Blood Brothers, skipping...
# Parquet file already exists for Ben Sidran, skipping...
# Parquet file already exists for Wardell Gray, skipping...
# Parquet file already exists for African Head Charge, skipping...
# Parquet file already exists for Michael Fracasso, skipping...
# Parquet file already exists for King Pleasure, skipping...
# Parquet file already exists for Mary Smith, skipping...
# Parquet file already exists for The Daredevil Christopher Wright, skipping...
# Parquet file already exists for The New Division, skipping...
# Parquet file already exists for Anthony Lewis, skipping...
# Parquet file already exists for Jesse Jo Stark, skipping...
# Parquet file already exists for Deee-Lite, skipping...
# Parquet file already exists for Martin Taylor, skipping...
# Parquet file already exists for Johnny Shines, skipping...
# Parquet file already exists for Irene Kral, skipping...
# Parquet file already exists for Carol Sloane, skipping...
# Parquet file already exists for Every Avenue, skipping...
# Parquet file already exists for Maria Callas, skipping...
# Parquet file already exists for Eddi Reader, skipping...
# Parquet file already exists for Magoo, skipping...
# Parquet file already exists for Bolt Thrower, skipping...
# Parquet file already exists for The Hatters, skipping...
# Parquet file already exists for A.R. Kane, skipping...
# Parquet file already exists for Clyde Stubblefield, skipping...
# Parquet file already exists for Deathspell Omega, skipping...
# Parquet file already exists for Die Warzau, skipping...
# Parquet file already exists for Agent Orange, skipping...
# Parquet file already exists for The Last Bandoleros, skipping...
# Parquet file already exists for Japancakes, skipping...
# Parquet file already exists for The Innocence Mission, skipping...
# Parquet file already exists for Patty Griffin, skipping...
# Parquet file already exists for Herman's Hermits, skipping...
# Parquet file already exists for Debby Boone, skipping...
# Parquet file already exists for Citizen Cain, skipping...
# Parquet file already exists for Waking Ashland, skipping...
# Parquet file already exists for Mark Chesnutt, skipping...
# Parquet file already exists for Cormega, skipping...
# Parquet file already exists for Kingdom Come, skipping...
# Parquet file already exists for Don Pullen, skipping...
# Parquet file already exists for Hiccup, skipping...
# Parquet file already exists for Pudgee Tha Phat Bastard, skipping...
# Parquet file already exists for Michael Henderson, skipping...
# Parquet file already exists for Les Nubians, skipping...
# Parquet file already exists for John Phillips, skipping...
# Parquet file already exists for Alcazar, skipping...
# Parquet file already exists for Sophie Tucker, skipping...
# Parquet file already exists for The Temper Trap, skipping...
# Parquet file already exists for Vaults, skipping...
# Parquet file already exists for Geoff Muldaur, skipping...
# Parquet file already exists for The Streets, skipping...
# Parquet file already exists for Oneida, skipping...
# Parquet file already exists for Tryon, skipping...
# Parquet file already exists for The Pop Group, skipping...
# Parquet file already exists for Keith Harling, skipping...
# Parquet file already exists for Dux Jones, skipping...
# Parquet file already exists for The Saxophones, skipping...
# Parquet file already exists for The Low Anthem, skipping...
# Parquet file already exists for Robert Wyatt, skipping...
# Parquet file already exists for Gentleman Reg, skipping...
# Parquet file already exists for Weedeater, skipping...
# Parquet file already exists for Urinals, skipping...
# Parquet file already exists for Charles Earland, skipping...
# Parquet file already exists for Joy Lynn White, skipping...
# Parquet file already exists for Kerry Livgren, skipping...
# Parquet file already exists for Mae West, skipping...
# Parquet file already exists for Katt Williams, skipping...
# Parquet file already exists for The Louvin Brothers, skipping...
# Parquet file already exists for Jamie O'Neal, skipping...
# Parquet file already exists for Mulatu Astatke, skipping...
# Parquet file already exists for Bayside, skipping...
# Parquet file already exists for Jazzy Jay, skipping...
# Parquet file already exists for The Merry-Go-Round, skipping...
# Parquet file already exists for Gucci Mane, skipping...
# Parquet file already exists for Com Truise, skipping...
# Parquet file already exists for Static-X, skipping...
# Parquet file already exists for DJ Pierre, skipping...
# Parquet file already exists for Yngwie Malmsteen, skipping...
# Parquet file already exists for Bennie Moten, skipping...
# Parquet file already exists for Monroe Mustang, skipping...
# Parquet file already exists for Susie Arioli, skipping...
# Parquet file already exists for Gene Clark, skipping...
# Parquet file already exists for Propagandhi, skipping...
# Parquet file already exists for New Model Army, skipping...
# Parquet file already exists for A.R. Rahman, skipping...
# Parquet file already exists for Vinnie Moore, skipping...
# Parquet file already exists for Ernie K-Doe, skipping...
# Parquet file already exists for Jungle Brothers, skipping...
# Parquet file already exists for Pete MacLeod, skipping...
# Parquet file already exists for Ravi Coltrane, skipping...
# Parquet file already exists for Hazell Dean, skipping...
# Parquet file already exists for Hefner, skipping...
# Parquet file already exists for Faun Fables, skipping...
# Parquet file already exists for Wayne Brady, skipping...
# Parquet file already exists for Anathallo, skipping...
# Parquet file already exists for Black Box, skipping...
# Parquet file already exists for Wimp Factor 14, skipping...
# Parquet file already exists for John Cage, skipping...
# Parquet file already exists for Fantasia, skipping...
# Parquet file already exists for Rottin Razkals, skipping...
# Parquet file already exists for Swervedriver, skipping...
# Parquet file already exists for Dick Haymes, skipping...
# Parquet file already exists for Zara Larsson, skipping...
# Parquet file already exists for Kid Cudi, skipping...
# Parquet file already exists for Lazy Lester, skipping...
# Parquet file already exists for Kirk Whalum, skipping...
# Parquet file already exists for The National Trust, skipping...
# Parquet file already exists for Republica, skipping...
# Parquet file already exists for Stetsasonic, skipping...
# Parquet file already exists for Social Distortion, skipping...
# Parquet file already exists for Roy Haynes, skipping...
# Parquet file already exists for Hannibal Marvin Peterson, skipping...
# Parquet file already exists for Zumpano, skipping...
# Parquet file already exists for Lyle Mays, skipping...
# Parquet file already exists for Santigold, skipping...
# Parquet file already exists for Television Personalities, skipping...
# Parquet file already exists for Stefan Grossman, skipping...
# Parquet file already exists for Jesse Fuller, skipping...
# Parquet file already exists for Jermaine Stewart, skipping...
# Parquet file already exists for Gorgon City, skipping...
# Parquet file already exists for The Monks, skipping...
# Parquet file already exists for Ingrid Michaelson, skipping...
# Parquet file already exists for Charles Brown, skipping...
# Parquet file already exists for 3rd Bass, skipping...
# Parquet file already exists for Astrud Gilberto, skipping...
# Parquet file already exists for Heather Headley, skipping...
# Parquet file already exists for Alien Sex Fiend, skipping...
# Parquet file already exists for The Weather Prophets, skipping...
# Parquet file already exists for Terje Rypdal, skipping...
# Parquet file already exists for Willie Dixon, skipping...
# Parquet file already exists for Chicago, skipping...
# Parquet file already exists for Crooks On Tape, skipping...
# Parquet file already exists for Iggy Azalea, skipping...
# Parquet file already exists for Ritchie Valens, skipping...
# Parquet file already exists for Girls At Our Best!, skipping...
# Parquet file already exists for Mentors, skipping...
# Parquet file already exists for Billie Eilish, skipping...
# Parquet file already exists for Rod Temperton, skipping...
# Parquet file already exists for Crispy Ambulance, skipping...
# Parquet file already exists for Jack Rose, skipping...
# Parquet file already exists for Arthur Prysock, skipping...
# Parquet file already exists for Alain Caron, skipping...
# Parquet file already exists for Mike Keneally, skipping...
# Parquet file already exists for Alex North, skipping...
# Parquet file already exists for The Brian Jonestown Massacre, skipping...
# Parquet file already exists for Hatchie, skipping...
# Parquet file already exists for Slint, skipping...
# Parquet file already exists for Ruth Etting, skipping...
# Parquet file already exists for Dog Eat Dog, skipping...
# Parquet file already exists for Muhal Richard Abrams, skipping...
# Parquet file already exists for The Itals, skipping...
# Parquet file already exists for Echo Lake, skipping...
# Parquet file already exists for The Chesterfield Kings, skipping...
# Parquet file already exists for Tal Farlow, skipping...
# Parquet file already exists for Markus Stockhausen, skipping...
# Parquet file already exists for Next Town Down, skipping...
# Parquet file already exists for Dicks, skipping...
# Parquet file already exists for The Mars Volta, skipping...
# Parquet file already exists for Chris Thile, skipping...
# Parquet file already exists for Severed Heads, skipping...
# Parquet file already exists for Aaron Copland, skipping...
# Parquet file already exists for Richard Meyer, skipping...
# Parquet file already exists for Vance Gilbert, skipping...
# Parquet file already exists for Royal Trux, skipping...
# Parquet file already exists for Ran Blake, skipping...
# Parquet file already exists for James Cotton, skipping...
# Parquet file already exists for David Arkenstone, skipping...
# Parquet file already exists for Gus Black, skipping...
# Parquet file already exists for The Hooters, skipping...
# Parquet file already exists for Walter Jackson, skipping...
# Parquet file already exists for Nadine Khouri, skipping...
# Parquet file already exists for Philip Aaberg, skipping...
# Parquet file already exists for The Faint, skipping...
# Parquet file already exists for Angie Martinez, skipping...
# Parquet file already exists for John Renbourn, skipping...
# Parquet file already exists for Kita Alexander, skipping...
# Parquet file already exists for Cheap Time, skipping...
# Parquet file already exists for Queensrÿche, skipping...
# Parquet file already exists for Atomic Rooster, skipping...
# Parquet file already exists for Culture Shock, skipping...
# Parquet file already exists for Muddy Waters, skipping...
# Parquet file already exists for Pinebender, skipping...
# Parquet file already exists for Stewart Francke, skipping...
# Parquet file already exists for Black Elk, skipping...
# Parquet file already exists for Lulu James, skipping...
# Parquet file already exists for Aerosmith, skipping...
# Parquet file already exists for Sally Taylor, skipping...
# ...
# Parquet file already exists for Fly Ashtray, skipping...
# Parquet file already exists for Jeff Buckley, skipping...
# Parquet file already exists for Brian Eno, skipping...
# Parquet file already exists for None More Black, skipping...
# Parquet file already exists for Eddie Fisher, skipping...
# Parquet file already exists for Bill Cunliffe, skipping...
# Parquet file already exists for Lloyd Price, skipping...
# Parquet file already exists for Marina Lima, skipping...
# Parquet file already exists for Mudvayne, skipping...
# Parquet file already exists for The Dillinger Escape Plan, skipping...
# Parquet file already exists for Johnny "Guitar" Watson, skipping...
# Parquet file already exists for The Big Wu, skipping...
# Parquet file already exists for Sean C. Johnson, skipping...
# Parquet file already exists for Dead Moon, skipping...
# Parquet file already exists for The London Souls, skipping...
# Parquet file already exists for Defiance, Ohio, skipping...
# Parquet file already exists for Nina Simone, skipping...
# Parquet file already exists for Stro Elliot, skipping...
# Parquet file already exists for The Screaming Blue Messiahs, skipping...
# Parquet file already exists for DJ Luke Nasty, skipping...
# Parquet file already exists for 24-7 Spyz, skipping...
# Parquet file already exists for James Andrews, skipping...
# Parquet file already exists for Tom T. Hall, skipping...
# Parquet file already exists for Fat Boys, skipping...
# Parquet file already exists for Highway 101, skipping...
# Parquet file already exists for Lana Del Rey, skipping...
# Parquet file already exists for The 5.6.7.8's, skipping...
# Parquet file already exists for Kid Dynamite, skipping...
# Parquet file already exists for 50 Cent, skipping...
# Parquet file already exists for Hailey Knox, skipping...
# Parquet file already exists for The Cult, skipping...
# Parquet file already exists for Judas Priest, skipping...
# Parquet file already exists for The Doobie Brothers, skipping...
# Parquet file already exists for Emerson Drive, skipping...
# Parquet file already exists for The Atlantics, skipping...
# Parquet file already exists for Ugly Duckling, skipping...
# Parquet file already exists for Swingin' Utters, skipping...
# Parquet file already exists for Nevermore, skipping...
# Parquet file already exists for Elek Bacsik, skipping...
# Parquet file already exists for Guy Lombardo, skipping...
# Parquet file already exists for Hypnolovewheel, skipping...
# Parquet file already exists for Urban Dance Squad, skipping...
# Parquet file already exists for Fabolous, skipping...
# Parquet file already exists for Al Bowlly, skipping...
# Parquet file already exists for James Supercave, skipping...
# Parquet file already exists for Grant McLennan, skipping...
# Parquet file already exists for Fortran 5, skipping...
# Parquet file already exists for Naked Raygun, skipping...
# Parquet file already exists for Dionne Warwick, skipping...
# Parquet file already exists for The Moog Cookbook, skipping...
# Parquet file already exists for Bryan White, skipping...
# Parquet file already exists for Blur, skipping...
# Parquet file already exists for Phantom Buffalo, skipping...
# Parquet file already exists for Juelz Santana, skipping...
# Parquet file already exists for The Beautiful South, skipping...
# Parquet file already exists for Caleb Johnson, skipping...
# Parquet file already exists for Stanley Crouch, skipping...
# Parquet file already exists for True West, skipping...
# Parquet file already exists for Antiseen, skipping...
# Parquet file already exists for Lonesome Bob, skipping...
# Parquet file already exists for Michael Bruce, skipping...
# Parquet file already exists for Andrew Bird, skipping...
# Parquet file already exists for Level 42, skipping...
# Parquet file already exists for Jon Lemmon, skipping...
# Parquet file already exists for Eddie Cantor, skipping...
# Parquet file already exists for Terry Stafford, skipping...
# Parquet file already exists for Bill Fay, skipping...
# Parquet file already exists for She Wants Revenge, skipping...
# Parquet file already exists for Steady Mobb'n, skipping...
# Parquet file already exists for ESG, skipping...
# Parquet file already exists for Westerman, skipping...
# Parquet file already exists for The Association, skipping...
# Parquet file already exists for Foghat, skipping...
# Parquet file already exists for Terence Ryan, skipping...
# Parquet file already exists for Deborah Cox, skipping...
# Parquet file already exists for Zardonic, skipping...
# Parquet file already exists for Ambrose Akinmusire, skipping...
# Parquet file already exists for The Artful Dodger, skipping...
# Parquet file already exists for Lower Class Brats, skipping...
# Parquet file already exists for Sonic Youth, skipping...
# Parquet file already exists for Lonnie Mack, skipping...
# Parquet file already exists for Charlie Shavers, skipping...
# Parquet file already exists for Tommy Roe, skipping...
# Parquet file already exists for The Tourists, skipping...
# Parquet file already exists for Skywave, skipping...
# Parquet file already exists for Eugene Chadbourne, skipping...
# Parquet file already exists for The Nice, skipping...
# Parquet file already exists for Cool Ghouls, skipping...
# Parquet file already exists for Johnny Ace, skipping...
# Parquet file already exists for Popa Chubby, skipping...
# Parquet file already exists for Taylor Swift, skipping...
# Parquet file already exists for Ohio Express, skipping...
# Parquet file already exists for Richard Thompson, skipping...
# Parquet file already exists for Marmalade, skipping...
# Parquet file already exists for John Williams, skipping...
# Parquet file already exists for The Sugarcubes, skipping...
# Parquet file already exists for Gastr Del Sol, skipping...
# Parquet file already exists for Larry Norman, skipping...
# Parquet file already exists for Avenged Sevenfold, skipping...
# Parquet file already exists for The Wanted, skipping...
# Parquet file already exists for Velvet Revolver, skipping...
# Parquet file already exists for Gov't Mule, skipping...
# Parquet file already exists for Jack Hardy, skipping...
# Parquet file already exists for The Jayhawks, skipping...
# Parquet file already exists for Les Paul, skipping...
# Parquet file already exists for C.W. McCall, skipping...
# Parquet file already exists for Jon Bon Jovi, skipping...
# Parquet file already exists for Bohannon, skipping...
# Parquet file already exists for Phil Asher, skipping...
# Parquet file already exists for Nocturnal Rites, skipping...
# Parquet file already exists for The Wannadies, skipping...
# Parquet file already exists for For Against, skipping...
# Parquet file already exists for Phoebe Ryan, skipping...
# Parquet file already exists for Reading Rainbow, skipping...
# Parquet file already exists for Dulcie Taylor, skipping...
# Parquet file already exists for Eric Von Schmidt, skipping...
# Parquet file already exists for Drew Baldridge, skipping...
# Parquet file already exists for Gravity Kills, skipping...
# Parquet file already exists for Spider Rockets, skipping...
# Parquet file already exists for Darker My Love, skipping...
# Parquet file already exists for Smiley Lewis, skipping...
# Parquet file already exists for Type O Negative, skipping...
# Parquet file already exists for Melba Montgomery, skipping...
# Parquet file already exists for Buddy Moss, skipping...
# Parquet file already exists for Big Moe, skipping...
# Parquet file already exists for Agnes Monica, skipping...
# Parquet file already exists for Bright Eyes, skipping...
# Parquet file already exists for Paul Young, skipping...
# Parquet file already exists for Troy Ave, skipping...
# Parquet file already exists for The Felice Brothers, skipping...
# Parquet file already exists for Pierre Schaeffer, skipping...
# Parquet file already exists for The Dylan Group, skipping...
# Parquet file already exists for George Russell, skipping...
# Parquet file already exists for Mickey Newbury, skipping...
# Parquet file already exists for Shinyribs, skipping...
# Parquet file already exists for Fenne Lily, skipping...
# Parquet file already exists for The Pointer Sisters, skipping...
# Parquet file already exists for Anita Ward, skipping...
# Parquet file already exists for Lyrics Born, skipping...
# Parquet file already exists for Los Criollos, skipping...
# Parquet file already exists for Albert Mangelsdorff, skipping...
# Parquet file already exists for The Roches, skipping...
# Parquet file already exists for The Banana Splits, skipping...
# Parquet file already exists for John Stewart, skipping...
# Parquet file already exists for Maino, skipping...
# Parquet file already exists for Lennie Tristano, skipping...
# Parquet file already exists for Controlled Bleeding, skipping...
# Parquet file already exists for Dee Dee Bridgewater, skipping...
# Parquet file already exists for Johnny Dodds, skipping...
# Parquet file already exists for Alter Bridge, skipping...
# Parquet file already exists for Otis Taylor, skipping...
# Parquet file already exists for Grayson Hugh, skipping...
# Parquet file already exists for Sweet Baboo, skipping...
# Parquet file already exists for Sage Francis, skipping...
# Parquet file already exists for Klaxons, skipping...
# Parquet file already exists for Justin Bieber, skipping...
# Parquet file already exists for Jimmy Fallon, skipping...
# Parquet file already exists for Leona Lewis, skipping...
# Parquet file already exists for Nappy Roots, skipping...
# Parquet file already exists for Richard Barone, skipping...
# Parquet file already exists for Hollywood Undead, skipping...
# Parquet file already exists for Todd Rundgren, skipping...
# Parquet file already exists for Gazelle Twin, skipping...
# Parquet file already exists for Japanther, skipping...
# Parquet file already exists for The American Analog Set, skipping...
# Parquet file already exists for Alan Bush, skipping...
# Parquet file already exists for Common Market, skipping...
# Parquet file already exists for Skin Yard, skipping...
# Parquet file already exists for Apache Indian, skipping...
# Parquet file already exists for Kevin Greenspon, skipping...
# Parquet file already exists for Joe Simon, skipping...
# Parquet file already exists for Dave Gahan, skipping...
# Parquet file already exists for Fred Eaglesmith, skipping...
# Parquet file already exists for The Skalatones, skipping...
# Parquet file already exists for Meli'sa Morgan, skipping...
# Parquet file already exists for Dar Williams, skipping...
# Parquet file already exists for Dollar Brand, skipping...
# Parquet file already exists for Joan Armatrading, skipping...
# Parquet file already exists for Quilt, skipping...
# Parquet file already exists for Tarnation, skipping...
# Parquet file already exists for Joseph Lamb, skipping...
# Parquet file already exists for The Bollock Brothers, skipping...
# Parquet file already exists for Little Village, skipping...
# Parquet file already exists for Glen Campbell, skipping...
# Parquet file already exists for Jennifer Knapp, skipping...
# Parquet file already exists for Elastica, skipping...
# Parquet file already exists for Der Plan, skipping...
# Parquet file already exists for Slant 6, skipping...
# Parquet file already exists for M83, skipping...
# Parquet file already exists for Alesha Dixon, skipping...
# Parquet file already exists for Cap'n Jazz, skipping...
# Parquet file already exists for Musical Youth, skipping...
# Parquet file already exists for Bivouac, skipping...
# Parquet file already exists for Ardalan, skipping...
# Parquet file already exists for Alice Coltrane, skipping...
# Parquet file already exists for Sleaford Mods, skipping...
# Parquet file already exists for Ryan Bingham, skipping...
# Parquet file already exists for David Lee Roth, skipping...
# Parquet file already exists for Warrant, skipping...
# Parquet file already exists for Freddie King, skipping...
# Parquet file already exists for Buckwheat Zydeco, skipping...
# Parquet file already exists for Franco Corelli, skipping...
# Parquet file already exists for Aventura, skipping...
# Parquet file already exists for The Leaves, skipping...
# Parquet file already exists for Matt Suggs, skipping...
# Parquet file already exists for Ian Brown, skipping...
# Parquet file already exists for Black Tambourine, skipping...
# Parquet file already exists for Jack Ladder, skipping...
# Parquet file already exists for Art Zoyd, skipping...
# Parquet file already exists for Derrick Carter, skipping...
# Parquet file already exists for Horace Silver, skipping...
# Parquet file already exists for The Tragically Hip, skipping...
# Parquet file already exists for Hamilton Park, skipping...
# Parquet file already exists for Phil Manzanera, skipping...
# Parquet file already exists for Peel Dream Magazine, skipping...
# Parquet file already exists for The Rogers Sisters, skipping...
# Parquet file already exists for Jeremy Enigk, skipping...
# Parquet file already exists for Michael Stipe, skipping...
# Parquet file already exists for Ian Campbell, skipping...
# Parquet file already exists for Redd Foxx, skipping...
# Parquet file already exists for Ben Folds, skipping...
# Parquet file already exists for Shirley Horn, skipping...
# Parquet file already exists for Jim Beard, skipping...
# Parquet file already exists for Boys Don't Cry, skipping...
# Parquet file already exists for Strata Florida, skipping...
# Parquet file already exists for Alexisonfire, skipping...
# Parquet file already exists for Lucie Silvas, skipping...
# Parquet file already exists for Far-Less, skipping...
# Parquet file already exists for Tom Russell, skipping...
# Parquet file already exists for Adam Sandler, skipping...
# Parquet file already exists for Soul Asylum, skipping...
# Parquet file already exists for Hey Monday, skipping...
# Parquet file already exists for Blindside Blues Band, skipping...
# Parquet file already exists for Trina, skipping...
# Parquet file already exists for Craig Armstrong, skipping...
# Parquet file already exists for Martyn Bates, skipping...
# Parquet file already exists for Clockcleaner, skipping...
# Parquet file already exists for STS9, skipping...
# Parquet file already exists for Buckfunk 3000, skipping...
# Parquet file already exists for Squirrel Bait, skipping...
# Parquet file already exists for Throbbing Gristle, skipping...
# Parquet file already exists for Floetry, skipping...
# Parquet file already exists for Crowded House, skipping...
# Parquet file already exists for Mariah Carey, skipping...
# Parquet file already exists for Skating Polly, skipping...
# Parquet file already exists for Andy Shauf, skipping...
# Parquet file already exists for The Budos Band, skipping...
# Parquet file already exists for Bob Mould, skipping...
# Parquet file already exists for Blue October, skipping...
# Parquet file already exists for The Bongos, skipping...
# Parquet file already exists for Henry Rollins, skipping...
# Parquet file already exists for Sunny Murray, skipping...
# Parquet file already exists for Jason James, skipping...
# Parquet file already exists for Dub Miller, skipping...
# Parquet file already exists for Field Music, skipping...
# Parquet file already exists for Richard Hawley, skipping...
# Parquet file already exists for Bell Biv DeVoe, skipping...
# Parquet file already exists for The Rubinoos, skipping...
# Parquet file already exists for Raja Kumari, skipping...
# Parquet file already exists for The Celibate Rifles, skipping...
# Parquet file already exists for Marduk, skipping...
# Parquet file already exists for Turf Talk, skipping...
# Parquet file already exists for Jay Reatard, skipping...
# Parquet file already exists for Karen Harding, skipping...
# Parquet file already exists for Kehlani, skipping...
# Parquet file already exists for Jobriath, skipping...
# Parquet file already exists for Kraftwerk, skipping...
# Parquet file already exists for The Swingle Singers, skipping...
# Parquet file already exists for Tenacious D, skipping...
# Parquet file already exists for The Damnwells, skipping...
# Parquet file already exists for The House of Love, skipping...
# Parquet file already exists for Lacy J. Dalton, skipping...
# Parquet file already exists for Descendents, skipping...
# Parquet file already exists for Billy Cobham, skipping...
# Completed processing all artists.

# %%
# max_retries = 3
# retry_counter = 0

# while not failed_requests.empty and retry_counter < max_retries:
#     print(f"Retrying failed requests (attempt {retry_counter + 1}/{max_retries})...")
#     retry_failed_requests = pd.DataFrame(columns=["Spotify ID"])
#     for _, row in failed_requests.iterrows():
#         artist_id = row["Spotify ID"]
#         artist_name = artist_ids[artist_id]
#         sanitized_artist_name = sanitize_filename(artist_name)
#         parquet_file_path = f'{sanitized_artist_name}_tracks.parquet'

#         if os.path.exists(parquet_file_path):
#             print(f"Parquet file already exists for {artist_name}, skipping...")
#             continue
#         try:
#             refreshed_token, new_token_start_time = refresh_token(token_start_time)
#             if refreshed_token:
#                 token = refreshed_token
#                 token_start_time = new_token_start_time
#             albums = get_albums_for_artist(token, artist_id)

#             if albums is None:
#                 failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
#                 save_failed_requests(failed_requests)
#                 continue

#             album_df = pd.DataFrame.from_dict(albums, orient="index")
#             album_df.index.name = "album_name"

#             all_tracks_df = pd.DataFrame()
#             for album_id in tqdm(album_df['album_id'], desc=f"Processing {artist_name}"):
#                 time.sleep(1)
#                 try:
#                     tracks = get_tracks_for_album(token, album_id)

#                     if tracks is None:
#                         failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
#                         save_failed_requests(failed_requests)
#                         continue

#                     tracks = pd.DataFrame(tracks)
#                     tracks['album_id'] = album_id
#                     all_tracks_df = pd.concat([all_tracks_df, tracks], axis=0)
#                 except Exception as e:
#                     print(f"Warning: Error fetching tracks for {artist_name}: {e}")

#             try:
#                 af_df = get_audio_features(token, all_tracks_df['track_id'].tolist())
#                 af_df = af_df.rename(columns={'id': 'track_id'})
#                 all_aftracks_df = pd.merge(all_tracks_df, af_df, on='track_id')
#                 album_all_aftracks_df = pd.merge(album_df, all_aftracks_df, on='album_id')
#                 sanitized_artist_name = sanitize_filename(artist_name)
#                 album_all_aftracks_df.to_parquet(f'{sanitized_artist_name}_tracks.parquet')

#                 save_checkpoint(artist_id, artist_name)
#             except Exception as e:
#                 print(f"Warning: Error fetching audio features for {artist_name}: {e}")

#             iteration_counter += 1
#             if iteration_counter % sleep_interval == 0:
#                 time.sleep(1)

#         except Exception as e:
#             print(f"Error processing {artist_name}: {e}")
#             retry_failed_requests = retry_failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)

#     failed_requests = retry_failed_requests
#     retry_counter += 1

# if not failed_requests.empty:
#     print("Some requests still failed after all retries:")
#     print(failed_requests)
# else:
#     print("All failed requests have been successfully processed.")
