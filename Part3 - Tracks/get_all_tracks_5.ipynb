# %%
import os
import base64
import requests
from requests import post, get
import json
from tqdm import tqdm
import pandas as pd
import time
import math
import re

# %%
client_credentials = [
('434d040b6736474cb1aafe33f29a8fb1', 'bec6dd83182248549f54c5bf4b1bd6e3'),
('f106253257ab47439b4088989b48ed35', 'bbaecdc362c04ee89b170cd2857ce28e'),
('92576fe9dfc24a55ad08887b57952884', '529d46170ee543438eaa134799b2fc98'),
('0f6fcc3c5c2144aa963cbfb0b07a95f6', '4bb6ab342395448fa69452d59cd8de83'),
('126d9a57d73a4189874a6d787c34c7b7', '6798dcb99e5a413f8ffad713dcd01187'),
('d4c41c96ffa341988e90c4b59c59bb4b', 'bffb1da37b534570b6548613e1295b24'),
('205994adba1f4a49a9cde74854a62a6f', '4995b877a12844cdb00f46744689cfb6'),
('7594d0fd19ef40ec9ed78aad63366da8', '5f8cbb9ef3a547389d7ae7086223a232'),
('2fc60e3baea64caf949f36568b0b756d', '84bbdb2b0c7c4397bc8add7d5195b975'),
('8a50eb391c6440a0b1328b48ab3e9849', '901f990b222c4fdfa24da0bac1ecf700')
]



credential_index = 0

def get_token(client_id, client_secret):
    auth_string = client_id + ":" + client_secret
    auth_bytes = auth_string.encode("utf-8")
    auth_base64 = str(base64.b64encode(auth_bytes), "utf-8")

    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": "Basic " + auth_base64,
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"grant_type": "client_credentials"}

    response = requests.post(url, headers=headers, data=data)
    json_result = json.loads(response.content)

    if "access_token" in json_result:
        token = json_result["access_token"]
        return token
    else:
        print("Error: Failed to get access token")
        print(json_result)
        return None

def get_auth_header(token):
    return {"Authorization": "Bearer " + token}

def get_albums_for_artist(token, artist_id):
    url = f"https://api.spotify.com/v1/artists/{artist_id}/albums"
    headers = get_auth_header(token)
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        albums = json.loads(response.text)["items"]
        album_dict = {}
        for album in albums:
            album_id = album["id"]
            album_name = album["name"]
            album_tracks = album["total_tracks"]
            album_type = album["album_type"]
            album_release_date = album["release_date"]
            album_artists = [artist["name"] for artist in album["artists"]]
            album_images = album["images"]

            if album_name in album_dict:
                existing_tracks = album_dict[album_name]["total_tracks"]
                if album_tracks > existing_tracks:
                    album_dict[album_name] = {
                        "album_id": album_id,
                        "album_name": album_name,
                        "total_tracks": album_tracks,
                        "album_type": album_type,
                        "release_date": album_release_date,
                        "artists": album_artists,
                        "images": album_images
                    }
            else:
                album_dict[album_name] = {
                    "album_id": album_id,
                    "album_name": album_name,
                    "total_tracks": album_tracks,
                    "album_type": album_type,
                    "release_date": album_release_date,
                    "artists": album_artists,
                    "images": album_images
                }
        return album_dict
    else:
        print("Error: Failed to get albums for artist")
        print(response.content)
        return None
    
def get_tracks_for_album(token, album_id):
    url = f"https://api.spotify.com/v1/albums/{album_id}/tracks"
    headers = get_auth_header(token)
    params = {"market": "US"}
    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        tracks = json.loads(response.text)["items"]
        track_list = []
        for track in tracks:
            track_name = track["name"]
            track_id = track["id"]
            track_number = track["track_number"]
            track_explicit = track["explicit"]
            track_artists = [artist["name"] for artist in track["artists"]]
            track_dict = {
                "track_name": track_name,
                "track_id": track_id,
                "track_number": track_number,
                "track_explicit": track_explicit,
                "track_artists": track_artists,
            }
            track_list.append(track_dict)
        return track_list
    else:
        print("Error: Failed to get tracks for album")
        print(response.content)
        return None

# def get_audio_features(token, track_ids):
#     headers = {"Authorization": f"Bearer {token}"}
#     url = "https://api.spotify.com/v1/audio-features"
    
#     id_chunks = [track_ids[i:i+100] for i in range(0, len(track_ids), 100)]
    
#     dfs = []
#     for chunk in id_chunks:
#         params = {"ids": ",".join(chunk)}
#         response = requests.get(url, headers=headers, params=params)
#         data = response.json()["audio_features"]
#         features = pd.DataFrame(data)
#         features = features.drop(["type", "uri", "track_href", "analysis_url"], axis=1)
#         dfs.append(features)
    
#     features = pd.concat(dfs, ignore_index=True)
#     return features

def get_audio_features(token, track_ids):
    audio_features = []

    for i in range(0, len(track_ids), 50):
        chunk = track_ids[i:i + 50]
        ids = ','.join(chunk)
        url = f"https://api.spotify.com/v1/audio-features?ids={ids}"
        headers = {"Authorization": f"Bearer {token}"}
        r = requests.get(url, headers=headers)
        if r.status_code != 200:
            print(f"Error getting audio features for tracks: {r.status_code}")
            return None

        try:
            features = r.json()["audio_features"]
        except KeyError:
            features = []

        audio_features.extend(features)

    audio_features_filtered = []
    for feature in audio_features:
        if feature is not None:
            audio_features_filtered.append(feature)

    return pd.DataFrame(audio_features_filtered)



def load_checkpoint():
    if os.path.exists('checkpoint_5.json'):
        with open('checkpoint_5.json', 'r') as f:
            return json.load(f)
    else:
        return {"artist_id": "", "progress": 0}

def save_checkpoint(artist_id, progress):
    with open('checkpoint_5.json', 'w') as f:
        json.dump({"artist_id": artist_id, "progress": progress}, f)

def load_failed_requests():
    if os.path.exists('failed_requests_5.parquet'):
        return pd.read_parquet('failed_requests_5.parquet')
    else:
        return pd.DataFrame(columns=['Spotify ID'])

def save_failed_requests(df):
    df.to_parquet('failed_requests_5.parquet')

def refresh_token(token_start_time):
    global credential_index
    current_time = time.time()
    elapsed_time = current_time - token_start_time
    if elapsed_time >= 1800:
        credential_index = (credential_index + 1) % len(client_credentials)
        client_id, client_secret = client_credentials[credential_index]
        return get_token(client_id, client_secret), current_time
    return None, token_start_time

def sanitize_filename(filename):
    return re.sub(r'[\\/:"*?<>|]+', '_', filename)

# %%
with open('artist_ids_sub_dict_5.json', 'r') as f:
    artist_ids = json.load(f)
len(artist_ids)
# Out:
# 1201

# %%
token = get_token(client_credentials[0][0], client_credentials[0][1])
token_start_time = time.time()

checkpoint = load_checkpoint()
failed_requests = load_failed_requests()

start_from = checkpoint["artist_id"] if checkpoint["artist_id"] else list(artist_ids.keys())[0]
start_index = list(artist_ids.keys()).index(start_from)


iteration_counter = 0
sleep_interval = 50

for artist_id, artist_name in list(artist_ids.items())[start_index:]:
    sanitized_artist_name = sanitize_filename(artist_name)
    parquet_file_path = f'results/{sanitized_artist_name}_tracks.parquet'
    if os.path.exists(parquet_file_path):
        print(f"Parquet file already exists for {artist_name}, skipping...")
        continue
    try:
        refreshed_token, new_token_start_time = refresh_token(token_start_time)
        if refreshed_token:
            token = refreshed_token
            token_start_time = new_token_start_time

        albums = get_albums_for_artist(token, artist_id)

        if albums is None:
            failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
            save_failed_requests(failed_requests)
            continue

        album_df = pd.DataFrame.from_dict(albums, orient="index")
        album_df.index.name = "album_name"

        all_tracks_df = pd.DataFrame()
        for album_id in tqdm(album_df['album_id'], desc=f"Processing {artist_name}"):
            time.sleep(1)
            tracks = get_tracks_for_album(token, album_id)
            if tracks is None:
                failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
                save_failed_requests(failed_requests)
                continue

            tracks = pd.DataFrame(tracks)
            tracks['album_id'] = album_id
            all_tracks_df = pd.concat([all_tracks_df, tracks], axis=0)

        af_df = get_audio_features(token, all_tracks_df['track_id'].tolist())
        af_df = af_df.rename(columns={'id': 'track_id'})
        all_aftracks_df = pd.merge(all_tracks_df, af_df, on='track_id')
        album_all_aftracks_df = pd.merge(album_df, all_aftracks_df, on='album_id')
        sanitized_artist_name = sanitize_filename(artist_name)
        album_all_aftracks_df.to_parquet(f'results/{sanitized_artist_name}_tracks.parquet')

        save_checkpoint(artist_id, artist_name)
        iteration_counter += 1
        if iteration_counter % sleep_interval == 0:
            time.sleep(10)
            
    except Exception as e:
        print(f"Error processing {artist_name}: {e}")
        failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
        save_failed_requests(failed_requests)
        continue

print("Completed processing all artists.")
# Out:
# Parquet file already exists for Shelby Lynne, skipping...
# Parquet file already exists for Herbie Nichols, skipping...
# Parquet file already exists for Spirea X, skipping...
# Parquet file already exists for Josh Woodward, skipping...
# Parquet file already exists for Julie London, skipping...
# Parquet file already exists for Ali Farka Touré, skipping...
# Parquet file already exists for Anton Arensky, skipping...
# Parquet file already exists for Love Equals Death, skipping...
# Parquet file already exists for Xenia Rubinos, skipping...
# Parquet file already exists for Pissed Jeans, skipping...
# Parquet file already exists for Meghan Trainor, skipping...
# Parquet file already exists for Quasimoto, skipping...
# Parquet file already exists for Rachel's, skipping...
# Parquet file already exists for Hilton Ruiz, skipping...
# Parquet file already exists for Jerry Butler, skipping...
# Parquet file already exists for Morbid Angel, skipping...
# Parquet file already exists for Helen Morgan, skipping...
# Parquet file already exists for Cabaret Voltaire, skipping...
# Parquet file already exists for Flanagan & Allen, skipping...
# Parquet file already exists for Little Feat, skipping...
# Parquet file already exists for The Litter, skipping...
# Parquet file already exists for Nick Gilder, skipping...
# Parquet file already exists for James Mason, skipping...
# Parquet file already exists for Wolf Parade, skipping...
# Parquet file already exists for The Tony Williams Lifetime, skipping...
# Parquet file already exists for Robert Klein, skipping...
# Parquet file already exists for Johnny Hallyday, skipping...
# Parquet file already exists for Confederate Railroad, skipping...
# Parquet file already exists for Annie Eve, skipping...
# Parquet file already exists for Sunshine Anderson, skipping...
# Parquet file already exists for Alan Licht, skipping...
# Parquet file already exists for Goldie, skipping...
# Parquet file already exists for Les Baxter, skipping...
# Parquet file already exists for Wooden Stars, skipping...
# Parquet file already exists for Michael Calfan, skipping...
# Parquet file already exists for The Chameleons, skipping...
# Parquet file already exists for Memphis May Fire, skipping...
# Parquet file already exists for Mice Parade, skipping...
# Parquet file already exists for White Prism, skipping...
# Parquet file already exists for Bob Franke, skipping...
# Parquet file already exists for Juicy J, skipping...
# Parquet file already exists for Jackie Davis, skipping...
# Parquet file already exists for Annie Ross, skipping...
# Parquet file already exists for Taylor Dayne, skipping...
# Parquet file already exists for Paolo Nutini, skipping...
# Parquet file already exists for The Cadillac Three, skipping...
# Parquet file already exists for Popcaan, skipping...
# Parquet file already exists for Dick Gaughan, skipping...
# Parquet file already exists for Andy Kirk, skipping...
# Parquet file already exists for Bob Geldof, skipping...
# Parquet file already exists for Doris Troy, skipping...
# Parquet file already exists for Van Halen, skipping...
# Parquet file already exists for Stealers Wheel, skipping...
# Parquet file already exists for Jo-El Sonnier, skipping...
# Parquet file already exists for Childish Gambino, skipping...
# Parquet file already exists for Carolina Slim, skipping...
# Parquet file already exists for The Dresden Dolls, skipping...
# Parquet file already exists for Sports, skipping...
# Parquet file already exists for Tyrone Davis, skipping...
# Parquet file already exists for Congo Norvell, skipping...
# Parquet file already exists for N'Dambi, skipping...
# Parquet file already exists for Broken Teeth, skipping...
# Parquet file already exists for Paul Murphy Band, skipping...
# Parquet file already exists for Regina Belle, skipping...
# Parquet file already exists for Connie Francis, skipping...
# Parquet file already exists for The Dream Academy, skipping...
# Parquet file already exists for Gangsta Blac, skipping...
# Parquet file already exists for Ari Roar, skipping...
# Parquet file already exists for Billy Sherrill, skipping...
# Parquet file already exists for Tindersticks, skipping...
# Parquet file already exists for Adamski, skipping...
# Parquet file already exists for "Weird Al" Yankovic, skipping...
# Parquet file already exists for Clarence Clemons, skipping...
# Parquet file already exists for Rooney, skipping...
# Parquet file already exists for Jochen Rueckert, skipping...
# Parquet file already exists for Carl Butler, skipping...
# Parquet file already exists for Keith Hudson, skipping...
# Parquet file already exists for Joey Agresta, skipping...
# Parquet file already exists for The Vapors, skipping...
# Parquet file already exists for The Wildhearts, skipping...
# Parquet file already exists for Neutral Milk Hotel, skipping...
# Parquet file already exists for Chino Moreno, skipping...
# Parquet file already exists for Paramore, skipping...
# Parquet file already exists for Sigue Sigue Sputnik, skipping...
# Parquet file already exists for Darkest Hour, skipping...
# Parquet file already exists for Betty Harris, skipping...
# Parquet file already exists for Idaho, skipping...
# Parquet file already exists for Mr. Fingers, skipping...
# Parquet file already exists for Tina Brooks, skipping...
# Parquet file already exists for Nick Lachey, skipping...
# Parquet file already exists for The Everymen, skipping...
# Parquet file already exists for Gregory Hines, skipping...
# Parquet file already exists for Expert Alterations, skipping...
# Parquet file already exists for Hey Mercedes, skipping...
# Parquet file already exists for Empire Cast, skipping...
# Parquet file already exists for Sodom, skipping...
# Parquet file already exists for Don Dixon, skipping...
# Parquet file already exists for Tiger Okoshi, skipping...
# Parquet file already exists for Allysen Callery, skipping...
# Parquet file already exists for Margie Joseph, skipping...
# Parquet file already exists for Periphery, skipping...
# Parquet file already exists for MiniBoone, skipping...
# Parquet file already exists for Johnny Adams, skipping...
# Parquet file already exists for Hans Rott, skipping...
# Parquet file already exists for Yellowjackets, skipping...
# Parquet file already exists for Art Tatum, skipping...
# Parquet file already exists for Avishai Cohen, skipping...
# Parquet file already exists for Niccolò Paganini, skipping...
# Parquet file already exists for Blanks 77, skipping...
# Parquet file already exists for Art Brut, skipping...
# Parquet file already exists for Vinnie Colaiuta, skipping...
# Parquet file already exists for The Matches, skipping...
# Parquet file already exists for Toshi Reagon, skipping...
# Parquet file already exists for Buddy Rich, skipping...
# Parquet file already exists for Sean McConnell, skipping...
# Parquet file already exists for Cold Arizona, skipping...
# Parquet file already exists for Ali Akbar Khan, skipping...
# Parquet file already exists for These New Puritans, skipping...
# Parquet file already exists for Bernie Williams, skipping...
# Parquet file already exists for Gordon Bok, skipping...
# Parquet file already exists for Loggins & Messina, skipping...
# Parquet file already exists for Quickspace, skipping...
# Parquet file already exists for Roland Alphonso, skipping...
# Parquet file already exists for Jon Pardi, skipping...
# Parquet file already exists for Crystal Caines, skipping...
# Parquet file already exists for Glide, skipping...
# Parquet file already exists for Ashford & Simpson, skipping...
# Parquet file already exists for Switches, skipping...
# Parquet file already exists for Veruca Salt, skipping...
# Parquet file already exists for Black Thought, skipping...
# Parquet file already exists for The Housemartins, skipping...
# Parquet file already exists for Basic Channel, skipping...
# Parquet file already exists for Philip Glass, skipping...
# Parquet file already exists for Millencolin, skipping...
# Parquet file already exists for Portishead, skipping...
# Parquet file already exists for Wynn Stewart, skipping...
# Parquet file already exists for BackWordz, skipping...
# Parquet file already exists for Leroy Gibbons, skipping...
# Parquet file already exists for Eric Alexander, skipping...
# Parquet file already exists for John Surman, skipping...
# Parquet file already exists for Josey Wales, skipping...
# Parquet file already exists for The Tripwires, skipping...
# Parquet file already exists for The Now Time Delegation, skipping...
# Parquet file already exists for Pyotr Ilyich Tchaikovsky, skipping...
# Parquet file already exists for Beach House, skipping...
# Parquet file already exists for Hot Chocolate, skipping...
# Parquet file already exists for Danni Nicholls, skipping...
# Parquet file already exists for Madina Lake, skipping...
# Parquet file already exists for Orange 9mm, skipping...
# Parquet file already exists for Chromeo, skipping...
# Parquet file already exists for Norman Blake, skipping...
# Parquet file already exists for Chico Banks, skipping...
# Parquet file already exists for Skepta, skipping...
# Parquet file already exists for Cut Chemist, skipping...
# Parquet file already exists for Dan Tyminski, skipping...
# Parquet file already exists for God Bullies, skipping...
# Parquet file already exists for Alternative TV, skipping...
# Parquet file already exists for Seasons After, skipping...
# Parquet file already exists for DJ Screw, skipping...
# Parquet file already exists for Ayreon, skipping...
# Parquet file already exists for Richie Havens, skipping...
# Parquet file already exists for Gerald Wilson, skipping...
# Parquet file already exists for Pete Droge, skipping...
# Parquet file already exists for North Mississippi Allstars, skipping...
# Parquet file already exists for Sara Evans, skipping...
# Parquet file already exists for Scrufizzer, skipping...
# Parquet file already exists for Bill Morrissey, skipping...
# Parquet file already exists for Peter Murphy, skipping...
# Parquet file already exists for Montell Jordan, skipping...
# Parquet file already exists for The Happenings, skipping...
# Parquet file already exists for Comus, skipping...
# Parquet file already exists for Original Dixieland Jazz Band, skipping...
# Parquet file already exists for Patty Waters, skipping...
# Parquet file already exists for Geto Boys, skipping...
# Parquet file already exists for Mikey Wax, skipping...
# Parquet file already exists for Seeing Stars, skipping...
# Parquet file already exists for Karunesh, skipping...
# Parquet file already exists for Ma Rainey, skipping...
# Parquet file already exists for Seamus Egan, skipping...
# Parquet file already exists for The Chemical Brothers, skipping...
# Parquet file already exists for Crash Kelly, skipping...
# Parquet file already exists for Conan Gray, skipping...
# Parquet file already exists for En Vogue, skipping...
# Parquet file already exists for Death Valley High, skipping...
# Parquet file already exists for Ronnie Dawson, skipping...
# Parquet file already exists for The Toms, skipping...
# Parquet file already exists for Belle Barth, skipping...
# Parquet file already exists for Spooky Tooth, skipping...
# Parquet file already exists for Kacey Musgraves, skipping...
# Parquet file already exists for Andy Bey, skipping...
# Parquet file already exists for Mercy Drive, skipping...
# Parquet file already exists for Pat Smear, skipping...
# Parquet file already exists for Alkaline Trio, skipping...
# Parquet file already exists for Ensign, skipping...
# Parquet file already exists for Fuzzbox, skipping...
# Parquet file already exists for LCD Soundsystem, skipping...
# Parquet file already exists for Eisley, skipping...
# Parquet file already exists for Uncle Sam, skipping...
# Parquet file already exists for Rhonda Vincent, skipping...
# Parquet file already exists for Firefall, skipping...
# Parquet file already exists for Grinspoon, skipping...
# Parquet file already exists for Freakwater, skipping...
# Parquet file already exists for Breakaway, skipping...
# Parquet file already exists for Steven Halpern, skipping...
# Parquet file already exists for Sky Ferreira, skipping...
# Parquet file already exists for Reatards, skipping...
# Parquet file already exists for Jean Ritchie, skipping...
# Parquet file already exists for Grant Lee Buffalo, skipping...
# Parquet file already exists for Bernie Worrell, skipping...
# Parquet file already exists for Hey Colossus, skipping...
# Parquet file already exists for Joe Louis Walker, skipping...
# Parquet file already exists for Red Mitchell, skipping...
# Parquet file already exists for Carla Bruni, skipping...
# Parquet file already exists for Steppenwolf, skipping...
# Parquet file already exists for Rich Aucoin, skipping...
# Parquet file already exists for Rico Nasty, skipping...
# Parquet file already exists for Aaron Goldberg, skipping...
# Parquet file already exists for Conrad Sewell, skipping...
# Parquet file already exists for Elmer Snowden, skipping...
# Parquet file already exists for Sonic Avenues, skipping...
# Parquet file already exists for Rocket Scientists, skipping...
# Parquet file already exists for Jesse Stone, skipping...
# Parquet file already exists for Your Old Droog, skipping...
# Parquet file already exists for Adrian Utley, skipping...
# Parquet file already exists for Ellery Eskelin, skipping...
# Parquet file already exists for Demi Lovato, skipping...
# Parquet file already exists for The Flaming Sideburns, skipping...
# Parquet file already exists for Will Rigby, skipping...
# Parquet file already exists for Brand Nubian, skipping...
# Parquet file already exists for Chase Bryant, skipping...
# Parquet file already exists for Immature, skipping...
# Parquet file already exists for Andy Griggs, skipping...
# Parquet file already exists for Monty Python, skipping...
# Parquet file already exists for Nellie Tiger Travis, skipping...
# Parquet file already exists for Johnny Hodges, skipping...
# Parquet file already exists for Joseph Spence, skipping...
# Parquet file already exists for Sweetback, skipping...
# Parquet file already exists for Roy Brown, skipping...
# Parquet file already exists for Momus, skipping...
# Parquet file already exists for Arturo Sandoval, skipping...
# Parquet file already exists for Royal Crown Revue, skipping...
# Parquet file already exists for Kid Congo Powers, skipping...
# Parquet file already exists for Manu Chao, skipping...
# Parquet file already exists for Tom Coster, skipping...
# Parquet file already exists for Kurt Cobain, skipping...
# Parquet file already exists for Hothouse Flowers, skipping...
# Parquet file already exists for Milt Hinton, skipping...
# Parquet file already exists for Clint Black, skipping...
# Parquet file already exists for The Beach Boys, skipping...
# Parquet file already exists for The Sea and Cake, skipping...
# Parquet file already exists for Highway 13, skipping...
# Parquet file already exists for Lakim Shabazz, skipping...
# Parquet file already exists for Portastatic, skipping...
# Parquet file already exists for The Box Tops, skipping...
# Parquet file already exists for Matrimony, skipping...
# Parquet file already exists for Doria D, skipping...
# Parquet file already exists for Tom Petty, skipping...
# Parquet file already exists for Psychedelic Horseshit, skipping...
# Parquet file already exists for Werly Fairburn, skipping...
# Parquet file already exists for T-Connection, skipping...
# Parquet file already exists for The Whitlams, skipping...
# Parquet file already exists for Aaron Tippin, skipping...
# Parquet file already exists for Arthur Alexander, skipping...
# Parquet file already exists for Everlast, skipping...
# Parquet file already exists for Charles Gounod, skipping...
# Parquet file already exists for Hozier, skipping...
# Parquet file already exists for Money Mark, skipping...
# Parquet file already exists for Con Funk Shun, skipping...
# Parquet file already exists for Big Flame, skipping...
# Parquet file already exists for Jesse Harris, skipping...
# Parquet file already exists for Creedence Clearwater Revival, skipping...
# Parquet file already exists for Kevn Kinney, skipping...
# Parquet file already exists for Bascom Lamar Lunsford, skipping...
# Parquet file already exists for Enon, skipping...
# Parquet file already exists for Marc Broussard, skipping...
# Parquet file already exists for Dntel, skipping...
# Parquet file already exists for Thelma Houston, skipping...
# Parquet file already exists for Computer Games, skipping...
# Parquet file already exists for Missing Persons, skipping...
# Parquet file already exists for Hell Is For Heroes, skipping...
# Parquet file already exists for Perry Farrell, skipping...
# Parquet file already exists for Trummy Young, skipping...
# Parquet file already exists for Olivia Chaney, skipping...
# Parquet file already exists for Mind Brains, skipping...
# Parquet file already exists for Roy Orbison, skipping...
# Parquet file already exists for Vyces, skipping...
# Parquet file already exists for Shaliek, skipping...
# Parquet file already exists for Brandy, skipping...
# Parquet file already exists for Ad Infinitum, skipping...
# Parquet file already exists for Ultravox, skipping...
# Parquet file already exists for Tha Dogg Pound, skipping...
# Parquet file already exists for Humble Pie, skipping...
# Parquet file already exists for K.T. Oslin, skipping...
# Parquet file already exists for Bill Nelson, skipping...
# Parquet file already exists for Jeff Mills, skipping...
# Parquet file already exists for Albert King, skipping...
# Parquet file already exists for O Yuki Conjugate, skipping...
# Parquet file already exists for Buddy Emmons, skipping...
# Parquet file already exists for Rick Astley, skipping...
# Parquet file already exists for Melba Moore, skipping...
# Parquet file already exists for Shy Child, skipping...
# Parquet file already exists for Daniel Ash, skipping...
# Parquet file already exists for Dinah Shore, skipping...
# Parquet file already exists for Max Martin, skipping...
# Parquet file already exists for Styx, skipping...
# Parquet file already exists for Vangelis, skipping...
# Parquet file already exists for Chantal Kreviazuk, skipping...
# Parquet file already exists for Marty Friedman, skipping...
# Parquet file already exists for Ken Peplowski, skipping...
# Parquet file already exists for Mogwai, skipping...
# Parquet file already exists for Si Zentner, skipping...
# Parquet file already exists for Midland, skipping...
# Parquet file already exists for Brunning Sunflower Blues Band, skipping...
# Parquet file already exists for Anugama, skipping...
# Parquet file already exists for Chico DeBarge, skipping...
# Parquet file already exists for The Candyskins, skipping...
# Parquet file already exists for Aimee Mann, skipping...
# Parquet file already exists for Shriekback, skipping...
# Parquet file already exists for Stephanie Mills, skipping...
# Parquet file already exists for The Hollies, skipping...
# Parquet file already exists for The Uniques, skipping...
# Parquet file already exists for El Michels Affair, skipping...
# Parquet file already exists for The Dead 60s, skipping...
# Parquet file already exists for David S. Ware, skipping...
# Parquet file already exists for Jimmy Cobb, skipping...
# Parquet file already exists for Babybird, skipping...
# Parquet file already exists for The Brecker Brothers, skipping...
# Parquet file already exists for One Dove, skipping...
# Parquet file already exists for Pierce Edens, skipping...
# Parquet file already exists for Rockpile, skipping...
# Parquet file already exists for Badlands, skipping...
# Parquet file already exists for Randy Travis, skipping...
# Parquet file already exists for Lexie Mountain Boys, skipping...
# Parquet file already exists for Jerome Kern, skipping...
# Parquet file already exists for William S. Burroughs, skipping...
# Parquet file already exists for Owl City, skipping...
# Parquet file already exists for Frankie Lee Sims, skipping...
# Parquet file already exists for Max Frost, skipping...
# Parquet file already exists for Compound Red, skipping...
# Parquet file already exists for Giacomo Puccini, skipping...
# Parquet file already exists for The Nazz, skipping...
# Parquet file already exists for Candy Butchers, skipping...
# Parquet file already exists for The Tea Party, skipping...
# Parquet file already exists for Matthias Lupri, skipping...
# Parquet file already exists for John Bickerton, skipping...
# Parquet file already exists for Palehound, skipping...
# Parquet file already exists for Damian Marley, skipping...
# Parquet file already exists for Scrapper Blackwell, skipping...
# Parquet file already exists for Boyz N Da Hood, skipping...
# Parquet file already exists for Broken Social Scene, skipping...
# Parquet file already exists for Diamond Rio, skipping...
# Parquet file already exists for Citizen Four, skipping...
# Parquet file already exists for Boards of Canada, skipping...
# Parquet file already exists for Gene Watson, skipping...
# Parquet file already exists for Allen Ginsberg, skipping...
# Parquet file already exists for Kruder & Dorfmeister, skipping...
# Parquet file already exists for Bound Stems, skipping...
# Parquet file already exists for Michael Nesmith, skipping...
# Parquet file already exists for Sonny Fortune, skipping...
# Parquet file already exists for Rebecca Moore, skipping...
# Parquet file already exists for Richard Strauss, skipping...
# Parquet file already exists for Rancid, skipping...
# Parquet file already exists for Harry "Sweets" Edison, skipping...
# Parquet file already exists for The Revelers, skipping...
# Parquet file already exists for Graeme Revell, skipping...
# Parquet file already exists for Sha Na Na, skipping...
# Parquet file already exists for Khruangbin, skipping...
# Parquet file already exists for Carl Stalling, skipping...
# Parquet file already exists for Lionel Cartwright, skipping...
# Parquet file already exists for The Vandermark 5, skipping...
# Parquet file already exists for Kim Gordon, skipping...
# Parquet file already exists for Max Corbacho, skipping...
# Parquet file already exists for Stone Temple Pilots, skipping...
# Parquet file already exists for Tinashe, skipping...
# Parquet file already exists for Crooked Fingers, skipping...
# Parquet file already exists for Tilt, skipping...
# Parquet file already exists for Timi Yuro, skipping...
# Parquet file already exists for BØRNS, skipping...
# Parquet file already exists for Thomas Mapfumo, skipping...
# Parquet file already exists for Cherrywine, skipping...
# Parquet file already exists for Hoodoo Gurus, skipping...
# Parquet file already exists for Thom Yorke, skipping...
# Parquet file already exists for Kraftwelt, skipping...
# Parquet file already exists for Mark Whitfield, skipping...
# Parquet file already exists for Yma Sumac, skipping...
# Parquet file already exists for The Flashcubes, skipping...
# Parquet file already exists for Keri Hilson, skipping...
# Parquet file already exists for Mary Martin, skipping...
# Parquet file already exists for Mungo Jerry, skipping...
# Parquet file already exists for Steinski, skipping...
# Parquet file already exists for The Cardigans, skipping...
# Parquet file already exists for Beach Baby, skipping...
# Parquet file already exists for Combustible Edison, skipping...
# Parquet file already exists for Usher, skipping...
# Parquet file already exists for Elvin Jones, skipping...
# Parquet file already exists for 13th Floor Elevators, skipping...
# Parquet file already exists for The Merton Parkas, skipping...
# Parquet file already exists for Jonathan Richman, skipping...
# Parquet file already exists for Roy Clark, skipping...
# Parquet file already exists for The Manhattan Love Suicides, skipping...
# Parquet file already exists for Jim Kweskin, skipping...
# Parquet file already exists for DJ Shadow, skipping...
# Parquet file already exists for Yo Gotti, skipping...
# Parquet file already exists for Dead Kennedys, skipping...
# Parquet file already exists for Jacques Brel, skipping...
# Parquet file already exists for Holy Mountain, skipping...
# Parquet file already exists for The Stone Roses, skipping...
# Parquet file already exists for Slightly Stoopid, skipping...
# Parquet file already exists for Roscoe Holcomb, skipping...
# Parquet file already exists for The Well Wishers, skipping...
# Parquet file already exists for Baby Island, skipping...
# Parquet file already exists for Édith Piaf, skipping...
# Parquet file already exists for The Soft Hills, skipping...
# Parquet file already exists for Big Boi, skipping...
# Parquet file already exists for Husky, skipping...
# Parquet file already exists for Bobby McFerrin, skipping...
# Parquet file already exists for Discharge, skipping...
# Parquet file already exists for Malicorne, skipping...
# Parquet file already exists for Oliver Nelson, skipping...
# Parquet file already exists for Alex Maxwell, skipping...
# Parquet file already exists for Earl Thomas Conley, skipping...
# Parquet file already exists for Jo Stafford, skipping...
# Parquet file already exists for 10cc, skipping...
# Parquet file already exists for The Cribs, skipping...
# Parquet file already exists for Guitar Shorty, skipping...
# Parquet file already exists for Majek Fashek, skipping...
# Parquet file already exists for Adam Lambert, skipping...
# Parquet file already exists for The Butchies, skipping...
# Parquet file already exists for Teddy Thompson, skipping...
# Parquet file already exists for Parlor James, skipping...
# Parquet file already exists for One Direction, skipping...
# Parquet file already exists for Dominic Frontiere, skipping...
# Parquet file already exists for Johnnie Mikel, skipping...
# Parquet file already exists for Jamie Cullum, skipping...
# Parquet file already exists for Johnny Griffin, skipping...
# Parquet file already exists for Joy Askew, skipping...
# Parquet file already exists for Sunshine Skiffle Band, skipping...
# Parquet file already exists for Carlene Carter, skipping...
# Parquet file already exists for Alvvays, skipping...
# Parquet file already exists for Paul Stanley, skipping...
# Parquet file already exists for Stephin Merritt, skipping...
# Parquet file already exists for Greg Ashley, skipping...
# Parquet file already exists for Fergie, skipping...
# Parquet file already exists for Johnny Hartman, skipping...
# Parquet file already exists for Hazel Scott, skipping...
# Parquet file already exists for Drive-By Truckers, skipping...
# Parquet file already exists for Gerry Mulligan, skipping...
# Parquet file already exists for Mitch Easter, skipping...
# Parquet file already exists for Tom Paley, skipping...
# Parquet file already exists for Tamar Braxton, skipping...
# Parquet file already exists for Throwing Muses, skipping...
# Parquet file already exists for Dead Confederate, skipping...
# Parquet file already exists for Frank Morgan, skipping...
# Parquet file already exists for Steel Pulse, skipping...
# Parquet file already exists for The Idle Race, skipping...
# Parquet file already exists for The Real Tuesday Weld, skipping...
# Parquet file already exists for Victor Jara, skipping...
# Parquet file already exists for Oasis, skipping...
# Parquet file already exists for Dilated Peoples, skipping...
# Parquet file already exists for John Legend, skipping...
# Parquet file already exists for Black Ivory, skipping...
# Parquet file already exists for Rudimentary Peni, skipping...
# Parquet file already exists for Johnny Osbourne, skipping...
# Parquet file already exists for Another Bad Creation, skipping...
# Parquet file already exists for The Highwaymen, skipping...
# Parquet file already exists for Bill Stewart, skipping...
# Parquet file already exists for Spitalfield, skipping...
# Parquet file already exists for All We Are, skipping...
# Parquet file already exists for Shaggy, skipping...
# Parquet file already exists for Dehumanized, skipping...
# Parquet file already exists for Black Francis, skipping...
# Parquet file already exists for Judy Roderick, skipping...
# Parquet file already exists for Cheepskates, skipping...
# Parquet file already exists for Ten Foot Pole, skipping...
# Parquet file already exists for Buddy Johnson, skipping...
# Parquet file already exists for Rafael Anton Irisarri, skipping...
# Parquet file already exists for Trick Daddy, skipping...
# Parquet file already exists for Urban Verbs, skipping...
# Parquet file already exists for Brazilian Girls, skipping...
# Parquet file already exists for It Bites, skipping...
# Parquet file already exists for Howard Tate, skipping...
# Parquet file already exists for Sunnyland Slim, skipping...
# Parquet file already exists for Hanns Eisler, skipping...
# Parquet file already exists for 9th Wonder, skipping...
# Parquet file already exists for Lonesome Sundown, skipping...
# Parquet file already exists for Big Youth, skipping...
# Parquet file already exists for Ahmad Jamal, skipping...
# Parquet file already exists for Big Data, skipping...
# Parquet file already exists for Pearl Charles, skipping...
# Parquet file already exists for Cosmonauts, skipping...
# Parquet file already exists for Voyage, skipping...
# Parquet file already exists for Blind Idiot God, skipping...
# Parquet file already exists for Deuter, skipping...
# Parquet file already exists for Claire Holley, skipping...
# Parquet file already exists for Matt Simons, skipping...
# Parquet file already exists for Klaus Nomi, skipping...
# Parquet file already exists for Kelly Willis, skipping...
# Parquet file already exists for Neil Cavanagh, skipping...
# Parquet file already exists for True Love Always, skipping...
# Parquet file already exists for The Ocean Blue, skipping...
# Parquet file already exists for Ranking Dread, skipping...
# Parquet file already exists for 45 Grave, skipping...
# Parquet file already exists for Henry Butler, skipping...
# Parquet file already exists for The Aqua Velvets, skipping...
# Parquet file already exists for Sonny Rollins, skipping...
# Parquet file already exists for Sex Pistols, skipping...
# Parquet file already exists for Leon Thomas, skipping...
# Parquet file already exists for Mount Pilot, skipping...
# Parquet file already exists for Tomas Nordmark, skipping...
# Parquet file already exists for Converge, skipping...
# Parquet file already exists for Glenn Lewis, skipping...
# Parquet file already exists for Mink DeVille, skipping...
# Parquet file already exists for Mike McCready, skipping...
# Parquet file already exists for Lee Ranaldo, skipping...
# Parquet file already exists for The String Cheese Incident, skipping...
# Parquet file already exists for Johnny Dowd, skipping...
# Parquet file already exists for Linea 77, skipping...
# Parquet file already exists for Pegboy, skipping...
# Parquet file already exists for Area Code 615, skipping...
# Parquet file already exists for Peggy Seeger, skipping...
# Parquet file already exists for The Delgados, skipping...
# Parquet file already exists for Agalloch, skipping...
# Parquet file already exists for Mighty Sparrow, skipping...
# Parquet file already exists for The Bloody Beetroots, skipping...
# Parquet file already exists for Stresmatic, skipping...
# Parquet file already exists for Red Snapper, skipping...
# Parquet file already exists for Sam Bush, skipping...
# Parquet file already exists for Trouble, skipping...
# Parquet file already exists for Bad Manners, skipping...
# Parquet file already exists for Backstreet Boys, skipping...
# Parquet file already exists for Fiona Apple, skipping...
# Parquet file already exists for Consolidated, skipping...
# Parquet file already exists for George Michael, skipping...
# Parquet file already exists for Milli Vanilli, skipping...
# Parquet file already exists for Baxendale, skipping...
# Parquet file already exists for Rich Kids, skipping...
# Parquet file already exists for Billy Falcon, skipping...
# Parquet file already exists for Don Braden, skipping...
# Parquet file already exists for Sylvia Syms, skipping...
# Parquet file already exists for Burzum, skipping...
# Parquet file already exists for Gin Wigmore, skipping...
# Parquet file already exists for Tom Brosseau, skipping...
# Parquet file already exists for The Kills, skipping...
# Parquet file already exists for Hazel Dickens, skipping...
# Parquet file already exists for Rich Mullins, skipping...
# Parquet file already exists for The Duke Spirit, skipping...
# Parquet file already exists for Bobby Gordon, skipping...
# Parquet file already exists for Anni Rossi, skipping...
# Parquet file already exists for Koko Taylor, skipping...
# Parquet file already exists for The Aquadolls, skipping...
# Parquet file already exists for Yeah Yeah Yeahs, skipping...
# Parquet file already exists for Jonny Lang, skipping...
# Parquet file already exists for Minimal Compact, skipping...
# Parquet file already exists for Jonas Reinhardt, skipping...
# Parquet file already exists for Les Rallizes Dénudés, skipping...
# Parquet file already exists for Childhood, skipping...
# Parquet file already exists for Spice Girls, skipping...
# Parquet file already exists for Christopher Willits, skipping...
# Parquet file already exists for Cephalic Carnage, skipping...
# Parquet file already exists for Star Tropics, skipping...
# Parquet file already exists for Tenille Arts, skipping...
# Parquet file already exists for Strange Talk, skipping...
# Parquet file already exists for The Hellacopters, skipping...
# Parquet file already exists for MoKenStef, skipping...
# Parquet file already exists for Adam Rogers, skipping...
# Parquet file already exists for Dark Meat, skipping...
# Parquet file already exists for Alyson Williams, skipping...
# Parquet file already exists for Salem 66, skipping...
# Parquet file already exists for Keith Tippett, skipping...
# Parquet file already exists for People Like Us, skipping...
# Parquet file already exists for Steve Hackett, skipping...
# Parquet file already exists for Little Pink, skipping...
# Parquet file already exists for The Feelies, skipping...
# Parquet file already exists for Stackridge, skipping...
# Parquet file already exists for John McLaughlin, skipping...
# Parquet file already exists for Comethazine, skipping...
# Parquet file already exists for The International Submarine Band, skipping...
# Parquet file already exists for Dawn Richard, skipping...
# Parquet file already exists for Chiodos, skipping...
# Parquet file already exists for Frankie Yankovic, skipping...
# Parquet file already exists for Warm Brew, skipping...
# Parquet file already exists for Damaged Bug, skipping...
# Parquet file already exists for D.A. Wallach, skipping...
# Parquet file already exists for Andra Day, skipping...
# Parquet file already exists for Karl Goldmark, skipping...
# Parquet file already exists for Vanessa Carlton, skipping...
# Parquet file already exists for Glenn Travis, skipping...
# Parquet file already exists for Harry Pussy, skipping...
# Parquet file already exists for Samantha Fox, skipping...
# Parquet file already exists for The J. Geils Band, skipping...
# Parquet file already exists for Zara McFarlane, skipping...
# Parquet file already exists for Mr. Fox, skipping...
# Parquet file already exists for Elf Power, skipping...
# Parquet file already exists for Alex Chilton, skipping...
# Parquet file already exists for Robert Gordon, skipping...
# Parquet file already exists for Electric Frankenstein, skipping...
# Parquet file already exists for Lil Jon, skipping...
# Parquet file already exists for Mr. Lif, skipping...
# Parquet file already exists for Screaming Trees, skipping...
# Parquet file already exists for Yandel, skipping...
# Parquet file already exists for Jon Hassell, skipping...
# Parquet file already exists for Joe Brown, skipping...
# Parquet file already exists for Goldfrapp, skipping...
# Parquet file already exists for Chris Bell, skipping...
# Parquet file already exists for Jay Electronica, skipping...
# Parquet file already exists for France Gall, skipping...
# Parquet file already exists for Modest Mouse, skipping...
# Parquet file already exists for East India Youth, skipping...
# Parquet file already exists for Jane's Addiction, skipping...
# Parquet file already exists for Diplo, skipping...
# Parquet file already exists for Indigo Girls, skipping...
# Parquet file already exists for Los Zafiros, skipping...
# Parquet file already exists for Martin Sexton, skipping...
# Parquet file already exists for Utah Phillips, skipping...
# Parquet file already exists for God Is My Co-Pilot, skipping...
# Parquet file already exists for Gibson Bros., skipping...
# Parquet file already exists for Jon Foreman, skipping...
# Parquet file already exists for Holly Near, skipping...
# Parquet file already exists for Herb Ellis, skipping...
# Parquet file already exists for Teyana Taylor, skipping...
# Parquet file already exists for Fela Kuti, skipping...
# Parquet file already exists for Del Shannon, skipping...
# Parquet file already exists for Big Business, skipping...
# Parquet file already exists for The Brought Low, skipping...
# Parquet file already exists for Myron Floren, skipping...
# Parquet file already exists for The Hipstones, skipping...
# Parquet file already exists for Roswell Rudd, skipping...
# Parquet file already exists for Holly McNarland, skipping...
# Parquet file already exists for John Newman, skipping...
# Parquet file already exists for Bleeding Through, skipping...
# Parquet file already exists for Software, skipping...
# Parquet file already exists for Golden Earring, skipping...
# Parquet file already exists for La Monte Young, skipping...
# Parquet file already exists for Fuck Buttons, skipping...
# Parquet file already exists for John Boutté, skipping...
# Parquet file already exists for Murder By Death, skipping...
# Parquet file already exists for Rammstein, skipping...
# Parquet file already exists for Jigsaw, skipping...
# Parquet file already exists for Björk, skipping...
# Parquet file already exists for Wolfstone, skipping...
# Parquet file already exists for J. Holiday, skipping...
# Parquet file already exists for Doris Day, skipping...
# Parquet file already exists for James Luther Dickinson, skipping...
# Parquet file already exists for 3LW, skipping...
# Parquet file already exists for Cypress Hill, skipping...
# Parquet file already exists for Red Lorry Yellow Lorry, skipping...
# Parquet file already exists for The Nighthawks, skipping...
# Parquet file already exists for Cock Sparrer, skipping...
# Parquet file already exists for Lars Ulrich, skipping...
# Parquet file already exists for De La Soul, skipping...
# Parquet file already exists for James Gang, skipping...
# Parquet file already exists for Keith Relf, skipping...
# Parquet file already exists for Kill Creek, skipping...
# Parquet file already exists for Houston Person, skipping...
# Parquet file already exists for The J.B.'s, skipping...
# Parquet file already exists for The Tremeloes, skipping...
# Parquet file already exists for Tove Lo, skipping...
# Parquet file already exists for Molly Burch, skipping...
# Parquet file already exists for Skylar Stecker, skipping...
# Parquet file already exists for Quiet Riot, skipping...
# Parquet file already exists for Diana Krall, skipping...
# Parquet file already exists for French Kicks, skipping...
# Parquet file already exists for Edgar Froese, skipping...
# Parquet file already exists for The Nashville Bluegrass Band, skipping...
# Parquet file already exists for Ronnie Spector, skipping...
# Parquet file already exists for Gerald Veasley, skipping...
# Parquet file already exists for Kid Sister, skipping...
# Parquet file already exists for Celestial Shore, skipping...
# Parquet file already exists for Intelligent Hoodlum, skipping...
# Parquet file already exists for Tedeschi Trucks Band, skipping...
# Parquet file already exists for Wooden Shjips, skipping...
# Parquet file already exists for Pit Er Pat, skipping...
# Parquet file already exists for Major Lazer, skipping...
# Parquet file already exists for Chaotic Dischord, skipping...
# Parquet file already exists for The Lucksmiths, skipping...
# Parquet file already exists for Maroon 5, skipping...
# Parquet file already exists for Detroit's Most Wanted, skipping...
# Parquet file already exists for Eyehategod, skipping...
# Parquet file already exists for Alvin Youngblood Hart, skipping...
# Parquet file already exists for Fred Neil, skipping...
# Parquet file already exists for Coolio, skipping...
# Parquet file already exists for Once Blue, skipping...
# Parquet file already exists for Harry Belafonte, skipping...
# Parquet file already exists for Shanice, skipping...
# Parquet file already exists for Frankie Randall, skipping...
# Parquet file already exists for Air France, skipping...
# Parquet file already exists for Defunkt, skipping...
# Parquet file already exists for Paula Abdul, skipping...
# Parquet file already exists for Asia, skipping...
# Parquet file already exists for Victoria Spivey, skipping...
# Parquet file already exists for Richard Buckner, skipping...
# Parquet file already exists for Hugh Le Caine, skipping...
# Parquet file already exists for Stardancer, skipping...
# Parquet file already exists for Jay McShann, skipping...
# Parquet file already exists for Gene Russell, skipping...
# Parquet file already exists for Wham!, skipping...
# Parquet file already exists for Elis Regina, skipping...
# Parquet file already exists for Brooke Hogan, skipping...
# Parquet file already exists for Polyrock, skipping...
# Parquet file already exists for East River Pipe, skipping...
# Parquet file already exists for Reagan Youth, skipping...
# Parquet file already exists for Gathering Ground, skipping...
# Parquet file already exists for Dave Mason, skipping...
# Parquet file already exists for Edwyn Collins, skipping...
# Parquet file already exists for Jeff Berlin, skipping...
# Parquet file already exists for Grant Green, skipping...
# Parquet file already exists for X-Clan, skipping...
# Parquet file already exists for Testament, skipping...
# Parquet file already exists for Rationale, skipping...
# Parquet file already exists for Mo-Dettes, skipping...
# Parquet file already exists for Shop Assistants, skipping...
# Parquet file already exists for The Bluebells, skipping...
# Parquet file already exists for Darling West, skipping...
# Parquet file already exists for Jayne County, skipping...
# Parquet file already exists for Vladislav Delay, skipping...
# Parquet file already exists for The Melodians, skipping...
# Parquet file already exists for The Last Town Chorus, skipping...
# Parquet file already exists for Juniore, skipping...
# Parquet file already exists for Thomas Jefferson Slave Apartments, skipping...
# Parquet file already exists for Supersnazz, skipping...
# Parquet file already exists for Stereophonics, skipping...
# Parquet file already exists for Lonnie Brooks, skipping...
# Parquet file already exists for Tanya Tucker, skipping...
# Parquet file already exists for The Script, skipping...
# Parquet file already exists for Continental Drifters, skipping...
# Parquet file already exists for Fight Like Apes, skipping...
# Parquet file already exists for Aaron Lee Tasjan, skipping...
# Parquet file already exists for Masabumi Kikuchi, skipping...
# Parquet file already exists for Coasts, skipping...
# Parquet file already exists for Freddie Hubbard, skipping...
# Parquet file already exists for Pat Green, skipping...
# Parquet file already exists for Geggy Tah, skipping...
# Parquet file already exists for Barkmarket, skipping...
# Parquet file already exists for alt-J, skipping...
# Parquet file already exists for A.R.E. Weapons, skipping...
# Parquet file already exists for Steve Lacy, skipping...
# Parquet file already exists for Leroy Jenkins, skipping...
# Parquet file already exists for Lovespirals, skipping...
# Parquet file already exists for Inspiral Carpets, skipping...
# Parquet file already exists for Syntaks, skipping...
# Parquet file already exists for Miracle Legion, skipping...
# Parquet file already exists for Franklin Bruno, skipping...
# Parquet file already exists for This Perfect Day, skipping...
# Parquet file already exists for Alvino Rey, skipping...
# Parquet file already exists for The Rutles, skipping...
# Parquet file already exists for Mirror Queen, skipping...
# Parquet file already exists for Golden Delicious, skipping...
# Parquet file already exists for Nachtmystium, skipping...
# Parquet file already exists for Everclear, skipping...
# Parquet file already exists for Shakira, skipping...
# Parquet file already exists for The Doors, skipping...
# Parquet file already exists for Rumer, skipping...
# Parquet file already exists for Wendy Carlos, skipping...
# Parquet file already exists for Tsunami Bomb, skipping...
# Parquet file already exists for Craig David, skipping...
# Parquet file already exists for Peter Case, skipping...
# Parquet file already exists for The Collins Kids, skipping...
# Parquet file already exists for James Harman, skipping...
# Parquet file already exists for Ann Peebles, skipping...
# Parquet file already exists for Little Jimmy King, skipping...
# Parquet file already exists for Belinda Carlisle, skipping...
# Parquet file already exists for Kenny Roby, skipping...
# Parquet file already exists for Jain, skipping...
# Parquet file already exists for Captain Beyond, skipping...
# Parquet file already exists for The xx, skipping...
# Parquet file already exists for Karnivool, skipping...
# Parquet file already exists for Margaret Whiting, skipping...
# Parquet file already exists for Moon Taxi, skipping...
# Parquet file already exists for Eric Bogle, skipping...
# Parquet file already exists for Keith Jarrett, skipping...
# Parquet file already exists for Thomas A. Dorsey, skipping...
# Parquet file already exists for B*Witched, skipping...
# Parquet file already exists for Keith Urban, skipping...
# Parquet file already exists for Al Green, skipping...
# Parquet file already exists for Danny Gatton, skipping...
# Parquet file already exists for José Feliciano, skipping...
# Parquet file already exists for Diane Izzo, skipping...
# Parquet file already exists for Run River North, skipping...
# Parquet file already exists for O.V. Wright, skipping...
# Parquet file already exists for U.T.F.O., skipping...
# Parquet file already exists for Marley Carroll, skipping...
# Parquet file already exists for Bootsy Collins, skipping...
# Parquet file already exists for Sugababes, skipping...
# Parquet file already exists for Radial Spangle, skipping...
# Parquet file already exists for Eleven Hundred Springs, skipping...
# Parquet file already exists for Strangefolk, skipping...
# Parquet file already exists for Oscar Moore, skipping...
# Parquet file already exists for Ocean Colour Scene, skipping...
# Parquet file already exists for Sherrié Austin, skipping...
# Parquet file already exists for Joe Piscopo, skipping...
# Parquet file already exists for Moose Blood, skipping...
# Parquet file already exists for The Gourds, skipping...
# Parquet file already exists for Golden Smog, skipping...
# Parquet file already exists for Rita Marley, skipping...
# Parquet file already exists for The Rivingtons, skipping...
# Parquet file already exists for Moonshine Willy, skipping...
# Parquet file already exists for The Angels, skipping...
# Parquet file already exists for Okkervil River, skipping...
# Parquet file already exists for Wounded Lion, skipping...
# Parquet file already exists for Miaoux Miaoux, skipping...
# Parquet file already exists for A Winged Victory for the Sullen, skipping...
# Parquet file already exists for Sex Clark Five, skipping...
# Parquet file already exists for Tracy Bonham, skipping...
# Parquet file already exists for The Scofflaws, skipping...
# Parquet file already exists for Last Exit, skipping...
# Parquet file already exists for The O'Jays, skipping...
# Parquet file already exists for Galaxie 500, skipping...
# Parquet file already exists for The Flashing Lights, skipping...
# Parquet file already exists for Pearls Before Swine, skipping...
# Parquet file already exists for Scott Colley, skipping...
# Parquet file already exists for Ian Smith, skipping...
# Parquet file already exists for Gauntlet Hair, skipping...
# Parquet file already exists for Exhorder, skipping...
# Parquet file already exists for Strung Out, skipping...
# Parquet file already exists for Team Dresch, skipping...
# Parquet file already exists for Richard Davis, skipping...
# Parquet file already exists for The Misunderstood, skipping...
# Parquet file already exists for Gene Harris, skipping...
# Parquet file already exists for Don Omar, skipping...
# Parquet file already exists for New Duncan Imperials, skipping...
# Parquet file already exists for Giant Sand, skipping...
# Parquet file already exists for Basic Black, skipping...
# Parquet file already exists for Limblifter, skipping...
# Parquet file already exists for Roomful Of Blues, skipping...
# Parquet file already exists for Fat Day, skipping...
# ...
# Parquet file already exists for Djam Karet, skipping...
# Parquet file already exists for Pinback, skipping...
# Parquet file already exists for Bo Bice, skipping...
# Parquet file already exists for Hamilton Camp, skipping...
# Parquet file already exists for Iron Monkey, skipping...
# Parquet file already exists for Mannheim Steamroller, skipping...
# Parquet file already exists for Muslimgauze, skipping...
# Parquet file already exists for Burl Ives, skipping...
# Parquet file already exists for Spoon, skipping...
# Parquet file already exists for The Maddox Brothers & Rose, skipping...
# Parquet file already exists for Los Super Seven, skipping...
# Parquet file already exists for Esplendor Geométrico, skipping...
# Parquet file already exists for Franky Perez, skipping...
# Parquet file already exists for Basement Jaxx, skipping...
# Parquet file already exists for Hank Mobley, skipping...
# Parquet file already exists for Steve Morse, skipping...
# Parquet file already exists for Vernon Reid, skipping...
# Parquet file already exists for Steve Hogarth, skipping...
# Parquet file already exists for Staind, skipping...
# Parquet file already exists for Suffocation, skipping...
# Parquet file already exists for Biffy Clyro, skipping...
# Parquet file already exists for Lightning Bolt, skipping...
# Parquet file already exists for The Brothers Four, skipping...
# Parquet file already exists for Kevin Krauter, skipping...
# Parquet file already exists for The Electric Soft Parade, skipping...
# Parquet file already exists for Huntress, skipping...
# Parquet file already exists for Barn Owl, skipping...
# Parquet file already exists for Granian, skipping...
# Parquet file already exists for B.E.F., skipping...
# Parquet file already exists for The Unlovables, skipping...
# Parquet file already exists for Thrice, skipping...
# Parquet file already exists for The Soft Moon, skipping...
# Parquet file already exists for Slobberbone, skipping...
# Parquet file already exists for The Hudson Brothers, skipping...
# Parquet file already exists for John Martyn, skipping...
# Parquet file already exists for Syd Arthur, skipping...
# Parquet file already exists for Ricardo Montaner, skipping...
# Parquet file already exists for Siriusmo, skipping...
# Parquet file already exists for Michael Kroll, skipping...
# Parquet file already exists for Van Hunt, skipping...
# Parquet file already exists for The Postmarks, skipping...
# Parquet file already exists for Terri Clark, skipping...
# Parquet file already exists for Be Bop Deluxe, skipping...
# Parquet file already exists for The Explosion, skipping...
# Parquet file already exists for Spock's Beard, skipping...
# Parquet file already exists for Crywolf, skipping...
# Parquet file already exists for Dennis Bovell, skipping...
# Parquet file already exists for Big L, skipping...
# Parquet file already exists for Rosie Thomas, skipping...
# Parquet file already exists for Cult of Youth, skipping...
# Parquet file already exists for The Merseybeats, skipping...
# Parquet file already exists for The Bottle Rockets, skipping...
# Parquet file already exists for The Disco Biscuits, skipping...
# Parquet file already exists for Greg Osby, skipping...
# Parquet file already exists for Habibi, skipping...
# Parquet file already exists for Eminem, skipping...
# Parquet file already exists for Brook Benton, skipping...
# Parquet file already exists for Fozzy, skipping...
# Parquet file already exists for Hot Club Of Cowtown, skipping...
# Parquet file already exists for David Frizzell, skipping...
# Parquet file already exists for Eddy Arnold, skipping...
# Parquet file already exists for The Specials, skipping...
# Parquet file already exists for Carrie Rodriguez, skipping...
# Parquet file already exists for Idina Menzel, skipping...
# Parquet file already exists for Karen Dalton, skipping...
# Parquet file already exists for Peter and the Test Tube Babies, skipping...
# Parquet file already exists for Erase Errata, skipping...
# Parquet file already exists for T. Graham Brown, skipping...
# Parquet file already exists for Luna 13, skipping...
# Parquet file already exists for Hardline, skipping...
# Parquet file already exists for Prince Far I, skipping...
# Parquet file already exists for Charles Ives, skipping...
# Parquet file already exists for Xscape, skipping...
# Parquet file already exists for Monette Moore, skipping...
# Parquet file already exists for Crystal Waters, skipping...
# Parquet file already exists for Gene Loves Jezebel, skipping...
# Parquet file already exists for New Bomb Turks, skipping...
# Parquet file already exists for Timeflies, skipping...
# Parquet file already exists for Dylan Hyde, skipping...
# Parquet file already exists for Cassius, skipping...
# Parquet file already exists for Ar'mon & Trey, skipping...
# Parquet file already exists for Bulbous Creation, skipping...
# Parquet file already exists for Céline Dion, skipping...
# Parquet file already exists for Part Chimp, skipping...
# Parquet file already exists for David Crosby, skipping...
# Parquet file already exists for Jonah Jones Quartet, skipping...
# Parquet file already exists for Nikki Sudden, skipping...
# Parquet file already exists for Joe Maphis, skipping...
# Parquet file already exists for Deerhunter, skipping...
# Parquet file already exists for Hot Chip, skipping...
# Parquet file already exists for Garden Variety, skipping...
# Parquet file already exists for Labradford, skipping...
# Parquet file already exists for Colosseum II, skipping...
# Parquet file already exists for LTJ Bukem, skipping...
# Parquet file already exists for The Sugarman 3, skipping...
# Parquet file already exists for Natasha Bedingfield, skipping...
# Parquet file already exists for Lonnie Liston Smith, skipping...
# Parquet file already exists for Canned Heat, skipping...
# Parquet file already exists for Luther Vandross, skipping...
# Parquet file already exists for I Am Ghost, skipping...
# Parquet file already exists for Condemned, skipping...
# Parquet file already exists for Syleena Johnson, skipping...
# Parquet file already exists for Conor Maynard, skipping...
# Parquet file already exists for Near Miss, skipping...
# Parquet file already exists for L.E.S. Stitches, skipping...
# Parquet file already exists for Wet Wet Wet, skipping...
# Parquet file already exists for William Hooker, skipping...
# Parquet file already exists for Mike Watt, skipping...
# Parquet file already exists for Charles Mingus, skipping...
# Parquet file already exists for Moonshake, skipping...
# Parquet file already exists for Bloody Sunday, skipping...
# Parquet file already exists for Nicky Blitz, skipping...
# Parquet file already exists for Ziggy Elman, skipping...
# Parquet file already exists for Sebadoh, skipping...
# Parquet file already exists for Long John Baldry, skipping...
# Parquet file already exists for Mick Goodrick, skipping...
# Parquet file already exists for Matt Redman, skipping...
# Parquet file already exists for The Shirelles, skipping...
# Parquet file already exists for Phantom Tollbooth, skipping...
# Parquet file already exists for 3 Doors Down, skipping...
# Parquet file already exists for Kill the Alarm, skipping...
# Parquet file already exists for Jim Jackson, skipping...
# Parquet file already exists for Michel Petrucciani, skipping...
# Parquet file already exists for The Jimmy Castor Bunch, skipping...
# Parquet file already exists for Cross Canadian Ragweed, skipping...
# Parquet file already exists for Marc Dorsey, skipping...
# Parquet file already exists for Microdisney, skipping...
# Parquet file already exists for Tinsley Ellis, skipping...
# Parquet file already exists for Spacehog, skipping...
# Parquet file already exists for Trivium, skipping...
# Parquet file already exists for Peter Noone, skipping...
# Parquet file already exists for Live, skipping...
# Parquet file already exists for Eartha Kitt, skipping...
# Parquet file already exists for The Dandy Warhols, skipping...
# Parquet file already exists for Shawn Mendes, skipping...
# Parquet file already exists for Misha Mengelberg, skipping...
# Parquet file already exists for LeAnn Rimes, skipping...
# Parquet file already exists for Francesco Yates, skipping...
# Parquet file already exists for Mr. Airplane Man, skipping...
# Parquet file already exists for Kiya Juliet, skipping...
# Parquet file already exists for The Prettiots, skipping...
# Parquet file already exists for Mammoth Penguins, skipping...
# Parquet file already exists for Choking Victim, skipping...
# Parquet file already exists for Bun B, skipping...
# Parquet file already exists for Simply Red, skipping...
# Parquet file already exists for Lee Morgan, skipping...
# Parquet file already exists for Tommy Johnson, skipping...
# Parquet file already exists for Blancmange, skipping...
# Parquet file already exists for The Junipers, skipping...
# Parquet file already exists for 311, skipping...
# Parquet file already exists for Transvision Vamp, skipping...
# Parquet file already exists for The Wardlaw Brothers, skipping...
# Parquet file already exists for I.K. Dairo, skipping...
# Parquet file already exists for Billy Gilman, skipping...
# Parquet file already exists for Aesop Rock, skipping...
# Parquet file already exists for Good Charlotte, skipping...
# Parquet file already exists for Lakeside, skipping...
# Parquet file already exists for Wayman Tisdale, skipping...
# Parquet file already exists for IG Culture, skipping...
# Parquet file already exists for Vader, skipping...
# Parquet file already exists for Waka Flocka Flame, skipping...
# Parquet file already exists for Committed, skipping...
# Parquet file already exists for Death Trap City, skipping...
# Parquet file already exists for Leonie Pernet, skipping...
# Parquet file already exists for YAMANTAKA // SONIC TITAN, skipping...
# Parquet file already exists for Lil Bibby, skipping...
# Parquet file already exists for Doug Sahm, skipping...
# Parquet file already exists for In Her Own Words, skipping...
# Parquet file already exists for Blxst, skipping...
# Parquet file already exists for Frank Tedesso, skipping...
# Parquet file already exists for Ethel Waters, skipping...
# Parquet file already exists for W.C. Clark, skipping...
# Parquet file already exists for Mary Coughlan, skipping...
# Parquet file already exists for Gamma Ray, skipping...
# Parquet file already exists for Billy Nicholls, skipping...
# Parquet file already exists for Rebel MC, skipping...
# Parquet file already exists for The Nerves, skipping...
# Parquet file already exists for Straitjacket Fits, skipping...
# Parquet file already exists for Demetria McKinney, skipping...
# Parquet file already exists for Sophie Milman, skipping...
# Parquet file already exists for Primal Scream, skipping...
# Parquet file already exists for Brenda Lee, skipping...
# Parquet file already exists for The Communards, skipping...
# Parquet file already exists for Pip Proud, skipping...
# Parquet file already exists for R. Stevie Moore, skipping...
# Parquet file already exists for Great Plains, skipping...
# Parquet file already exists for Courtney Love, skipping...
# Parquet file already exists for The Muffs, skipping...
# Parquet file already exists for The Loud Family, skipping...
# Parquet file already exists for The Kinks, skipping...
# Parquet file already exists for Beefeater, skipping...
# Parquet file already exists for The Wallflowers, skipping...
# Parquet file already exists for Cowboy Mouth, skipping...
# Parquet file already exists for Ivory Joe Hunter, skipping...
# Parquet file already exists for Earl Sweatshirt, skipping...
# Parquet file already exists for Donald Fagen, skipping...
# Parquet file already exists for It's A Beautiful Day, skipping...
# Parquet file already exists for Greie Gut Fraktion, skipping...
# Parquet file already exists for David Gray, skipping...
# Parquet file already exists for Jane Kelly Williams, skipping...
# Parquet file already exists for Exploding Star Orchestra, skipping...
# Parquet file already exists for Symarip, skipping...
# Parquet file already exists for Captain Sinbad, skipping...
# Parquet file already exists for Soilent Green, skipping...
# Parquet file already exists for Commissioned, skipping...
# Parquet file already exists for Hank Snow, skipping...
# Parquet file already exists for The-Dream, skipping...
# Parquet file already exists for Sydney Wayser, skipping...
# Parquet file already exists for MSTRKRFT, skipping...
# Parquet file already exists for Doctor Clayton, skipping...
# Parquet file already exists for Bud Shank, skipping...
# Parquet file already exists for Sleepy LaBeef, skipping...
# Parquet file already exists for Fats Waller, skipping...
# Parquet file already exists for Tony Rice, skipping...
# Parquet file already exists for Betty Davis, skipping...
# Parquet file already exists for Larry Jon Wilson, skipping...
# Parquet file already exists for Redd Kross, skipping...
# Parquet file already exists for Jim Croce, skipping...
# Parquet file already exists for Refused, skipping...
# Parquet file already exists for Roy Hall, skipping...
# Parquet file already exists for The Dramatics, skipping...
# Parquet file already exists for Hieroglyphics, skipping...
# Parquet file already exists for J Mascis, skipping...
# Parquet file already exists for Angelic Upstarts, skipping...
# Parquet file already exists for Leftover Salmon, skipping...
# Parquet file already exists for Toninho Horta, skipping...
# Parquet file already exists for SWV, skipping...
# Parquet file already exists for Candy Dulfer, skipping...
# Parquet file already exists for DJ Premier, skipping...
# Parquet file already exists for Delta Spirit, skipping...
# Parquet file already exists for Doctor Ross, skipping...
# Parquet file already exists for Warren Zevon, skipping...
# Parquet file already exists for Uncle Kracker, skipping...
# Parquet file already exists for Vance Joy, skipping...
# Parquet file already exists for G. Dep, skipping...
# Parquet file already exists for Kurt Rosenwinkel, skipping...
# Parquet file already exists for Visage, skipping...
# Parquet file already exists for Jerry Vale, skipping...
# Parquet file already exists for Laurel Halo, skipping...
# Parquet file already exists for Jordyn Jones, skipping...
# Parquet file already exists for The Accidentals, skipping...
# Parquet file already exists for Richard Pryor, skipping...
# Parquet file already exists for Clinic, skipping...
# Parquet file already exists for The Statler Brothers, skipping...
# Parquet file already exists for The Dead C, skipping...
# Parquet file already exists for Gonzalo Rubalcaba, skipping...
# Parquet file already exists for Hearts and Flowers, skipping...
# Parquet file already exists for Otis Blackwell, skipping...
# Parquet file already exists for Egg Hunt, skipping...
# Parquet file already exists for The Wrights, skipping...
# Parquet file already exists for The Pink Spiders, skipping...
# Parquet file already exists for The Corrs, skipping...
# Parquet file already exists for David Wilcox, skipping...
# Parquet file already exists for G-Eazy, skipping...
# Parquet file already exists for Spanky & Our Gang, skipping...
# Parquet file already exists for N.O.R.E., skipping...
# Parquet file already exists for Mark Lindsay, skipping...
# Parquet file already exists for Information Society, skipping...
# Parquet file already exists for Michael Penn, skipping...
# Parquet file already exists for Dr. Dog, skipping...
# Parquet file already exists for Lawrence Welk, skipping...
# Parquet file already exists for Ida Maria, skipping...
# Parquet file already exists for Dungen, skipping...
# Parquet file already exists for Gloria Jones, skipping...
# Parquet file already exists for Robbie Craig, skipping...
# Parquet file already exists for Sham 69, skipping...
# Parquet file already exists for Billy Joel, skipping...
# Parquet file already exists for Phil Alvin, skipping...
# Parquet file already exists for Regina Spektor, skipping...
# Parquet file already exists for Harry Styles, skipping...
# Parquet file already exists for Israel Vibration, skipping...
# Parquet file already exists for Yazoo, skipping...
# Parquet file already exists for Lady Leshurr, skipping...
# Parquet file already exists for Chris Impellitteri, skipping...
# Completed processing all artists.

# %%
# max_retries = 3
# retry_counter = 0

# while not failed_requests.empty and retry_counter < max_retries:
#     print(f"Retrying failed requests (attempt {retry_counter + 1}/{max_retries})...")
#     retry_failed_requests = pd.DataFrame(columns=["Spotify ID"])
#     for _, row in failed_requests.iterrows():
#         artist_id = row["Spotify ID"]
#         artist_name = artist_ids[artist_id]
#         sanitized_artist_name = sanitize_filename(artist_name)
#         parquet_file_path = f'{sanitized_artist_name}_tracks.parquet'

#         if os.path.exists(parquet_file_path):
#             print(f"Parquet file already exists for {artist_name}, skipping...")
#             continue
#         try:
#             refreshed_token, new_token_start_time = refresh_token(token_start_time)
#             if refreshed_token:
#                 token = refreshed_token
#                 token_start_time = new_token_start_time
#             albums = get_albums_for_artist(token, artist_id)

#             if albums is None:
#                 failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
#                 save_failed_requests(failed_requests)
#                 continue

#             album_df = pd.DataFrame.from_dict(albums, orient="index")
#             album_df.index.name = "album_name"

#             all_tracks_df = pd.DataFrame()
#             for album_id in tqdm(album_df['album_id'], desc=f"Processing {artist_name}"):
#                 time.sleep(1)
#                 try:
#                     tracks = get_tracks_for_album(token, album_id)

#                     if tracks is None:
#                         failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
#                         save_failed_requests(failed_requests)
#                         continue

#                     tracks = pd.DataFrame(tracks)
#                     tracks['album_id'] = album_id
#                     all_tracks_df = pd.concat([all_tracks_df, tracks], axis=0)
#                 except Exception as e:
#                     print(f"Warning: Error fetching tracks for {artist_name}: {e}")

#             try:
#                 af_df = get_audio_features(token, all_tracks_df['track_id'].tolist())
#                 af_df = af_df.rename(columns={'id': 'track_id'})
#                 all_aftracks_df = pd.merge(all_tracks_df, af_df, on='track_id')
#                 album_all_aftracks_df = pd.merge(album_df, all_aftracks_df, on='album_id')
#                 sanitized_artist_name = sanitize_filename(artist_name)
#                 album_all_aftracks_df.to_parquet(f'{sanitized_artist_name}_tracks.parquet')

#                 save_checkpoint(artist_id, artist_name)
#             except Exception as e:
#                 print(f"Warning: Error fetching audio features for {artist_name}: {e}")

#             iteration_counter += 1
#             if iteration_counter % sleep_interval == 0:
#                 time.sleep(1)

#         except Exception as e:
#             print(f"Error processing {artist_name}: {e}")
#             retry_failed_requests = retry_failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)

#     failed_requests = retry_failed_requests
#     retry_counter += 1

# if not failed_requests.empty:
#     print("Some requests still failed after all retries:")
#     print(failed_requests)
# else:
#     print("All failed requests have been successfully processed.")
