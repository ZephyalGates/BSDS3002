# %%
import os
import base64
import requests
from requests import post, get
import json
from tqdm import tqdm
import pandas as pd
import time
import math
import re

# %%
client_credentials = [
('e136636f77fe48d0982f3a8f5d204b32', '19f6e82af81749f1af49cff026f5132d'),
('a6ca26208aa64a939b97a239c5279bc5', 'f8ba0c2abc5145019ba929889fc09269'),
('c98b1397fe4749e79643d9a975b66eeb', '5b5c9c7b9ecb4060b09aefd9991718a7'),
('ce1557f37c8d4244ae40059131038262', 'e7ceb3e3e8ad426b96042bc2981a6523'),
('a556e9f4b5ef43148adb16b4f5cba16e', '846713a241dd49faabf03af9ac39261d'),
('a260d39b823949acb2299876cdc65ff1', '298a323f4b4049e6b28324c293c4313b'),
('0a2e08d86f8a48f380be70525158adcb', '26efcd1345e54fc1bc000afb4c06f68d'),
('3934951e08bd40fbab0ad9bd149b85b0', '5bdc62e55eee43288ee15e74405d6f36'),
('486e9c9f9acf4c0f82a1afb951c8b71f', '611a5716769545be9ea9c88d05ef6c4b'),
('5001ca2352ed4a7fbb1ee247f61c0679', '6aa6c81185f74e5fa0f8e09c50c133f3')
]

credential_index = 0

def get_token(client_id, client_secret):
    auth_string = client_id + ":" + client_secret
    auth_bytes = auth_string.encode("utf-8")
    auth_base64 = str(base64.b64encode(auth_bytes), "utf-8")

    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": "Basic " + auth_base64,
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"grant_type": "client_credentials"}

    response = requests.post(url, headers=headers, data=data)
    json_result = json.loads(response.content)

    if "access_token" in json_result:
        token = json_result["access_token"]
        return token
    else:
        print("Error: Failed to get access token")
        print(json_result)
        return None

def get_auth_header(token):
    return {"Authorization": "Bearer " + token}

def get_albums_for_artist(token, artist_id):
    url = f"https://api.spotify.com/v1/artists/{artist_id}/albums"
    headers = get_auth_header(token)
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        albums = json.loads(response.text)["items"]
        album_dict = {}
        for album in albums:
            album_id = album["id"]
            album_name = album["name"]
            album_tracks = album["total_tracks"]
            album_type = album["album_type"]
            album_release_date = album["release_date"]
            album_artists = [artist["name"] for artist in album["artists"]]
            album_images = album["images"]

            if album_name in album_dict:
                existing_tracks = album_dict[album_name]["total_tracks"]
                if album_tracks > existing_tracks:
                    album_dict[album_name] = {
                        "album_id": album_id,
                        "album_name": album_name,
                        "total_tracks": album_tracks,
                        "album_type": album_type,
                        "release_date": album_release_date,
                        "artists": album_artists,
                        "images": album_images
                    }
            else:
                album_dict[album_name] = {
                    "album_id": album_id,
                    "album_name": album_name,
                    "total_tracks": album_tracks,
                    "album_type": album_type,
                    "release_date": album_release_date,
                    "artists": album_artists,
                    "images": album_images
                }
        return album_dict
    else:
        print("Error: Failed to get albums for artist")
        print(response.content)
        return None
    
def get_tracks_for_album(token, album_id):
    url = f"https://api.spotify.com/v1/albums/{album_id}/tracks"
    headers = get_auth_header(token)
    params = {"market": "US"}
    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        tracks = json.loads(response.text)["items"]
        track_list = []
        for track in tracks:
            track_name = track["name"]
            track_id = track["id"]
            track_number = track["track_number"]
            track_explicit = track["explicit"]
            track_artists = [artist["name"] for artist in track["artists"]]
            track_dict = {
                "track_name": track_name,
                "track_id": track_id,
                "track_number": track_number,
                "track_explicit": track_explicit,
                "track_artists": track_artists,
            }
            track_list.append(track_dict)
        return track_list
    else:
        print("Error: Failed to get tracks for album")
        print(response.content)
        return None

# def get_audio_features(token, track_ids):
#     headers = {"Authorization": f"Bearer {token}"}
#     url = "https://api.spotify.com/v1/audio-features"
    
#     id_chunks = [track_ids[i:i+100] for i in range(0, len(track_ids), 100)]
    
#     dfs = []
#     for chunk in id_chunks:
#         params = {"ids": ",".join(chunk)}
#         response = requests.get(url, headers=headers, params=params)
#         data = response.json()["audio_features"]
#         features = pd.DataFrame(data)
#         features = features.drop(["type", "uri", "track_href", "analysis_url"], axis=1)
#         dfs.append(features)
    
#     features = pd.concat(dfs, ignore_index=True)
#     return features

def get_audio_features(token, track_ids):
    audio_features = []

    for i in range(0, len(track_ids), 50):
        chunk = track_ids[i:i + 50]
        ids = ','.join(chunk)
        url = f"https://api.spotify.com/v1/audio-features?ids={ids}"
        headers = {"Authorization": f"Bearer {token}"}
        r = requests.get(url, headers=headers)
        if r.status_code != 200:
            print(f"Error getting audio features for tracks: {r.status_code}")
            return None

        try:
            features = r.json()["audio_features"]
        except KeyError:
            features = []

        audio_features.extend(features)

    audio_features_filtered = []
    for feature in audio_features:
        if feature is not None:
            audio_features_filtered.append(feature)

    return pd.DataFrame(audio_features_filtered)



def load_checkpoint():
    if os.path.exists('checkpoint_8.json'):
        with open('checkpoint_8.json', 'r') as f:
            return json.load(f)
    else:
        return {"artist_id": "", "progress": 0}

def save_checkpoint(artist_id, progress):
    with open('checkpoint_8.json', 'w') as f:
        json.dump({"artist_id": artist_id, "progress": progress}, f)

def load_failed_requests():
    if os.path.exists('failed_requests_8.parquet'):
        return pd.read_parquet('failed_requests_8.parquet')
    else:
        return pd.DataFrame(columns=['Spotify ID'])

def save_failed_requests(df):
    df.to_parquet('failed_requests_8.parquet')

def refresh_token(token_start_time):
    global credential_index
    current_time = time.time()
    elapsed_time = current_time - token_start_time
    if elapsed_time >= 1800:
        credential_index = (credential_index + 1) % len(client_credentials)
        client_id, client_secret = client_credentials[credential_index]
        return get_token(client_id, client_secret), current_time
    return None, token_start_time

def sanitize_filename(filename):
    return re.sub(r'[\\/:"*?<>|]+', '_', filename)

# %%
with open('artist_ids_sub_dict_8.json', 'r') as f:
    artist_ids = json.load(f)
len(artist_ids)
# Out:
# 1010

# %%
token = get_token(client_credentials[0][0], client_credentials[0][1])
token_start_time = time.time()

checkpoint = load_checkpoint()
failed_requests = load_failed_requests()

start_from = checkpoint["artist_id"] if checkpoint["artist_id"] else list(artist_ids.keys())[0]
start_index = list(artist_ids.keys()).index(start_from)


iteration_counter = 0
sleep_interval = 50

for artist_id, artist_name in list(artist_ids.items())[start_index:]:
    try:
        refreshed_token, new_token_start_time = refresh_token(token_start_time)
        if refreshed_token:
            token = refreshed_token
            token_start_time = new_token_start_time

        albums = get_albums_for_artist(token, artist_id)

        if albums is None:
            failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
            save_failed_requests(failed_requests)
            continue

        album_df = pd.DataFrame.from_dict(albums, orient="index")
        album_df.index.name = "album_name"

        all_tracks_df = pd.DataFrame()
        for album_id in tqdm(album_df['album_id'], desc=f"Processing {artist_name}"):
            time.sleep(1)
            tracks = get_tracks_for_album(token, album_id)
            if tracks is None:
                failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
                save_failed_requests(failed_requests)
                continue

            tracks = pd.DataFrame(tracks)
            tracks['album_id'] = album_id
            all_tracks_df = pd.concat([all_tracks_df, tracks], axis=0)

        af_df = get_audio_features(token, all_tracks_df['track_id'].tolist())
        af_df = af_df.rename(columns={'id': 'track_id'})
        all_aftracks_df = pd.merge(all_tracks_df, af_df, on='track_id')
        album_all_aftracks_df = pd.merge(album_df, all_aftracks_df, on='album_id')
        sanitized_artist_name = sanitize_filename(artist_name)
        album_all_aftracks_df.to_parquet(f'results/{sanitized_artist_name}_tracks.parquet')

        save_checkpoint(artist_id, artist_name)
        iteration_counter += 1
        if iteration_counter % sleep_interval == 0:
            time.sleep(10)
            
    except Exception as e:
        print(f"Error processing {artist_name}: {e}")
        failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
        save_failed_requests(failed_requests)
        continue

print("Completed processing all artists.")
# Out:
# Processing Michel Camilo: 100%|██████████| 15/15 [00:16<00:00,  1.12s/it]
# Processing Slim Thug: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing Mansun: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# Processing Carl Cox: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing Rob Mazurek: 100%|██████████| 15/15 [00:16<00:00,  1.12s/it]
# Processing Clara Ponty: 100%|██████████| 7/7 [00:07<00:00,  1.13s/it]
# Processing KMFDM: 100%|██████████| 13/13 [00:14<00:00,  1.13s/it]
# Processing Bruce Robison: 100%|██████████| 12/12 [00:13<00:00,  1.12s/it]
# Processing Godflesh: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing Scott Walker: 100%|██████████| 12/12 [00:13<00:00,  1.09s/it]
# Processing The Dodos: 100%|██████████| 9/9 [00:10<00:00,  1.12s/it]
# Processing Northern State: 100%|██████████| 5/5 [00:05<00:00,  1.14s/it]
# Processing Fuel: 100%|██████████| 8/8 [00:08<00:00,  1.11s/it]
# Processing Ultramarine: 100%|██████████| 8/8 [00:08<00:00,  1.12s/it]
# Processing Red Animal War: 100%|██████████| 3/3 [00:03<00:00,  1.13s/it]
# Processing Sheppard: 100%|██████████| 4/4 [00:04<00:00,  1.11s/it]
# Processing Bonnie Tyler: 100%|██████████| 14/14 [00:15<00:00,  1.13s/it]
# Processing The Sword: 100%|██████████| 10/10 [00:11<00:00,  1.12s/it]
# Processing Freda Payne: 100%|██████████| 13/13 [00:14<00:00,  1.12s/it]
# Processing Ayo Jay: 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]
# Processing Oneohtrix Point Never: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing Angelo Badalamenti: 100%|██████████| 17/17 [00:19<00:00,  1.12s/it]
# Processing The Delta 72: 100%|██████████| 3/3 [00:03<00:00,  1.12s/it]
# Processing Bobby Vinton: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Luciana Souza:   0%|          | 0/13 [00:00<?, ?it/s]
# Error processing Keith James: 'album_id'
# Processing Luciana Souza: 100%|██████████| 13/13 [00:14<00:00,  1.12s/it]
# Processing Junior Boys: 100%|██████████| 6/6 [00:06<00:00,  1.12s/it]
# Processing Mr. Oizo: 100%|██████████| 11/11 [00:12<00:00,  1.10s/it]
# Processing Ty Tabor: 100%|██████████| 7/7 [00:07<00:00,  1.12s/it]
# Processing Hayley Williams: 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Processing The Zutons: 100%|██████████| 4/4 [00:04<00:00,  1.10s/it]
# Processing Quarterflash: 100%|██████████| 4/4 [00:04<00:00,  1.10s/it]
# Processing Nathan Cavaleri: 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]
# Processing Praxis: 100%|██████████| 9/9 [00:10<00:00,  1.12s/it]
# Processing King Jammy: 100%|██████████| 12/12 [00:13<00:00,  1.12s/it]
# Processing Didjits: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
# Processing Vanessa Bell Armstrong: 100%|██████████| 10/10 [00:11<00:00,  1.13s/it]
# Processing Total: 100%|██████████| 2/2 [00:02<00:00,  1.11s/it]
# Processing XO-IQ: 100%|██████████| 6/6 [00:06<00:00,  1.12s/it]
# Processing RZA: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing Al Martino: 100%|██████████| 20/20 [00:22<00:00,  1.13s/it]
# Processing Goatwhore:   0%|          | 0/9 [00:00<?, ?it/s]
# Error processing David Massengill: 'album_id'
# Error processing Crescent City Maulers: 'album_id'
# Processing Goatwhore: 100%|██████████| 9/9 [00:09<00:00,  1.11s/it]
# Processing Liquor Giants: 100%|██████████| 3/3 [00:03<00:00,  1.14s/it]
# Processing Mamie Smith: 100%|██████████| 17/17 [00:19<00:00,  1.14s/it]
# Processing Barney Bigard: 100%|██████████| 20/20 [00:23<00:00,  1.15s/it]
# Processing Duffy: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Processing Adam Torres: 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Processing Dennis Miller: 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Processing Don Drummond: 100%|██████████| 9/9 [00:10<00:00,  1.13s/it]
# Processing Senseless Things: 100%|██████████| 3/3 [00:03<00:00,  1.13s/it]
# Processing Richard Bona: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# Processing Rotary Connection: 100%|██████████| 6/6 [00:06<00:00,  1.12s/it]
# Processing I, Ludicrous: 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Processing James Chance & The Contortions: 100%|██████████| 5/5 [00:05<00:00,  1.13s/it]
# Processing Leoš Janáček: 100%|██████████| 15/15 [00:16<00:00,  1.13s/it]
# Processing Aicha Kone: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
# Processing Sébastien Tellier: 100%|██████████| 15/15 [00:16<00:00,  1.12s/it]
# Processing The New Deal: 100%|██████████| 9/9 [00:10<00:00,  1.12s/it]
# Processing Young Knives: 100%|██████████| 9/9 [00:10<00:00,  1.13s/it]
# Processing Strange Fruit Project: 100%|██████████| 6/6 [00:06<00:00,  1.11s/it]
# Processing Bert Kaempfert: 100%|██████████| 20/20 [00:22<00:00,  1.13s/it]
# Processing The Roberta Martin Singers: 100%|██████████| 13/13 [00:14<00:00,  1.13s/it]
# Processing Markéta Irglová: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
# Processing The Third Eye Foundation: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
# Processing Eddie Henderson: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing Benoît Pioulard: 100%|██████████| 19/19 [00:20<00:00,  1.10s/it]
# Processing The Pied Pipers: 100%|██████████| 18/18 [00:20<00:00,  1.13s/it]
# Processing Mike Viola: 100%|██████████| 8/8 [00:09<00:00,  1.13s/it]
# Processing Pat Travers Band: 100%|██████████| 5/5 [00:05<00:00,  1.14s/it]
# Processing Black Star: 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]
# Processing The Williams Brothers: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Ill Niño: 100%|██████████| 11/11 [00:12<00:00,  1.11s/it]
# Processing Brigitte Bardot: 100%|██████████| 17/17 [00:19<00:00,  1.12s/it]
# Processing Mark Morrison: 100%|██████████| 8/8 [00:08<00:00,  1.10s/it]
# Processing Blu Cantrell: 100%|██████████| 3/3 [00:03<00:00,  1.11s/it]
# Processing Lionel Hampton: 100%|██████████| 18/18 [00:20<00:00,  1.14s/it]
# Processing The Fall of Troy: 100%|██████████| 10/10 [00:10<00:00,  1.10s/it]
# Processing Robert Randolph & The Family Band: 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]
# Processing Sonny Boy Williamson II: 100%|██████████| 19/19 [00:21<00:00,  1.14s/it]
# Processing Gene Vincent: 100%|██████████| 3/3 [00:03<00:00,  1.11s/it]
# Processing Zuco 103: 100%|██████████| 9/9 [00:10<00:00,  1.13s/it]
# Processing Ike Turner: 100%|██████████| 17/17 [00:19<00:00,  1.15s/it]
# Processing Billy May: 100%|██████████| 20/20 [00:22<00:00,  1.15s/it]
# Processing Ray Noble: 100%|██████████| 20/20 [00:22<00:00,  1.14s/it]
# Processing Les Brown: 100%|██████████| 20/20 [00:22<00:00,  1.14s/it]
# Processing Dub Pistols: 100%|██████████| 15/15 [00:16<00:00,  1.12s/it]
# Processing The Gibson Brothers: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# Processing Richard Marx: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing Shane MacGowan: 100%|██████████| 3/3 [00:03<00:00,  1.10s/it]
# Processing Steve Harley & Cockney Rebel: 100%|██████████| 9/9 [00:09<00:00,  1.11s/it]
# Processing Woody Herman: 100%|██████████| 20/20 [00:22<00:00,  1.14s/it]
# Processing Kay Kyser:  46%|████▌     | 6/13 [00:06<00:07,  1.13s/it]
# Error: Failed to get tracks for album
# b'{\n  "error" : {\n    "status" : 404,\n    "message" : "Non existing id: \'6RwtslgAmWXpdZDmFNfyql\'"\n  }\n}'
# Processing Kay Kyser: 100%|██████████| 13/13 [00:14<00:00,  1.14s/it]
# Processing Don Cornell: 100%|██████████| 18/18 [00:20<00:00,  1.15s/it]
# Processing Kool & The Gang: 100%|██████████| 20/20 [00:21<00:00,  1.10s/it]
# Processing Count Ossie: 100%|██████████| 1/1 [00:01<00:00,  1.16s/it]
# Processing Dean Wareham: 100%|██████████| 4/4 [00:04<00:00,  1.13s/it]
# Processing Bill Monroe: 100%|██████████| 20/20 [00:22<00:00,  1.15s/it]
# Processing Merle Haggard: 100%|██████████| 19/19 [00:21<00:00,  1.12s/it]
# Processing Adolescents:   0%|          | 0/10 [00:00<?, ?it/s]
# Error processing Heather Maloney: 'album_id'
# Processing Adolescents: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# Processing The Popguns: 100%|██████████| 7/7 [00:07<00:00,  1.13s/it]
# Processing Gossip: 100%|██████████| 13/13 [00:14<00:00,  1.12s/it]
# Processing µ-Ziq: 100%|██████████| 8/8 [00:08<00:00,  1.12s/it]
# Processing will.i.am: 100%|██████████| 7/7 [00:07<00:00,  1.11s/it]
# Processing of Montreal: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing bob hund: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing blink-182: 100%|██████████| 11/11 [00:12<00:00,  1.10s/it]
# Processing a-ha: 100%|██████████| 18/18 [00:19<00:00,  1.11s/it]
# Processing Zion & Lennox: 100%|██████████| 6/6 [00:06<00:00,  1.11s/it]
# Processing Zac Brown Band:   0%|          | 0/10 [00:00<?, ?it/s]
# Error processing Zack De La Rocha: 'album_id'
# Processing Zac Brown Band: 100%|██████████| 10/10 [00:11<00:00,  1.10s/it]
# Processing Z-Ro: 100%|██████████| 19/19 [00:21<00:00,  1.12s/it]
# Processing Yung Joc: 100%|██████████| 4/4 [00:04<00:00,  1.10s/it]
# Processing Young Buck: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing Yoko Ono: 100%|██████████| 18/18 [00:20<00:00,  1.12s/it]
# Processing Yesterday's New Quintet: 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Processing Yahzarah: 100%|██████████| 3/3 [00:03<00:00,  1.13s/it]
# Processing Yael Naim: 100%|██████████| 8/8 [00:08<00:00,  1.12s/it]
# Processing Xiu Xiu: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# Processing Xavier Cugat: 100%|██████████| 19/19 [00:21<00:00,  1.13s/it]
# Processing X-Ecutioners: 100%|██████████| 3/3 [00:03<00:00,  1.12s/it]
# Processing Wooden Wand: 100%|██████████| 13/13 [00:14<00:00,  1.13s/it]
# Processing Wisin & Yandel: 100%|██████████| 19/19 [00:21<00:00,  1.12s/it]
# Processing Wipers: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing Windy & Carl: 100%|██████████| 7/7 [00:07<00:00,  1.10s/it]
# Processing Willie Nelson: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing William Parker: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing Will Young: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing West, Bruce & Laing: 100%|██████████| 3/3 [00:03<00:00,  1.11s/it]
# Processing Wesley Willis: 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Processing Wes Montgomery: 100%|██████████| 18/18 [00:19<00:00,  1.11s/it]
# Processing Webb Pierce: 100%|██████████| 16/16 [00:18<00:00,  1.15s/it]
# Processing Wayne Fontana & The Mindbenders: 100%|██████████| 5/5 [00:05<00:00,  1.15s/it]
# Processing W.A.S.P.: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing Vybz Kartel: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Vicki Sue Robinson: 100%|██████████| 5/5 [00:05<00:00,  1.10s/it]
# Processing Vanessa Hudgens: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Processing Ursula Rucker: 100%|██████████| 4/4 [00:04<00:00,  1.13s/it]
# Processing Ultramagnetic MC's:   0%|          | 0/9 [00:00<?, ?it/s]
# Error processing Uncle Jamm's Army: 'album_id'
# Processing Ultramagnetic MC's: 100%|██████████| 9/9 [00:10<00:00,  1.11s/it]
# Processing Tyga: 100%|██████████| 17/17 [00:18<00:00,  1.10s/it]
# Processing Tye Tribbett: 100%|██████████| 8/8 [00:08<00:00,  1.11s/it]
# Processing Turning Point: 100%|██████████| 8/8 [00:08<00:00,  1.12s/it]
# Processing Trisha Yearwood: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# Processing Toro y Moi: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# Processing Too $hort: 100%|██████████| 18/18 [00:20<00:00,  1.11s/it]
# Processing Tony Orlando & Dawn: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# Processing Tony Bennett: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing Tony Allen: 100%|██████████| 15/15 [00:16<00:00,  1.10s/it]
# Processing Tommy Steele: 100%|██████████| 19/19 [00:21<00:00,  1.15s/it]
# Processing Tommy James & The Shondells: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# Processing Tommy Dorsey: 100%|██████████| 20/20 [00:22<00:00,  1.14s/it]
# Processing Tommy Bolin: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Tom Jones: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing TobyMac: 100%|██████████| 19/19 [00:20<00:00,  1.10s/it]
# Processing To Rococo Rot: 100%|██████████| 9/9 [00:10<00:00,  1.12s/it]
# Processing Tito Puente: 100%|██████████| 20/20 [00:22<00:00,  1.14s/it]
# Processing Tim O'Brien: 100%|██████████| 19/19 [00:21<00:00,  1.13s/it]
# Processing Three 6 Mafia: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing Theory of a Deadman: 100%|██████████| 11/11 [00:12<00:00,  1.12s/it]
# Processing Theoretical Girls: 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
# Processing Thelonious Monk: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing Thee Oh Sees: 100%|██████████| 20/20 [00:21<00:00,  1.10s/it]
# Processing Thee Mighty Caesars: 100%|██████████| 4/4 [00:04<00:00,  1.12s/it]
# Processing The Young Fresh Fellows: 100%|██████████| 10/10 [00:11<00:00,  1.14s/it]
# Processing The Weavers: 100%|██████████| 19/19 [00:21<00:00,  1.14s/it]
# Processing The Watersons: 100%|██████████| 7/7 [00:07<00:00,  1.14s/it]
# Processing The Warlocks: 100%|██████████| 13/13 [00:14<00:00,  1.12s/it]
# Processing The Vibrators: 100%|██████████| 19/19 [00:21<00:00,  1.14s/it]
# Processing The Vaselines: 100%|██████████| 3/3 [00:03<00:00,  1.12s/it]
# Processing The Untouchables: 100%|██████████| 12/12 [00:13<00:00,  1.13s/it]
# Processing The Untamed Youth: 100%|██████████| 2/2 [00:02<00:00,  1.14s/it]
# Processing The Undisputed Truth: 100%|██████████| 8/8 [00:08<00:00,  1.10s/it]
# Processing The Trashmen: 100%|██████████| 8/8 [00:09<00:00,  1.13s/it]
# Processing The Three O'Clock: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
# Processing The Three Degrees: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# Processing The Swan Silvertones: 100%|██████████| 19/19 [00:21<00:00,  1.14s/it]
# Processing The Sugarhill Gang: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# Processing The Streetwalkin' Cheetahs: 100%|██████████| 6/6 [00:06<00:00,  1.14s/it]
# Processing The Staple Singers: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing The Spinners: 100%|██████████| 20/20 [00:22<00:00,  1.10s/it]
# Processing The Spencer Davis Group: 100%|██████████| 19/19 [00:21<00:00,  1.12s/it]
# Processing The Spaniels: 100%|██████████| 20/20 [00:23<00:00,  1.16s/it]
# Processing The Soul Stirrers: 100%|██████████| 19/19 [00:21<00:00,  1.14s/it]
# Processing The Sonics: 100%|██████████| 11/11 [00:12<00:00,  1.11s/it]
# Processing The Selecter: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# Processing The Seldom Scene: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing The Rock-A-Teens: 100%|██████████| 4/4 [00:04<00:00,  1.13s/it]
# Processing The Righteous Brothers: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# Processing The Red Jumpsuit Apparatus: 100%|██████████| 7/7 [00:07<00:00,  1.10s/it]
# Processing The Raincoats: 100%|██████████| 5/5 [00:05<00:00,  1.10s/it]
# Processing The Quireboys: 100%|██████████| 17/17 [00:19<00:00,  1.13s/it]
# Processing The Pussycat Dolls: 100%|██████████| 3/3 [00:03<00:00,  1.12s/it]
# Processing The Postal Service: 100%|██████████| 3/3 [00:03<00:00,  1.10s/it]
# Processing The Polecats: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
# Processing The Pogues: 100%|██████████| 14/14 [00:15<00:00,  1.12s/it]
# Processing The Platters: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing The Paul Butterfield Blues Band: 100%|██████████| 17/17 [00:19<00:00,  1.12s/it]
# Processing The Paris Sisters: 100%|██████████| 13/13 [00:14<00:00,  1.13s/it]
# Processing The Outlaws: 100%|██████████| 18/18 [00:20<00:00,  1.12s/it]
# Processing The Orioles: 100%|██████████| 19/19 [00:21<00:00,  1.15s/it]
# Processing The Octopus Project: 100%|██████████| 9/9 [00:10<00:00,  1.12s/it]
# Processing The Oak Ridge Boys: 100%|██████████| 17/17 [00:19<00:00,  1.14s/it]
# Processing The Mountain Goats: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing The Motels: 100%|██████████| 11/11 [00:12<00:00,  1.11s/it]
# Processing The Monotones: 100%|██████████| 9/9 [00:10<00:00,  1.13s/it]
# Processing The Modern Lovers: 100%|██████████| 7/7 [00:07<00:00,  1.11s/it]
# Processing The Mills Brothers: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing The Milkshakes: 100%|██████████| 11/11 [00:12<00:00,  1.13s/it]
# Processing The Mighty Mighty Bosstones: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing The Marked Men: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
# Processing The Manhattan Transfer: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing The Lounge Lizards: 100%|██████████| 7/7 [00:07<00:00,  1.11s/it]
# Processing The Lotus Eaters: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
# Processing The Lightning Seeds: 100%|██████████| 13/13 [00:14<00:00,  1.12s/it]
# Processing The Lettermen: 100%|██████████| 19/19 [00:21<00:00,  1.12s/it]
# Processing The Legendary Pink Dots: 100%|██████████| 20/20 [00:22<00:00,  1.13s/it]
# Processing The Kingston Trio: 100%|██████████| 20/20 [00:22<00:00,  1.13s/it]
# Processing The Jon Spencer Blues Explosion: 100%|██████████| 14/14 [00:16<00:00,  1.15s/it]
# Processing The Jive Five: 100%|██████████| 14/14 [00:15<00:00,  1.14s/it]
# Processing The Jesus and Mary Chain: 100%|██████████| 14/14 [00:15<00:00,  1.11s/it]
# Processing The Jazz Crusaders: 100%|██████████| 19/19 [00:21<00:00,  1.13s/it]
# Processing The Jackson 5: 100%|██████████| 17/17 [00:18<00:00,  1.10s/it]
# Processing The Ink Spots: 100%|██████████| 14/14 [00:15<00:00,  1.11s/it]
# Processing The Honeydogs: 100%|██████████| 10/10 [00:11<00:00,  1.13s/it]
# Processing The Holy Modal Rounders: 100%|██████████| 11/11 [00:12<00:00,  1.13s/it]
# Processing The Handsome Family:   0%|          | 0/6 [00:00<?, ?it/s]
# Error processing The Hang Ups: 'album_id'
# Processing The Handsome Family: 100%|██████████| 6/6 [00:06<00:00,  1.13s/it]
# Processing The Hacker: 100%|██████████| 9/9 [00:09<00:00,  1.11s/it]
# Processing The Gutter Twins: 100%|██████████| 2/2 [00:02<00:00,  1.09s/it]
# Processing The Gun Club: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing The Greenhornes: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
# Processing The Graham Bond Organisation: 100%|██████████| 3/3 [00:03<00:00,  1.14s/it]
# Processing The Good, the Bad & the Queen: 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Processing The Go-Go's: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# Processing The Go-Betweens: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing The Glitter Band: 100%|██████████| 10/10 [00:11<00:00,  1.14s/it]
# Processing The Georgia Satellites: 100%|██████████| 11/11 [00:12<00:00,  1.12s/it]
# Processing The Gaylads: 100%|██████████| 9/9 [00:10<00:00,  1.13s/it]
# Processing The Free Design: 100%|██████████| 12/12 [00:13<00:00,  1.12s/it]
# Processing The Four Tunes: 100%|██████████| 10/10 [00:11<00:00,  1.16s/it]
# Processing The Foundations: 100%|██████████| 7/7 [00:07<00:00,  1.11s/it]
# Processing The Fleshtones: 100%|██████████| 11/11 [00:12<00:00,  1.13s/it]
# Processing The Fixx: 100%|██████████| 12/12 [00:13<00:00,  1.12s/it]
# Processing The Five Stairsteps: 100%|██████████| 4/4 [00:04<00:00,  1.11s/it]
# Processing The Five Satins: 100%|██████████| 19/19 [00:21<00:00,  1.15s/it]
# Processing The Five Keys: 100%|██████████| 17/17 [00:19<00:00,  1.17s/it]
# Processing The Five Blind Boys Of Mississippi: 100%|██████████| 9/9 [00:10<00:00,  1.14s/it]
# Processing The Fairfield Four: 100%|██████████| 13/13 [00:14<00:00,  1.14s/it]
# Processing The Fabulous Thunderbirds: 100%|██████████| 14/14 [00:15<00:00,  1.13s/it]
# Processing The Exploited: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing The Everly Brothers: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing The Ethiopians: 100%|██████████| 15/15 [00:16<00:00,  1.12s/it]
# Processing The Emotions: 100%|██████████| 8/8 [00:08<00:00,  1.10s/it]
# Processing The Electric Flag: 100%|██████████| 13/13 [00:14<00:00,  1.14s/it]
# Processing The Easybeats: 100%|██████████| 13/13 [00:14<00:00,  1.12s/it]
# Processing The Durutti Column: 100%|██████████| 17/17 [00:18<00:00,  1.12s/it]
# Processing The Drifters: 100%|██████████| 19/19 [00:21<00:00,  1.13s/it]
# Processing The Dictators: 100%|██████████| 10/10 [00:11<00:00,  1.12s/it]
# Processing The Dickies: 100%|██████████| 14/14 [00:15<00:00,  1.12s/it]
# Processing The Deviants: 100%|██████████| 4/4 [00:04<00:00,  1.12s/it]
# Processing The Delmore Brothers: 100%|██████████| 20/20 [00:22<00:00,  1.15s/it]
# Processing The Del-Vikings: 100%|██████████| 19/19 [00:21<00:00,  1.14s/it]
# Processing The Dave Brubeck Quartet: 100%|██████████| 13/13 [00:14<00:00,  1.12s/it]
# Processing The D.O.C.: 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Processing The Crystals: 100%|██████████| 4/4 [00:04<00:00,  1.11s/it]
# Processing The Crusaders: 100%|██████████| 19/19 [00:20<00:00,  1.10s/it]
# Processing The Crazy World Of Arthur Brown: 100%|██████████| 8/8 [00:08<00:00,  1.12s/it]
# Processing The Cover Girls: 100%|██████████| 7/7 [00:07<00:00,  1.12s/it]
# Processing The Connells: 100%|██████████| 8/8 [00:08<00:00,  1.11s/it]
# Processing The Coasters: 100%|██████████| 7/7 [00:07<00:00,  1.14s/it]
# Processing The City On Film: 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Processing The Chinese Stars: 100%|██████████| 3/3 [00:03<00:00,  1.12s/it]
# Processing The Chambers Brothers: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing The Cascades: 100%|██████████| 4/4 [00:04<00:00,  1.11s/it]
# Processing The Carter Family: 100%|██████████| 18/18 [00:20<00:00,  1.14s/it]
# Processing The Bruisers: 100%|██████████| 7/7 [00:07<00:00,  1.12s/it]
# Processing The Brian Setzer Orchestra: 100%|██████████| 15/15 [00:17<00:00,  1.13s/it]
# Processing The Bouncing Souls: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing The Bobby Fuller Four: 100%|██████████| 4/4 [00:04<00:00,  1.13s/it]
# Processing The Blue Sky Boys: 100%|██████████| 20/20 [00:22<00:00,  1.15s/it]
# Processing The Blind Boys Of Alabama: 100%|██████████| 18/18 [00:20<00:00,  1.13s/it]
# Processing The Blackbyrds: 100%|██████████| 7/7 [00:07<00:00,  1.11s/it]
# Processing The Black Halos: 100%|██████████| 6/6 [00:06<00:00,  1.13s/it]
# Processing The Big Bopper: 100%|██████████| 11/11 [00:12<00:00,  1.15s/it]
# Processing The Bevis Frond: 100%|██████████| 18/18 [00:20<00:00,  1.13s/it]
# Processing The Bar-Kays: 100%|██████████| 14/14 [00:15<00:00,  1.12s/it]
# Processing The Bangles: 100%|██████████| 11/11 [00:12<00:00,  1.11s/it]
# Processing The Archies: 100%|██████████| 8/8 [00:08<00:00,  1.12s/it]
# Processing The Andrews Sisters: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing The Ames Brothers: 100%|██████████| 20/20 [00:22<00:00,  1.14s/it]
# Processing The Amboy Dukes: 100%|██████████| 11/11 [00:12<00:00,  1.12s/it]
# Processing The Alan Parsons Project: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing The Aislers Set: 100%|██████████| 4/4 [00:04<00:00,  1.12s/it]
# Processing The Abyssinians: 100%|██████████| 12/12 [00:13<00:00,  1.12s/it]
# Processing The "5" Royales: 100%|██████████| 20/20 [00:23<00:00,  1.16s/it]
# Processing Tex Ritter: 100%|██████████| 19/19 [00:21<00:00,  1.13s/it]
# Processing Tennessee Ernie Ford: 100%|██████████| 19/19 [00:21<00:00,  1.14s/it]
# Processing Tegan and Sara: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# Processing Teenage Fanclub: 100%|██████████| 11/11 [00:12<00:00,  1.12s/it]
# Processing Ted Leo and the Pharmacists: 100%|██████████| 7/7 [00:07<00:00,  1.11s/it]
# Processing Tech N9ne: 100%|██████████| 14/14 [00:15<00:00,  1.10s/it]
# Processing Tapes 'n Tapes: 100%|██████████| 4/4 [00:04<00:00,  1.11s/it]
# Processing Tammi Terrell: 100%|██████████| 7/7 [00:07<00:00,  1.11s/it]
# Processing Talib Kweli: 100%|██████████| 14/14 [00:15<00:00,  1.12s/it]
# Processing Taj Mahal: 100%|██████████| 18/18 [00:20<00:00,  1.11s/it]
# Processing Sérgio Mendes: 100%|██████████| 11/11 [00:12<00:00,  1.11s/it]
# Processing Supreme Beings of Leisure:   0%|          | 0/4 [00:00<?, ?it/s]
# Error processing Sweep the Leg Johnny: 'album_id'
# Processing Supreme Beings of Leisure: 100%|██████████| 4/4 [00:04<00:00,  1.10s/it]
# Processing Supersuckers: 100%|██████████| 12/12 [00:13<00:00,  1.13s/it]
# Processing Sun Ra: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Sugar Pie DeSanto: 100%|██████████| 10/10 [00:11<00:00,  1.13s/it]
# Processing Sugar Minott: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Styles P: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# Processing Stubborn All-Stars: 100%|██████████| 3/3 [00:03<00:00,  1.12s/it]
# Processing Stevie Ray Vaughan: 100%|██████████| 19/19 [00:20<00:00,  1.10s/it]
# Processing Stevie Nicks: 100%|██████████| 18/18 [00:19<00:00,  1.10s/it]
# Processing Steve Wynn: 100%|██████████| 11/11 [00:12<00:00,  1.14s/it]
# Processing Steve Wariner: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Steve Roach: 100%|██████████| 20/20 [00:22<00:00,  1.10s/it]
# Processing Steve Miller Band: 100%|██████████| 20/20 [00:22<00:00,  1.10s/it]
# Processing Steve Cropper: 100%|██████████| 7/7 [00:07<00:00,  1.11s/it]
# Processing Steve Coleman: 100%|██████████| 10/10 [00:11<00:00,  1.12s/it]
# Processing Stereo MC's: 100%|██████████| 9/9 [00:10<00:00,  1.12s/it]
# Processing Stephen Kellogg: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
# Processing Stephen Duffy: 100%|██████████| 9/9 [00:10<00:00,  1.14s/it]
# Processing Stanley Turrentine: 100%|██████████| 19/19 [00:21<00:00,  1.12s/it]
# Processing Stan Getz: 100%|██████████| 14/14 [00:15<00:00,  1.12s/it]
# Processing Split Lip Rayfield: 100%|██████████| 6/6 [00:06<00:00,  1.13s/it]
# Processing Spike Jones: 100%|██████████| 20/20 [00:22<00:00,  1.13s/it]
# Processing Spice 1: 100%|██████████| 19/19 [00:21<00:00,  1.13s/it]
# Processing Sonic Boom: 100%|██████████| 7/7 [00:07<00:00,  1.12s/it]
# Processing Songs: Ohia: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing Son By Four: 100%|██████████| 10/10 [00:11<00:00,  1.12s/it]
# Processing Small Faces: 100%|██████████| 17/17 [00:19<00:00,  1.12s/it]
# Processing Sly & The Family Stone: 100%|██████████| 17/17 [00:18<00:00,  1.10s/it]
# Processing Slim Gaillard: 100%|██████████| 17/17 [00:19<00:00,  1.15s/it]
# Processing Sleater-Kinney: 100%|██████████| 13/13 [00:14<00:00,  1.10s/it]
# Processing Skeeter Davis: 100%|██████████| 17/17 [00:19<00:00,  1.13s/it]
# Processing Siouxsie and the Banshees: 100%|██████████| 15/15 [00:16<00:00,  1.10s/it]
# Processing Silkk The Shocker: 100%|██████████| 7/7 [00:07<00:00,  1.11s/it]
# Processing Sigur Rós: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# Processing Sidney Bechet: 100%|██████████| 18/18 [00:20<00:00,  1.12s/it]
# Processing Shirley Bassey: 100%|██████████| 18/18 [00:19<00:00,  1.10s/it]
# Processing Selena Gomez: 100%|██████████| 7/7 [00:07<00:00,  1.10s/it]
# Processing Sean Paul: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# Processing Sean Kingston: 100%|██████████| 4/4 [00:04<00:00,  1.10s/it]
# Processing Seamus Ennis: 100%|██████████| 5/5 [00:05<00:00,  1.13s/it]
# Processing Screamin' Jay Hawkins: 100%|██████████| 19/19 [00:21<00:00,  1.13s/it]
# Processing Sarah Vaughan: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Sarah Brightman: 100%|██████████| 11/11 [00:12<00:00,  1.11s/it]
# Processing Sarabeth Tucek: 100%|██████████| 2/2 [00:02<00:00,  1.11s/it]
# Processing S Club 7: 100%|██████████| 5/5 [00:05<00:00,  1.10s/it]
# Processing Ryan Adams: 100%|██████████| 15/15 [00:16<00:00,  1.10s/it]
# Processing Ry Cooder: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing Rufus Wainwright: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing Rubén Blades: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing RuPaul: 100%|██████████| 20/20 [00:22<00:00,  1.10s/it]
# Processing Roy Acuff: 100%|██████████| 18/18 [00:20<00:00,  1.15s/it]
# Processing Ronnie Earl: 100%|██████████| 9/9 [00:10<00:00,  1.11s/it]
# Processing Roni Size: 100%|██████████| 9/9 [00:10<00:00,  1.12s/it]
# Processing Roky Erickson: 100%|██████████| 10/10 [00:11<00:00,  1.12s/it]
# Processing Roger Sanchez: 100%|██████████| 9/9 [00:10<00:00,  1.12s/it]
# Processing Rodney Crowell: 100%|██████████| 18/18 [00:20<00:00,  1.12s/it]
# Processing Rod Stewart: 100%|██████████| 14/14 [00:15<00:00,  1.11s/it]
# Processing Rod Piazza: 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Processing Robyn Hitchcock: 100%|██████████| 11/11 [00:12<00:00,  1.13s/it]
# Processing Roberta Flack: 100%|██████████| 18/18 [00:20<00:00,  1.11s/it]
# Processing Robert Rich: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Robert Plant: 100%|██████████| 17/17 [00:18<00:00,  1.10s/it]
# Processing Robert Nighthawk: 100%|██████████| 18/18 [00:20<00:00,  1.16s/it]
# Processing Robert Glasper: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# Processing Robbie Williams: 100%|██████████| 13/13 [00:14<00:00,  1.10s/it]
# Processing Robben Ford: 100%|██████████| 8/8 [00:08<00:00,  1.12s/it]
# Processing Ricky Skaggs: 100%|██████████| 18/18 [00:19<00:00,  1.11s/it]
# Processing Ricky Martin: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing Rick Braun: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing Richard Clayderman: 100%|██████████| 18/18 [00:19<00:00,  1.11s/it]
# Processing Richard "Groove" Holmes: 100%|██████████| 18/18 [00:20<00:00,  1.12s/it]
# Processing Rev. Gary Davis: 100%|██████████| 17/17 [00:19<00:00,  1.14s/it]
# Processing Ray Price: 100%|██████████| 18/18 [00:20<00:00,  1.15s/it]
# Processing Ray Parker Jr.: 100%|██████████| 7/7 [00:07<00:00,  1.10s/it]
# Processing Ray J: 100%|██████████| 11/11 [00:12<00:00,  1.10s/it]
# Processing Ray Conniff: 100%|██████████| 17/17 [00:19<00:00,  1.12s/it]
# Processing Ray Charles: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Ray Barretto: 100%|██████████| 19/19 [00:21<00:00,  1.13s/it]
# Processing Ravi Shankar: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing Randy VanWarmer: 100%|██████████| 10/10 [00:11<00:00,  1.12s/it]
# Processing Randy Newman: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Randy Crawford: 100%|██████████| 19/19 [00:20<00:00,  1.10s/it]
# Processing Ramsey Lewis: 100%|██████████| 19/19 [00:21<00:00,  1.12s/it]
# Processing Ramones: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing Ralph Stanley: 100%|██████████| 19/19 [00:21<00:00,  1.12s/it]
# Processing Raheem DeVaughn: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing Rah Digga: 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Processing R.L. Burnside: 100%|██████████| 13/13 [00:14<00:00,  1.12s/it]
# Processing Quincy Jones: 100%|██████████| 10/10 [00:11<00:00,  1.14s/it]
# Processing Queens of the Stone Age: 100%|██████████| 10/10 [00:11<00:00,  1.10s/it]
# Processing Public Image Ltd.: 100%|██████████| 18/18 [00:19<00:00,  1.11s/it]
# Processing Primal Fear: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing Porter Wagoner: 100%|██████████| 17/17 [00:19<00:00,  1.14s/it]
# Processing Plácido Domingo: 100%|██████████| 18/18 [00:20<00:00,  1.14s/it]
# Processing Plasmatics: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# Processing Plain White T's: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# Processing Pinetop Smith: 100%|██████████| 4/4 [00:04<00:00,  1.14s/it]
# Processing Pharoahe Monch: 100%|██████████| 5/5 [00:05<00:00,  1.10s/it]
# Processing Petula Clark: 100%|██████████| 18/18 [00:20<00:00,  1.13s/it]
# Processing Peter Tosh: 100%|██████████| 18/18 [00:19<00:00,  1.11s/it]
# Processing Peter Holsapple: 100%|██████████| 4/4 [00:04<00:00,  1.13s/it]
# Processing Peter Hammill: 100%|██████████| 17/17 [00:19<00:00,  1.12s/it]
# Processing Peter Bjorn and John: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing Peter Bardens: 100%|██████████| 3/3 [00:03<00:00,  1.11s/it]
# Processing Pete Townshend: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing Pete Tong: 100%|██████████| 7/7 [00:07<00:00,  1.10s/it]
# Processing Pete Rock: 100%|██████████| 17/17 [00:18<00:00,  1.10s/it]
# Processing Pete Johnson: 100%|██████████| 20/20 [00:22<00:00,  1.15s/it]
# Processing Pet Shop Boys: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# Processing Perry Como: 100%|██████████| 18/18 [00:20<00:00,  1.12s/it]
# Processing Pernice Brothers: 100%|██████████| 8/8 [00:09<00:00,  1.13s/it]
# Processing Pee Wee Crayton: 100%|██████████| 18/18 [00:20<00:00,  1.14s/it]
# Processing Paulina Rubio: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing Paula Cole: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# Processing Paul van Dyk: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Paul Whiteman: 100%|██████████| 19/19 [00:21<00:00,  1.15s/it]
# Processing Paul Weller: 100%|██████████| 14/14 [00:15<00:00,  1.11s/it]
# Processing Paul Wall: 100%|██████████| 18/18 [00:19<00:00,  1.11s/it]
# Processing Paul Revere & The Raiders: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Paul Burch: 100%|██████████| 10/10 [00:11<00:00,  1.13s/it]
# Processing Patti Smith: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing Patsy Montana: 100%|██████████| 9/9 [00:10<00:00,  1.14s/it]
# Processing Pastor Troy: 100%|██████████| 20/20 [00:22<00:00,  1.14s/it]
# Processing Paint It Black: 100%|██████████| 3/3 [00:03<00:00,  1.11s/it]
# Processing P.O.D.: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing Otis Redding: 100%|██████████| 20/20 [00:21<00:00,  1.10s/it]
# Processing Ohio Players: 100%|██████████| 17/17 [00:18<00:00,  1.10s/it]
# Processing Of Mice & Men: 100%|██████████| 11/11 [00:12<00:00,  1.10s/it]
# Processing OK Go: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# Processing Nusrat Fateh Ali Khan: 100%|██████████| 20/20 [00:21<00:00,  1.10s/it]
# Processing Norman Connors: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Nils Petter Molvær: 100%|██████████| 14/14 [00:15<00:00,  1.11s/it]
# Processing Nikolai Rimsky-Korsakov: 100%|██████████| 15/15 [00:16<00:00,  1.12s/it]
# Processing Nicole Scherzinger: 100%|██████████| 3/3 [00:03<00:00,  1.10s/it]
# Processing Nick Jonas: 100%|██████████| 6/6 [00:06<00:00,  1.12s/it]
# Processing Nick Cave & The Bad Seeds: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing New York Dolls: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing Nels Cline: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing Nate Dogg:   0%|          | 0/14 [00:00<?, ?it/s]
# Error processing Neil Young: 'album_id'
# Processing Nate Dogg: 100%|██████████| 14/14 [00:15<00:00,  1.11s/it]
# Processing Natalie Cole: 100%|██████████| 18/18 [00:19<00:00,  1.11s/it]
# Processing Nat King Cole: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Mr. Vegas: 100%|██████████| 14/14 [00:15<00:00,  1.13s/it]
# Processing Mr. Scruff: 100%|██████████| 11/11 [00:12<00:00,  1.11s/it]
# Processing Moxy Früvous: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
# Processing Move D: 100%|██████████| 8/8 [00:08<00:00,  1.11s/it]
# Processing Mos Def: 100%|██████████| 6/6 [00:06<00:00,  1.11s/it]
# Processing Monchy & Alexandra: 100%|██████████| 13/13 [00:14<00:00,  1.12s/it]
# Processing Molly O'Day: 100%|██████████| 1/1 [00:01<00:00,  1.12s/it]
# Processing Mojo Nixon: 100%|██████████| 13/13 [00:14<00:00,  1.12s/it]
# Processing Moe Bandy: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Mnemic: 100%|██████████| 5/5 [00:05<00:00,  1.10s/it]
# Processing Mistah F.A.B.: 100%|██████████| 20/20 [00:22<00:00,  1.13s/it]
# Processing Missy Elliott: 100%|██████████| 7/7 [00:07<00:00,  1.10s/it]
# Processing Mississippi Fred McDowell: 100%|██████████| 14/14 [00:15<00:00,  1.13s/it]
# Processing Miss Kittin: 100%|██████████| 11/11 [00:12<00:00,  1.11s/it]
# Processing Misfits: 100%|██████████| 11/11 [00:12<00:00,  1.11s/it]
# Processing Minnie Riperton: 100%|██████████| 9/9 [00:09<00:00,  1.10s/it]
# Processing Miles Davis: 100%|██████████| 18/18 [00:19<00:00,  1.10s/it]
# Processing Mike Marshall: 100%|██████████| 20/20 [00:22<00:00,  1.14s/it]
# Processing Mike Bloomfield: 100%|██████████| 18/18 [00:20<00:00,  1.13s/it]
# Processing Mick Harvey: 100%|██████████| 12/12 [00:13<00:00,  1.13s/it]
# Processing Michael Franti & Spearhead: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# Processing Meredith Monk: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing Memphis Bleek: 100%|██████████| 6/6 [00:06<00:00,  1.10s/it]
# Processing Mel Tormé: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# Processing Meat Beat Manifesto: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing Me First and the Gimme Gimmes: 100%|██████████| 8/8 [00:08<00:00,  1.10s/it]
# Processing Maynard Ferguson: 100%|██████████| 19/19 [00:21<00:00,  1.12s/it]
# Processing Max Romeo: 100%|██████████| 18/18 [00:20<00:00,  1.13s/it]
# Processing Matthew Sweet: 100%|██████████| 17/17 [00:19<00:00,  1.13s/it]
# Processing Matchbox Twenty: 100%|██████████| 6/6 [00:06<00:00,  1.10s/it]
# Processing Master P: 100%|██████████| 15/15 [00:16<00:00,  1.12s/it]
# Processing Mary Wells: 100%|██████████| 15/15 [00:17<00:00,  1.14s/it]
# Processing Mary Margaret O'Hara: 100%|██████████| 2/2 [00:02<00:00,  1.14s/it]
# Processing Mary J. Blige: 100%|██████████| 14/14 [00:15<00:00,  1.11s/it]
# Processing Marty Stuart: 100%|██████████| 15/15 [00:16<00:00,  1.12s/it]
# Processing Martin Carthy: 100%|██████████| 13/13 [00:14<00:00,  1.14s/it]
# Processing Martha Reeves & The Vandellas: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# Processing Marta Sánchez: 100%|██████████| 14/14 [00:15<00:00,  1.12s/it]
# Processing Mark de Clive-Lowe: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing Mark Stewart: 100%|██████████| 14/14 [00:15<00:00,  1.12s/it]
# Processing Mark Knopfler: 100%|██████████| 18/18 [00:19<00:00,  1.10s/it]
# Processing Maria Taylor: 100%|██████████| 8/8 [00:08<00:00,  1.11s/it]
# Processing Marcos Valle: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing Marc Cohn: 100%|██████████| 9/9 [00:09<00:00,  1.10s/it]
# Processing Marc Almond: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing Malcolm McLaren: 100%|██████████| 6/6 [00:06<00:00,  1.10s/it]
# Processing Maddy Prior: 100%|██████████| 17/17 [00:19<00:00,  1.12s/it]
# Processing Mad Professor: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Mac Dre: 100%|██████████| 15/15 [00:16<00:00,  1.13s/it]
# Processing MC Eiht: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# Processing M. Ward: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# Processing Lyle Lovett: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing Lupe Fiasco: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing Luke Vibert: 100%|██████████| 12/12 [00:13<00:00,  1.10s/it]
# Processing Luke Haines: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing Luiz Bonfá: 100%|██████████| 20/20 [00:22<00:00,  1.13s/it]
# Processing Louisiana Red: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# Processing Louis Armstrong: 100%|██████████| 18/18 [00:20<00:00,  1.11s/it]
# Processing Lou Reed: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing Los Straitjackets: 100%|██████████| 10/10 [00:11<00:00,  1.13s/it]
# Processing Los Panchos: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Los Corraleros De Majagual: 100%|██████████| 19/19 [00:21<00:00,  1.15s/it]
# Processing Lorrie Morgan: 100%|██████████| 18/18 [00:20<00:00,  1.11s/it]
# Processing Lo Fidelity Allstars: 100%|██████████| 3/3 [00:03<00:00,  1.11s/it]
# Processing Little Texas: 100%|██████████| 7/7 [00:07<00:00,  1.12s/it]
# Processing Little Jimmy Dickens: 100%|██████████| 19/19 [00:21<00:00,  1.15s/it]
# Processing Little Caesar: 100%|██████████| 3/3 [00:03<00:00,  1.12s/it]
# Processing Little Big Town: 100%|██████████| 10/10 [00:11<00:00,  1.10s/it]
# Processing Lisa Loeb: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# Processing Lisa Gerrard: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Link Wray: 100%|██████████| 20/20 [00:22<00:00,  1.13s/it]
# Processing Linda Ronstadt: 100%|██████████| 20/20 [00:22<00:00,  1.10s/it]
# Processing Lila McCann: 100%|██████████| 4/4 [00:04<00:00,  1.11s/it]
# Processing Lila Downs: 100%|██████████| 19/19 [00:21<00:00,  1.13s/it]
# Processing Lil' Troy: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
# Processing Lil' Kim: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it]
# Processing Lil' Flip: 100%|██████████| 18/18 [00:20<00:00,  1.13s/it]
# Processing Lightnin' Slim: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# Processing Lightnin' Hopkins: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Lighter Shade Of Brown: 100%|██████████| 9/9 [00:10<00:00,  1.12s/it]
# Processing Levon Helm: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing Levellers: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Les Georges Leningrad: 100%|██████████| 1/1 [00:01<00:00,  1.12s/it]
# Processing Leon Russell: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing Leo Kottke: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing Lena Horne: 100%|██████████| 17/17 [00:19<00:00,  1.13s/it]
# Processing Lee Ritenour: 100%|██████████| 14/14 [00:15<00:00,  1.10s/it]
# Processing Lee Fields: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# Processing Lee "Scratch" Perry: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing Leaders of the New School: 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Processing Larry Graham: 100%|██████████| 6/6 [00:06<00:00,  1.10s/it]
# Processing Larry Carlton: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# Processing Lambert, Hendricks & Ross: 100%|██████████| 18/18 [00:20<00:00,  1.14s/it]
# Processing Lamb of God: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing Lady Saw: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# Processing LaVern Baker: 100%|██████████| 18/18 [00:20<00:00,  1.15s/it]
# Processing La Sonora Dinamita: 100%|██████████| 20/20 [00:22<00:00,  1.13s/it]
# Processing Kutt Calhoun: 100%|██████████| 7/7 [00:07<00:00,  1.11s/it]
# Processing Kris Kristofferson: 100%|██████████| 19/19 [00:21<00:00,  1.12s/it]
# Processing Kool Keith: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Kool G Rap: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing Klaus Schulze: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Kitty Wells: 100%|██████████| 14/14 [00:15<00:00,  1.13s/it]
# Processing Kirk Franklin: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing Kings of Leon: 100%|██████████| 8/8 [00:08<00:00,  1.10s/it]
# Processing Kings of Convenience: 100%|██████████| 4/4 [00:04<00:00,  1.11s/it]
# Processing Kingpin Skinny Pimp: 100%|██████████| 13/13 [00:14<00:00,  1.12s/it]
# Processing King Tubby: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing King Britt: 100%|██████████| 10/10 [00:11<00:00,  1.12s/it]
# Processing Kimya Dawson: 100%|██████████| 6/6 [00:06<00:00,  1.10s/it]
# Processing Kim Weston: 100%|██████████| 9/9 [00:10<00:00,  1.12s/it]
# Processing Killa Kyleon: 100%|██████████| 18/18 [00:20<00:00,  1.12s/it]
# Processing Kid Loco: 100%|██████████| 11/11 [00:12<00:00,  1.10s/it]
# Processing Keyshia Cole: 100%|██████████| 7/7 [00:07<00:00,  1.11s/it]
# Processing Kevin Welch: 100%|██████████| 11/11 [00:12<00:00,  1.11s/it]
# Processing Kenny Rogers: 100%|██████████| 19/19 [00:20<00:00,  1.10s/it]
# Processing Kelly Rowland: 100%|██████████| 11/11 [00:12<00:00,  1.11s/it]
# Processing Kelly Price: 100%|██████████| 7/7 [00:07<00:00,  1.11s/it]
# Processing Keith Whitley: 100%|██████████| 8/8 [00:08<00:00,  1.10s/it]
# Processing Keak Da Sneak: 100%|██████████| 18/18 [00:20<00:00,  1.13s/it]
# Processing Kathryn Williams: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# Processing KK Null: 100%|██████████| 9/9 [00:09<00:00,  1.11s/it]
# Processing Jóhann Jóhannsson: 100%|██████████| 18/18 [00:19<00:00,  1.11s/it]
# Processing Junior Murvin: 100%|██████████| 7/7 [00:07<00:00,  1.12s/it]
# Processing Jump, Little Children: 100%|██████████| 7/7 [00:07<00:00,  1.12s/it]
# Processing Julio Iglesias: 100%|██████████| 13/13 [00:14<00:00,  1.12s/it]
# Processing Julieta Venegas: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# Processing Julie Andrews: 100%|██████████| 11/11 [00:12<00:00,  1.11s/it]
# Processing José González: 100%|██████████| 7/7 [00:07<00:00,  1.10s/it]
# Processing José Carreras: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# Processing Josh Joplin Group: 100%|██████████| 3/3 [00:03<00:00,  1.11s/it]
# Processing Jools Holland: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Johnny Thunders: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Johnny Kidd & The Pirates: 100%|██████████| 6/6 [00:06<00:00,  1.14s/it]
# Processing Johnny Clegg: 100%|██████████| 17/17 [00:19<00:00,  1.12s/it]
# Processing Johnny Cash: 100%|██████████| 20/20 [00:22<00:00,  1.10s/it]
# Processing John Scofield: 100%|██████████| 15/15 [00:16<00:00,  1.10s/it]
# Processing John P. Kee: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing John Mayall & The Bluesbreakers: 100%|██████████| 19/19 [00:21<00:00,  1.12s/it]
# Processing John Lydon: 100%|██████████| 4/4 [00:04<00:00,  1.12s/it]
# Processing John Lennon: 100%|██████████| 18/18 [00:19<00:00,  1.10s/it]
# Processing John Lee Hooker: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing John Frusciante: 100%|██████████| 10/10 [00:11<00:00,  1.10s/it]
# Processing John Foxx: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing John Doe: 100%|██████████| 7/7 [00:07<00:00,  1.13s/it]
# Processing John Digweed: 100%|██████████| 11/11 [00:12<00:00,  1.11s/it]
# Processing John Coltrane: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing John Anderson: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing John Abercrombie: 100%|██████████| 17/17 [00:18<00:00,  1.12s/it]
# Processing Johann Sebastian Bach: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Joey DeFrancesco: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Joe Williams: 100%|██████████| 17/17 [00:19<00:00,  1.14s/it]
# Processing Joe Sample:   0%|          | 0/19 [00:00<?, ?it/s]
# Error processing Joe Tex: 'album_id'
# Processing Joe Sample: 100%|██████████| 19/19 [00:20<00:00,  1.10s/it]
# Processing Joe Pass: 100%|██████████| 18/18 [00:20<00:00,  1.11s/it]
# Processing Joe Jackson: 100%|██████████| 15/15 [00:16<00:00,  1.12s/it]
# Processing Joe Hill Louis: 100%|██████████| 4/4 [00:04<00:00,  1.16s/it]
# Processing Joe Cocker: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing Joe Budden: 100%|██████████| 18/18 [00:20<00:00,  1.11s/it]
# Processing Jocelyn Brown: 100%|██████████| 6/6 [00:06<00:00,  1.11s/it]
# Processing Joan Baez: 100%|██████████| 18/18 [00:20<00:00,  1.13s/it]
# Processing Jimmy Smith: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Jimmie Lunceford: 100%|██████████| 20/20 [00:23<00:00,  1.15s/it]
# Processing Jimmie Davis: 100%|██████████| 18/18 [00:20<00:00,  1.14s/it]
# Processing Jimi Hendrix: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# Processing Jim Reeves: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing Jim Jones: 100%|██████████| 14/14 [00:15<00:00,  1.11s/it]
# Processing Jim Hall: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Jim Ed Brown: 100%|██████████| 15/15 [00:16<00:00,  1.12s/it]
# Processing Jet: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# Processing Jessie James Decker: 100%|██████████| 6/6 [00:06<00:00,  1.11s/it]
# Processing Jessica Simpson: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# Processing Jessi Colter: 100%|██████████| 12/12 [00:13<00:00,  1.12s/it]
# Processing Jesse Dayton: 100%|██████████| 10/10 [00:11<00:00,  1.13s/it]
# Processing Jerry Reed: 100%|██████████| 18/18 [00:19<00:00,  1.11s/it]
# Processing Jerry Garcia: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Jermaine Jackson: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# Processing Jermaine Dupri: 100%|██████████| 3/3 [00:03<00:00,  1.11s/it]
# Processing Jeremy Camp: 100%|██████████| 17/17 [00:18<00:00,  1.10s/it]
# Processing Jennifer O'Connor: 100%|██████████| 7/7 [00:07<00:00,  1.12s/it]
# Processing Jennifer Hudson: 100%|██████████| 4/4 [00:04<00:00,  1.12s/it]
# Processing Jelly Roll Morton: 100%|██████████| 20/20 [00:23<00:00,  1.15s/it]
# Processing Jello Biafra: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing Jeffrey Lewis: 100%|██████████| 13/13 [00:14<00:00,  1.10s/it]
# Processing Jeff Beck: 100%|██████████| 18/18 [00:19<00:00,  1.10s/it]
# Processing Jeannie C. Riley: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing Jarvis Cocker:   0%|          | 0/8 [00:00<?, ?it/s]
# Error processing Jazze Pha: 'album_id'
# Processing Jarvis Cocker: 100%|██████████| 8/8 [00:08<00:00,  1.10s/it]
# ...
# Processing Dwarves: 100%|██████████| 17/17 [00:18<00:00,  1.12s/it]
# Processing Dusty Springfield: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Duncan Sheik: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing Duke Ellington: 100%|██████████| 17/17 [00:18<00:00,  1.12s/it]
# Processing Duane Allman: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
# Processing Dru Hill: 100%|██████████| 6/6 [00:06<00:00,  1.10s/it]
# Processing Dropkick Murphys: 100%|██████████| 16/16 [00:17<00:00,  1.09s/it]
# Processing DragonForce: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# Processing Dr. Octagon: 100%|██████████| 8/8 [00:08<00:00,  1.11s/it]
# Processing Dr. John: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing Dr. Hook: 100%|██████████| 20/20 [00:22<00:00,  1.10s/it]
# Processing Dr. Feelgood: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Doyle Bramhall II: 100%|██████████| 6/6 [00:06<00:00,  1.10s/it]
# Processing Doug E. Fresh: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
# Processing Dottie West: 100%|██████████| 19/19 [00:21<00:00,  1.13s/it]
# Processing Donald Byrd: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# Processing Dominik Eulberg: 100%|██████████| 14/14 [00:15<00:00,  1.10s/it]
# Processing Dolly Parton: 100%|██████████| 15/15 [00:16<00:00,  1.10s/it]
# Processing Does It Offend You, Yeah?: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Processing Doc Watson: 100%|██████████| 18/18 [00:20<00:00,  1.14s/it]
# Processing Dizzy Gillespie: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# Processing Dizzee Rascal: 100%|██████████| 13/13 [00:14<00:00,  1.10s/it]
# Processing Dinosaur Jr.: 100%|██████████| 15/15 [00:16<00:00,  1.09s/it]
# Processing Dianne Reeves: 100%|██████████| 18/18 [00:19<00:00,  1.10s/it]
# Processing Diana Ross: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# Processing Diamanda Galás: 100%|██████████| 18/18 [00:19<00:00,  1.11s/it]
# Processing Dexys Midnight Runners: 100%|██████████| 6/6 [00:06<00:00,  1.11s/it]
# Processing Desmond Dekker: 100%|██████████| 17/17 [00:19<00:00,  1.13s/it]
# Processing Dennis Brown: 100%|██████████| 19/19 [00:21<00:00,  1.12s/it]
# Processing Denise LaSalle: 100%|██████████| 14/14 [00:15<00:00,  1.13s/it]
# Processing Delirious?: 100%|██████████| 18/18 [00:19<00:00,  1.11s/it]
# Processing Deep Blue Something: 100%|██████████| 4/4 [00:04<00:00,  1.14s/it]
# Processing Death Angel: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing DeVotchKa: 100%|██████████| 6/6 [00:06<00:00,  1.12s/it]
# Processing Dazz Band: 100%|██████████| 18/18 [00:20<00:00,  1.11s/it]
# Processing Daz Dillinger: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing David Sylvian: 100%|██████████| 18/18 [00:19<00:00,  1.10s/it]
# Processing David Sanborn: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing David Gilmour: 100%|██████████| 8/8 [00:08<00:00,  1.10s/it]
# Processing David Crowder Band: 100%|██████████| 15/15 [00:16<00:00,  1.10s/it]
# Processing David Cassidy:   0%|          | 0/17 [00:00<?, ?it/s]
# Error processing David Coverdale: 'album_id'
# Processing David Cassidy: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing David Byrne: 100%|██████████| 19/19 [00:20<00:00,  1.10s/it]
# Processing David Banner: 100%|██████████| 8/8 [00:08<00:00,  1.12s/it]
# Processing David "Fathead" Newman: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Dave Matthews Band: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing Datach'i: 100%|██████████| 5/5 [00:05<00:00,  1.13s/it]
# Processing Dark Angel: 100%|██████████| 3/3 [00:03<00:00,  1.09s/it]
# Processing Dannii Minogue: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing Daniel Bedingfield: 100%|██████████| 3/3 [00:03<00:00,  1.10s/it]
# Processing Danger Mouse: 100%|██████████| 6/6 [00:06<00:00,  1.09s/it]
# Processing Dan Penn: 100%|██████████| 6/6 [00:06<00:00,  1.11s/it]
# Processing Da Beatminerz: 100%|██████████| 4/4 [00:04<00:00,  1.12s/it]
# Processing DJ Spooky: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing DJ Magic Mike: 100%|██████████| 15/15 [00:16<00:00,  1.12s/it]
# Processing DJ Jazzy Jeff & The Fresh Prince: 100%|██████████| 6/6 [00:06<00:00,  1.10s/it]
# Processing Curtis Mayfield: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# Processing Current 93: 100%|██████████| 19/19 [00:21<00:00,  1.12s/it]
# Processing Crosby, Stills, Nash & Young: 100%|██████████| 8/8 [00:08<00:00,  1.10s/it]
# Processing Counting Crows: 100%|██████████| 14/14 [00:15<00:00,  1.11s/it]
# Processing Count Basie: 100%|██████████| 15/15 [00:17<00:00,  1.14s/it]
# Processing Cornell Campbell: 100%|██████████| 18/18 [00:20<00:00,  1.13s/it]
# Processing Corinne Bailey Rae: 100%|██████████| 6/6 [00:06<00:00,  1.11s/it]
# Processing Corbin Bleu: 100%|██████████| 2/2 [00:02<00:00,  1.09s/it]
# Processing Cooper-Moore: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Processing Conway Twitty: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Conor Oberst: 100%|██████████| 8/8 [00:08<00:00,  1.10s/it]
# Processing Compton's Most Wanted: 100%|██████████| 7/7 [00:07<00:00,  1.12s/it]
# Processing Cocoa Tea: 100%|██████████| 18/18 [00:20<00:00,  1.12s/it]
# Processing CocoRosie: 100%|██████████| 8/8 [00:08<00:00,  1.11s/it]
# Processing Clyde McPhatter: 100%|██████████| 19/19 [00:21<00:00,  1.14s/it]
# Processing Club Nouveau: 100%|██████████| 8/8 [00:08<00:00,  1.11s/it]
# Processing Cliff Richard: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing Clarence "Gatemouth" Brown: 100%|██████████| 19/19 [00:21<00:00,  1.13s/it]
# Processing Clan of Xymox: 100%|██████████| 12/12 [00:13<00:00,  1.13s/it]
# Processing Chrisette Michele: 100%|██████████| 9/9 [00:09<00:00,  1.11s/it]
# Processing Chris de Burgh: 100%|██████████| 13/13 [00:14<00:00,  1.13s/it]
# Processing Chris Thomas King: 100%|██████████| 14/14 [00:15<00:00,  1.12s/it]
# Processing Chris Botti: 100%|██████████| 13/13 [00:14<00:00,  1.10s/it]
# Processing Chico Hamilton: 100%|██████████| 19/19 [00:21<00:00,  1.13s/it]
# Processing Chick Webb: 100%|██████████| 20/20 [00:22<00:00,  1.14s/it]
# Processing Chick Corea: 100%|██████████| 19/19 [00:20<00:00,  1.10s/it]
# Processing Chet Atkins: 100%|██████████| 12/12 [00:13<00:00,  1.12s/it]
# Processing Charlie Sexton: 100%|██████████| 3/3 [00:03<00:00,  1.10s/it]
# Processing Charlie Parker: 100%|██████████| 13/13 [00:14<00:00,  1.12s/it]
# Processing Charlie Hunter: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Charlie Haden: 100%|██████████| 18/18 [00:19<00:00,  1.11s/it]
# Processing Charles Wright & The Watts 103rd Street Rhythm Band: 100%|██████████| 8/8 [00:08<00:00,  1.11s/it]
# Processing Chad Mitchell Trio: 100%|██████████| 18/18 [00:20<00:00,  1.13s/it]
# Processing Celia Cruz: 100%|██████████| 20/20 [00:22<00:00,  1.13s/it]
# Processing CeCe Winans: 100%|██████████| 13/13 [00:14<00:00,  1.10s/it]
# Processing Cat Power: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# Processing Carl Craig: 100%|██████████| 8/8 [00:08<00:00,  1.11s/it]
# Processing Captain Beefheart & His Magic Band: 100%|██████████| 18/18 [00:20<00:00,  1.13s/it]
# Processing Cannonball Adderley: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing Candlemass: 100%|██████████| 18/18 [00:19<00:00,  1.11s/it]
# Processing Caitlin Cary: 100%|██████████| 3/3 [00:03<00:00,  1.12s/it]
# Processing Cab Calloway: 100%|██████████| 14/14 [00:15<00:00,  1.11s/it]
# Processing Béla Bartók: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing Byron Lee & The Dragonaires: 100%|██████████| 8/8 [00:08<00:00,  1.12s/it]
# Processing Buzzcocks: 100%|██████████| 17/17 [00:19<00:00,  1.12s/it]
# Processing Bulletboys: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# Processing Bugz in the Attic: 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]
# Processing Buddy Holly: 100%|██████████| 10/10 [00:11<00:00,  1.10s/it]
# Processing Buddy Guy: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing Bruce Springsteen: 100%|██████████| 19/19 [00:20<00:00,  1.10s/it]
# Processing Bruce Hornsby: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing Brownie McGhee: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# Processing Brotha Lynch Hung: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing Brian Wilson: 100%|██████████| 14/14 [00:15<00:00,  1.12s/it]
# Processing Brian Tyler: 100%|██████████| 20/20 [00:22<00:00,  1.10s/it]
# Processing Brian McFadden: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it]
# Processing Brad Mehldau: 100%|██████████| 17/17 [00:18<00:00,  1.10s/it]
# Processing Bow Wow: 100%|██████████| 12/12 [00:13<00:00,  1.10s/it]
# Processing Bounty Killer: 100%|██████████| 19/19 [00:21<00:00,  1.12s/it]
# Processing Boo-Yaa T.R.I.B.E.: 100%|██████████| 9/9 [00:09<00:00,  1.10s/it]
# Processing Bonnie Raitt: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Boney M.: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# Processing Boney James: 100%|██████████| 17/17 [00:18<00:00,  1.10s/it]
# Processing Bobby "Blue" Bland: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Bob Wills & His Texas Playboys: 100%|██████████| 20/20 [00:22<00:00,  1.14s/it]
# Processing Bob Seger: 100%|██████████| 17/17 [00:18<00:00,  1.10s/it]
# Processing Bob Marley & The Wailers: 100%|██████████| 20/20 [00:21<00:00,  1.10s/it]
# Processing Bob James: 100%|██████████| 18/18 [00:19<00:00,  1.10s/it]
# Processing Blood, Sweat & Tears: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing Blood on the Saddle: 100%|██████████| 10/10 [00:11<00:00,  1.12s/it]
# Processing Blind Willie McTell: 100%|██████████| 17/17 [00:19<00:00,  1.14s/it]
# Processing Blind Willie Johnson: 100%|██████████| 15/15 [00:16<00:00,  1.12s/it]
# Processing Blake Shelton: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# Processing Bing Crosby: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Billy Eckstine: 100%|██████████| 20/20 [00:22<00:00,  1.15s/it]
# Processing Billy Childish: 100%|██████████| 17/17 [00:19<00:00,  1.13s/it]
# Processing Billy Bragg: 100%|██████████| 11/11 [00:12<00:00,  1.12s/it]
# Processing Bill Justis: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# Processing Bill Haley & His Comets: 100%|██████████| 19/19 [00:21<00:00,  1.12s/it]
# Processing Bill Evans: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Big Walter Horton: 100%|██████████| 11/11 [00:12<00:00,  1.11s/it]
# Processing Big Sandy & His Fly-Rite Boys: 100%|██████████| 12/12 [00:13<00:00,  1.13s/it]
# Processing Big Mama Thornton: 100%|██████████| 19/19 [00:21<00:00,  1.13s/it]
# Processing Big Maceo: 100%|██████████| 19/19 [00:21<00:00,  1.15s/it]
# Processing Big Jay McNeely: 100%|██████████| 20/20 [00:22<00:00,  1.14s/it]
# Processing Bettye Swann: 100%|██████████| 4/4 [00:04<00:00,  1.11s/it]
# Processing Betty Wright: 100%|██████████| 17/17 [00:18<00:00,  1.12s/it]
# Processing Betty Everett: 100%|██████████| 19/19 [00:21<00:00,  1.13s/it]
# Processing Betty Carter: 100%|██████████| 19/19 [00:21<00:00,  1.13s/it]
# Processing Beth Gibbons: 100%|██████████| 2/2 [00:02<00:00,  1.09s/it]
# Processing Bert Jansch: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# Processing Benjamin Britten: 100%|██████████| 18/18 [00:20<00:00,  1.12s/it]
# Processing Bathory: 100%|██████████| 13/13 [00:14<00:00,  1.10s/it]
# Processing Barry White: 100%|██████████| 16/16 [00:17<00:00,  1.10s/it]
# Processing Barrington Levy: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Barbra Streisand: 100%|██████████| 18/18 [00:19<00:00,  1.10s/it]
# Processing Baby Huey: 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Processing Baby Bash: 100%|██████████| 19/19 [00:21<00:00,  1.11s/it]
# Processing B.T. Express: 100%|██████████| 8/8 [00:08<00:00,  1.10s/it]
# Processing B.J. Thomas: 100%|██████████| 18/18 [00:20<00:00,  1.11s/it]
# Processing Atomic Kitten: 100%|██████████| 3/3 [00:03<00:00,  1.10s/it]
# Processing At the Drive-In: 100%|██████████| 6/6 [00:06<00:00,  1.10s/it]
# Processing Astor Piazzolla: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Processing Ashlee Simpson: 100%|██████████| 4/4 [00:04<00:00,  1.13s/it]
# Processing Asher Roth: 100%|██████████| 9/9 [00:09<00:00,  1.10s/it]
# Processing Asha Bhosle: 100%|██████████| 18/18 [00:19<00:00,  1.11s/it]
# Processing Artie Shaw: 100%|██████████| 18/18 [00:20<00:00,  1.13s/it]
# Processing Arthur Baker: 100%|██████████| 1/1 [00:01<00:00,  1.12s/it]
# Processing Arthur "Big Boy" Crudup: 100%|██████████| 15/15 [00:17<00:00,  1.14s/it]
# Processing Arrested Development: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# Processing Antônio Carlos Jobim: 100%|██████████| 20/20 [00:22<00:00,  1.11s/it]
# Processing Antipop Consortium: 100%|██████████| 4/4 [00:04<00:00,  1.10s/it]
# Processing Anti-Nowhere League: 100%|██████████| 17/17 [00:19<00:00,  1.12s/it]
# Processing Angels & Airwaves: 100%|██████████| 9/9 [00:09<00:00,  1.10s/it]
# Processing Andy Timmons: 100%|██████████| 11/11 [00:12<00:00,  1.10s/it]
# Processing Andy Fairweather Low: 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Processing Andrea Bocelli: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# Processing Amon Düül II: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# Processing Alvin Lee: 100%|██████████| 20/20 [00:22<00:00,  1.13s/it]
# Processing Alton Ellis: 100%|██████████| 18/18 [00:20<00:00,  1.12s/it]
# Processing All Natural Lemon & Lime Flavors: 100%|██████████| 3/3 [00:03<00:00,  1.09s/it]
# Processing Alison Krauss: 100%|██████████| 15/15 [00:16<00:00,  1.10s/it]
# Processing Alice Russell: 100%|██████████| 9/9 [00:10<00:00,  1.13s/it]
# Processing Alfredo Gutierrez: 100%|██████████| 20/20 [00:22<00:00,  1.13s/it]
# Processing Alejandro Fernández: 100%|██████████| 17/17 [00:18<00:00,  1.12s/it]
# Processing Alec Empire: 100%|██████████| 18/18 [00:20<00:00,  1.11s/it]
# Processing Albert Collins: 100%|██████████| 18/18 [00:20<00:00,  1.12s/it]
# Processing Albert Ayler: 100%|██████████| 17/17 [00:18<00:00,  1.11s/it]
# Processing Al Kapone: 100%|██████████| 7/7 [00:07<00:00,  1.11s/it]
# Processing Al Di Meola: 100%|██████████| 13/13 [00:14<00:00,  1.11s/it]
# Processing Al Dexter: 100%|██████████| 13/13 [00:14<00:00,  1.15s/it]
# Processing Afrika Bambaataa: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# Processing Add N To (X): 100%|██████████| 7/7 [00:07<00:00,  1.12s/it]
# Processing ABBA: 100%|██████████| 14/14 [00:15<00:00,  1.09s/it]
# Processing :Wumpscut:: 100%|██████████| 14/14 [00:15<00:00,  1.13s/it]
# Processing 54-40: 100%|██████████| 18/18 [00:20<00:00,  1.12s/it]
# Processing 10,000 Maniacs: 100%|██████████| 17/17 [00:18<00:00,  1.10s/it]
# Processing ...And You Will Know Us by the Trail of Dead: 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# Processing The Funk Brothers: 100%|██████████| 1/1 [00:01<00:00,  1.12s/it]
# Processing 8Ball & MJG: 100%|██████████| 14/14 [00:15<00:00,  1.13s/it]
# Processing Frank Zappa: 100%|██████████| 9/9 [00:09<00:00,  1.10s/it]
# Processing Three 6 Mafia: 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# Processing Billy Ward & The Dominoes: 100%|██████████| 7/7 [00:07<00:00,  1.14s/it]
# Processing Doyle Bramhall II: 100%|██████████| 3/3 [00:03<00:00,  1.11s/it]
# Processing Zion & Lennox: 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
# Processing 8Ball & MJG: 100%|██████████| 19/19 [00:21<00:00,  1.12s/it]
# Processing The Jeff Healey Band: 100%|██████████| 11/11 [00:12<00:00,  1.12s/it]
# Processing Jessie J: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# Processing The Brian Setzer Orchestra: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# Processing The Bomb Squad: 100%|██████████| 6/6 [00:06<00:00,  1.12s/it]
# Processing The Jimmy Castor Bunch:   0%|          | 0/4 [00:00<?, ?it/s]
# Error processing The Wildhearts: 'album_id'
# Processing The Jimmy Castor Bunch: 100%|██████████| 4/4 [00:04<00:00,  1.11s/it]
# Processing The Prodigy: 100%|██████████| 18/18 [00:19<00:00,  1.10s/it]
# Processing Louis Jordan: 100%|██████████| 11/11 [00:12<00:00,  1.13s/it]
# Processing Georgie Fame:   0%|          | 0/3 [00:00<?, ?it/s]
# Error processing The Derek Trucks Band: 'album_id'
# Processing Georgie Fame: 100%|██████████| 3/3 [00:03<00:00,  1.11s/it]
# Completed processing all artists.

# %%
# max_retries = 3
# retry_counter = 0

# while not failed_requests.empty and retry_counter < max_retries:
#     print(f"Retrying failed requests (attempt {retry_counter + 1}/{max_retries})...")
#     retry_failed_requests = pd.DataFrame(columns=["Spotify ID"])
#     for _, row in failed_requests.iterrows():
#         artist_id = row["Spotify ID"]
#         artist_name = artist_ids[artist_id]
#         sanitized_artist_name = sanitize_filename(artist_name)
#         parquet_file_path = f'{sanitized_artist_name}_tracks.parquet'

#         if os.path.exists(parquet_file_path):
#             print(f"Parquet file already exists for {artist_name}, skipping...")
#             continue
#         try:
#             refreshed_token, new_token_start_time = refresh_token(token_start_time)
#             if refreshed_token:
#                 token = refreshed_token
#                 token_start_time = new_token_start_time
#             albums = get_albums_for_artist(token, artist_id)

#             if albums is None:
#                 failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
#                 save_failed_requests(failed_requests)
#                 continue

#             album_df = pd.DataFrame.from_dict(albums, orient="index")
#             album_df.index.name = "album_name"

#             all_tracks_df = pd.DataFrame()
#             for album_id in tqdm(album_df['album_id'], desc=f"Processing {artist_name}"):
#                 time.sleep(1)
#                 try:
#                     tracks = get_tracks_for_album(token, album_id)

#                     if tracks is None:
#                         failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
#                         save_failed_requests(failed_requests)
#                         continue

#                     tracks = pd.DataFrame(tracks)
#                     tracks['album_id'] = album_id
#                     all_tracks_df = pd.concat([all_tracks_df, tracks], axis=0)
#                 except Exception as e:
#                     print(f"Warning: Error fetching tracks for {artist_name}: {e}")

#             try:
#                 af_df = get_audio_features(token, all_tracks_df['track_id'].tolist())
#                 af_df = af_df.rename(columns={'id': 'track_id'})
#                 all_aftracks_df = pd.merge(all_tracks_df, af_df, on='track_id')
#                 album_all_aftracks_df = pd.merge(album_df, all_aftracks_df, on='album_id')
#                 sanitized_artist_name = sanitize_filename(artist_name)
#                 album_all_aftracks_df.to_parquet(f'{sanitized_artist_name}_tracks.parquet')

#                 save_checkpoint(artist_id, artist_name)
#             except Exception as e:
#                 print(f"Warning: Error fetching audio features for {artist_name}: {e}")

#             iteration_counter += 1
#             if iteration_counter % sleep_interval == 0:
#                 time.sleep(1)

#         except Exception as e:
#             print(f"Error processing {artist_name}: {e}")
#             retry_failed_requests = retry_failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)

#     failed_requests = retry_failed_requests
#     retry_counter += 1

# if not failed_requests.empty:
#     print("Some requests still failed after all retries:")
#     print(failed_requests)
# else:
#     print("All failed requests have been successfully processed.")
