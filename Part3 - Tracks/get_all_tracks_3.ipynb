# %%
import os
import base64
import requests
from requests import post, get
import json
from tqdm import tqdm
import pandas as pd
import time
import math
import re

# %%
client_credentials = [
('99f2f345b8394b50ac1b8dc1f0c00fe3', '7a2d2e2264114afe8dcd06a9698f7c40'),
('9b3fd46dd05143f3b2a8a1d09d13b3e6', 'a8214552ed424e8f9e77e667938e1569'),
('f1e33b9fd79f4c27bb1959b543397b5b', '24bf3c98a1b64d2c8d0814cc00c395a2'),
('8980a46d6c6f4b04afdc1dc811ab0302', 'a449aeb444ef457bbca21fcba09fb3ff'),
('bfbd3a53eff148899f1c003f71990c62', '083442bd2552477d92d8d956a3dca081'),
('828f192529984132960c2964fdf6c25a', 'd3fbcedb1b2e4446b0aaaa8002542407'),
('c6281585d64c4d77b535b0a5054347ab', '40de31ae41b84f1ca8cc6588ad3738c5'),
('7e803f814d69411eb214f4643fb43d99', '7ba59fa4c14f42efb15679f756ff9d94'),
('6fca169b877c489b82dbbfb1626ecb69', '7f4cefd772a0409d8cf47bdc495e21e7'),
('69b74a932a4e40aba2c07fe8f235a9a1', '609d13e078e3421a866a3a9568e96c47')

]



credential_index = 0

def get_token(client_id, client_secret):
    auth_string = client_id + ":" + client_secret
    auth_bytes = auth_string.encode("utf-8")
    auth_base64 = str(base64.b64encode(auth_bytes), "utf-8")

    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": "Basic " + auth_base64,
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"grant_type": "client_credentials"}

    response = requests.post(url, headers=headers, data=data)
    json_result = json.loads(response.content)

    if "access_token" in json_result:
        token = json_result["access_token"]
        return token
    else:
        print("Error: Failed to get access token")
        print(json_result)
        return None

def get_auth_header(token):
    return {"Authorization": "Bearer " + token}

def get_albums_for_artist(token, artist_id):
    url = f"https://api.spotify.com/v1/artists/{artist_id}/albums"
    headers = get_auth_header(token)
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        albums = json.loads(response.text)["items"]
        album_dict = {}
        for album in albums:
            album_id = album["id"]
            album_name = album["name"]
            album_tracks = album["total_tracks"]
            album_type = album["album_type"]
            album_release_date = album["release_date"]
            album_artists = [artist["name"] for artist in album["artists"]]
            album_images = album["images"]

            if album_name in album_dict:
                existing_tracks = album_dict[album_name]["total_tracks"]
                if album_tracks > existing_tracks:
                    album_dict[album_name] = {
                        "album_id": album_id,
                        "album_name": album_name,
                        "total_tracks": album_tracks,
                        "album_type": album_type,
                        "release_date": album_release_date,
                        "artists": album_artists,
                        "images": album_images
                    }
            else:
                album_dict[album_name] = {
                    "album_id": album_id,
                    "album_name": album_name,
                    "total_tracks": album_tracks,
                    "album_type": album_type,
                    "release_date": album_release_date,
                    "artists": album_artists,
                    "images": album_images
                }
        return album_dict
    else:
        print("Error: Failed to get albums for artist")
        print(response.content)
        return None
    
def get_tracks_for_album(token, album_id):
    url = f"https://api.spotify.com/v1/albums/{album_id}/tracks"
    headers = get_auth_header(token)
    params = {"market": "US"}
    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        tracks = json.loads(response.text)["items"]
        track_list = []
        for track in tracks:
            track_name = track["name"]
            track_id = track["id"]
            track_number = track["track_number"]
            track_explicit = track["explicit"]
            track_artists = [artist["name"] for artist in track["artists"]]
            track_dict = {
                "track_name": track_name,
                "track_id": track_id,
                "track_number": track_number,
                "track_explicit": track_explicit,
                "track_artists": track_artists,
            }
            track_list.append(track_dict)
        return track_list
    else:
        print("Error: Failed to get tracks for album")
        print(response.content)
        return None

# def get_audio_features(token, track_ids):
#     headers = {"Authorization": f"Bearer {token}"}
#     url = "https://api.spotify.com/v1/audio-features"
    
#     id_chunks = [track_ids[i:i+100] for i in range(0, len(track_ids), 100)]
    
#     dfs = []
#     for chunk in id_chunks:
#         params = {"ids": ",".join(chunk)}
#         response = requests.get(url, headers=headers, params=params)
#         data = response.json()["audio_features"]
#         features = pd.DataFrame(data)
#         features = features.drop(["type", "uri", "track_href", "analysis_url"], axis=1)
#         dfs.append(features)
    
#     features = pd.concat(dfs, ignore_index=True)
#     return features

def get_audio_features(token, track_ids):
    audio_features = []

    for i in range(0, len(track_ids), 50):
        chunk = track_ids[i:i + 50]
        ids = ','.join(chunk)
        url = f"https://api.spotify.com/v1/audio-features?ids={ids}"
        headers = {"Authorization": f"Bearer {token}"}
        r = requests.get(url, headers=headers)
        if r.status_code != 200:
            print(f"Error getting audio features for tracks: {r.status_code}")
            return None

        try:
            features = r.json()["audio_features"]
        except KeyError:
            features = []

        audio_features.extend(features)

    audio_features_filtered = []
    for feature in audio_features:
        if feature is not None:
            audio_features_filtered.append(feature)

    return pd.DataFrame(audio_features_filtered)



def load_checkpoint():
    if os.path.exists('checkpoint_3.json'):
        with open('checkpoint_3.json', 'r') as f:
            return json.load(f)
    else:
        return {"artist_id": "", "progress": 0}

def save_checkpoint(artist_id, progress):
    with open('checkpoint_3.json', 'w') as f:
        json.dump({"artist_id": artist_id, "progress": progress}, f)

def load_failed_requests():
    if os.path.exists('failed_requests_3.parquet'):
        return pd.read_parquet('failed_requests_3.parquet')
    else:
        return pd.DataFrame(columns=['Spotify ID'])

def save_failed_requests(df):
    df.to_parquet('failed_requests_3.parquet')

def refresh_token(token_start_time):
    global credential_index
    current_time = time.time()
    elapsed_time = current_time - token_start_time
    if elapsed_time >= 1800:
        credential_index = (credential_index + 1) % len(client_credentials)
        client_id, client_secret = client_credentials[credential_index]
        return get_token(client_id, client_secret), current_time
    return None, token_start_time

def sanitize_filename(filename):
    return re.sub(r'[\\/:"*?<>|]+', '_', filename)

# %%
with open('artist_ids_sub_dict_3.json', 'r') as f:
    artist_ids = json.load(f)
len(artist_ids)
# Out:
# 1201

# %%
token = get_token(client_credentials[0][0], client_credentials[0][1])
token_start_time = time.time()

checkpoint = load_checkpoint()
failed_requests = load_failed_requests()

start_from = checkpoint["artist_id"] if checkpoint["artist_id"] else list(artist_ids.keys())[0]
start_index = list(artist_ids.keys()).index(start_from)


iteration_counter = 0
sleep_interval = 50

for artist_id, artist_name in list(artist_ids.items())[start_index:]:
    sanitized_artist_name = sanitize_filename(artist_name)
    parquet_file_path = f'results/{sanitized_artist_name}_tracks.parquet'
    if os.path.exists(parquet_file_path):
        print(f"Parquet file already exists for {artist_name}, skipping...")
        continue
    try:
        refreshed_token, new_token_start_time = refresh_token(token_start_time)
        if refreshed_token:
            token = refreshed_token
            token_start_time = new_token_start_time

        albums = get_albums_for_artist(token, artist_id)

        if albums is None:
            failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
            save_failed_requests(failed_requests)
            continue

        album_df = pd.DataFrame.from_dict(albums, orient="index")
        album_df.index.name = "album_name"

        all_tracks_df = pd.DataFrame()
        for album_id in tqdm(album_df['album_id'], desc=f"Processing {artist_name}"):
            time.sleep(1)
            tracks = get_tracks_for_album(token, album_id)
            if tracks is None:
                failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
                save_failed_requests(failed_requests)
                continue

            tracks = pd.DataFrame(tracks)
            tracks['album_id'] = album_id
            all_tracks_df = pd.concat([all_tracks_df, tracks], axis=0)

        af_df = get_audio_features(token, all_tracks_df['track_id'].tolist())
        af_df = af_df.rename(columns={'id': 'track_id'})
        all_aftracks_df = pd.merge(all_tracks_df, af_df, on='track_id')
        album_all_aftracks_df = pd.merge(album_df, all_aftracks_df, on='album_id')
        sanitized_artist_name = sanitize_filename(artist_name)
        album_all_aftracks_df.to_parquet(f'results/{sanitized_artist_name}_tracks.parquet')

        save_checkpoint(artist_id, artist_name)
        iteration_counter += 1
        if iteration_counter % sleep_interval == 0:
            time.sleep(10)
            
    except Exception as e:
        print(f"Error processing {artist_name}: {e}")
        failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
        save_failed_requests(failed_requests)
        continue

print("Completed processing all artists.")
# Out:
# Parquet file already exists for Fig Dish, skipping...
# Parquet file already exists for Maisie Peters, skipping...
# Parquet file already exists for Jessica Andrews, skipping...
# Parquet file already exists for Holger Czukay, skipping...
# Parquet file already exists for Charles Bukowski, skipping...
# Parquet file already exists for The High Llamas, skipping...
# Parquet file already exists for Paul Brady, skipping...
# Parquet file already exists for Soilwork, skipping...
# Parquet file already exists for Kurtis Blow, skipping...
# Parquet file already exists for Marcus Canty, skipping...
# Parquet file already exists for Major Lance, skipping...
# Parquet file already exists for Shawn Lane, skipping...
# Parquet file already exists for Azure Ray, skipping...
# Parquet file already exists for Pixies, skipping...
# Parquet file already exists for The Ivy League, skipping...
# Parquet file already exists for The Falcons, skipping...
# Parquet file already exists for Foetus, skipping...
# Parquet file already exists for Dire Straits, skipping...
# Parquet file already exists for Tokyo Police Club, skipping...
# Parquet file already exists for Jackie Paris, skipping...
# Parquet file already exists for Metallica, skipping...
# Parquet file already exists for Harry Chapin, skipping...
# Parquet file already exists for Robin Holcomb, skipping...
# Parquet file already exists for 90 Day Men, skipping...
# Parquet file already exists for The Dorsey Brothers, skipping...
# Parquet file already exists for Orbital, skipping...
# Parquet file already exists for Clancy Eccles, skipping...
# Parquet file already exists for Susie Ibarra, skipping...
# Parquet file already exists for Damien Jurado, skipping...
# Parquet file already exists for Leon Sylvers III, skipping...
# Parquet file already exists for Jeffree Star, skipping...
# Parquet file already exists for Chris Montez, skipping...
# Parquet file already exists for Zoot Woman, skipping...
# Parquet file already exists for The Chainsmokers, skipping...
# Parquet file already exists for Stylusboy, skipping...
# Parquet file already exists for Bob Dylan, skipping...
# Parquet file already exists for Erik Norlander, skipping...
# Parquet file already exists for Imperial Drag, skipping...
# Parquet file already exists for Carlos Vives, skipping...
# Parquet file already exists for New Order, skipping...
# Parquet file already exists for Bassholes, skipping...
# Parquet file already exists for Indigenous, skipping...
# Parquet file already exists for Candlebox, skipping...
# Parquet file already exists for Newsboys, skipping...
# Parquet file already exists for Allan Sherman, skipping...
# Parquet file already exists for Barely Civil, skipping...
# Parquet file already exists for Chris Cagle, skipping...
# Parquet file already exists for Har Mar Superstar, skipping...
# Parquet file already exists for Spinal Tap, skipping...
# Parquet file already exists for October London, skipping...
# Parquet file already exists for Earl Hines, skipping...
# Parquet file already exists for No Doubt, skipping...
# Parquet file already exists for Julian Lennon, skipping...
# Parquet file already exists for Boyz II Men, skipping...
# Parquet file already exists for Green Velvet, skipping...
# Parquet file already exists for Boukman Eksperyans, skipping...
# Parquet file already exists for Bill Withers, skipping...
# Parquet file already exists for The Congos, skipping...
# Parquet file already exists for Preoccupations, skipping...
# Parquet file already exists for Hardfloor, skipping...
# Parquet file already exists for Rodan, skipping...
# Parquet file already exists for Doug Keith, skipping...
# Parquet file already exists for Trembling Blue Stars, skipping...
# Parquet file already exists for These Arms Are Snakes, skipping...
# Parquet file already exists for Billy Idol, skipping...
# Parquet file already exists for Dirty Three, skipping...
# Parquet file already exists for Madball, skipping...
# Parquet file already exists for Levi Dexter, skipping...
# Parquet file already exists for Jackie Mittoo, skipping...
# Parquet file already exists for John Lewis, skipping...
# Parquet file already exists for The 1900s, skipping...
# Parquet file already exists for Jackson C. Frank, skipping...
# Parquet file already exists for Balzac, skipping...
# Parquet file already exists for Enrique Iglesias, skipping...
# Parquet file already exists for Todd Edwards, skipping...
# Parquet file already exists for L.V., skipping...
# Parquet file already exists for Atlanta Rhythm Section, skipping...
# Parquet file already exists for Miri Ben-Ari, skipping...
# Parquet file already exists for Skillet, skipping...
# Parquet file already exists for Smoke City, skipping...
# Parquet file already exists for Joe Bonamassa, skipping...
# Parquet file already exists for High Sunn, skipping...
# Parquet file already exists for Vladimir Horowitz, skipping...
# Parquet file already exists for Holly Cole, skipping...
# Parquet file already exists for Rob Thomas, skipping...
# Parquet file already exists for Duane Eddy, skipping...
# Parquet file already exists for Peter La Farge, skipping...
# Parquet file already exists for Two Dollar Pistols, skipping...
# Parquet file already exists for Broken Bells, skipping...
# Parquet file already exists for Brigitte Fontaine, skipping...
# Parquet file already exists for Adrian Lux, skipping...
# Parquet file already exists for Steve Vai, skipping...
# Parquet file already exists for Forrest Fang, skipping...
# Parquet file already exists for Gabrielle Roth & The Mirrors, skipping...
# Parquet file already exists for YOURCODENAMEIS:MILO, skipping...
# Parquet file already exists for Theophilus Beckford, skipping...
# Parquet file already exists for In Flames, skipping...
# Parquet file already exists for The Muckrakers, skipping...
# Parquet file already exists for John Holt, skipping...
# Parquet file already exists for Apollo Sunshine, skipping...
# Parquet file already exists for Eddie Jefferson, skipping...
# Parquet file already exists for Darius Milhaud, skipping...
# Parquet file already exists for Ariana Grande, skipping...
# Parquet file already exists for Eels, skipping...
# Parquet file already exists for Branford Marsalis, skipping...
# Parquet file already exists for Baha Men, skipping...
# Parquet file already exists for Shiraz Lane, skipping...
# Parquet file already exists for The Stanley Brothers, skipping...
# Parquet file already exists for Silicon Teens, skipping...
# Parquet file already exists for Prurient, skipping...
# Parquet file already exists for Courtney Pine, skipping...
# Parquet file already exists for Salif Keita, skipping...
# Parquet file already exists for World Trade, skipping...
# Parquet file already exists for Colbie Caillat, skipping...
# Parquet file already exists for Marmozets, skipping...
# Parquet file already exists for George McCrae, skipping...
# Parquet file already exists for Bobby Timmons, skipping...
# Parquet file already exists for Anal Cunt, skipping...
# Parquet file already exists for Charles Lloyd, skipping...
# Parquet file already exists for The Exploding Hearts, skipping...
# Parquet file already exists for Ron Miles, skipping...
# Parquet file already exists for Nina Hagen, skipping...
# Parquet file already exists for Havoc, skipping...
# Parquet file already exists for Eric Burdon, skipping...
# Parquet file already exists for Trinidad Cardona, skipping...
# Parquet file already exists for Lady Sovereign, skipping...
# Parquet file already exists for Pennywise, skipping...
# Parquet file already exists for James Morrison, skipping...
# Parquet file already exists for MC Lars, skipping...
# Parquet file already exists for Gym Class Heroes, skipping...
# Parquet file already exists for Comets On Fire, skipping...
# Parquet file already exists for Bill Bruford, skipping...
# Parquet file already exists for John Simon, skipping...
# Parquet file already exists for Charlie Barnet, skipping...
# Parquet file already exists for Jimmy Reed, skipping...
# Parquet file already exists for Kameron Marlowe, skipping...
# Parquet file already exists for Extreme Noise Terror, skipping...
# Parquet file already exists for Sid Vicious, skipping...
# Parquet file already exists for Rosemary Clooney, skipping...
# Parquet file already exists for Autograph, skipping...
# Parquet file already exists for China Drum, skipping...
# Parquet file already exists for Rob Henke, skipping...
# Parquet file already exists for Ripley Caine, skipping...
# Parquet file already exists for Ja Rule, skipping...
# Parquet file already exists for Megan Reilly, skipping...
# Parquet file already exists for Duke Bootee, skipping...
# Parquet file already exists for Gang Starr, skipping...
# Parquet file already exists for Digable Planets, skipping...
# Parquet file already exists for Let's Active, skipping...
# Parquet file already exists for Christopher Lawrence, skipping...
# Parquet file already exists for Stephen Malkmus, skipping...
# Parquet file already exists for Rory Block, skipping...
# Parquet file already exists for Unearth, skipping...
# Parquet file already exists for Arnett Cobb, skipping...
# Parquet file already exists for The Royal Wylds, skipping...
# Parquet file already exists for Dread Zeppelin, skipping...
# Parquet file already exists for Jim Dandy, skipping...
# Parquet file already exists for Queen, skipping...
# Parquet file already exists for Acid King, skipping...
# Parquet file already exists for Petra, skipping...
# Parquet file already exists for Roxy Music, skipping...
# Parquet file already exists for Sprung Monkey, skipping...
# Parquet file already exists for Lindsay Fuller, skipping...
# Parquet file already exists for Atari Teenage Riot, skipping...
# Parquet file already exists for Ant Banks, skipping...
# Parquet file already exists for Fischerspooner, skipping...
# Parquet file already exists for Annie Gallup, skipping...
# Parquet file already exists for Metro Station, skipping...
# Parquet file already exists for Ollabelle, skipping...
# Parquet file already exists for Ken Nordine, skipping...
# Parquet file already exists for Colin Meloy, skipping...
# Parquet file already exists for Muggsy Spanier, skipping...
# Parquet file already exists for Dubstar, skipping...
# Parquet file already exists for Silversun Pickups, skipping...
# Parquet file already exists for Caribou, skipping...
# Parquet file already exists for Blossoms, skipping...
# Parquet file already exists for Emma Townshend, skipping...
# Parquet file already exists for Across The Sky, skipping...
# Parquet file already exists for Sun Kil Moon, skipping...
# Parquet file already exists for Diane Schuur, skipping...
# Parquet file already exists for Darkhouse Family, skipping...
# Parquet file already exists for Ryan Kisor, skipping...
# Parquet file already exists for Thomas Dolby, skipping...
# Parquet file already exists for Glassjaw, skipping...
# Parquet file already exists for The Pioneers, skipping...
# Parquet file already exists for Steve Bug, skipping...
# Parquet file already exists for Fats Navarro, skipping...
# Parquet file already exists for Mary Jane Girls, skipping...
# Parquet file already exists for Animotion, skipping...
# Parquet file already exists for Alexander von Zemlinsky, skipping...
# Parquet file already exists for Barbara Dennerlein, skipping...
# Parquet file already exists for Wolfmother, skipping...
# Parquet file already exists for Body Count, skipping...
# Parquet file already exists for The Plimsouls, skipping...
# Parquet file already exists for Danny Elfman, skipping...
# Parquet file already exists for Geddy Lee, skipping...
# Parquet file already exists for Poor Righteous Teachers, skipping...
# Parquet file already exists for John Cohen, skipping...
# Parquet file already exists for Operation Ivy, skipping...
# Parquet file already exists for Urge Overkill, skipping...
# Parquet file already exists for The Used, skipping...
# Parquet file already exists for Them Crooked Vultures, skipping...
# Parquet file already exists for Patty Smyth, skipping...
# Parquet file already exists for Deniece Williams, skipping...
# Parquet file already exists for A$AP Ferg, skipping...
# Parquet file already exists for Ronnie Milsap, skipping...
# Parquet file already exists for The Ladybug Transistor, skipping...
# Parquet file already exists for Robbie Fulks, skipping...
# Parquet file already exists for Andreas Moe, skipping...
# Parquet file already exists for Great Big Sea, skipping...
# Parquet file already exists for Chumbawamba, skipping...
# Parquet file already exists for Henry Cow, skipping...
# Parquet file already exists for Post Malone, skipping...
# Parquet file already exists for Model 500, skipping...
# Parquet file already exists for Youth Code, skipping...
# Parquet file already exists for Jody Watley, skipping...
# Parquet file already exists for Nerf Herder, skipping...
# Parquet file already exists for T.I., skipping...
# Parquet file already exists for Carl Perkins, skipping...
# Parquet file already exists for Christopher Owens, skipping...
# Parquet file already exists for Groove Collective, skipping...
# Parquet file already exists for Morris Albert, skipping...
# Parquet file already exists for Adam Guettel, skipping...
# Parquet file already exists for The Datsuns, skipping...
# Parquet file already exists for Linda Perry, skipping...
# Parquet file already exists for Tift Merritt, skipping...
# Parquet file already exists for American Hi-Fi, skipping...
# Parquet file already exists for Swans, skipping...
# Parquet file already exists for Grace Jones, skipping...
# Parquet file already exists for Derroll Adams, skipping...
# Parquet file already exists for The Golden Dogs, skipping...
# Parquet file already exists for Dan Baird, skipping...
# Parquet file already exists for The Adverts, skipping...
# Parquet file already exists for Allstar Weekend, skipping...
# Parquet file already exists for Jim O'Rourke, skipping...
# Parquet file already exists for Anton Webern, skipping...
# Parquet file already exists for Nelly Furtado, skipping...
# Parquet file already exists for Elliott Sharp, skipping...
# Parquet file already exists for Rev. Claude Jeter, skipping...
# Parquet file already exists for Chris Butler, skipping...
# Parquet file already exists for Lionrock, skipping...
# Parquet file already exists for Bloodhound Gang, skipping...
# Parquet file already exists for Hubert Sumlin, skipping...
# Parquet file already exists for Liz Story, skipping...
# Parquet file already exists for Mark O'Connor, skipping...
# Parquet file already exists for Country Joe McDonald, skipping...
# Parquet file already exists for Dave Navarro, skipping...
# Parquet file already exists for Rick Wakeman, skipping...
# Parquet file already exists for The Wonder Years, skipping...
# Parquet file already exists for Slapp Happy, skipping...
# Parquet file already exists for The Black Maria, skipping...
# Parquet file already exists for Downchild Blues Band, skipping...
# Parquet file already exists for Viva L'American Death Ray Music, skipping...
# Parquet file already exists for Michael Krassner, skipping...
# Parquet file already exists for Hate Dept., skipping...
# Parquet file already exists for The Partridge Family, skipping...
# Parquet file already exists for Jake E. Lee, skipping...
# Parquet file already exists for The Flesh Eaters, skipping...
# Parquet file already exists for Tamia, skipping...
# Parquet file already exists for Charlie Palmieri, skipping...
# Parquet file already exists for Dallas Wayne, skipping...
# Parquet file already exists for Castlecomer, skipping...
# Parquet file already exists for Keane, skipping...
# Parquet file already exists for the everybodyfields, skipping...
# Parquet file already exists for A Thorn For Every Heart, skipping...
# Parquet file already exists for Magnolia Electric Co., skipping...
# Parquet file already exists for Ela Orleans, skipping...
# Parquet file already exists for Blondie, skipping...
# Parquet file already exists for Nick Mulvey, skipping...
# Parquet file already exists for Syd Straw, skipping...
# Parquet file already exists for John Pizzarelli, skipping...
# Parquet file already exists for Tom Vek, skipping...
# Parquet file already exists for Bill Anderson, skipping...
# Parquet file already exists for Gary Stewart, skipping...
# Parquet file already exists for Nicki Minaj, skipping...
# Parquet file already exists for Volbeat, skipping...
# Parquet file already exists for The Mighty Imperials, skipping...
# Parquet file already exists for Andrew W.K., skipping...
# Parquet file already exists for Melvins, skipping...
# Parquet file already exists for Upchurch, skipping...
# Parquet file already exists for Mal Waldron, skipping...
# Parquet file already exists for Garfield Akers, skipping...
# Parquet file already exists for Whiskeytown, skipping...
# Parquet file already exists for Cave In, skipping...
# Parquet file already exists for Venom, skipping...
# Parquet file already exists for Demdike Stare, skipping...
# Parquet file already exists for MF DOOM, skipping...
# Parquet file already exists for Todd Rhodes, skipping...
# Parquet file already exists for Julie Doiron, skipping...
# Parquet file already exists for Larry Young, skipping...
# Parquet file already exists for Glasser, skipping...
# Parquet file already exists for Silje Nes, skipping...
# Parquet file already exists for Dro Carey, skipping...
# Parquet file already exists for Everything Everything, skipping...
# Parquet file already exists for Margaret Glaspy, skipping...
# Parquet file already exists for Kenny Barron, skipping...
# Parquet file already exists for Judy Henske, skipping...
# Parquet file already exists for Gallon Drunk, skipping...
# Parquet file already exists for Marcia Ball, skipping...
# Parquet file already exists for Orchestra Baobab, skipping...
# Parquet file already exists for Pig Destroyer, skipping...
# Parquet file already exists for The Kentucky Headhunters, skipping...
# Parquet file already exists for Carla Bley, skipping...
# Parquet file already exists for Room 5, skipping...
# Parquet file already exists for Mastodon, skipping...
# Parquet file already exists for Eagulls, skipping...
# Parquet file already exists for Company Flow, skipping...
# Parquet file already exists for Dr. Strangely Strange, skipping...
# Parquet file already exists for Pete Seeger, skipping...
# Parquet file already exists for Bill Chase, skipping...
# Parquet file already exists for Charlie Peacock, skipping...
# Parquet file already exists for Brooks & Dunn, skipping...
# Parquet file already exists for Afroman, skipping...
# Parquet file already exists for The Godfathers, skipping...
# Parquet file already exists for Clogs, skipping...
# Parquet file already exists for Casualty Park, skipping...
# Parquet file already exists for Placebo, skipping...
# Parquet file already exists for Shooter Jennings, skipping...
# Parquet file already exists for Vic Damone, skipping...
# Parquet file already exists for Eagles, skipping...
# Parquet file already exists for Semisonic, skipping...
# Parquet file already exists for Warren G, skipping...
# Parquet file already exists for Cedar Walton, skipping...
# Parquet file already exists for Senser, skipping...
# Parquet file already exists for Bronski Beat, skipping...
# Parquet file already exists for James Hetfield, skipping...
# Parquet file already exists for Little Sammy Davis, skipping...
# Parquet file already exists for Luke Combs, skipping...
# Parquet file already exists for Sarah Ross, skipping...
# Parquet file already exists for Thee Headcoatees, skipping...
# Parquet file already exists for Bluff City, skipping...
# Parquet file already exists for Langston Hughes, skipping...
# Parquet file already exists for Tony MacAlpine, skipping...
# Parquet file already exists for El-P, skipping...
# Parquet file already exists for Chris Brown, skipping...
# Parquet file already exists for Bloc Party, skipping...
# Parquet file already exists for Young Statues, skipping...
# Parquet file already exists for Mike Scott, skipping...
# Parquet file already exists for Blind John Davis, skipping...
# Parquet file already exists for Smoking Popes, skipping...
# Parquet file already exists for Kalmah, skipping...
# Parquet file already exists for Les Rythmes Digitales, skipping...
# Parquet file already exists for Grim Reaper, skipping...
# Parquet file already exists for Bobby Bare, skipping...
# Parquet file already exists for Tina Turner, skipping...
# Parquet file already exists for '68 Comeback, skipping...
# Parquet file already exists for Frantz Casseus, skipping...
# Parquet file already exists for Kellie Pickler, skipping...
# Parquet file already exists for Simon Joyner, skipping...
# Parquet file already exists for Bob Brookmeyer, skipping...
# Parquet file already exists for The Crucifucks, skipping...
# Parquet file already exists for Norma Jean, skipping...
# Parquet file already exists for The Hi-Lo's, skipping...
# Parquet file already exists for Eat Static, skipping...
# Parquet file already exists for Cardinals Pride, skipping...
# Parquet file already exists for The Roosevelts, skipping...
# Parquet file already exists for Blitzen Trapper, skipping...
# Parquet file already exists for Busta Rhymes, skipping...
# Parquet file already exists for Adam Green, skipping...
# Parquet file already exists for Laurent Garnier, skipping...
# Parquet file already exists for Alex Gopher, skipping...
# Parquet file already exists for Gary Hoey, skipping...
# Parquet file already exists for Tall Black Guy, skipping...
# Parquet file already exists for Charlie Feathers, skipping...
# Parquet file already exists for Hanne Hukkelberg, skipping...
# Parquet file already exists for The Nightcrawlers, skipping...
# Parquet file already exists for Lindsey Buckingham, skipping...
# Parquet file already exists for Luscious Jackson, skipping...
# Parquet file already exists for NRBQ, skipping...
# Parquet file already exists for Lou Barlow, skipping...
# Parquet file already exists for Snooks Eaglin, skipping...
# Parquet file already exists for Tahiti 80, skipping...
# Parquet file already exists for Winterpills, skipping...
# Parquet file already exists for James Blunt, skipping...
# Parquet file already exists for Cabbage, skipping...
# Parquet file already exists for Street Dogs, skipping...
# Parquet file already exists for Ann Hampton Callaway, skipping...
# Parquet file already exists for Black Mountain, skipping...
# Parquet file already exists for Frou Frou, skipping...
# Parquet file already exists for William Prince, skipping...
# Parquet file already exists for The Minders, skipping...
# Parquet file already exists for Fréhel, skipping...
# Parquet file already exists for Rod Bernard, skipping...
# Parquet file already exists for Boredoms, skipping...
# Parquet file already exists for Mandy Moore, skipping...
# Parquet file already exists for Hot Tuna, skipping...
# Parquet file already exists for John Gilmore, skipping...
# Parquet file already exists for Jimmy Bryant, skipping...
# Parquet file already exists for Big Brother & The Holding Company, skipping...
# Parquet file already exists for Little Milton, skipping...
# Parquet file already exists for Carolina Chocolate Drops, skipping...
# Parquet file already exists for D.R.I., skipping...
# Parquet file already exists for Rahzel, skipping...
# Parquet file already exists for Nosferatu, skipping...
# Parquet file already exists for Sturgill Simpson, skipping...
# Parquet file already exists for Axl Rose, skipping...
# Parquet file already exists for The Marcels, skipping...
# Parquet file already exists for Deanna Kirk, skipping...
# Parquet file already exists for Bo Diddley, skipping...
# Parquet file already exists for Mabel Mercer, skipping...
# Parquet file already exists for Pulseprogramming, skipping...
# Parquet file already exists for John Patitucci, skipping...
# Parquet file already exists for India.Arie, skipping...
# Parquet file already exists for Anti-Flag, skipping...
# Parquet file already exists for San Serac, skipping...
# Parquet file already exists for Boy George, skipping...
# Parquet file already exists for Zero Boys, skipping...
# Parquet file already exists for Madcon, skipping...
# Parquet file already exists for Mayer Hawthorne, skipping...
# Parquet file already exists for Air Waves, skipping...
# Parquet file already exists for Les Claypool, skipping...
# Parquet file already exists for The Juliana Theory, skipping...
# Parquet file already exists for Orthrelm, skipping...
# Parquet file already exists for Lou Donaldson, skipping...
# Parquet file already exists for Lily Allen, skipping...
# Parquet file already exists for Bob Hope, skipping...
# Parquet file already exists for Dokken, skipping...
# Parquet file already exists for Gojira, skipping...
# Parquet file already exists for Jamila Woods, skipping...
# Parquet file already exists for The Deadly Snakes, skipping...
# Parquet file already exists for Greg Davis, skipping...
# Parquet file already exists for The Chieftains, skipping...
# Parquet file already exists for Honeymoon Suite, skipping...
# Parquet file already exists for Alexander von Schlippenbach, skipping...
# Parquet file already exists for Joe Walsh, skipping...
# Parquet file already exists for Das EFX, skipping...
# Parquet file already exists for The Sonora Pine, skipping...
# Parquet file already exists for The Funk Brothers, skipping...
# Parquet file already exists for KRS-One, skipping...
# Parquet file already exists for Eric Bogosian, skipping...
# Parquet file already exists for Joe Henderson, skipping...
# Parquet file already exists for Univers Zero, skipping...
# Parquet file already exists for TRUSTcompany, skipping...
# Parquet file already exists for Tadd Dameron, skipping...
# Parquet file already exists for Salad Boys, skipping...
# Parquet file already exists for Danger Danger, skipping...
# Parquet file already exists for Richard Berry, skipping...
# Parquet file already exists for Billy Ocean, skipping...
# Parquet file already exists for Mack 10, skipping...
# Parquet file already exists for Chicago Underground Duo, skipping...
# Parquet file already exists for Theo Parrish, skipping...
# Parquet file already exists for Don Gibson, skipping...
# Parquet file already exists for Albert Ammons, skipping...
# Parquet file already exists for Jimmy Barnes, skipping...
# Parquet file already exists for June Christy, skipping...
# Parquet file already exists for Tony Glover, skipping...
# Parquet file already exists for The Last Internationale, skipping...
# Parquet file already exists for Pulse Ultra, skipping...
# Parquet file already exists for The Meat Purveyors, skipping...
# Parquet file already exists for Brian Lynch, skipping...
# Parquet file already exists for Shabba Ranks, skipping...
# Parquet file already exists for Stonewall Jackson, skipping...
# Parquet file already exists for The Manhattans, skipping...
# Parquet file already exists for Ratatat, skipping...
# Parquet file already exists for Alien Ant Farm, skipping...
# Parquet file already exists for Nico Muhly, skipping...
# Parquet file already exists for Savina Yannatou, skipping...
# Parquet file already exists for Red Nichols, skipping...
# Parquet file already exists for Hooverphonic, skipping...
# Parquet file already exists for Shirley Scott, skipping...
# Parquet file already exists for Planningtorock, skipping...
# Parquet file already exists for Clifton Chenier, skipping...
# Parquet file already exists for Radiohead, skipping...
# Parquet file already exists for Fifth Harmony, skipping...
# Parquet file already exists for Aubrie Sellers, skipping...
# Parquet file already exists for Ricky Van Shelton, skipping...
# Parquet file already exists for Merzbow, skipping...
# Parquet file already exists for George Duke, skipping...
# Parquet file already exists for Khalid, skipping...
# Parquet file already exists for Arbor Labor Union, skipping...
# Parquet file already exists for SHeDAISY, skipping...
# Parquet file already exists for The Rascals, skipping...
# Parquet file already exists for Baker Grace, skipping...
# Parquet file already exists for Lavender Diamond, skipping...
# Parquet file already exists for Nigel Holton, skipping...
# Parquet file already exists for David Mayfield, skipping...
# Parquet file already exists for Dave Pike, skipping...
# Parquet file already exists for Glasses Malone, skipping...
# Parquet file already exists for Earl Hooker, skipping...
# Parquet file already exists for Casey Scott, skipping...
# Parquet file already exists for Diddy, skipping...
# Parquet file already exists for Cowboy Troy, skipping...
# Parquet file already exists for Terror Fabulous, skipping...
# Parquet file already exists for The Detroit Cobras, skipping...
# Parquet file already exists for Avoid One Thing, skipping...
# Parquet file already exists for Skyler Stonestreet, skipping...
# Parquet file already exists for Ascension, skipping...
# Parquet file already exists for John Hammond, skipping...
# Parquet file already exists for Dorothy Ashby, skipping...
# Parquet file already exists for The Von Bondies, skipping...
# Parquet file already exists for Two Door Cinema Club, skipping...
# Parquet file already exists for Papoose, skipping...
# Parquet file already exists for The Time Flys, skipping...
# Parquet file already exists for Jonn Serrie, skipping...
# Parquet file already exists for Strike Anywhere, skipping...
# Parquet file already exists for Disco Inferno, skipping...
# Parquet file already exists for Incan Abraham, skipping...
# Parquet file already exists for Stan Ridgway, skipping...
# Parquet file already exists for Doyle Lawson & Quicksilver, skipping...
# Parquet file already exists for Afterlife, skipping...
# Parquet file already exists for Amy Allison, skipping...
# Parquet file already exists for Jimmy Forrest, skipping...
# Parquet file already exists for Kaskade, skipping...
# Parquet file already exists for An Albatross, skipping...
# Parquet file already exists for Booker Ervin, skipping...
# Parquet file already exists for Blaque, skipping...
# Parquet file already exists for Benji Lewis, skipping...
# Parquet file already exists for Free Energy, skipping...
# Parquet file already exists for Mattias IA Eklundh, skipping...
# Parquet file already exists for Action Action, skipping...
# Parquet file already exists for Killa Tay, skipping...
# Parquet file already exists for John Vanderslice, skipping...
# Parquet file already exists for The Negatones, skipping...
# Parquet file already exists for Gregory Abbott, skipping...
# Parquet file already exists for Tony Arata, skipping...
# Parquet file already exists for Noel Redding, skipping...
# Parquet file already exists for Art Pepper, skipping...
# Parquet file already exists for Kenny Larkin, skipping...
# Parquet file already exists for The Blasters, skipping...
# Parquet file already exists for Rufus Thomas, skipping...
# Parquet file already exists for Luis Fonsi, skipping...
# Parquet file already exists for Jack DeJohnette, skipping...
# Parquet file already exists for Joe Lovano, skipping...
# Parquet file already exists for Kal P. Dal, skipping...
# Parquet file already exists for Charles Kynard, skipping...
# Parquet file already exists for Exodus, skipping...
# Parquet file already exists for Kenny Werner, skipping...
# Parquet file already exists for The Marshall Tucker Band, skipping...
# Parquet file already exists for Sam Kinison, skipping...
# Parquet file already exists for Quarashi, skipping...
# Parquet file already exists for Joy Williams, skipping...
# Parquet file already exists for Red Callender, skipping...
# Parquet file already exists for Dick Hyman, skipping...
# Parquet file already exists for Andrew Lloyd Webber, skipping...
# Parquet file already exists for Mick Ronson, skipping...
# Parquet file already exists for The All-American Rejects, skipping...
# Parquet file already exists for Lori McKenna, skipping...
# Parquet file already exists for Strange Wilds, skipping...
# Parquet file already exists for RJD2, skipping...
# Parquet file already exists for Doll Skin, skipping...
# Parquet file already exists for Palace, skipping...
# Parquet file already exists for The Smashing Pumpkins, skipping...
# Parquet file already exists for Luniz, skipping...
# Parquet file already exists for Pete Yorn, skipping...
# Parquet file already exists for Burial, skipping...
# Parquet file already exists for River Matthews, skipping...
# Parquet file already exists for Chris Isaak, skipping...
# Parquet file already exists for Cactus World News, skipping...
# Parquet file already exists for Cappadonna, skipping...
# Parquet file already exists for Terry Reid, skipping...
# Parquet file already exists for Six Finger Satellite, skipping...
# Parquet file already exists for Terry Jacks, skipping...
# Parquet file already exists for Harley Allen, skipping...
# Parquet file already exists for Moreno Veloso, skipping...
# Parquet file already exists for Vera Lynn, skipping...
# Parquet file already exists for Adema, skipping...
# Parquet file already exists for These Animal Men, skipping...
# Parquet file already exists for Good Clean Fun, skipping...
# Parquet file already exists for Jean Sibelius, skipping...
# Parquet file already exists for Michael Bolton, skipping...
# Parquet file already exists for Danilo Perez, skipping...
# Parquet file already exists for The Violents, skipping...
# Parquet file already exists for Baths, skipping...
# Parquet file already exists for Anita O'Day, skipping...
# Parquet file already exists for Conflict, skipping...
# Parquet file already exists for Michael Crawford, skipping...
# Parquet file already exists for Gallows, skipping...
# Parquet file already exists for Meat Loaf, skipping...
# Parquet file already exists for The Original Soul Stirrers, skipping...
# Parquet file already exists for Jackie Wilson, skipping...
# Parquet file already exists for Sex Gang Children, skipping...
# Parquet file already exists for Faith No More, skipping...
# Parquet file already exists for Wheatus, skipping...
# Parquet file already exists for The Meatmen, skipping...
# Parquet file already exists for Lansing-Dreiden, skipping...
# Parquet file already exists for Sister Sledge, skipping...
# Parquet file already exists for Bobby Braddock, skipping...
# Parquet file already exists for Rae Morris, skipping...
# Parquet file already exists for Headcase, skipping...
# Parquet file already exists for Kevin Garrett, skipping...
# Parquet file already exists for Joy Zipper, skipping...
# Parquet file already exists for Titanic Sinclair, skipping...
# Parquet file already exists for Björn Olsson, skipping...
# Parquet file already exists for Tone Stith, skipping...
# Parquet file already exists for ROAM, skipping...
# Parquet file already exists for The Turtles, skipping...
# Parquet file already exists for Sherbet, skipping...
# Parquet file already exists for Orleans, skipping...
# Parquet file already exists for Dom Um Romao, skipping...
# Parquet file already exists for Leo Watson, skipping...
# Parquet file already exists for Warren Smith, skipping...
# Parquet file already exists for Debra Laws, skipping...
# Parquet file already exists for Pérez Prado, skipping...
# Parquet file already exists for Carleen Anderson, skipping...
# Parquet file already exists for Disturbed, skipping...
# Parquet file already exists for Mark Isham, skipping...
# Parquet file already exists for Spray Paint, skipping...
# Parquet file already exists for Jane Siberry, skipping...
# Parquet file already exists for Tom Principato, skipping...
# Parquet file already exists for Eve, skipping...
# Parquet file already exists for Peter Rowan, skipping...
# Parquet file already exists for Chris Connelly, skipping...
# Parquet file already exists for Vitalic, skipping...
# Parquet file already exists for Jason Becker, skipping...
# Parquet file already exists for The Marx Brothers, skipping...
# Parquet file already exists for Don Grolnick, skipping...
# Parquet file already exists for Freddy Fender, skipping...
# Parquet file already exists for All City, skipping...
# Parquet file already exists for Failure, skipping...
# Parquet file already exists for Karlheinz Stockhausen, skipping...
# Parquet file already exists for Starrah, skipping...
# Parquet file already exists for Jesse Powell, skipping...
# Parquet file already exists for Pierce Turner, skipping...
# Parquet file already exists for Adam Duritz, skipping...
# Parquet file already exists for Cole Taylor, skipping...
# Parquet file already exists for Roots Manuva, skipping...
# Parquet file already exists for The Vamps, skipping...
# Parquet file already exists for Good NEWZ Girls, skipping...
# Parquet file already exists for David Cook, skipping...
# Parquet file already exists for Alicia Keys, skipping...
# Parquet file already exists for Western Electric, skipping...
# Parquet file already exists for Mouthwash, skipping...
# Parquet file already exists for Spade Cooley, skipping...
# Parquet file already exists for Don "Sugarcane" Harris, skipping...
# Parquet file already exists for John Paul Jones, skipping...
# Parquet file already exists for Trainwreck Riders, skipping...
# Parquet file already exists for Carl Czerny, skipping...
# Parquet file already exists for Boom Bip, skipping...
# Parquet file already exists for Dave Burrell, skipping...
# Parquet file already exists for Michael Wycoff, skipping...
# Parquet file already exists for Kira Isabella, skipping...
# Parquet file already exists for Jon Hendricks, skipping...
# Parquet file already exists for Flesh For Lulu, skipping...
# Parquet file already exists for Flat Worms, skipping...
# Parquet file already exists for Lucille Bogan, skipping...
# Parquet file already exists for Vico C, skipping...
# Parquet file already exists for Anthony Kiedis, skipping...
# Parquet file already exists for Paradise Lost, skipping...
# Parquet file already exists for Steve Reid, skipping...
# Parquet file already exists for Stacy Lattisaw, skipping...
# Parquet file already exists for Howard Roberts, skipping...
# Parquet file already exists for Clark, skipping...
# Parquet file already exists for U.S. Maple, skipping...
# Parquet file already exists for Little Mix, skipping...
# Parquet file already exists for Willie Nile, skipping...
# Parquet file already exists for Svend Asmussen, skipping...
# Parquet file already exists for Lee Clayton, skipping...
# Parquet file already exists for Guster, skipping...
# Parquet file already exists for Swedish House Mafia, skipping...
# Parquet file already exists for Feist, skipping...
# Parquet file already exists for Sam Smith, skipping...
# Parquet file already exists for Tony Sheridan, skipping...
# Parquet file already exists for Humphrey Lyttelton, skipping...
# Parquet file already exists for The Textones, skipping...
# Parquet file already exists for Stateless, skipping...
# Parquet file already exists for Underground Resistance, skipping...
# Parquet file already exists for Pink Grease, skipping...
# Parquet file already exists for Three Trapped Tigers, skipping...
# Parquet file already exists for Mike Oldfield, skipping...
# Parquet file already exists for Ronnie Hawkins, skipping...
# Parquet file already exists for Gino Vannelli, skipping...
# Parquet file already exists for Bill Staines, skipping...
# Parquet file already exists for Richard Belzer, skipping...
# Parquet file already exists for Danielle Nicole, skipping...
# Parquet file already exists for Britny Fox, skipping...
# Parquet file already exists for Bobby Womack, skipping...
# Parquet file already exists for White Lies, skipping...
# Parquet file already exists for Alex Lifeson, skipping...
# Parquet file already exists for Vixen, skipping...
# Parquet file already exists for They Might Be Giants, skipping...
# Parquet file already exists for Akercocke, skipping...
# Parquet file already exists for The Casket Lottery, skipping...
# Parquet file already exists for Grandpa Jones, skipping...
# Parquet file already exists for The Rooftop Singers, skipping...
# Parquet file already exists for Ella Mae Morse, skipping...
# Parquet file already exists for Bette Midler, skipping...
# Parquet file already exists for Twin Forks, skipping...
# Parquet file already exists for Baxter Dury, skipping...
# Parquet file already exists for Danny Thompson, skipping...
# Parquet file already exists for Dewey Balfa, skipping...
# Parquet file already exists for Angel Witch, skipping...
# Parquet file already exists for Wild Party, skipping...
# Parquet file already exists for 2Pac, skipping...
# Parquet file already exists for Compay Segundo, skipping...
# Parquet file already exists for Charles Koechlin, skipping...
# Parquet file already exists for The Hangabouts, skipping...
# Parquet file already exists for Sonny Payne, skipping...
# Parquet file already exists for The Microphones, skipping...
# Parquet file already exists for Alex Sipiagin, skipping...
# Parquet file already exists for Chris Stills, skipping...
# Parquet file already exists for Arthur Honegger, skipping...
# Parquet file already exists for ONE OK ROCK, skipping...
# Parquet file already exists for Sex Mob, skipping...
# Parquet file already exists for Hurricane G, skipping...
# Parquet file already exists for South Park Mexican, skipping...
# Parquet file already exists for Old Crow Medicine Show, skipping...
# Parquet file already exists for Zoltán Kodály, skipping...
# Parquet file already exists for Jean-Jacques Perrey, skipping...
# Parquet file already exists for Mount Shasta, skipping...
# Parquet file already exists for Violeta Parra, skipping...
# Parquet file already exists for Róisín Murphy, skipping...
# Parquet file already exists for Winston Jarrett, skipping...
# Parquet file already exists for The Pine Hill Haints, skipping...
# Parquet file already exists for Eleni Mandell, skipping...
# Parquet file already exists for The Bluetones, skipping...
# Parquet file already exists for Ithamara Koorax, skipping...
# Parquet file already exists for Randy Hansen, skipping...
# Parquet file already exists for Andy Gibb, skipping...
# Parquet file already exists for Vanishing Twin, skipping...
# Parquet file already exists for Killer Mike, skipping...
# Parquet file already exists for Brokeback, skipping...
# Parquet file already exists for The Captain Howdy, skipping...
# Parquet file already exists for Alan Lomax, skipping...
# Parquet file already exists for Winger, skipping...
# Parquet file already exists for Jamie T, skipping...
# Parquet file already exists for Simple Kid, skipping...
# Parquet file already exists for Thad Jones, skipping...
# Parquet file already exists for John Stevens, skipping...
# Parquet file already exists for Underoath, skipping...
# Parquet file already exists for Miklós Rózsa, skipping...
# Parquet file already exists for Lotte Lenya, skipping...
# Parquet file already exists for Tank, skipping...
# Parquet file already exists for Digital Underground, skipping...
# Parquet file already exists for King Sunny Ade, skipping...
# Parquet file already exists for John Tchicai, skipping...
# Parquet file already exists for Strike Under, skipping...
# Parquet file already exists for Lindsay Lohan, skipping...
# Parquet file already exists for Earl Brutus, skipping...
# Parquet file already exists for Tim Lyddon, skipping...
# Parquet file already exists for Meshuggah, skipping...
# Parquet file already exists for The Ronettes, skipping...
# Parquet file already exists for Dan Sultan, skipping...
# Parquet file already exists for Richie Kotzen, skipping...
# Parquet file already exists for Lili Haydn, skipping...
# Parquet file already exists for The Sunshine Fix, skipping...
# Parquet file already exists for Charles Manier, skipping...
# Parquet file already exists for Fille Qui Mousse, skipping...
# Parquet file already exists for Change, skipping...
# Parquet file already exists for Amp Fiddler, skipping...
# Parquet file already exists for DJ Toomp, skipping...
# Parquet file already exists for Sue Foley, skipping...
# Parquet file already exists for Darlene Love, skipping...
# Parquet file already exists for Juan Atkins, skipping...
# Parquet file already exists for Ratgrave, skipping...
# Parquet file already exists for Devendra Banhart, skipping...
# Parquet file already exists for Keren Ann, skipping...
# Parquet file already exists for Cam starring Anggun, skipping...
# Parquet file already exists for Ozomatli, skipping...
# Parquet file already exists for Agnostic Front, skipping...
# Parquet file already exists for Tha Eastsidaz, skipping...
# Parquet file already exists for Mates of State, skipping...
# Parquet file already exists for That Petrol Emotion, skipping...
# Parquet file already exists for Hi-Five, skipping...
# Parquet file already exists for The Keggs, skipping...
# Parquet file already exists for Shelly Manne, skipping...
# Parquet file already exists for Craig Mack, skipping...
# Parquet file already exists for Papa Roach, skipping...
# Parquet file already exists for Sting, skipping...
# Parquet file already exists for MMOTHS, skipping...
# Parquet file already exists for Free Kitten, skipping...
# Parquet file already exists for Field Mob, skipping...
# Parquet file already exists for Sandy Denny, skipping...
# Parquet file already exists for John Cale, skipping...
# Parquet file already exists for Mutemath, skipping...
# Parquet file already exists for Hannah Montana, skipping...
# Parquet file already exists for Country Teasers, skipping...
# Parquet file already exists for FKA twigs, skipping...
# Parquet file already exists for Lydia Lunch, skipping...
# Parquet file already exists for The Flys, skipping...
# Parquet file already exists for Robert Cage, skipping...
# Parquet file already exists for Peter Himmelman, skipping...
# Parquet file already exists for Elle Belle, skipping...
# Parquet file already exists for Tyondai Braxton, skipping...
# Parquet file already exists for DeBarge, skipping...
# Parquet file already exists for Right Said Fred, skipping...
# Parquet file already exists for Sam Kulik, skipping...
# Parquet file already exists for Pavement, skipping...
# Parquet file already exists for Karamelo Santo, skipping...
# Parquet file already exists for Derrick May, skipping...
# Parquet file already exists for Don Patterson, skipping...
# Parquet file already exists for Willie Colón, skipping...
# Parquet file already exists for Jules Shear, skipping...
# Parquet file already exists for Jonzun Crew, skipping...
# Parquet file already exists for Ace of Base, skipping...
# Parquet file already exists for Michael Price, skipping...
# Parquet file already exists for *NSYNC, skipping...
# Parquet file already exists for Gill Landry, skipping...
# Parquet file already exists for Pieces Of A Dream, skipping...
# Parquet file already exists for Garrison Starr, skipping...
# Parquet file already exists for Les Savy Fav, skipping...
# Parquet file already exists for Tamba 4, skipping...
# Parquet file already exists for Miley Cyrus, skipping...
# Parquet file already exists for Airy Jeanine, skipping...
# Parquet file already exists for Marlena Shaw, skipping...
# Parquet file already exists for Fu Manchu, skipping...
# Parquet file already exists for Sublime, skipping...
# Parquet file already exists for Mike Patton, skipping...
# Parquet file already exists for Hilltop Hoods, skipping...
# Parquet file already exists for Smile Empty Soul, skipping...
# Parquet file already exists for Lalah Hathaway, skipping...
# Parquet file already exists for King Missile, skipping...
# Parquet file already exists for Overkill, skipping...
# Parquet file already exists for Oval, skipping...
# Parquet file already exists for Lifetime, skipping...
# Parquet file already exists for Don Blackman, skipping...
# Parquet file already exists for Narada Michael Walden, skipping...
# Parquet file already exists for Black 47, skipping...
# Parquet file already exists for Wings, skipping...
# Parquet file already exists for The Amazons, skipping...
# Parquet file already exists for Melted Toys, skipping...
# Parquet file already exists for Frank Rosolino, skipping...
# Parquet file already exists for The Tear Garden, skipping...
# Parquet file already exists for Popol Vuh, skipping...
# Parquet file already exists for Uriah Heep, skipping...
# Parquet file already exists for Bobby Bradford, skipping...
# Parquet file already exists for The Frames, skipping...
# Parquet file already exists for Ray Anthony, skipping...
# Parquet file already exists for Gil Scott-Heron, skipping...
# Parquet file already exists for You Am I, skipping...
# Parquet file already exists for Happy Family, skipping...
# Parquet file already exists for Wire, skipping...
# Parquet file already exists for Dead Meadow, skipping...
# Parquet file already exists for David Bowie, skipping...
# Parquet file already exists for Basia, skipping...
# Parquet file already exists for Gang Green, skipping...
# Parquet file already exists for Dressy Bessy, skipping...
# Parquet file already exists for Röyksopp, skipping...
# ...
# Parquet file already exists for Dale Hawkins, skipping...
# Parquet file already exists for Sleepytime Gorilla Museum, skipping...
# Parquet file already exists for The Tornados, skipping...
# Parquet file already exists for Beverley Knight, skipping...
# Parquet file already exists for Lowell Fulson, skipping...
# Parquet file already exists for Big Wreck, skipping...
# Parquet file already exists for Trans Am, skipping...
# Parquet file already exists for Kelis, skipping...
# Parquet file already exists for Carolyn Hester, skipping...
# Parquet file already exists for Kane Strang, skipping...
# Parquet file already exists for Los Campesinos!, skipping...
# Parquet file already exists for The Ravens, skipping...
# Parquet file already exists for Johnny Coles, skipping...
# Parquet file already exists for A Sunny Day In Glasgow, skipping...
# Parquet file already exists for Toni Childs, skipping...
# Parquet file already exists for Fine Young Cannibals, skipping...
# Parquet file already exists for Manic Street Preachers, skipping...
# Parquet file already exists for Randy Rhoads, skipping...
# Parquet file already exists for D Generation, skipping...
# Parquet file already exists for Breaking Benjamin, skipping...
# Parquet file already exists for Jordan Rakei, skipping...
# Parquet file already exists for The Raveonettes, skipping...
# Parquet file already exists for Oysterhead, skipping...
# Parquet file already exists for Zac Efron, skipping...
# Parquet file already exists for Memphis Minnie, skipping...
# Parquet file already exists for White Willow, skipping...
# Parquet file already exists for The Impossibles, skipping...
# Parquet file already exists for Andy White, skipping...
# Parquet file already exists for Daryle Singletary, skipping...
# Parquet file already exists for Mutual Benefit, skipping...
# Parquet file already exists for Anthony Green, skipping...
# Parquet file already exists for Leonard Bernstein, skipping...
# Parquet file already exists for Decyfer Down, skipping...
# Parquet file already exists for Daedelus, skipping...
# Parquet file already exists for Bud Freeman, skipping...
# Parquet file already exists for Brian Kennedy, skipping...
# Parquet file already exists for Janis Ian, skipping...
# Parquet file already exists for The Moody Blues, skipping...
# Parquet file already exists for Technotronic, skipping...
# Parquet file already exists for Obits, skipping...
# Parquet file already exists for Gordon Lightfoot, skipping...
# Parquet file already exists for The Echoing Green, skipping...
# Parquet file already exists for Miss Li, skipping...
# Parquet file already exists for Justin Nozuka, skipping...
# Parquet file already exists for Ty Herndon, skipping...
# Parquet file already exists for Sonny Sharrock, skipping...
# Parquet file already exists for Black Sabbath, skipping...
# Parquet file already exists for Little Richard, skipping...
# Parquet file already exists for Jimmy Webb, skipping...
# Parquet file already exists for Antimatter, skipping...
# Parquet file already exists for Dennis Dunaway, skipping...
# Parquet file already exists for Carrie Underwood, skipping...
# Parquet file already exists for Tav Falco's Panther Burns, skipping...
# Parquet file already exists for The Seeds, skipping...
# Parquet file already exists for Jason Falkner, skipping...
# Parquet file already exists for Larry Levan, skipping...
# Parquet file already exists for Morphine, skipping...
# Parquet file already exists for The Stratford 4, skipping...
# Parquet file already exists for Merril Bainbridge, skipping...
# Parquet file already exists for Lou Levy, skipping...
# Parquet file already exists for Red Rider, skipping...
# Parquet file already exists for Ronnie Lane, skipping...
# Parquet file already exists for Marc Ducret, skipping...
# Parquet file already exists for The Dirty Dozen Brass Band, skipping...
# Parquet file already exists for Aswad, skipping...
# Parquet file already exists for Blue Öyster Cult, skipping...
# Parquet file already exists for Pianosaurus, skipping...
# Parquet file already exists for Gorilla Biscuits, skipping...
# Parquet file already exists for Al Cohn, skipping...
# Parquet file already exists for William Clarke, skipping...
# Parquet file already exists for Slash, skipping...
# Parquet file already exists for Rollins Band, skipping...
# Parquet file already exists for Mad Season, skipping...
# Parquet file already exists for Wolfgang Voigt, skipping...
# Parquet file already exists for Elise LeGrow, skipping...
# Parquet file already exists for Mark Dresser, skipping...
# Parquet file already exists for Kate Voegele, skipping...
# Parquet file already exists for The Baptist Generals, skipping...
# Parquet file already exists for Guillemots, skipping...
# Parquet file already exists for The Hellecasters, skipping...
# Parquet file already exists for Kenny Wollesen, skipping...
# Parquet file already exists for Millie Jackson, skipping...
# Parquet file already exists for Marshall Jefferson, skipping...
# Parquet file already exists for The Beta Band, skipping...
# Parquet file already exists for Snooky Pryor, skipping...
# Parquet file already exists for Pablo Aslan, skipping...
# Parquet file already exists for Mutabaruka, skipping...
# Parquet file already exists for Umphrey's McGee, skipping...
# Parquet file already exists for MU330, skipping...
# Parquet file already exists for Platinum Pied Pipers, skipping...
# Parquet file already exists for Del Amitri, skipping...
# Parquet file already exists for Jonathan Coulton, skipping...
# Parquet file already exists for The Comas, skipping...
# Parquet file already exists for Igor Stravinsky, skipping...
# Parquet file already exists for Phoenix, skipping...
# Parquet file already exists for Plies, skipping...
# Parquet file already exists for Syd Barrett, skipping...
# Parquet file already exists for Alberta Hunter, skipping...
# Parquet file already exists for John Parish, skipping...
# Parquet file already exists for Down To The Bone, skipping...
# Parquet file already exists for Dirty Pretty Things, skipping...
# Parquet file already exists for Bill Graham, skipping...
# Parquet file already exists for Blue Ash, skipping...
# Parquet file already exists for David Guetta, skipping...
# Parquet file already exists for Martin Rev, skipping...
# Parquet file already exists for The Kooks, skipping...
# Parquet file already exists for Anathema, skipping...
# Parquet file already exists for Emma Pollock, skipping...
# Parquet file already exists for Chris Spheeris, skipping...
# Parquet file already exists for Neon Waltz, skipping...
# Parquet file already exists for Carole King, skipping...
# Parquet file already exists for Alicia Myers, skipping...
# Parquet file already exists for Erik Truffaz, skipping...
# Parquet file already exists for Yes, skipping...
# Parquet file already exists for The Lofty Pillars, skipping...
# Parquet file already exists for Oliver Sain, skipping...
# Parquet file already exists for Wes Finch, skipping...
# Parquet file already exists for Joe Maneri, skipping...
# Parquet file already exists for World Leader Pretend, skipping...
# Parquet file already exists for Jamaaladeen Tacuma, skipping...
# Parquet file already exists for Mildred Bailey, skipping...
# Parquet file already exists for Darren Sylvester, skipping...
# Parquet file already exists for Lisa "Left Eye" Lopes, skipping...
# Parquet file already exists for Schneider TM, skipping...
# Parquet file already exists for Caspar Brötzmann Massaker, skipping...
# Parquet file already exists for Captain Sensible, skipping...
# Parquet file already exists for Gene Simmons, skipping...
# Parquet file already exists for Morton Subotnick, skipping...
# Parquet file already exists for The Airborne Toxic Event, skipping...
# Parquet file already exists for Walter Beasley, skipping...
# Parquet file already exists for Plumb, skipping...
# Parquet file already exists for Hank Thompson, skipping...
# Parquet file already exists for Russell Malone, skipping...
# Parquet file already exists for Asobi Seksu, skipping...
# Parquet file already exists for Enemy You, skipping...
# Parquet file already exists for Romeo Void, skipping...
# Parquet file already exists for Turin Brakes, skipping...
# Parquet file already exists for Julee Cruise, skipping...
# Parquet file already exists for Hank Garland, skipping...
# Parquet file already exists for Jennifer Paige, skipping...
# Parquet file already exists for A Global Threat, skipping...
# Parquet file already exists for The Dark Fantastic, skipping...
# Parquet file already exists for Holy Fuck, skipping...
# Parquet file already exists for Carpenters, skipping...
# Parquet file already exists for The Capsules, skipping...
# Parquet file already exists for Bone Crusher, skipping...
# Parquet file already exists for Brett Dennen, skipping...
# Parquet file already exists for Don McLean, skipping...
# Parquet file already exists for Deadsy, skipping...
# Parquet file already exists for Eric Reed, skipping...
# Parquet file already exists for Tiësto, skipping...
# Parquet file already exists for Boo Hewerdine, skipping...
# Parquet file already exists for The Reflectors, skipping...
# Parquet file already exists for CJ Solar, skipping...
# Parquet file already exists for Junior Brown, skipping...
# Parquet file already exists for NOFX, skipping...
# Parquet file already exists for Rosie Flores, skipping...
# Parquet file already exists for The Anniversary, skipping...
# Parquet file already exists for Joe Bataan, skipping...
# Parquet file already exists for The Steamkings, skipping...
# Parquet file already exists for The Maytals, skipping...
# Parquet file already exists for Cymbals Eat Guitars, skipping...
# Parquet file already exists for Kandace Springs, skipping...
# Parquet file already exists for Liza Minnelli, skipping...
# Parquet file already exists for Howlin Rain, skipping...
# Parquet file already exists for Walter Gibbons, skipping...
# Parquet file already exists for Three Days Grace, skipping...
# Parquet file already exists for Sophie B. Hawkins, skipping...
# Parquet file already exists for Chuck Willis, skipping...
# Parquet file already exists for Holy Wave, skipping...
# Parquet file already exists for Willy DeVille, skipping...
# Parquet file already exists for Glen Moore, skipping...
# Parquet file already exists for Kristofer Maddigan, skipping...
# Parquet file already exists for The Supremes, skipping...
# Parquet file already exists for Gene Pitney, skipping...
# Parquet file already exists for 1990s, skipping...
# Parquet file already exists for Rachel Taylor, skipping...
# Parquet file already exists for Bo Weavil Jackson, skipping...
# Parquet file already exists for Roger McGuinn, skipping...
# Parquet file already exists for Dot Rotten, skipping...
# Parquet file already exists for Fatboy Slim, skipping...
# Parquet file already exists for The Donnas, skipping...
# Parquet file already exists for Smokie Norful, skipping...
# Parquet file already exists for Doctor Nerve, skipping...
# Parquet file already exists for Eileen Ivers, skipping...
# Parquet file already exists for Amy Winehouse, skipping...
# Parquet file already exists for Widespread Panic, skipping...
# Parquet file already exists for Exploding White Mice, skipping...
# Parquet file already exists for Iron Maiden, skipping...
# Parquet file already exists for Marvin Gaye, skipping...
# Parquet file already exists for Snuffy Jenkins, skipping...
# Parquet file already exists for Otis Spann, skipping...
# Parquet file already exists for Leon Bridges, skipping...
# Parquet file already exists for Oliver Lake, skipping...
# Parquet file already exists for Red Foley, skipping...
# Parquet file already exists for Palace Brothers, skipping...
# Parquet file already exists for Rick Springfield, skipping...
# Parquet file already exists for Charlie Byrd, skipping...
# Parquet file already exists for Raul Midón, skipping...
# Parquet file already exists for Jake Bugg, skipping...
# Parquet file already exists for Amorphis, skipping...
# Parquet file already exists for DevilDriver, skipping...
# Parquet file already exists for The Falcons, skipping...
# Parquet file already exists for Amanda Palmer, skipping...
# Parquet file already exists for P!nk, skipping...
# Parquet file already exists for 12 Rounds, skipping...
# Parquet file already exists for Work Drugs, skipping...
# Parquet file already exists for Dayna Kurtz, skipping...
# Parquet file already exists for Greg Ginn, skipping...
# Parquet file already exists for Darkthrone, skipping...
# Parquet file already exists for The Summer Set, skipping...
# Parquet file already exists for The Spinanes, skipping...
# Parquet file already exists for Downtown Boys, skipping...
# Parquet file already exists for The Chymes, skipping...
# Parquet file already exists for The Dishes, skipping...
# Parquet file already exists for Cindy Lee Berryhill, skipping...
# Parquet file already exists for Rev Theory, skipping...
# Parquet file already exists for Neurosis, skipping...
# Parquet file already exists for Motherhead Bug, skipping...
# Parquet file already exists for The Isley Brothers, skipping...
# Parquet file already exists for Casa Loma Orchestra, skipping...
# Parquet file already exists for Joe Perry, skipping...
# Parquet file already exists for The Who, skipping...
# Parquet file already exists for Mudcrutch, skipping...
# Parquet file already exists for Frank Hutchison, skipping...
# Parquet file already exists for Lauren Hoffman, skipping...
# Parquet file already exists for David Yazbek, skipping...
# Parquet file already exists for Luke Temple, skipping...
# Parquet file already exists for David Poe, skipping...
# Parquet file already exists for Marsha Ambrosius, skipping...
# Parquet file already exists for Emerson Hart, skipping...
# Parquet file already exists for John Sebastian, skipping...
# Parquet file already exists for Lita Ford, skipping...
# Parquet file already exists for Force M.D.'s, skipping...
# Parquet file already exists for Athlete, skipping...
# Parquet file already exists for Bad English, skipping...
# Parquet file already exists for Luke Sital-Singh, skipping...
# Parquet file already exists for Tim Pierce, skipping...
# Parquet file already exists for Oxford Collapse, skipping...
# Parquet file already exists for Rachelle Ferrell, skipping...
# Parquet file already exists for The Tractors, skipping...
# Parquet file already exists for Richard Youngs, skipping...
# Parquet file already exists for Bif Naked, skipping...
# Parquet file already exists for Albert Harris, skipping...
# Parquet file already exists for McCarthy, skipping...
# Parquet file already exists for Omarion, skipping...
# Parquet file already exists for Justin Timberlake, skipping...
# Parquet file already exists for The Young Gods, skipping...
# Parquet file already exists for The Neon Judgement, skipping...
# Parquet file already exists for Joel Grey, skipping...
# Parquet file already exists for The Tubes, skipping...
# Parquet file already exists for The Vidalias, skipping...
# Parquet file already exists for Starflyer 59, skipping...
# Parquet file already exists for Fairweather, skipping...
# Parquet file already exists for Cutting Crew, skipping...
# Parquet file already exists for Waco Brothers, skipping...
# Parquet file already exists for Something Corporate, skipping...
# Parquet file already exists for Oscar Brand, skipping...
# Parquet file already exists for Interpol, skipping...
# Parquet file already exists for Laura Love, skipping...
# Parquet file already exists for Helloween, skipping...
# Parquet file already exists for The Boogie Kings, skipping...
# Parquet file already exists for Poison, skipping...
# Parquet file already exists for Mary Lou Williams, skipping...
# Parquet file already exists for Steve Forbert, skipping...
# Parquet file already exists for Talk Talk, skipping...
# Parquet file already exists for The Rifles, skipping...
# Parquet file already exists for Pistol Annies, skipping...
# Parquet file already exists for John Mooney, skipping...
# Parquet file already exists for The Green Pajamas, skipping...
# Parquet file already exists for Bernadette Peters, skipping...
# Parquet file already exists for Mason Jennings, skipping...
# Parquet file already exists for Tiny Tim, skipping...
# Completed processing all artists.

# %%
# max_retries = 3
# retry_counter = 0

# while not failed_requests.empty and retry_counter < max_retries:
#     print(f"Retrying failed requests (attempt {retry_counter + 1}/{max_retries})...")
#     retry_failed_requests = pd.DataFrame(columns=["Spotify ID"])
#     for _, row in failed_requests.iterrows():
#         artist_id = row["Spotify ID"]
#         artist_name = artist_ids[artist_id]
#         sanitized_artist_name = sanitize_filename(artist_name)
#         parquet_file_path = f'{sanitized_artist_name}_tracks.parquet'

#         if os.path.exists(parquet_file_path):
#             print(f"Parquet file already exists for {artist_name}, skipping...")
#             continue
#         try:
#             refreshed_token, new_token_start_time = refresh_token(token_start_time)
#             if refreshed_token:
#                 token = refreshed_token
#                 token_start_time = new_token_start_time
#             albums = get_albums_for_artist(token, artist_id)

#             if albums is None:
#                 failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
#                 save_failed_requests(failed_requests)
#                 continue

#             album_df = pd.DataFrame.from_dict(albums, orient="index")
#             album_df.index.name = "album_name"

#             all_tracks_df = pd.DataFrame()
#             for album_id in tqdm(album_df['album_id'], desc=f"Processing {artist_name}"):
#                 time.sleep(1)
#                 try:
#                     tracks = get_tracks_for_album(token, album_id)

#                     if tracks is None:
#                         failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
#                         save_failed_requests(failed_requests)
#                         continue

#                     tracks = pd.DataFrame(tracks)
#                     tracks['album_id'] = album_id
#                     all_tracks_df = pd.concat([all_tracks_df, tracks], axis=0)
#                 except Exception as e:
#                     print(f"Warning: Error fetching tracks for {artist_name}: {e}")

#             try:
#                 af_df = get_audio_features(token, all_tracks_df['track_id'].tolist())
#                 af_df = af_df.rename(columns={'id': 'track_id'})
#                 all_aftracks_df = pd.merge(all_tracks_df, af_df, on='track_id')
#                 album_all_aftracks_df = pd.merge(album_df, all_aftracks_df, on='album_id')
#                 sanitized_artist_name = sanitize_filename(artist_name)
#                 album_all_aftracks_df.to_parquet(f'{sanitized_artist_name}_tracks.parquet')

#                 save_checkpoint(artist_id, artist_name)
#             except Exception as e:
#                 print(f"Warning: Error fetching audio features for {artist_name}: {e}")

#             iteration_counter += 1
#             if iteration_counter % sleep_interval == 0:
#                 time.sleep(1)

#         except Exception as e:
#             print(f"Error processing {artist_name}: {e}")
#             retry_failed_requests = retry_failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)

#     failed_requests = retry_failed_requests
#     retry_counter += 1

# if not failed_requests.empty:
#     print("Some requests still failed after all retries:")
#     print(failed_requests)
# else:
#     print("All failed requests have been successfully processed.")
