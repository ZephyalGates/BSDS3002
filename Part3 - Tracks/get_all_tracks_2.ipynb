# %%
import os
import base64
import requests
from requests import post, get
import json
from tqdm import tqdm
import pandas as pd
import time
import math
import re

# %%
client_credentials = [
('ef58993d4fbe446ca6a6edd303a56c80', '3fe8edaf5c8147ff9e81ea858b410102'),
('e857908311cd436abed7fe2b1dc99bd5', '56411c35c3874b9ebbaf3f3fe80a811c'),
('470adf495fd548298483dc4d1a38b1e2', 'c16d7144415946028ae38b6d635f6bfd'),
('adafeb81352e4bddb7d5f3be5956ada8', 'a09dbec853264e94a0a5f61eb6df67ed'),
('4c42335d9dc74a36a48cee122449c9d6', '7b0c7b87143d4051b0e3891e70e83da9'),
('ed1bfedbe22244fdbc9f9a592bb8b153', '50585f3a59364e48980e5f576ec9d719'),
('dc3085808e9e490a8426ec00952e12c9', '4b9c26457b034c79b8363ed19ebd9e30'),
('af8d0d58749e48c19ac32f47a8089e31', 'c021220c33f94bd6bceec431617564c8'),
('200886fa3780485faa62b4e89034f7b8', '0deb41f8c0684e619ebceff7e7160d44'),
('46a05bf1cd064188a47c2ec88aca1aeb', 'ca9ce67a39a44b81854d64c9a6acb2bd')

]



credential_index = 0

def get_token(client_id, client_secret):
    auth_string = client_id + ":" + client_secret
    auth_bytes = auth_string.encode("utf-8")
    auth_base64 = str(base64.b64encode(auth_bytes), "utf-8")

    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": "Basic " + auth_base64,
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"grant_type": "client_credentials"}

    response = requests.post(url, headers=headers, data=data)
    json_result = json.loads(response.content)

    if "access_token" in json_result:
        token = json_result["access_token"]
        return token
    else:
        print("Error: Failed to get access token")
        print(json_result)
        return None

def get_auth_header(token):
    return {"Authorization": "Bearer " + token}

def get_albums_for_artist(token, artist_id):
    url = f"https://api.spotify.com/v1/artists/{artist_id}/albums"
    headers = get_auth_header(token)
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        albums = json.loads(response.text)["items"]
        album_dict = {}
        for album in albums:
            album_id = album["id"]
            album_name = album["name"]
            album_tracks = album["total_tracks"]
            album_type = album["album_type"]
            album_release_date = album["release_date"]
            album_artists = [artist["name"] for artist in album["artists"]]
            album_images = album["images"]

            if album_name in album_dict:
                existing_tracks = album_dict[album_name]["total_tracks"]
                if album_tracks > existing_tracks:
                    album_dict[album_name] = {
                        "album_id": album_id,
                        "album_name": album_name,
                        "total_tracks": album_tracks,
                        "album_type": album_type,
                        "release_date": album_release_date,
                        "artists": album_artists,
                        "images": album_images
                    }
            else:
                album_dict[album_name] = {
                    "album_id": album_id,
                    "album_name": album_name,
                    "total_tracks": album_tracks,
                    "album_type": album_type,
                    "release_date": album_release_date,
                    "artists": album_artists,
                    "images": album_images
                }
        return album_dict
    else:
        print("Error: Failed to get albums for artist")
        print(response.content)
        return None
    
def get_tracks_for_album(token, album_id):
    url = f"https://api.spotify.com/v1/albums/{album_id}/tracks"
    headers = get_auth_header(token)
    params = {"market": "US"}
    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        tracks = json.loads(response.text)["items"]
        track_list = []
        for track in tracks:
            track_name = track["name"]
            track_id = track["id"]
            track_number = track["track_number"]
            track_explicit = track["explicit"]
            track_artists = [artist["name"] for artist in track["artists"]]
            track_dict = {
                "track_name": track_name,
                "track_id": track_id,
                "track_number": track_number,
                "track_explicit": track_explicit,
                "track_artists": track_artists,
            }
            track_list.append(track_dict)
        return track_list
    else:
        print("Error: Failed to get tracks for album")
        print(response.content)
        return None

# def get_audio_features(token, track_ids):
#     headers = {"Authorization": f"Bearer {token}"}
#     url = "https://api.spotify.com/v1/audio-features"
    
#     id_chunks = [track_ids[i:i+100] for i in range(0, len(track_ids), 100)]
    
#     dfs = []
#     for chunk in id_chunks:
#         params = {"ids": ",".join(chunk)}
#         response = requests.get(url, headers=headers, params=params)
#         data = response.json()["audio_features"]
#         features = pd.DataFrame(data)
#         features = features.drop(["type", "uri", "track_href", "analysis_url"], axis=1)
#         dfs.append(features)
    
#     features = pd.concat(dfs, ignore_index=True)
#     return features

def get_audio_features(token, track_ids):
    audio_features = []

    for i in range(0, len(track_ids), 50):
        chunk = track_ids[i:i + 50]
        ids = ','.join(chunk)
        url = f"https://api.spotify.com/v1/audio-features?ids={ids}"
        headers = {"Authorization": f"Bearer {token}"}
        r = requests.get(url, headers=headers)
        if r.status_code != 200:
            print(f"Error getting audio features for tracks: {r.status_code}")
            return None

        try:
            features = r.json()["audio_features"]
        except KeyError:
            features = []

        audio_features.extend(features)

    audio_features_filtered = []
    for feature in audio_features:
        if feature is not None:
            audio_features_filtered.append(feature)

    return pd.DataFrame(audio_features_filtered)



def load_checkpoint():
    if os.path.exists('checkpoint_2.json'):
        with open('checkpoint.json_2', 'r') as f:
            return json.load(f)
    else:
        return {"artist_id": "", "progress": 0}

def save_checkpoint(artist_id, progress):
    with open('checkpoint_2.json', 'w') as f:
        json.dump({"artist_id": artist_id, "progress": progress}, f)

def load_failed_requests():
    if os.path.exists('failed_requests_2.parquet'):
        return pd.read_parquet('failed_requests_2.parquet')
    else:
        return pd.DataFrame(columns=['Spotify ID'])

def save_failed_requests(df):
    df.to_parquet('failed_requests_2.parquet')

def refresh_token(token_start_time):
    global credential_index
    current_time = time.time()
    elapsed_time = current_time - token_start_time
    if elapsed_time >= 1800:
        credential_index = (credential_index + 1) % len(client_credentials)
        client_id, client_secret = client_credentials[credential_index]
        return get_token(client_id, client_secret), current_time
    return None, token_start_time

def sanitize_filename(filename):
    return re.sub(r'[\\/:"*?<>|]+', '_', filename)

# %%
with open('artist_ids_sub_dict_2.json', 'r') as f:
    artist_ids = json.load(f)
len(artist_ids)
# Out:
# 1201

# %%
token = get_token(client_credentials[0][0], client_credentials[0][1])
token_start_time = time.time()

checkpoint = load_checkpoint()
failed_requests = load_failed_requests()

start_from = checkpoint["artist_id"] if checkpoint["artist_id"] else list(artist_ids.keys())[0]
start_index = list(artist_ids.keys()).index(start_from)


iteration_counter = 0
sleep_interval = 50

for artist_id, artist_name in list(artist_ids.items())[start_index:]:
    sanitized_artist_name = sanitize_filename(artist_name)
    parquet_file_path = f'results/{sanitized_artist_name}_tracks.parquet'
    if os.path.exists(parquet_file_path):
        print(f"Parquet file already exists for {artist_name}, skipping...")
        continue
    try:
        refreshed_token, new_token_start_time = refresh_token(token_start_time)
        if refreshed_token:
            token = refreshed_token
            token_start_time = new_token_start_time

        albums = get_albums_for_artist(token, artist_id)

        if albums is None:
            failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
            save_failed_requests(failed_requests)
            continue

        album_df = pd.DataFrame.from_dict(albums, orient="index")
        album_df.index.name = "album_name"

        all_tracks_df = pd.DataFrame()
        for album_id in tqdm(album_df['album_id'], desc=f"Processing {artist_name}"):
            time.sleep(1)
            tracks = get_tracks_for_album(token, album_id)
            if tracks is None:
                failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
                save_failed_requests(failed_requests)
                continue

            tracks = pd.DataFrame(tracks)
            tracks['album_id'] = album_id
            all_tracks_df = pd.concat([all_tracks_df, tracks], axis=0)

        af_df = get_audio_features(token, all_tracks_df['track_id'].tolist())
        af_df = af_df.rename(columns={'id': 'track_id'})
        all_aftracks_df = pd.merge(all_tracks_df, af_df, on='track_id')
        album_all_aftracks_df = pd.merge(album_df, all_aftracks_df, on='album_id')
        sanitized_artist_name = sanitize_filename(artist_name)
        album_all_aftracks_df.to_parquet(f'results/{sanitized_artist_name}_tracks.parquet')

        save_checkpoint(artist_id, artist_name)
        iteration_counter += 1
        if iteration_counter % sleep_interval == 0:
            time.sleep(10)
            
    except Exception as e:
        print(f"Error processing {artist_name}: {e}")
        failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
        save_failed_requests(failed_requests)
        continue

print("Completed processing all artists.")
# Out:
# Parquet file already exists for Ty England, skipping...
# Parquet file already exists for Melissa Ferrick, skipping...
# Parquet file already exists for The Lilac Time, skipping...
# Parquet file already exists for James Williamson, skipping...
# Parquet file already exists for D.A.R.K., skipping...
# Parquet file already exists for Tracy Lawrence, skipping...
# Parquet file already exists for Otis Grand, skipping...
# Parquet file already exists for Mike Birbiglia, skipping...
# Parquet file already exists for Trouble Club, skipping...
# Parquet file already exists for The Chantels, skipping...
# Parquet file already exists for Peter Doherty, skipping...
# Parquet file already exists for Jadis, skipping...
# Parquet file already exists for Michael Nyman, skipping...
# Parquet file already exists for Eddie Griffin, skipping...
# Parquet file already exists for Tonéx, skipping...
# Parquet file already exists for Jack Nitzsche, skipping...
# Parquet file already exists for Bee Gees, skipping...
# Parquet file already exists for Rahsaan Roland Kirk, skipping...
# Parquet file already exists for Judy Collins, skipping...
# Parquet file already exists for Mario Pavone, skipping...
# Parquet file already exists for Olivia Lane, skipping...
# Parquet file already exists for Hawthorne Heights, skipping...
# Parquet file already exists for Zuzu, skipping...
# Parquet file already exists for Kasabian, skipping...
# Parquet file already exists for Maura O'Connell, skipping...
# Parquet file already exists for Lafayette Afro Rock Band, skipping...
# Parquet file already exists for Naftule Brandwein, skipping...
# Parquet file already exists for Minny Pops, skipping...
# Parquet file already exists for Kwest Tha Madd Lad, skipping...
# Parquet file already exists for Cliff Burton, skipping...
# Parquet file already exists for Labi Siffre, skipping...
# Parquet file already exists for Goodbye June, skipping...
# Parquet file already exists for Born Against, skipping...
# Parquet file already exists for Kinghorse, skipping...
# Parquet file already exists for Mountain, skipping...
# Parquet file already exists for The Knife, skipping...
# Parquet file already exists for Richard Ashcroft, skipping...
# Parquet file already exists for Toni Fisher, skipping...
# Parquet file already exists for Tripping The Light Fantastic, skipping...
# Parquet file already exists for The Family Stand, skipping...
# Parquet file already exists for Frightened Rabbit, skipping...
# Parquet file already exists for Austin Plaine, skipping...
# Parquet file already exists for Tomás Luis de Victoria, skipping...
# Parquet file already exists for The Cleftones, skipping...
# Parquet file already exists for Blind Lemon Jefferson, skipping...
# Parquet file already exists for Lewis Taylor, skipping...
# Parquet file already exists for Kazumi Watanabe, skipping...
# Parquet file already exists for William Orbit, skipping...
# Parquet file already exists for Alex Boyd, skipping...
# Parquet file already exists for Tanya Morgan, skipping...
# Parquet file already exists for DTCV, skipping...
# Parquet file already exists for Anna Nalick, skipping...
# Parquet file already exists for Marijohn Wilkin, skipping...
# Parquet file already exists for Dance Gavin Dance, skipping...
# Parquet file already exists for Lonnie Spiker, skipping...
# Parquet file already exists for King Curtis, skipping...
# Parquet file already exists for Raymond Scott, skipping...
# Parquet file already exists for Charlie Christian, skipping...
# Parquet file already exists for The Method Actors, skipping...
# Parquet file already exists for Parliament, skipping...
# Parquet file already exists for Malvina Reynolds, skipping...
# Parquet file already exists for John Fogerty, skipping...
# Parquet file already exists for Jesse McCartney, skipping...
# Parquet file already exists for Toni Lynn Washington, skipping...
# Parquet file already exists for The Figgs, skipping...
# Parquet file already exists for Hoodie Allen, skipping...
# Parquet file already exists for The Perishers, skipping...
# Parquet file already exists for Nancy Sinatra, skipping...
# Parquet file already exists for The Lumineers, skipping...
# Parquet file already exists for David Fiuczynski, skipping...
# Parquet file already exists for Burning Airlines, skipping...
# Parquet file already exists for Sparks, skipping...
# Parquet file already exists for Source Direct, skipping...
# Parquet file already exists for Yelawolf, skipping...
# Parquet file already exists for Downy Mildew, skipping...
# Parquet file already exists for The Mighty Sceptres, skipping...
# Parquet file already exists for Doves, skipping...
# Parquet file already exists for Tomahawk, skipping...
# Parquet file already exists for Bad Religion, skipping...
# Parquet file already exists for Fiction Plane, skipping...
# Parquet file already exists for Liars, skipping...
# Parquet file already exists for Iron City Houserockers, skipping...
# Parquet file already exists for Iluvatar, skipping...
# Parquet file already exists for Sonny Clark, skipping...
# Parquet file already exists for Kadhja Bonet, skipping...
# Parquet file already exists for that dog., skipping...
# Parquet file already exists for Channel One, skipping...
# Parquet file already exists for Kygo, skipping...
# Parquet file already exists for Carmen McRae, skipping...
# Parquet file already exists for Marc Ribot, skipping...
# Parquet file already exists for Franz Schubert, skipping...
# Parquet file already exists for Jose Manuel Calderon, skipping...
# Parquet file already exists for BJ The Chicago Kid, skipping...
# Parquet file already exists for The Dayton Family, skipping...
# Parquet file already exists for Lynn Anderson, skipping...
# Parquet file already exists for Barrett Baber, skipping...
# Parquet file already exists for Justus Köhncke, skipping...
# Parquet file already exists for Laura Bell Bundy, skipping...
# Parquet file already exists for Roger Manning, skipping...
# Parquet file already exists for Dead Letter Circus, skipping...
# Parquet file already exists for Katharine McPhee, skipping...
# Parquet file already exists for Mark Snow, skipping...
# Parquet file already exists for The Creases, skipping...
# Parquet file already exists for King Tee, skipping...
# Parquet file already exists for Lorde, skipping...
# Parquet file already exists for Scar Symmetry, skipping...
# Parquet file already exists for American Aquarium, skipping...
# Parquet file already exists for Greg Lake, skipping...
# Parquet file already exists for Lenny Welch, skipping...
# Parquet file already exists for Tori Amos, skipping...
# Parquet file already exists for Fatso Jetson, skipping...
# Parquet file already exists for Exhumed, skipping...
# Parquet file already exists for Anton Bruckner, skipping...
# Parquet file already exists for Eric Kloss, skipping...
# Parquet file already exists for John Giorno, skipping...
# Parquet file already exists for Travis Tritt, skipping...
# Parquet file already exists for James Crase, skipping...
# Parquet file already exists for Imperial Teen, skipping...
# Parquet file already exists for Fruupp, skipping...
# Parquet file already exists for Nervous Cabaret, skipping...
# Parquet file already exists for Mtume, skipping...
# Parquet file already exists for A$AP Twelvyy, skipping...
# Parquet file already exists for Shattered Faith, skipping...
# Parquet file already exists for Ben Harper, skipping...
# Parquet file already exists for Andrew Hill, skipping...
# Parquet file already exists for Jack Garratt, skipping...
# Parquet file already exists for Tim Dog, skipping...
# Parquet file already exists for Carl Philipp Emanuel Bach, skipping...
# Parquet file already exists for Thelonious Monk Quartet, skipping...
# Parquet file already exists for The Mendoza Line, skipping...
# Parquet file already exists for Saigon Kick, skipping...
# Parquet file already exists for Pain of Salvation, skipping...
# Parquet file already exists for Love As Laughter, skipping...
# Parquet file already exists for Bruce Cockburn, skipping...
# Parquet file already exists for Edwin McCain, skipping...
# Parquet file already exists for Orange Then Blue, skipping...
# Parquet file already exists for The Legal Matters, skipping...
# Parquet file already exists for Ryan Shaw, skipping...
# Parquet file already exists for Michael Rother, skipping...
# Parquet file already exists for Eclection, skipping...
# Parquet file already exists for Terry Allen, skipping...
# Parquet file already exists for Jawbox, skipping...
# Parquet file already exists for Michael Mayer, skipping...
# Parquet file already exists for Johnny Vidacovich, skipping...
# Parquet file already exists for Christina Perri, skipping...
# Parquet file already exists for Laurie Anderson, skipping...
# Parquet file already exists for Ellie Greenwich, skipping...
# Parquet file already exists for Jane Olivor, skipping...
# Parquet file already exists for Uncle Dave Macon, skipping...
# Parquet file already exists for Action Figures, skipping...
# Parquet file already exists for Mick Collins, skipping...
# Parquet file already exists for Rockwell, skipping...
# Parquet file already exists for Driver Friendly, skipping...
# Parquet file already exists for Electrelane, skipping...
# Parquet file already exists for Trombone Shorty, skipping...
# Parquet file already exists for James Montgomery, skipping...
# Parquet file already exists for Pale Saints, skipping...
# Parquet file already exists for Axel Leon, skipping...
# Parquet file already exists for Tim Hardin, skipping...
# Parquet file already exists for YG, skipping...
# Parquet file already exists for Tesla, skipping...
# Parquet file already exists for Loney Dear, skipping...
# Parquet file already exists for The Ting Tings, skipping...
# Parquet file already exists for Craig Chaquico, skipping...
# Parquet file already exists for U.P.O., skipping...
# Parquet file already exists for Big Star, skipping...
# Parquet file already exists for Adolf Wölfli, skipping...
# Parquet file already exists for Shades Apart, skipping...
# Parquet file already exists for Lamar Campbell & Spirit Of Praise, skipping...
# Parquet file already exists for Million Dead, skipping...
# Parquet file already exists for Plush, skipping...
# Parquet file already exists for Bill Callahan, skipping...
# Parquet file already exists for Joanna Newsom, skipping...
# Parquet file already exists for Hammerhead, skipping...
# Parquet file already exists for Deftones, skipping...
# Parquet file already exists for The Gaslamp Killer, skipping...
# Parquet file already exists for Pink Anderson, skipping...
# Parquet file already exists for Edgard Varèse, skipping...
# Parquet file already exists for Carla Thomas, skipping...
# Parquet file already exists for Stan Rogers, skipping...
# Parquet file already exists for Ben Weaver, skipping...
# Parquet file already exists for Cheap Trick, skipping...
# Parquet file already exists for Ozric Tentacles, skipping...
# Parquet file already exists for Buddy DeFranco, skipping...
# Parquet file already exists for Cro-Mags, skipping...
# Parquet file already exists for Augustana, skipping...
# Parquet file already exists for Suzi Quatro, skipping...
# Parquet file already exists for Terri Binion, skipping...
# Parquet file already exists for Ms. Dynamite, skipping...
# Parquet file already exists for The Mummies, skipping...
# Parquet file already exists for The Egyptian Lover, skipping...
# Parquet file already exists for New Found Glory, skipping...
# Parquet file already exists for The Dubliners, skipping...
# Parquet file already exists for Junie Morrison, skipping...
# Parquet file already exists for Fennesz, skipping...
# Parquet file already exists for Tall Ships, skipping...
# Parquet file already exists for Timothy Bloom, skipping...
# Parquet file already exists for Bree Sharp, skipping...
# Parquet file already exists for Mixtapes, skipping...
# Parquet file already exists for Pablo Cruise, skipping...
# Parquet file already exists for A Number Of Names, skipping...
# Parquet file already exists for The Wailers, skipping...
# Parquet file already exists for Jack Smith, skipping...
# Parquet file already exists for James Cleveland, skipping...
# Parquet file already exists for Nurse With Wound, skipping...
# Parquet file already exists for Allday, skipping...
# Parquet file already exists for The Pretty Things, skipping...
# Parquet file already exists for SNFU, skipping...
# Parquet file already exists for John Kongos, skipping...
# Parquet file already exists for Marvin Sease, skipping...
# Parquet file already exists for Soulwax, skipping...
# Parquet file already exists for Rev. F.W. McGee, skipping...
# Parquet file already exists for Tim Green, skipping...
# Parquet file already exists for Rebecca Padula, skipping...
# Parquet file already exists for Ruben Studdard, skipping...
# Parquet file already exists for Cisco Houston, skipping...
# Parquet file already exists for Sam Phillips, skipping...
# Parquet file already exists for Starlight Mints, skipping...
# Parquet file already exists for Friendly Fires, skipping...
# Parquet file already exists for Steven Curtis Chapman, skipping...
# Parquet file already exists for Bix Beiderbecke, skipping...
# Parquet file already exists for Big Blue Hearts, skipping...
# Parquet file already exists for Slide Hampton, skipping...
# Parquet file already exists for Matt Pond PA, skipping...
# Parquet file already exists for Son Volt, skipping...
# Parquet file already exists for Ec8or, skipping...
# Parquet file already exists for Geri Halliwell, skipping...
# Parquet file already exists for The Gories, skipping...
# Parquet file already exists for Rory Gallagher, skipping...
# Parquet file already exists for Burt Bacharach, skipping...
# Parquet file already exists for Men's Recovery Project, skipping...
# Parquet file already exists for Luka Bloom, skipping...
# Parquet file already exists for Swales, skipping...
# Parquet file already exists for Acker Bilk, skipping...
# Parquet file already exists for Jessie J, skipping...
# Parquet file already exists for Kleeer, skipping...
# Parquet file already exists for Fanny Brice, skipping...
# Parquet file already exists for Giuda, skipping...
# Parquet file already exists for George Coleman, skipping...
# Parquet file already exists for Set Your Goals, skipping...
# Parquet file already exists for Burning Star Core, skipping...
# Parquet file already exists for Bob Forrest, skipping...
# Parquet file already exists for Finley Quaye, skipping...
# Parquet file already exists for Fever Tree, skipping...
# Parquet file already exists for The Grip Weeds, skipping...
# Parquet file already exists for Ned's Atomic Dustbin, skipping...
# Parquet file already exists for Pee Wee King, skipping...
# Parquet file already exists for Agent Ribbons, skipping...
# Parquet file already exists for Bill Frisell, skipping...
# Parquet file already exists for Archie Shepp, skipping...
# Parquet file already exists for Gandalf, skipping...
# Parquet file already exists for Absofacto, skipping...
# Parquet file already exists for Toby Keith, skipping...
# Parquet file already exists for Love Battery, skipping...
# Parquet file already exists for Gong, skipping...
# Parquet file already exists for Avant, skipping...
# Parquet file already exists for Good Evening Manchester, skipping...
# Parquet file already exists for Yank Rachell, skipping...
# Parquet file already exists for Ghost, skipping...
# Parquet file already exists for Kinski, skipping...
# Parquet file already exists for August Burns Red, skipping...
# Parquet file already exists for Rickie Lee Jones, skipping...
# Parquet file already exists for Meic Stevens, skipping...
# Parquet file already exists for The Fully Down, skipping...
# Parquet file already exists for Ruckazoid, skipping...
# Parquet file already exists for The V-Roys, skipping...
# Parquet file already exists for Atheist, skipping...
# Parquet file already exists for Lonnie Johnson, skipping...
# Parquet file already exists for Boys Life, skipping...
# Parquet file already exists for Mick Moloney, skipping...
# Parquet file already exists for Sun Club, skipping...
# Parquet file already exists for The Shins, skipping...
# Parquet file already exists for Adam Ant, skipping...
# Parquet file already exists for Buddy Miles, skipping...
# Parquet file already exists for Magrudergrind, skipping...
# Parquet file already exists for The Cars, skipping...
# Parquet file already exists for Demons & Wizards, skipping...
# Parquet file already exists for Tommy Trash, skipping...
# Parquet file already exists for Leroy Carr, skipping...
# Parquet file already exists for Dan Hicks & His Hot Licks, skipping...
# Parquet file already exists for Tevin Campbell, skipping...
# Parquet file already exists for Thurston Moore, skipping...
# Parquet file already exists for The Memories, skipping...
# Parquet file already exists for George Garzone, skipping...
# Parquet file already exists for Early Man, skipping...
# Parquet file already exists for Violent Society, skipping...
# Parquet file already exists for Bratmobile, skipping...
# Parquet file already exists for Marion Brown, skipping...
# Parquet file already exists for Sammy Kershaw, skipping...
# Parquet file already exists for Jack Logan, skipping...
# Parquet file already exists for Nikki Jean, skipping...
# Parquet file already exists for Samantha Fish, skipping...
# Parquet file already exists for Joe Satriani, skipping...
# Parquet file already exists for Crazyhead, skipping...
# Parquet file already exists for Cornelius Cardew, skipping...
# Parquet file already exists for Chastity Belt, skipping...
# Parquet file already exists for Chelsea Wolfe, skipping...
# Parquet file already exists for Sally Shapiro, skipping...
# Parquet file already exists for Shocking Blue, skipping...
# Parquet file already exists for Aberfeldy, skipping...
# Parquet file already exists for Nana Caymmi, skipping...
# Parquet file already exists for Novastar, skipping...
# Parquet file already exists for The Damned, skipping...
# Parquet file already exists for Mississippi Sheiks, skipping...
# Parquet file already exists for Tyler Farr, skipping...
# Parquet file already exists for Girlpool, skipping...
# Parquet file already exists for Shalamar, skipping...
# Parquet file already exists for Gavin DeGraw, skipping...
# Parquet file already exists for Lionel Richie, skipping...
# Parquet file already exists for Caedmon's Call, skipping...
# Parquet file already exists for Fastbacks, skipping...
# Parquet file already exists for Furry Lewis, skipping...
# Parquet file already exists for Jimmy Ruffin, skipping...
# Parquet file already exists for Snoop Dogg, skipping...
# Parquet file already exists for Sivert Høyem, skipping...
# Parquet file already exists for Loretta Lynn, skipping...
# Parquet file already exists for Gillie Da Kid, skipping...
# Parquet file already exists for Lou Ann Barton, skipping...
# Parquet file already exists for Busy P, skipping...
# Parquet file already exists for Deep Sea Diver, skipping...
# Parquet file already exists for Emperor X, skipping...
# Parquet file already exists for Rosie Ledet, skipping...
# Parquet file already exists for Caitlin Rose, skipping...
# Parquet file already exists for Mary Mary, skipping...
# Parquet file already exists for Black Flag, skipping...
# Parquet file already exists for Lil Xan, skipping...
# Parquet file already exists for Ben Folds Five, skipping...
# Parquet file already exists for Blue Magic, skipping...
# Parquet file already exists for Lorenzo Feliciati, skipping...
# Parquet file already exists for June Tabor, skipping...
# Parquet file already exists for Hotel Books, skipping...
# Parquet file already exists for All About Eve, skipping...
# Parquet file already exists for Jumbling Towers, skipping...
# Parquet file already exists for Crystal Stilts, skipping...
# Parquet file already exists for Joy Division, skipping...
# Parquet file already exists for The Winter Blanket, skipping...
# Parquet file already exists for Steve Lawrence, skipping...
# Parquet file already exists for Najee, skipping...
# Parquet file already exists for Lower Than Atlantis, skipping...
# Parquet file already exists for The Dead Milkmen, skipping...
# Parquet file already exists for Kelly Hogan, skipping...
# Parquet file already exists for Tamba Trio, skipping...
# Parquet file already exists for Sammy Hagar, skipping...
# Parquet file already exists for Ronald Bruner, Jr., skipping...
# Parquet file already exists for Thee Headcoats, skipping...
# Parquet file already exists for The Long Ryders, skipping...
# Parquet file already exists for T-Model Ford, skipping...
# Parquet file already exists for Tracy Chapman, skipping...
# Parquet file already exists for Massive Attack, skipping...
# Parquet file already exists for Steady B, skipping...
# Parquet file already exists for Fats Domino, skipping...
# Parquet file already exists for B. Smyth, skipping...
# Parquet file already exists for God Street Wine, skipping...
# Parquet file already exists for Billy Bauer, skipping...
# Parquet file already exists for Madeleine Peyroux, skipping...
# Parquet file already exists for Melvin Sparks, skipping...
# Parquet file already exists for Bentley Rhythm Ace, skipping...
# Parquet file already exists for The Paranoid Style, skipping...
# Parquet file already exists for Jim Campilongo, skipping...
# Parquet file already exists for Grand Champeen, skipping...
# Parquet file already exists for Le Orme, skipping...
# Parquet file already exists for Jeffrey Gaines, skipping...
# Parquet file already exists for Juicy Lucy, skipping...
# Parquet file already exists for Kendrick Lamar, skipping...
# Parquet file already exists for Arvo Pärt, skipping...
# Parquet file already exists for Estrogen Highs, skipping...
# Parquet file already exists for Dream Warriors, skipping...
# Parquet file already exists for Unbroken, skipping...
# Parquet file already exists for Starcastle, skipping...
# Parquet file already exists for Jonatha Brooke, skipping...
# Parquet file already exists for Ministry, skipping...
# Parquet file already exists for The Sundays, skipping...
# Parquet file already exists for Marcus Printup, skipping...
# Parquet file already exists for Midlake, skipping...
# Parquet file already exists for The Flamingos, skipping...
# Parquet file already exists for Little Walter, skipping...
# Parquet file already exists for Horace Brown, skipping...
# Parquet file already exists for Steve Winwood, skipping...
# Parquet file already exists for The Remains, skipping...
# Parquet file already exists for Richmond Fontaine, skipping...
# Parquet file already exists for Michael Longo, skipping...
# Parquet file already exists for Martin Denny, skipping...
# Parquet file already exists for Eileen Farrell, skipping...
# Parquet file already exists for Dick Feller, skipping...
# Parquet file already exists for Milky Wimpshake, skipping...
# Parquet file already exists for Sean Jones, skipping...
# Parquet file already exists for Thea Gilmore, skipping...
# Parquet file already exists for William Carlos Williams, skipping...
# Parquet file already exists for Audio Adrenaline, skipping...
# Parquet file already exists for Gabby Pahinui, skipping...
# Parquet file already exists for The Temptations, skipping...
# Parquet file already exists for Paul Anka, skipping...
# Parquet file already exists for The Black Angels, skipping...
# Parquet file already exists for River Tiber, skipping...
# Parquet file already exists for Kendall Jones, skipping...
# Parquet file already exists for Behemoth, skipping...
# Parquet file already exists for Steve Smyth, skipping...
# Parquet file already exists for Klaus Johann Grobe, skipping...
# Parquet file already exists for Martha Raye, skipping...
# Parquet file already exists for Potty Mouth, skipping...
# Parquet file already exists for The Wreckers, skipping...
# Parquet file already exists for Silvio Rodríguez, skipping...
# Parquet file already exists for The Boxmasters, skipping...
# Parquet file already exists for Freddie Gibbs, skipping...
# Parquet file already exists for Joe Zawinul, skipping...
# Parquet file already exists for Eddie South, skipping...
# Parquet file already exists for Susanne Sundfør, skipping...
# Parquet file already exists for The Embarrassment, skipping...
# Parquet file already exists for Savoy Brown, skipping...
# Parquet file already exists for Josh White, skipping...
# Parquet file already exists for Freeway, skipping...
# Parquet file already exists for Trent Reznor and Atticus Ross, skipping...
# Parquet file already exists for Jimmy Page, skipping...
# Parquet file already exists for $uicideboy$, skipping...
# Parquet file already exists for Kneebody, skipping...
# Parquet file already exists for Justin Furstenfeld, skipping...
# Parquet file already exists for Pentagram, skipping...
# Parquet file already exists for Lex Humphries, skipping...
# Parquet file already exists for Dan Hill, skipping...
# Parquet file already exists for MORTEN, skipping...
# Parquet file already exists for The Red Thread, skipping...
# Parquet file already exists for Monolake, skipping...
# Parquet file already exists for ABC, skipping...
# Parquet file already exists for Hank Jones, skipping...
# Parquet file already exists for Slick Rick, skipping...
# Parquet file already exists for Valerie Dore, skipping...
# Parquet file already exists for Memphis Slim, skipping...
# Parquet file already exists for Sunny Sweeney, skipping...
# Parquet file already exists for Paul Thorn, skipping...
# Parquet file already exists for Megan Tibbits, skipping...
# Parquet file already exists for Jerry Lee Lewis, skipping...
# Parquet file already exists for Depeche Mode, skipping...
# Parquet file already exists for The Halibuts, skipping...
# Parquet file already exists for Do Or Die, skipping...
# Parquet file already exists for Talk In Tongues, skipping...
# Parquet file already exists for Leonard Caston, skipping...
# Parquet file already exists for Tranquility Bass, skipping...
# Parquet file already exists for Cold Showers, skipping...
# Parquet file already exists for This Beautiful Mess, skipping...
# Parquet file already exists for Hawkwind, skipping...
# Parquet file already exists for Gorefest, skipping...
# Parquet file already exists for Band of Horses, skipping...
# Parquet file already exists for Love Spit Love, skipping...
# Parquet file already exists for Dark Funeral, skipping...
# Parquet file already exists for H2O, skipping...
# Parquet file already exists for New Birth Brass Band, skipping...
# Parquet file already exists for Pressurehed, skipping...
# Parquet file already exists for Faye Webster, skipping...
# Parquet file already exists for Porch Ghouls, skipping...
# Parquet file already exists for Anthrax, skipping...
# Parquet file already exists for Glenn Underground, skipping...
# Parquet file already exists for Ace Frehley, skipping...
# Parquet file already exists for Jerry Cantrell, skipping...
# Parquet file already exists for Enslaved, skipping...
# Parquet file already exists for Bill Kirchen, skipping...
# Parquet file already exists for The Walkmen, skipping...
# Parquet file already exists for Aereogramme, skipping...
# Parquet file already exists for Waddie Mitchell, skipping...
# Parquet file already exists for Solex, skipping...
# Parquet file already exists for Tess Parks, skipping...
# Parquet file already exists for Tom Paxton, skipping...
# Parquet file already exists for Carcass, skipping...
# Parquet file already exists for A Skylit Drive, skipping...
# Parquet file already exists for The Neville Brothers, skipping...
# Parquet file already exists for Chris Christian, skipping...
# Parquet file already exists for Joey Dosik, skipping...
# Parquet file already exists for Anthony Hamilton, skipping...
# Parquet file already exists for Jamie Foxx, skipping...
# Parquet file already exists for Kate Wolf, skipping...
# Parquet file already exists for Dave Hollister, skipping...
# Parquet file already exists for Jimmie Rodgers, skipping...
# Parquet file already exists for Los Lonely Boys, skipping...
# Parquet file already exists for Electric Wizard, skipping...
# Parquet file already exists for Ira Newborn, skipping...
# Parquet file already exists for The Victoria Lucas, skipping...
# Parquet file already exists for Neil Diamond, skipping...
# Parquet file already exists for Jacob Fred Jazz Odyssey, skipping...
# Parquet file already exists for Fruition, skipping...
# Parquet file already exists for Pokey Bear, skipping...
# Parquet file already exists for Patti Witten, skipping...
# Parquet file already exists for Café Tacvba, skipping...
# Parquet file already exists for Jacob Latimore, skipping...
# Parquet file already exists for David Ramirez, skipping...
# Parquet file already exists for Blue Scholars, skipping...
# Parquet file already exists for In Tall Buildings, skipping...
# Parquet file already exists for The Obsessives, skipping...
# Parquet file already exists for Desi Valentine, skipping...
# Parquet file already exists for Thin White Rope, skipping...
# Parquet file already exists for Zarah Leander, skipping...
# Parquet file already exists for Madonna, skipping...
# Parquet file already exists for The Internet, skipping...
# Parquet file already exists for Anointed, skipping...
# Parquet file already exists for Harry Partch, skipping...
# Parquet file already exists for Paolino Dalla Porta, skipping...
# Parquet file already exists for Laraaji, skipping...
# Parquet file already exists for The Lovely Bad Things, skipping...
# Parquet file already exists for The Monochrome Set, skipping...
# Parquet file already exists for Kristin Hersh, skipping...
# Parquet file already exists for Arto Lindsay, skipping...
# Parquet file already exists for The Records, skipping...
# Parquet file already exists for The Ponys, skipping...
# Parquet file already exists for Barney Kessel, skipping...
# Parquet file already exists for The Neptunes, skipping...
# Parquet file already exists for The Mar-Keys, skipping...
# Parquet file already exists for Chris Connor, skipping...
# Parquet file already exists for Young Marble Giants, skipping...
# Parquet file already exists for Joni Mitchell, skipping...
# Parquet file already exists for Propellerheads, skipping...
# Parquet file already exists for Earthlings?, skipping...
# Parquet file already exists for Japandroids, skipping...
# Parquet file already exists for Kenny Loggins, skipping...
# Parquet file already exists for The Strangeloves, skipping...
# Parquet file already exists for Champion Jack Dupree, skipping...
# Parquet file already exists for Electric Eels, skipping...
# Parquet file already exists for Mac Lethal, skipping...
# Parquet file already exists for Matmos, skipping...
# Parquet file already exists for Aqua, skipping...
# Parquet file already exists for Remy Shand, skipping...
# Parquet file already exists for Liam Finn, skipping...
# Parquet file already exists for Fugees, skipping...
# Parquet file already exists for Long John Hunter, skipping...
# Parquet file already exists for Organized Konfusion, skipping...
# Parquet file already exists for Tom Gabel, skipping...
# Parquet file already exists for Cracker, skipping...
# Parquet file already exists for Victor Wooten, skipping...
# Parquet file already exists for Mike Errico, skipping...
# Parquet file already exists for Jade Novah, skipping...
# Parquet file already exists for Rick Trevino, skipping...
# Parquet file already exists for Clarence Williams, skipping...
# Parquet file already exists for Blue Rodeo, skipping...
# Parquet file already exists for Trevor Jones, skipping...
# Parquet file already exists for Julius Hemphill, skipping...
# Parquet file already exists for Hole, skipping...
# Parquet file already exists for Vern Gosdin, skipping...
# Parquet file already exists for Loscil, skipping...
# Parquet file already exists for Loren Gold, skipping...
# Parquet file already exists for Matt Monro, skipping...
# Parquet file already exists for Lianne La Havas, skipping...
# Parquet file already exists for Komputer, skipping...
# Parquet file already exists for Saving Abel, skipping...
# Parquet file already exists for SoulHat, skipping...
# Parquet file already exists for Soul Position, skipping...
# Parquet file already exists for Eric Church, skipping...
# Parquet file already exists for Mickey Gilley, skipping...
# Parquet file already exists for Squeeze, skipping...
# Parquet file already exists for Azealia Banks, skipping...
# Parquet file already exists for Macka B, skipping...
# Parquet file already exists for Steve Perry, skipping...
# Parquet file already exists for Pitchshifter, skipping...
# Parquet file already exists for Sammie, skipping...
# Parquet file already exists for Steel Train, skipping...
# Parquet file already exists for Taylor McFerrin, skipping...
# Parquet file already exists for David Baerwald, skipping...
# Parquet file already exists for Graham Central Station, skipping...
# Parquet file already exists for Cold Crush Brothers, skipping...
# Parquet file already exists for Charlie Chaplin, skipping...
# Parquet file already exists for Rainer Maria, skipping...
# Parquet file already exists for Wyclef Jean, skipping...
# Parquet file already exists for Thighpaulsandra, skipping...
# Parquet file already exists for Menudo, skipping...
# Parquet file already exists for Julian Cope, skipping...
# Parquet file already exists for The Golden Gate Quartet, skipping...
# Parquet file already exists for Andrea Marcovicci, skipping...
# Parquet file already exists for One Last Wish, skipping...
# Parquet file already exists for Jason Aldean, skipping...
# Parquet file already exists for Iceberg Slim, skipping...
# Parquet file already exists for Judie Tzuke, skipping...
# Parquet file already exists for Tone Float, skipping...
# Parquet file already exists for Mia Martina, skipping...
# Parquet file already exists for Robert Armani, skipping...
# Parquet file already exists for Benny Joy, skipping...
# Parquet file already exists for Kate Bush, skipping...
# Parquet file already exists for Charles Trenet, skipping...
# Parquet file already exists for Jack Bruce, skipping...
# Parquet file already exists for Isyss, skipping...
# Parquet file already exists for Tall Firs, skipping...
# Parquet file already exists for Brinsley Schwarz, skipping...
# Parquet file already exists for Mother Feather, skipping...
# Parquet file already exists for Medwyn Goodall, skipping...
# Parquet file already exists for Michael Stearns, skipping...
# Parquet file already exists for Chris Knox, skipping...
# Parquet file already exists for Randy Houser, skipping...
# Parquet file already exists for The Horrors, skipping...
# Parquet file already exists for This Heat, skipping...
# Parquet file already exists for Erik Satie, skipping...
# Parquet file already exists for Company B, skipping...
# Parquet file already exists for Mose Allison, skipping...
# Parquet file already exists for The Geraldine Fibbers, skipping...
# Parquet file already exists for Lee Bannon, skipping...
# Parquet file already exists for Al Kooper, skipping...
# Parquet file already exists for The Chantays, skipping...
# Parquet file already exists for Tony Molina, skipping...
# Parquet file already exists for Frank Ocean, skipping...
# Parquet file already exists for Railroad Jerk, skipping...
# Parquet file already exists for Skip James, skipping...
# Parquet file already exists for Ester Drang, skipping...
# Parquet file already exists for Skylar Grey, skipping...
# Parquet file already exists for Richie Hawtin, skipping...
# Parquet file already exists for The Only Ones, skipping...
# Parquet file already exists for Peanut Butter Wolf, skipping...
# Parquet file already exists for Kim Wilson, skipping...
# Parquet file already exists for Joe Morris, skipping...
# Parquet file already exists for Susanna Hoffs, skipping...
# Parquet file already exists for Wallace Roney, skipping...
# Parquet file already exists for V. Bozeman, skipping...
# Parquet file already exists for Dead Boys, skipping...
# Parquet file already exists for Sarah McLachlan, skipping...
# Parquet file already exists for Lisandro Meza, skipping...
# Parquet file already exists for Herbert Grönemeyer, skipping...
# Parquet file already exists for Bonnie Anderson, skipping...
# Parquet file already exists for Morrissey, skipping...
# Parquet file already exists for Sun City Girls, skipping...
# Parquet file already exists for My Vitriol, skipping...
# Parquet file already exists for Firehouse, skipping...
# Parquet file already exists for Hoyt Axton, skipping...
# Parquet file already exists for Death By Stereo, skipping...
# Parquet file already exists for Mack Wilds, skipping...
# Parquet file already exists for Dustin Lynch, skipping...
# Parquet file already exists for The Verlaines, skipping...
# Parquet file already exists for Shep Pettibone, skipping...
# Parquet file already exists for Gene Taylor, skipping...
# Parquet file already exists for Doug Powell, skipping...
# Parquet file already exists for Vince Neil, skipping...
# Parquet file already exists for Charlie Rich, skipping...
# Parquet file already exists for Frank Zappa, skipping...
# Parquet file already exists for X-Ray Spex, skipping...
# Parquet file already exists for Alphaville, skipping...
# Parquet file already exists for Jim Ford, skipping...
# Parquet file already exists for Nina Nastasia, skipping...
# Parquet file already exists for Soulfly, skipping...
# Parquet file already exists for Subhumans, skipping...
# Parquet file already exists for Durrty Goodz, skipping...
# Parquet file already exists for Spank Rock, skipping...
# Parquet file already exists for Whissell, skipping...
# Parquet file already exists for Maurice Chevalier, skipping...
# Parquet file already exists for Paul Simon, skipping...
# Parquet file already exists for Willard Grant Conspiracy, skipping...
# Parquet file already exists for Smash Mouth, skipping...
# Parquet file already exists for Bobby Byrd, skipping...
# Parquet file already exists for Deana Carter, skipping...
# Parquet file already exists for Ane Brun, skipping...
# Parquet file already exists for Pretty Girls Make Graves, skipping...
# Parquet file already exists for Telefon Tel Aviv, skipping...
# Parquet file already exists for The New Pornographers, skipping...
# Parquet file already exists for The Primitives, skipping...
# Parquet file already exists for Buffalo Daughter, skipping...
# Parquet file already exists for The Pack, skipping...
# Parquet file already exists for Earl Palmer, skipping...
# Parquet file already exists for Cannibal Corpse, skipping...
# Parquet file already exists for Joe Higgs, skipping...
# Parquet file already exists for Paddy O'Brien, skipping...
# Parquet file already exists for Lil Mama, skipping...
# Parquet file already exists for Pave The Rocket, skipping...
# Parquet file already exists for Billy Currington, skipping...
# Parquet file already exists for Willie Murphy, skipping...
# Parquet file already exists for Kathy Mattea, skipping...
# Parquet file already exists for Nena, skipping...
# Parquet file already exists for Wet Willie, skipping...
# Parquet file already exists for TWRP, skipping...
# Parquet file already exists for Rilo Kiley, skipping...
# Parquet file already exists for Giovanni Pierluigi da Palestrina, skipping...
# Parquet file already exists for Boud Deun, skipping...
# Parquet file already exists for U-Roy, skipping...
# Parquet file already exists for Hear'Say, skipping...
# Parquet file already exists for The Dixon Brothers, skipping...
# Parquet file already exists for Willie Love, skipping...
# Parquet file already exists for Ranie Burnette, skipping...
# Parquet file already exists for Liz Phair, skipping...
# Parquet file already exists for Holy Ghost!, skipping...
# Parquet file already exists for Lisa Fischer, skipping...
# Parquet file already exists for The Honeymoon Killers, skipping...
# Parquet file already exists for Dave Grusin, skipping...
# Parquet file already exists for Micky Dolenz, skipping...
# Parquet file already exists for Genesis, skipping...
# Parquet file already exists for Tunji Ige, skipping...
# Parquet file already exists for Lisa Stansfield, skipping...
# Parquet file already exists for Jimmy Henderson, skipping...
# Parquet file already exists for Adam Gnade, skipping...
# Parquet file already exists for Nipsey Hussle, skipping...
# Parquet file already exists for Z.Z. Hill, skipping...
# Parquet file already exists for Gretchen Wilson, skipping...
# Parquet file already exists for Screaming Females, skipping...
# Parquet file already exists for Bernard Cribbins, skipping...
# Parquet file already exists for Lucille Hegamin, skipping...
# Parquet file already exists for Shakin' Stevens, skipping...
# Parquet file already exists for Oscar Pettiford, skipping...
# Parquet file already exists for Voice Of A Generation, skipping...
# Parquet file already exists for Johnny "Big Moose" Walker, skipping...
# Parquet file already exists for Mannie Fresh, skipping...
# Parquet file already exists for Lars Erstrand, skipping...
# Parquet file already exists for Luis Miguel, skipping...
# Parquet file already exists for The Marvelettes, skipping...
# Parquet file already exists for Jay Bennett, skipping...
# Parquet file already exists for Grateful Dead, skipping...
# Parquet file already exists for Dallas Smith, skipping...
# Parquet file already exists for Bobby Charles, skipping...
# Parquet file already exists for Angel Kaplan, skipping...
# Parquet file already exists for The Gits, skipping...
# Parquet file already exists for Map.ache, skipping...
# Parquet file already exists for Thundercat, skipping...
# Parquet file already exists for Beres Hammond, skipping...
# Parquet file already exists for Anna Cordell, skipping...
# Parquet file already exists for Laufey, skipping...
# Parquet file already exists for Kimberly Cole, skipping...
# Parquet file already exists for Four Year Strong, skipping...
# Parquet file already exists for B. Fleischmann, skipping...
# Parquet file already exists for Jacob Sartorius, skipping...
# Parquet file already exists for Machinedrum, skipping...
# Parquet file already exists for Larry Sparks, skipping...
# Parquet file already exists for DMX Krew, skipping...
# Parquet file already exists for John Denver, skipping...
# Parquet file already exists for Toothpaste 2000, skipping...
# Parquet file already exists for Kenny Garrett, skipping...
# Parquet file already exists for Connie Smith, skipping...
# Parquet file already exists for mewithoutYou, skipping...
# Parquet file already exists for Wilson Pickett, skipping...
# Parquet file already exists for Freddie Jackson, skipping...
# Parquet file already exists for Espers, skipping...
# Parquet file already exists for The Impressions, skipping...
# Parquet file already exists for Nik Freitas, skipping...
# Parquet file already exists for Patricia Barber, skipping...
# Parquet file already exists for Joe Elliott, skipping...
# Parquet file already exists for Bud Powell, skipping...
# Parquet file already exists for Andreas Dorau, skipping...
# Parquet file already exists for James Talley, skipping...
# Parquet file already exists for The Nice Boys, skipping...
# Parquet file already exists for Chris Potter, skipping...
# Parquet file already exists for Bauhaus, skipping...
# Parquet file already exists for Michael Angelo Batio, skipping...
# Parquet file already exists for Kid Ink, skipping...
# Parquet file already exists for Ducks Deluxe, skipping...
# Parquet file already exists for J.J. Johnson, skipping...
# Parquet file already exists for MisterWives, skipping...
# Parquet file already exists for Five Finger Death Punch, skipping...
# Parquet file already exists for Cecilia Bartoli, skipping...
# Parquet file already exists for Glen Washington, skipping...
# Parquet file already exists for Nils Frahm, skipping...
# Parquet file already exists for The Album Leaf, skipping...
# Parquet file already exists for MxPx, skipping...
# Parquet file already exists for Da Lata, skipping...
# Parquet file already exists for The White Stripes, skipping...
# Parquet file already exists for The Essex Green, skipping...
# Parquet file already exists for Benton Falls, skipping...
# Parquet file already exists for Girl Talk, skipping...
# Parquet file already exists for Fred Frith, skipping...
# Parquet file already exists for Dickie Peterson, skipping...
# Parquet file already exists for Last Crack, skipping...
# Parquet file already exists for Mark Hummel, skipping...
# Parquet file already exists for Martina McBride, skipping...
# Parquet file already exists for Sinéad O'Connor, skipping...
# Parquet file already exists for Pat Cisarano, skipping...
# Parquet file already exists for Andrea Parker, skipping...
# Parquet file already exists for Calexico, skipping...
# Parquet file already exists for Tracey Ullman, skipping...
# Parquet file already exists for Simply Saucer, skipping...
# Parquet file already exists for William Elliott Whitmore, skipping...
# Parquet file already exists for Randy Waldman, skipping...
# Parquet file already exists for Opeth, skipping...
# Parquet file already exists for Bobby Day, skipping...
# Parquet file already exists for Take That, skipping...
# Parquet file already exists for Soft Machine, skipping...
# Parquet file already exists for SVRCINA, skipping...
# Parquet file already exists for Timothy Monger, skipping...
# Parquet file already exists for Vic Chesnutt, skipping...
# Parquet file already exists for FOREVER ANTi PoP, skipping...
# Parquet file already exists for Evelyn "Champagne" King, skipping...
# Parquet file already exists for Jadakiss, skipping...
# Parquet file already exists for Someone Still Loves You Boris Yeltsin, skipping...
# Parquet file already exists for Tigercats, skipping...
# Parquet file already exists for Bongwater, skipping...
# Parquet file already exists for Judy Garland, skipping...
# Parquet file already exists for Bingo Players, skipping...
# Parquet file already exists for Lawrence Rothman, skipping...
# Parquet file already exists for Tommy Keene, skipping...
# Parquet file already exists for Trampolene, skipping...
# Parquet file already exists for Suzanne Ciani, skipping...
# Parquet file already exists for El Jeffrey, skipping...
# Parquet file already exists for Stephen Bishop, skipping...
# Parquet file already exists for Clay Aiken, skipping...
# Parquet file already exists for Crystal Antlers, skipping...
# Parquet file already exists for The Crystal Method, skipping...
# Parquet file already exists for Cults, skipping...
# Parquet file already exists for Buju Banton, skipping...
# Parquet file already exists for Ludus, skipping...
# Parquet file already exists for June Tyson, skipping...
# Parquet file already exists for Brenda Kahn, skipping...
# Parquet file already exists for Foxes, skipping...
# Parquet file already exists for Beyoncé, skipping...
# Parquet file already exists for Michael Brecker, skipping...
# Parquet file already exists for Brian McKnight, skipping...
# Parquet file already exists for The Saturday Knights, skipping...
# Parquet file already exists for Yonder Mountain String Band, skipping...
# Parquet file already exists for Tavares, skipping...
# Parquet file already exists for Kyuss, skipping...
# Parquet file already exists for Mike Jones, skipping...
# Parquet file already exists for Fursaxa, skipping...
# Parquet file already exists for Hawk Nelson, skipping...
# Parquet file already exists for Django Reinhardt, skipping...
# Parquet file already exists for Steve Riley & The Mamou Playboys, skipping...
# Parquet file already exists for Nick Howard, skipping...
# Parquet file already exists for The Radiators, skipping...
# Parquet file already exists for Hungry Lucy, skipping...
# Parquet file already exists for Judy Kuhn, skipping...
# Parquet file already exists for Melanie Fiona, skipping...
# Parquet file already exists for Michael Hurley, skipping...
# Parquet file already exists for Louise Goffin, skipping...
# Parquet file already exists for Candi Staton, skipping...
# Parquet file already exists for California X, skipping...
# Parquet file already exists for Archie Fisher, skipping...
# Parquet file already exists for Roadkill Ghost Choir, skipping...
# Parquet file already exists for Josh Roseman Unit, skipping...
# Parquet file already exists for Roger Waters, skipping...
# Parquet file already exists for Rogue Wave, skipping...
# Parquet file already exists for Phil Collins, skipping...
# Parquet file already exists for Nashville Pussy, skipping...
# Parquet file already exists for Imani Coppola, skipping...
# Parquet file already exists for The Beguiled, skipping...
# Parquet file already exists for Mitchell Akiyama, skipping...
# Parquet file already exists for Bob Gibson, skipping...
# Parquet file already exists for The Living End, skipping...
# Parquet file already exists for Port O'Brien, skipping...
# Parquet file already exists for Crippled Black Phoenix, skipping...
# Parquet file already exists for Bobby Brown, skipping...
# ...
# Parquet file already exists for Secret Affair, skipping...
# Parquet file already exists for Erasure, skipping...
# Parquet file already exists for The Most Serene Republic, skipping...
# Parquet file already exists for New American Shame, skipping...
# Parquet file already exists for Drake Bell, skipping...
# Parquet file already exists for Jimmy Martin, skipping...
# Parquet file already exists for Shelleyan Orphan, skipping...
# Parquet file already exists for Kenny G, skipping...
# Parquet file already exists for Daughter, skipping...
# Parquet file already exists for Black Uhuru, skipping...
# Parquet file already exists for Kelly Harrell, skipping...
# Parquet file already exists for Felicia Temple, skipping...
# Parquet file already exists for Liam Lynch, skipping...
# Parquet file already exists for Ultimate Fakebook, skipping...
# Parquet file already exists for Giuffria, skipping...
# Parquet file already exists for The Flashbulb, skipping...
# Parquet file already exists for Breathless, skipping...
# Parquet file already exists for Bowery Electric, skipping...
# Parquet file already exists for Kim Deal, skipping...
# Parquet file already exists for Peetie Wheatstraw, skipping...
# Parquet file already exists for The Guess Who, skipping...
# Parquet file already exists for The Runaways, skipping...
# Parquet file already exists for Odd Nosdam, skipping...
# Parquet file already exists for The Osmonds, skipping...
# Parquet file already exists for Paul Desmond, skipping...
# Parquet file already exists for Memphis Jug Band, skipping...
# Parquet file already exists for John Hartford, skipping...
# Parquet file already exists for Grant-Lee Phillips, skipping...
# Parquet file already exists for Vanilla Fudge, skipping...
# Parquet file already exists for Global Communication, skipping...
# Parquet file already exists for Ebba Forsberg, skipping...
# Parquet file already exists for Kajagoogoo, skipping...
# Parquet file already exists for The Concretes, skipping...
# Parquet file already exists for Jupiter One, skipping...
# Parquet file already exists for Lumidee, skipping...
# Parquet file already exists for Chuck Strong, skipping...
# Parquet file already exists for Goody Grace, skipping...
# Parquet file already exists for Commodores, skipping...
# Parquet file already exists for Rah Rah, skipping...
# Parquet file already exists for Gridlock, skipping...
# Parquet file already exists for Da Brat, skipping...
# Parquet file already exists for Chevelle, skipping...
# Parquet file already exists for Steven Wilson, skipping...
# Parquet file already exists for Stray Cats, skipping...
# Parquet file already exists for Tedo Stone, skipping...
# Parquet file already exists for Shocking Pinks, skipping...
# Parquet file already exists for Sallie Martin, skipping...
# Parquet file already exists for Juan Gabriel, skipping...
# Parquet file already exists for Slim Harpo, skipping...
# Parquet file already exists for Tom Rush, skipping...
# Parquet file already exists for Pete Steele, skipping...
# Parquet file already exists for Yashin, skipping...
# Parquet file already exists for Trenchmouth, skipping...
# Parquet file already exists for Zion I, skipping...
# Parquet file already exists for Camila Cabello, skipping...
# Parquet file already exists for Annie Lennox, skipping...
# Parquet file already exists for Chris Lane, skipping...
# Parquet file already exists for The Walkabouts, skipping...
# Parquet file already exists for John Prine, skipping...
# Parquet file already exists for Faye Adams, skipping...
# Parquet file already exists for Dan Croll, skipping...
# Parquet file already exists for Zony Mash, skipping...
# Parquet file already exists for Fictionist, skipping...
# Parquet file already exists for Delays, skipping...
# Parquet file already exists for Dave Meder, skipping...
# Parquet file already exists for MC Lyte, skipping...
# Parquet file already exists for Richard Addinsell, skipping...
# Parquet file already exists for Mindless Self Indulgence, skipping...
# Parquet file already exists for Djivan Gasparyan, skipping...
# Parquet file already exists for Guadalcanal Diary, skipping...
# Parquet file already exists for Pansy Division, skipping...
# Parquet file already exists for Nicola Alesini, skipping...
# Parquet file already exists for Will Jay, skipping...
# Parquet file already exists for Bon Iver, skipping...
# Parquet file already exists for Bennie Maupin, skipping...
# Parquet file already exists for Billy Taylor, skipping...
# Parquet file already exists for Destroy All Monsters, skipping...
# Parquet file already exists for Bully, skipping...
# Parquet file already exists for Samara Lubelski, skipping...
# Parquet file already exists for William Michael Morgan, skipping...
# Parquet file already exists for Erin Boheme, skipping...
# Parquet file already exists for Flyleaf, skipping...
# Parquet file already exists for Cabas, skipping...
# Parquet file already exists for P.F. Sloan, skipping...
# Parquet file already exists for Ancient Future, skipping...
# Parquet file already exists for Travie McCoy, skipping...
# Parquet file already exists for Roy Rogers, skipping...
# Parquet file already exists for Ciara, skipping...
# Parquet file already exists for Zingaia, skipping...
# Parquet file already exists for Phebe Starr, skipping...
# Parquet file already exists for State Champs, skipping...
# Parquet file already exists for Tony Williams, skipping...
# Parquet file already exists for Tish Hinojosa, skipping...
# Parquet file already exists for Jamie Lawson, skipping...
# Parquet file already exists for Richard Elliot, skipping...
# Parquet file already exists for The Police, skipping...
# Parquet file already exists for Krokus, skipping...
# Parquet file already exists for Lagbaja, skipping...
# Parquet file already exists for Myracle Brah, skipping...
# Parquet file already exists for Stevie Wonder, skipping...
# Parquet file already exists for Engelbert Humperdinck, skipping...
# Parquet file already exists for Dodgy, skipping...
# Parquet file already exists for Peter Blegvad, skipping...
# Parquet file already exists for The La's, skipping...
# Parquet file already exists for Dweezil Zappa, skipping...
# Parquet file already exists for Total Babes, skipping...
# Parquet file already exists for Air Supply, skipping...
# Parquet file already exists for Present, skipping...
# Parquet file already exists for Remy Ma, skipping...
# Parquet file already exists for Glee Cast, skipping...
# Parquet file already exists for Leaf Hound, skipping...
# Parquet file already exists for Guns N' Roses, skipping...
# Parquet file already exists for Band Of Susans, skipping...
# Parquet file already exists for JamisonParker, skipping...
# Parquet file already exists for Maurice Jarre, skipping...
# Parquet file already exists for Dagmar Krause, skipping...
# Parquet file already exists for Joe Liggins, skipping...
# Parquet file already exists for Dino Valente, skipping...
# Parquet file already exists for Boymerang, skipping...
# Parquet file already exists for Brass Construction, skipping...
# Parquet file already exists for The Band, skipping...
# Parquet file already exists for Christina Carter, skipping...
# Parquet file already exists for Daphne Loves Derby, skipping...
# Parquet file already exists for Calvin Richardson, skipping...
# Parquet file already exists for Vince Trombetta, skipping...
# Parquet file already exists for From Indian Lakes, skipping...
# Parquet file already exists for Babyshambles, skipping...
# Parquet file already exists for Exuma, skipping...
# Parquet file already exists for The Wild Swans, skipping...
# Parquet file already exists for Arcwelder, skipping...
# Parquet file already exists for Twisted Sister, skipping...
# Parquet file already exists for John Coltrane Quartet, skipping...
# Parquet file already exists for Young Killer, skipping...
# Parquet file already exists for The Cool Kids, skipping...
# Parquet file already exists for The Pharaohs, skipping...
# Parquet file already exists for Helen Love, skipping...
# Parquet file already exists for Dwele, skipping...
# Parquet file already exists for Hampton Grease Band, skipping...
# Parquet file already exists for The Moments, skipping...
# Parquet file already exists for Ethan Gruska, skipping...
# Parquet file already exists for Christopher Cross, skipping...
# Parquet file already exists for Sleigh Bells, skipping...
# Parquet file already exists for Roy Hamilton, skipping...
# Parquet file already exists for Klara Lewis, skipping...
# Parquet file already exists for Urban Rescue, skipping...
# Parquet file already exists for Better Than Ezra, skipping...
# Parquet file already exists for The Piano Guys, skipping...
# Parquet file already exists for BMX Bandits, skipping...
# Parquet file already exists for Any Trouble, skipping...
# Parquet file already exists for Mugison, skipping...
# Parquet file already exists for The Blackout Pact, skipping...
# Parquet file already exists for Renaissance, skipping...
# Parquet file already exists for Brenda Russell, skipping...
# Parquet file already exists for Izzy Bizu, skipping...
# Parquet file already exists for Dr. Jeffrey Thompson, skipping...
# Parquet file already exists for Jewel, skipping...
# Parquet file already exists for The Skatalites, skipping...
# Parquet file already exists for Our Lady Peace, skipping...
# Parquet file already exists for Ted Hawkins, skipping...
# Parquet file already exists for George Hodos, skipping...
# Parquet file already exists for Gary Valente, skipping...
# Parquet file already exists for The Fleetwoods, skipping...
# Parquet file already exists for Ben Vaughn, skipping...
# Parquet file already exists for Guy Davis, skipping...
# Parquet file already exists for Soulive, skipping...
# Parquet file already exists for The Roots, skipping...
# Parquet file already exists for Chicken Lips, skipping...
# Parquet file already exists for Sara Bareilles, skipping...
# Parquet file already exists for Violent Femmes, skipping...
# Parquet file already exists for Active Child, skipping...
# Parquet file already exists for The Normal, skipping...
# Parquet file already exists for Dean Martin, skipping...
# Parquet file already exists for Drive Like Jehu, skipping...
# Parquet file already exists for Greg Graffin, skipping...
# Parquet file already exists for Eddie Hazel, skipping...
# Parquet file already exists for Fat Nick, skipping...
# Parquet file already exists for Shyne, skipping...
# Parquet file already exists for AudioDamn!, skipping...
# Parquet file already exists for Sarah Borges, skipping...
# Parquet file already exists for Death of Samantha, skipping...
# Parquet file already exists for Joey Beltram, skipping...
# Parquet file already exists for Nikki Yanofsky, skipping...
# Parquet file already exists for La Muerte, skipping...
# Parquet file already exists for Poco, skipping...
# Parquet file already exists for Cyndi Lauper, skipping...
# Parquet file already exists for Great White, skipping...
# Parquet file already exists for John Klemmer, skipping...
# Parquet file already exists for Pop Will Eat Itself, skipping...
# Parquet file already exists for Jon Jang, skipping...
# Parquet file already exists for FaltyDL, skipping...
# Parquet file already exists for Whistle, skipping...
# Parquet file already exists for Rick James, skipping...
# Parquet file already exists for Cheri Knight, skipping...
# Parquet file already exists for Shenandoah, skipping...
# Parquet file already exists for Taking Back Sunday, skipping...
# Parquet file already exists for Lefty Frizzell, skipping...
# Parquet file already exists for Teisco Del Rey, skipping...
# Parquet file already exists for The Tornadoes, skipping...
# Parquet file already exists for The Outfield, skipping...
# Parquet file already exists for Edward Sharpe & The Magnetic Zeros, skipping...
# Parquet file already exists for Matthew Koma, skipping...
# Parquet file already exists for deadmau5, skipping...
# Parquet file already exists for The Heliocentrics, skipping...
# Parquet file already exists for The Music Machine, skipping...
# Parquet file already exists for Crime Mob, skipping...
# Parquet file already exists for Crumb, skipping...
# Parquet file already exists for Michael Carpenter, skipping...
# Parquet file already exists for Egg, skipping...
# Parquet file already exists for Shirley Collins, skipping...
# Parquet file already exists for Johnnie Ray, skipping...
# Parquet file already exists for Go West, skipping...
# Parquet file already exists for Tin Huey, skipping...
# Parquet file already exists for Oswego, skipping...
# Parquet file already exists for The Midnight, skipping...
# Parquet file already exists for Francine Reed, skipping...
# Parquet file already exists for Otep, skipping...
# Parquet file already exists for Psychic TV, skipping...
# Parquet file already exists for King's X, skipping...
# Parquet file already exists for Pan Sonic, skipping...
# Parquet file already exists for Dan Auerbach, skipping...
# Parquet file already exists for Donna The Buffalo, skipping...
# Parquet file already exists for Mark Erelli, skipping...
# Parquet file already exists for Rachele Lynae, skipping...
# Parquet file already exists for Cibo Matto, skipping...
# Parquet file already exists for Nas, skipping...
# Parquet file already exists for Jazzyfatnastees, skipping...
# Parquet file already exists for Mavis Staples, skipping...
# Parquet file already exists for The McCoury Brothers, skipping...
# Parquet file already exists for Kate McGarry, skipping...
# Parquet file already exists for As One, skipping...
# Parquet file already exists for Omni Trio, skipping...
# Parquet file already exists for Mike Stern, skipping...
# Parquet file already exists for Gay Dad, skipping...
# Parquet file already exists for Superdrag, skipping...
# Parquet file already exists for Fever Ray, skipping...
# Parquet file already exists for Television, skipping...
# Parquet file already exists for Beatallica, skipping...
# Parquet file already exists for Point Of Grace, skipping...
# Parquet file already exists for Nellie McKay, skipping...
# Parquet file already exists for Della Reese, skipping...
# Parquet file already exists for Sandy Bull, skipping...
# Parquet file already exists for David Toop, skipping...
# Parquet file already exists for Donnie McClurkin, skipping...
# Parquet file already exists for Ken Colyer, skipping...
# Parquet file already exists for Andy Williams, skipping...
# Parquet file already exists for Scott 4, skipping...
# Parquet file already exists for Chris Ardoin, skipping...
# Parquet file already exists for Third Eye Blind, skipping...
# Parquet file already exists for The Sweet Inspirations, skipping...
# Parquet file already exists for Murphy's Law, skipping...
# Parquet file already exists for Triumvirat, skipping...
# Parquet file already exists for Black Strobe, skipping...
# Parquet file already exists for Blue States, skipping...
# Parquet file already exists for David Clavijo, skipping...
# Parquet file already exists for Jimmy Dorsey, skipping...
# Parquet file already exists for Miriam Makeba, skipping...
# Parquet file already exists for The Flower Kings, skipping...
# Parquet file already exists for T. Texas Tyler, skipping...
# Parquet file already exists for George W. Johnson, skipping...
# Parquet file already exists for Ani DiFranco, skipping...
# Parquet file already exists for Aretha Franklin, skipping...
# Parquet file already exists for Raoul Björkenheim, skipping...
# Parquet file already exists for Travis Mills, skipping...
# Parquet file already exists for The Gap Band, skipping...
# Parquet file already exists for The Byrds, skipping...
# Parquet file already exists for Was (Not Was), skipping...
# Parquet file already exists for Bobby Rydell, skipping...
# Parquet file already exists for Aaron Parks, skipping...
# Parquet file already exists for Bill Laswell, skipping...
# Parquet file already exists for George Gershwin, skipping...
# Parquet file already exists for The Clash, skipping...
# Parquet file already exists for Céu, skipping...
# Parquet file already exists for Girls Aloud, skipping...
# Parquet file already exists for Stephen Sondheim, skipping...
# Parquet file already exists for Samhain, skipping...
# Parquet file already exists for DC Talk, skipping...
# Completed processing all artists.

# %%
# max_retries = 3
# retry_counter = 0

# while not failed_requests.empty and retry_counter < max_retries:
#     print(f"Retrying failed requests (attempt {retry_counter + 1}/{max_retries})...")
#     retry_failed_requests = pd.DataFrame(columns=["Spotify ID"])
#     for _, row in failed_requests.iterrows():
#         artist_id = row["Spotify ID"]
#         artist_name = artist_ids[artist_id]
#         sanitized_artist_name = sanitize_filename(artist_name)
#         parquet_file_path = f'{sanitized_artist_name}_tracks.parquet'

#         if os.path.exists(parquet_file_path):
#             print(f"Parquet file already exists for {artist_name}, skipping...")
#             continue
#         try:
#             refreshed_token, new_token_start_time = refresh_token(token_start_time)
#             if refreshed_token:
#                 token = refreshed_token
#                 token_start_time = new_token_start_time
#             albums = get_albums_for_artist(token, artist_id)

#             if albums is None:
#                 failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
#                 save_failed_requests(failed_requests)
#                 continue

#             album_df = pd.DataFrame.from_dict(albums, orient="index")
#             album_df.index.name = "album_name"

#             all_tracks_df = pd.DataFrame()
#             for album_id in tqdm(album_df['album_id'], desc=f"Processing {artist_name}"):
#                 time.sleep(1)
#                 try:
#                     tracks = get_tracks_for_album(token, album_id)

#                     if tracks is None:
#                         failed_requests = failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)
#                         save_failed_requests(failed_requests)
#                         continue

#                     tracks = pd.DataFrame(tracks)
#                     tracks['album_id'] = album_id
#                     all_tracks_df = pd.concat([all_tracks_df, tracks], axis=0)
#                 except Exception as e:
#                     print(f"Warning: Error fetching tracks for {artist_name}: {e}")

#             try:
#                 af_df = get_audio_features(token, all_tracks_df['track_id'].tolist())
#                 af_df = af_df.rename(columns={'id': 'track_id'})
#                 all_aftracks_df = pd.merge(all_tracks_df, af_df, on='track_id')
#                 album_all_aftracks_df = pd.merge(album_df, all_aftracks_df, on='album_id')
#                 sanitized_artist_name = sanitize_filename(artist_name)
#                 album_all_aftracks_df.to_parquet(f'{sanitized_artist_name}_tracks.parquet')

#                 save_checkpoint(artist_id, artist_name)
#             except Exception as e:
#                 print(f"Warning: Error fetching audio features for {artist_name}: {e}")

#             iteration_counter += 1
#             if iteration_counter % sleep_interval == 0:
#                 time.sleep(1)

#         except Exception as e:
#             print(f"Error processing {artist_name}: {e}")
#             retry_failed_requests = retry_failed_requests.append({"Spotify ID": artist_id}, ignore_index=True)

#     failed_requests = retry_failed_requests
#     retry_counter += 1

# if not failed_requests.empty:
#     print("Some requests still failed after all retries:")
#     print(failed_requests)
# else:
#     print("All failed requests have been successfully processed.")
