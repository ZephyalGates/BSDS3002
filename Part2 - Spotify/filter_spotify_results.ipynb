# %%
from fuzzywuzzy import fuzz
import pandas as pd
import re
import unicodedata

# %%
df = pd.read_parquet("artists_with_infos.parquet")

# %%
df.head()
# Out:
#                Artist        Spotify Name  \
# 0                Bono              Bonobo
# 1           Motörhead           Motörhead
# 2  Nils Petter Molvær  Nils Petter Molvær
# 3       Color Me Badd       Color Me Badd
# 4       Trumans Water       Trumans Water
#
#                                               Genres  Popularity
# 0  [downtempo, electronica, jazztronica, nu jazz,...        67.0
# 1  [album rock, hard rock, metal, rock, speed metal]        68.0
# 2  [contemporary jazz, ecm-style jazz, fourth wor...        39.0
# 3  [boy band, contemporary r&b, new jack swing, r...        53.0
# 4                                       [noise rock]         7.0

# %%
def compute_similarity(s1, s2):
    if s1 is None or s2 is None:
        return 0
    else:
        return fuzz.ratio(s1.lower(), s2.lower())

def preprocess_string(s):

    if isinstance(s, str):
        s = s.replace("$", "s")
        s = s.replace("!", "i")
        s = s.replace("/", " ")

        s = re.sub(r'[^\w\s]', '', s)
        s = s.replace("&", "and")
        s = s.lower()
        return s
    else:

        return ""

# %%
df["Similarity"] = df.apply(lambda row: compute_similarity(row["Artist"], row["Spotify Name"]), axis=1)

df_filtered = df[df["Similarity"] >= 95]

df_leftover = df[df["Similarity"] < 95]

print(len(df), len(df_filtered), len(df_leftover))
# Out:
# 13661 9890 3771

# %%
df_leftover2 = df_leftover.copy(deep=True)
df_leftover2.loc[:, "Artist2"] = df_leftover2.loc[:, "Artist"].apply(preprocess_string)
df_leftover2.loc[:, "Spotify Name2"] = df_leftover2.loc[:, "Spotify Name"].apply(preprocess_string)
df_leftover2["Similarity2"] = df_leftover2.apply(lambda row: compute_similarity(row["Artist2"], row["Spotify Name2"]), axis=1)

# %%
#df_leftover2[df_leftover2["Similarity"] < df_leftover2["Similarity2"]]

df_leftover2_pickup = df_leftover2[df_leftover2["Similarity"] < df_leftover2["Similarity2"]]
df_leftover3a = df_leftover2[df_leftover2["Similarity"] >= df_leftover2["Similarity2"]]
df_filtered2 = df_leftover2_pickup[df_leftover2_pickup["Similarity2"] >= 95]
df_leftover3b = df_leftover2_pickup[df_leftover2_pickup["Similarity2"] < 95]

df_leftover3 = pd.concat([df_leftover3a, df_leftover3b])

print(len(df_leftover2), len(df_filtered2), len(df_leftover3))

df_filtered2
# Out:
# 3771 102 3669
#                                  Artist                        Spotify Name  \
# 486                           Lil' Keke                           Lil’ Keke
# 546                             N*E*R*D                             N.E.R.D
# 570                        Pan?American                        Pan-American
# 718                             UK Subs                           U.K. Subs
# 752       Joan Jett and the Blackhearts         Joan Jett & the Blackhearts
# ...                                 ...                                 ...
# 13121  Mitch Ryder & The Detroit Wheels  Mitch Ryder and The Detroit Wheels
# 13167                             Ke$ha                               Kesha
# 13232                   Meade Lux Lewis                   Meade "Lux" Lewis
# 13547                          Lil Troy                           Lil' Troy
# 13581                         Styles P.                            Styles P
#
#                                                   Genres  Popularity  \
# 486    [chopped and screwed, crunk, dirty south rap, ...        55.0
# 546                          [hip hop, virginia hip hop]        60.0
# 570    [ambient, compositional ambient, dark jazz, dr...        32.0
# 718                           [oi, pub rock, punk, uk82]        37.0
# 752                                    [glam punk, rock]        67.0
# ...                                                  ...         ...
# 13121                                     [detroit rock]        31.0
# 13167                    [dance pop, pop, post-teen pop]        78.0
# 13232               [boogie-woogie, piano blues, stride]        24.0
# 13547  [dirty south rap, gangster rap, houston rap, s...        52.0
# 13581  [alternative hip hop, battle rap, east coast h...        64.0
#
#        Similarity                          Artist2  \
# 486            89                         lil keke
# 546            57                             nerd
# 570            92                      panamerican
# 718            88                          uk subs
# 752            93    joan jett and the blackhearts
# ...           ...                              ...
# 13121          94  mitch ryder  the detroit wheels
# 13167          80                            kesha
# 13232          94                  meade lux lewis
# 13547          94                         lil troy
# 13581          94                         styles p
#
#                             Spotify Name2  Similarity2
# 486                              lil keke          100
# 546                                  nerd          100
# 570                           panamerican          100
# 718                               uk subs          100
# 752            joan jett  the blackhearts           95
# ...                                   ...          ...
# 13121  mitch ryder and the detroit wheels           95
# 13167                               kesha          100
# 13232                     meade lux lewis          100
# 13547                            lil troy          100
# 13581                            styles p          100
#
# [102 rows x 8 columns]

# %%
df_leftover3
# Out:
#                                                   Artist  \
# 0                                                   Bono
# 6                                                    Can
# 9                    Justin Timberlake duet with Beyonce
# 19                                    Hana and the Goose
# 28     Paul Revere & Mark Lindsay formerly of Paul Re...
# ...                                                  ...
# 13561                                  Stones & feathers
# 13571                                             J Nash
# 13586                                          CORNELIUS
# 13608                                     Johnny Hammond
# 13650                     Hank Penny & His Radio Cowboys
#
#                            Spotify Name  \
# 0                                Bonobo
# 6                               Cannons
# 9                Who TF Is Justin Time?
# 19                                 HANA
# 28            Paul Revere & The Raiders
# ...                                 ...
# 13561                The Rolling Stones
# 13571                           J-Nasty
# 13586  Cornelius Brothers & Sister Rose
# 13608            Johnny "Hammond" Smith
# 13650                        Hank Penny
#
#                                                   Genres  Popularity  \
# 0      [downtempo, electronica, jazztronica, nu jazz,...        67.0
# 6                                                   None        63.0
# 9                                 [country rap, redneck]        49.0
# 19                                            [dark pop]        47.0
# 28     [bubblegum pop, classic garage rock, classic r...        42.0
# ...                                                  ...         ...
# 13561             [british invasion, classic rock, rock]        81.0
# 13571                                               None        30.0
# 13586                                     [classic soul]        44.0
# 13608  [hammond organ, jazz funk, jazz organ, soul jazz]        30.0
# 13650                    [cowboy western, western swing]        12.0
#
#        Similarity                                            Artist2  \
# 0              80                                               bono
# 6              60                                                can
# 9              39                justin timberlake duet with beyonce
# 19             36                                 hana and the goose
# 28             56  paul revere  mark lindsay formerly of paul rev...
# ...           ...                                                ...
# 13561          40                                   stones  feathers
# 13571          62                                             j nash
# 13586          44                                          cornelius
# 13608          78                                     johnny hammond
# 13650          50                      hank penny  his radio cowboys
#
#                          Spotify Name2  Similarity2
# 0                               bonobo           80
# 6                              cannons           60
# 9                who tf is justin time           39
# 19                                hana           36
# 28            paul revere  the raiders           56
# ...                                ...          ...
# 13561               the rolling stones           41
# 13571                           jnasty           67
# 13586  cornelius brothers  sister rose           45
# 13608             johnny hammond smith           82
# 13650                       hank penny           51
#
# [3669 rows x 8 columns]

# %%
print(df_leftover3.isnull().sum())
df_leftover3[df_leftover3.isnull().any(axis=1)]

df_leftover3_pickup = df_leftover3.dropna()

print(len(df_leftover3), len(df_leftover3_pickup))
# Out:
# Artist              0
# Spotify Name      683
# Genres           1133
# Popularity        722
# Similarity          0
# Artist2             0
# Spotify Name2       0
# Similarity2         0
# dtype: int64
# 3669 2530

# %%
df_leftover3_pickup
# Out:
#                                                   Artist  \
# 0                                                   Bono
# 9                    Justin Timberlake duet with Beyonce
# 19                                    Hana and the Goose
# 28     Paul Revere & Mark Lindsay formerly of Paul Re...
# 38                                       Jeff Beck Group
# ...                                                  ...
# 13555                                    Of Mice And Men
# 13561                                  Stones & feathers
# 13586                                          CORNELIUS
# 13608                                     Johnny Hammond
# 13650                     Hank Penny & His Radio Cowboys
#
#                            Spotify Name  \
# 0                                Bonobo
# 9                Who TF Is Justin Time?
# 19                                 HANA
# 28            Paul Revere & The Raiders
# 38                            Jeff Beck
# ...                                 ...
# 13555                     Of Mice & Men
# 13561                The Rolling Stones
# 13586  Cornelius Brothers & Sister Rose
# 13608            Johnny "Hammond" Smith
# 13650                        Hank Penny
#
#                                                   Genres  Popularity  \
# 0      [downtempo, electronica, jazztronica, nu jazz,...        67.0
# 9                                 [country rap, redneck]        49.0
# 19                                            [dark pop]        47.0
# 28     [bubblegum pop, classic garage rock, classic r...        42.0
# 38     [album rock, art rock, blues rock, british blu...        62.0
# ...                                                  ...         ...
# 13555  [melodic metalcore, metalcore, post-screamo, s...        63.0
# 13561             [british invasion, classic rock, rock]        81.0
# 13586                                     [classic soul]        44.0
# 13608  [hammond organ, jazz funk, jazz organ, soul jazz]        30.0
# 13650                    [cowboy western, western swing]        12.0
#
#        Similarity                                            Artist2  \
# 0              80                                               bono
# 9              39                justin timberlake duet with beyonce
# 19             36                                 hana and the goose
# 28             56  paul revere  mark lindsay formerly of paul rev...
# 38             75                                    jeff beck group
# ...           ...                                                ...
# 13555          86                                    of mice and men
# 13561          40                                   stones  feathers
# 13586          44                                          cornelius
# 13608          78                                     johnny hammond
# 13650          50                      hank penny  his radio cowboys
#
#                          Spotify Name2  Similarity2
# 0                               bonobo           80
# 9                who tf is justin time           39
# 19                                hana           36
# 28            paul revere  the raiders           56
# 38                           jeff beck           75
# ...                                ...          ...
# 13555                     of mice  men           89
# 13561               the rolling stones           41
# 13586  cornelius brothers  sister rose           45
# 13608             johnny hammond smith           82
# 13650                       hank penny           51
#
# [2530 rows x 8 columns]

# %%
def split_artist_name(name):
    words = name.split()
    normalized_words = []
    for word in words:
        normalized_word = ""
        for char in word:
            if unicodedata.category(char)[0] != 'M':
                normalized_word += unicodedata.normalize('NFKD', char).encode('ASCII', 'ignore').decode('utf-8')
        normalized_words.append(normalized_word)
    return normalized_words
    
# def find_longest_consecutive_match(words1, words2):

#     i, j = 0, 0
#     longest_match, current_match = 0, 0
    
#     while i < len(words1) and j < len(words2):
#         if words1[i] == words2[j]:
#             current_match += 1
#             longest_match = max(longest_match, current_match)
#         else:
#             current_match = 0
#         i += 1
#         j += 1
    
#     return longest_match

def find_longest_consecutive_match(words1, words2):
    longest_match = 0
    for i in range(len(words1)):
        for j in range(len(words2)):
            if words1[i] == words2[j]:
                current_match = 1
                while (i + current_match < len(words1)
                        and j + current_match < len(words2)
                        and words1[i + current_match] == words2[j + current_match]):
                    current_match += 1
                longest_match = max(longest_match, current_match)
    return longest_match

# %%
df_leftover3_pickup_test = df_leftover3_pickup.copy(deep=True)

df_leftover3_pickup_test["Artist2_Key"] = df_leftover3_pickup_test["Artist2"].apply(split_artist_name)
df_leftover3_pickup_test["Spotify2_Key"] = df_leftover3_pickup_test["Spotify Name2"].apply(split_artist_name)

df_leftover3_pickup_test

df_leftover3_pickup_test["Longest_Consecutive_Words"] = df_leftover3_pickup_test.apply(
    lambda x: find_longest_consecutive_match(x["Artist2_Key"], x["Spotify2_Key"]), axis=1)

df_leftover3_pickup_test[df_leftover3_pickup_test["Longest_Consecutive_Words"] >= 2]
# Out:
#                                                   Artist  \
# 28     Paul Revere & Mark Lindsay formerly of Paul Re...
# 38                                       Jeff Beck Group
# 42                                     Frankie Trumbauer
# 63                                              DJ Magic
# 66                                        Esme Patterson
# ...                                                  ...
# 13505             Jah Wobble & The Invaders of the Heart
# 13541                     Ronnie Earl & the Broadcasters
# 13555                                    Of Mice And Men
# 13608                                     Johnny Hammond
# 13650                     Hank Penny & His Radio Cowboys
#
#                               Spotify Name  \
# 28               Paul Revere & The Raiders
# 38                               Jeff Beck
# 42     Frankie Trumbauer And His Orchestra
# 63                           DJ Magic Mike
# 66                          Esmé Patterson
# ...                                    ...
# 13505                           Jah Wobble
# 13541                          Ronnie Earl
# 13555                        Of Mice & Men
# 13608               Johnny "Hammond" Smith
# 13650                           Hank Penny
#
#                                                   Genres  Popularity  \
# 28     [bubblegum pop, classic garage rock, classic r...        42.0
# 38     [album rock, art rock, blues rock, british blu...        62.0
# 42                                     [man's orchestra]        15.0
# 63                         [electro, miami bass, trival]        33.0
# 66                                       [new americana]        33.0
# ...                                                  ...         ...
# 13505                         [experimental dub, uk dub]        32.0
# 13541  [blues, blues rock, electric blues, modern blues]        38.0
# 13555  [melodic metalcore, metalcore, post-screamo, s...        63.0
# 13608  [hammond organ, jazz funk, jazz organ, soul jazz]        30.0
# 13650                    [cowboy western, western swing]        12.0
#
#        Similarity                                            Artist2  \
# 28             56  paul revere  mark lindsay formerly of paul rev...
# 38             75                                    jeff beck group
# 42             65                                  frankie trumbauer
# 63             76                                           dj magic
# 66             93                                     esme patterson
# ...           ...                                                ...
# 13505          42              jah wobble  the invaders of the heart
# 13541          54                      ronnie earl  the broadcasters
# 13555          86                                    of mice and men
# 13608          78                                     johnny hammond
# 13650          50                      hank penny  his radio cowboys
#
#                              Spotify Name2  Similarity2  \
# 28                paul revere  the raiders           56
# 38                               jeff beck           75
# 42     frankie trumbauer and his orchestra           65
# 63                           dj magic mike           76
# 66                          esmé patterson           93
# ...                                    ...          ...
# 13505                           jah wobble           43
# 13541                          ronnie earl           55
# 13555                         of mice  men           89
# 13608                 johnny hammond smith           82
# 13650                           hank penny           51
#
#                                              Artist2_Key  \
# 28     [paul, revere, mark, lindsay, formerly, of, pa...
# 38                                   [jeff, beck, group]
# 42                                  [frankie, trumbauer]
# 63                                           [dj, magic]
# 66                                     [esme, patterson]
# ...                                                  ...
# 13505       [jah, wobble, the, invaders, of, the, heart]
# 13541                  [ronnie, earl, the, broadcasters]
# 13555                               [of, mice, and, men]
# 13608                                  [johnny, hammond]
# 13650                 [hank, penny, his, radio, cowboys]
#
#                                     Spotify2_Key  Longest_Consecutive_Words
# 28                  [paul, revere, the, raiders]                          4
# 38                                  [jeff, beck]                          2
# 42     [frankie, trumbauer, and, his, orchestra]                          2
# 63                             [dj, magic, mike]                          2
# 66                             [esme, patterson]                          2
# ...                                          ...                        ...
# 13505                              [jah, wobble]                          2
# 13541                             [ronnie, earl]                          2
# 13555                            [of, mice, men]                          2
# 13608                   [johnny, hammond, smith]                          2
# 13650                              [hank, penny]                          2
#
# [1121 rows x 11 columns]

# %%
df_filtered3 = df_leftover3_pickup_test[df_leftover3_pickup_test["Longest_Consecutive_Words"] >= 2]
df_leftover4 = df_leftover3_pickup_test[df_leftover3_pickup_test["Longest_Consecutive_Words"] < 2]

print(len(df_filtered3), len(df_leftover4))
# Out:
# 1121 1409

# %%
df_leftover4
# Out:
#                                        Artist  \
# 0                                        Bono
# 9         Justin Timberlake duet with Beyonce
# 19                         Hana and the Goose
# 64                                       Come
# 74                                   Sister C
# ...                                       ...
# 13287                            Brick & Lace
# 13296  Biosphere & Higher Intelligence Agency
# 13299                            Wendy & Lisa
# 13561                       Stones & feathers
# 13586                               CORNELIUS
#
#                            Spotify Name  \
# 0                                Bonobo
# 9                Who TF Is Justin Time?
# 19                                 HANA
# 64                          Comethazine
# 74                        Sister Crayon
# ...                                 ...
# 13287                    Brick + Mortar
# 13296                         biosphere
# 13299                             WENDY
# 13561                The Rolling Stones
# 13586  Cornelius Brothers & Sister Rose
#
#                                                   Genres  Popularity  \
# 0      [downtempo, electronica, jazztronica, nu jazz,...        67.0
# 9                                 [country rap, redneck]        49.0
# 19                                            [dark pop]        47.0
# 64     [meme rap, rap, trap, underground hip hop, vap...        67.0
# 74                                    [sacramento indie]        24.0
# ...                                                  ...         ...
# 13287  [asbury park indie, modern alternative rock, m...        55.0
# 13296                           [lo-fi beats, lo-fi rap]        52.0
# 13299                                [k-pop, korean pop]        58.0
# 13561             [british invasion, classic rock, rock]        81.0
# 13586                                     [classic soul]        44.0
#
#        Similarity                                Artist2  \
# 0              80                                   bono
# 9              39    justin timberlake duet with beyonce
# 19             36                     hana and the goose
# 64             53                                   come
# 74             76                               sister c
# ...           ...                                    ...
# 13287          62                            brick  lace
# 13296          38  biosphere  higher intelligence agency
# 13299          59                            wendy  lisa
# 13561          40                       stones  feathers
# 13586          44                              cornelius
#
#                          Spotify Name2  Similarity2  \
# 0                               bonobo           80
# 9                who tf is justin time           39
# 19                                hana           36
# 64                         comethazine           53
# 74                       sister crayon           76
# ...                                ...          ...
# 13287                    brick  mortar           67
# 13296                        biosphere           39
# 13299                            wendy           62
# 13561               the rolling stones           41
# 13586  cornelius brothers  sister rose           45
#
#                                      Artist2_Key  \
# 0                                         [bono]
# 9      [justin, timberlake, duet, with, beyonce]
# 19                       [hana, and, the, goose]
# 64                                        [come]
# 74                                   [sister, c]
# ...                                          ...
# 13287                              [brick, lace]
# 13296  [biosphere, higher, intelligence, agency]
# 13299                              [wendy, lisa]
# 13561                         [stones, feathers]
# 13586                                [cornelius]
#
#                               Spotify2_Key  Longest_Consecutive_Words
# 0                                 [bonobo]                          0
# 9              [who, tf, is, justin, time]                          1
# 19                                  [hana]                          1
# 64                           [comethazine]                          0
# 74                        [sister, crayon]                          1
# ...                                    ...                        ...
# 13287                      [brick, mortar]                          1
# 13296                          [biosphere]                          1
# 13299                              [wendy]                          1
# 13561               [the, rolling, stones]                          1
# 13586  [cornelius, brothers, sister, rose]                          1
#
# [1409 rows x 11 columns]

# %%
df_leftover4
# Out:
#                                        Artist  \
# 0                                        Bono
# 9         Justin Timberlake duet with Beyonce
# 19                         Hana and the Goose
# 64                                       Come
# 74                                   Sister C
# ...                                       ...
# 13287                            Brick & Lace
# 13296  Biosphere & Higher Intelligence Agency
# 13299                            Wendy & Lisa
# 13561                       Stones & feathers
# 13586                               CORNELIUS
#
#                            Spotify Name  \
# 0                                Bonobo
# 9                Who TF Is Justin Time?
# 19                                 HANA
# 64                          Comethazine
# 74                        Sister Crayon
# ...                                 ...
# 13287                    Brick + Mortar
# 13296                         biosphere
# 13299                             WENDY
# 13561                The Rolling Stones
# 13586  Cornelius Brothers & Sister Rose
#
#                                                   Genres  Popularity  \
# 0      [downtempo, electronica, jazztronica, nu jazz,...        67.0
# 9                                 [country rap, redneck]        49.0
# 19                                            [dark pop]        47.0
# 64     [meme rap, rap, trap, underground hip hop, vap...        67.0
# 74                                    [sacramento indie]        24.0
# ...                                                  ...         ...
# 13287  [asbury park indie, modern alternative rock, m...        55.0
# 13296                           [lo-fi beats, lo-fi rap]        52.0
# 13299                                [k-pop, korean pop]        58.0
# 13561             [british invasion, classic rock, rock]        81.0
# 13586                                     [classic soul]        44.0
#
#        Similarity                                Artist2  \
# 0              80                                   bono
# 9              39    justin timberlake duet with beyonce
# 19             36                     hana and the goose
# 64             53                                   come
# 74             76                               sister c
# ...           ...                                    ...
# 13287          62                            brick  lace
# 13296          38  biosphere  higher intelligence agency
# 13299          59                            wendy  lisa
# 13561          40                       stones  feathers
# 13586          44                              cornelius
#
#                          Spotify Name2  Similarity2  \
# 0                               bonobo           80
# 9                who tf is justin time           39
# 19                                hana           36
# 64                         comethazine           53
# 74                       sister crayon           76
# ...                                ...          ...
# 13287                    brick  mortar           67
# 13296                        biosphere           39
# 13299                            wendy           62
# 13561               the rolling stones           41
# 13586  cornelius brothers  sister rose           45
#
#                                      Artist2_Key  \
# 0                                         [bono]
# 9      [justin, timberlake, duet, with, beyonce]
# 19                       [hana, and, the, goose]
# 64                                        [come]
# 74                                   [sister, c]
# ...                                          ...
# 13287                              [brick, lace]
# 13296  [biosphere, higher, intelligence, agency]
# 13299                              [wendy, lisa]
# 13561                         [stones, feathers]
# 13586                                [cornelius]
#
#                               Spotify2_Key  Longest_Consecutive_Words
# 0                                 [bonobo]                          0
# 9              [who, tf, is, justin, time]                          1
# 19                                  [hana]                          1
# 64                           [comethazine]                          0
# 74                        [sister, crayon]                          1
# ...                                    ...                        ...
# 13287                      [brick, mortar]                          1
# 13296                          [biosphere]                          1
# 13299                              [wendy]                          1
# 13561               [the, rolling, stones]                          1
# 13586  [cornelius, brothers, sister, rose]                          1
#
# [1409 rows x 11 columns]

# %%
strings_to_search = ['and', 'the']
df_leftover4_test = df_leftover4[df_leftover4['Artist2_Key'].apply(lambda x: any(elem.lower() in strings_to_search for elem in x)) | 
                 df_leftover4['Spotify2_Key'].apply(lambda x: any(elem.lower() in strings_to_search for elem in x))]
df_leftover4_test
# Out:
#                        Artist                   Spotify Name  \
# 19         Hana and the Goose                           HANA
# 76                  The Faces                          Faces
# 92     The Trash Can Sinatras              Trashcan Sinatras
# 115               The Stevens  The Stevenson Ranch Davidians
# 154                 Vibrators                  The Vibrators
# ...                       ...                            ...
# 12629          Seals & Crofts               Seals and Crofts
# 12799          Sly And Robbie                   Sly & Robbie
# 12880     Angels and Airwaves              Angels & Airwaves
# 13000      Renaldo & the Loaf                 Renaldo Domino
# 13561       Stones & feathers             The Rolling Stones
#
#                                                   Genres  Popularity  \
# 19                                            [dark pop]        47.0
# 76     [album rock, art rock, blues rock, classic roc...        60.0
# 92     [britpop, c86, chamber pop, power pop, scottis...        33.0
# 115                                         [psych gaze]        18.0
# 154                  [hardcore punk, oi, pub rock, punk]        34.0
# ...                                                  ...         ...
# 12629  [adult standards, album rock, bubblegum pop, c...        58.0
# 12799                        [dub, reggae, roots reggae]        46.0
# 12880                         [pop punk, socal pop punk]        59.0
# 13000                                 [traditional soul]        15.0
# 13561             [british invasion, classic rock, rock]        81.0
#
#        Similarity                 Artist2                  Spotify Name2  \
# 19             36      hana and the goose                           hana
# 76             71               the faces                          faces
# 92             87  the trash can sinatras              trashcan sinatras
# 115            55             the stevens  the stevenson ranch davidians
# 154            82               vibrators                  the vibrators
# ...           ...                     ...                            ...
# 12629          87           seals  crofts               seals and crofts
# 12799          85          sly and robbie                    sly  robbie
# 12880          89     angels and airwaves               angels  airwaves
# 13000          56       renaldo  the loaf                 renaldo domino
# 13561          40        stones  feathers             the rolling stones
#
#        Similarity2                  Artist2_Key  \
# 19              36      [hana, and, the, goose]
# 76              71                 [the, faces]
# 92              87  [the, trash, can, sinatras]
# 115             55               [the, stevens]
# 154             82                  [vibrators]
# ...            ...                          ...
# 12629           90              [seals, crofts]
# 12799           88           [sly, and, robbie]
# 12880           91      [angels, and, airwaves]
# 13000           58         [renaldo, the, loaf]
# 13561           41           [stones, feathers]
#
#                              Spotify2_Key  Longest_Consecutive_Words
# 19                                 [hana]                          1
# 76                                [faces]                          1
# 92                   [trashcan, sinatras]                          1
# 115    [the, stevenson, ranch, davidians]                          1
# 154                      [the, vibrators]                          1
# ...                                   ...                        ...
# 12629                [seals, and, crofts]                          1
# 12799                       [sly, robbie]                          1
# 12880                  [angels, airwaves]                          1
# 13000                   [renaldo, domino]                          1
# 13561              [the, rolling, stones]                          1
#
# [275 rows x 11 columns]

# %%
pattern = r'\b(?:{})\b'.format('|'.join(strings_to_search))
replace_func = lambda lst: ''.join([re.sub(pattern, '', s, flags=re.IGNORECASE).strip() for s in lst])
df_leftover4_test['Artist2_Key_NoStopWords'] = df_leftover4_test['Artist2_Key'].apply(replace_func).astype(str)
df_leftover4_test['Spotify2_Key_NoStopWords'] = df_leftover4_test['Spotify2_Key'].apply(replace_func).astype(str)


df_leftover4_test
# Out:
# <ipython-input-159-85dee444072a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_leftover4_test['Artist2_Key_NoStopWords'] = df_leftover4_test['Artist2_Key'].apply(replace_func).astype(str)
# <ipython-input-159-85dee444072a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_leftover4_test['Spotify2_Key_NoStopWords'] = df_leftover4_test['Spotify2_Key'].apply(replace_func).astype(str)
#                        Artist                   Spotify Name  \
# 19         Hana and the Goose                           HANA
# 76                  The Faces                          Faces
# 92     The Trash Can Sinatras              Trashcan Sinatras
# 115               The Stevens  The Stevenson Ranch Davidians
# 154                 Vibrators                  The Vibrators
# ...                       ...                            ...
# 12629          Seals & Crofts               Seals and Crofts
# 12799          Sly And Robbie                   Sly & Robbie
# 12880     Angels and Airwaves              Angels & Airwaves
# 13000      Renaldo & the Loaf                 Renaldo Domino
# 13561       Stones & feathers             The Rolling Stones
#
#                                                   Genres  Popularity  \
# 19                                            [dark pop]        47.0
# 76     [album rock, art rock, blues rock, classic roc...        60.0
# 92     [britpop, c86, chamber pop, power pop, scottis...        33.0
# 115                                         [psych gaze]        18.0
# 154                  [hardcore punk, oi, pub rock, punk]        34.0
# ...                                                  ...         ...
# 12629  [adult standards, album rock, bubblegum pop, c...        58.0
# 12799                        [dub, reggae, roots reggae]        46.0
# 12880                         [pop punk, socal pop punk]        59.0
# 13000                                 [traditional soul]        15.0
# 13561             [british invasion, classic rock, rock]        81.0
#
#        Similarity                 Artist2                  Spotify Name2  \
# 19             36      hana and the goose                           hana
# 76             71               the faces                          faces
# 92             87  the trash can sinatras              trashcan sinatras
# 115            55             the stevens  the stevenson ranch davidians
# 154            82               vibrators                  the vibrators
# ...           ...                     ...                            ...
# 12629          87           seals  crofts               seals and crofts
# 12799          85          sly and robbie                    sly  robbie
# 12880          89     angels and airwaves               angels  airwaves
# 13000          56       renaldo  the loaf                 renaldo domino
# 13561          40        stones  feathers             the rolling stones
#
#        Similarity2                  Artist2_Key  \
# 19              36      [hana, and, the, goose]
# 76              71                 [the, faces]
# 92              87  [the, trash, can, sinatras]
# 115             55               [the, stevens]
# 154             82                  [vibrators]
# ...            ...                          ...
# 12629           90              [seals, crofts]
# 12799           88           [sly, and, robbie]
# 12880           91      [angels, and, airwaves]
# 13000           58         [renaldo, the, loaf]
# 13561           41           [stones, feathers]
#
#                              Spotify2_Key  Longest_Consecutive_Words  \
# 19                                 [hana]                          1
# 76                                [faces]                          1
# 92                   [trashcan, sinatras]                          1
# 115    [the, stevenson, ranch, davidians]                          1
# 154                      [the, vibrators]                          1
# ...                                   ...                        ...
# 12629                [seals, and, crofts]                          1
# 12799                       [sly, robbie]                          1
# 12880                  [angels, airwaves]                          1
# 13000                   [renaldo, domino]                          1
# 13561              [the, rolling, stones]                          1
#
#       Artist2_Key_NoStopWords Spotify2_Key_NoStopWords
# 19                  hanagoose                     hana
# 76                      faces                    faces
# 92           trashcansinatras         trashcansinatras
# 115                   stevens  stevensonranchdavidians
# 154                 vibrators                vibrators
# ...                       ...                      ...
# 12629             sealscrofts              sealscrofts
# 12799               slyrobbie                slyrobbie
# 12880          angelsairwaves           angelsairwaves
# 13000             renaldoloaf            renaldodomino
# 13561          stonesfeathers            rollingstones
#
# [275 rows x 13 columns]

# %%
df_filtered4 = df_leftover4_test[df_leftover4_test['Artist2_Key_NoStopWords'] == df_leftover4_test['Spotify2_Key_NoStopWords']]
df_filtered4
# Out:
#                        Artist       Spotify Name  \
# 76                  The Faces              Faces
# 92     The Trash Can Sinatras  Trashcan Sinatras
# 154                 Vibrators      The Vibrators
# 379                  Spaniels       The Spaniels
# 665                 Honeydogs      The Honeydogs
# ...                       ...                ...
# 9551          Chris And Cosey      Chris & Cosey
# 10807                 Barkays       The Bar-Kays
# 12629          Seals & Crofts   Seals and Crofts
# 12799          Sly And Robbie       Sly & Robbie
# 12880     Angels and Airwaves  Angels & Airwaves
#
#                                                   Genres  Popularity  \
# 76     [album rock, art rock, blues rock, classic roc...        60.0
# 92     [britpop, c86, chamber pop, power pop, scottis...        33.0
# 154                  [hardcore punk, oi, pub rock, punk]        34.0
# 379                          [doo-wop, rhythm and blues]        38.0
# 665                                  [minneapolis indie]        12.0
# ...                                                  ...         ...
# 9551   [british experimental, british industrial, ebm...        29.0
# 10807  [classic soul, disco, electro, funk, memphis s...        46.0
# 12629  [adult standards, album rock, bubblegum pop, c...        58.0
# 12799                        [dub, reggae, roots reggae]        46.0
# 12880                         [pop punk, socal pop punk]        59.0
#
#        Similarity                 Artist2      Spotify Name2  Similarity2  \
# 76             71               the faces              faces           71
# 92             87  the trash can sinatras  trashcan sinatras           87
# 154            82               vibrators      the vibrators           82
# 379            80                spaniels       the spaniels           80
# 665            82               honeydogs      the honeydogs           82
# ...           ...                     ...                ...          ...
# 9551           86         chris and cosey       chris  cosey           89
# 10807          74                 barkays        the barkays           78
# 12629          87           seals  crofts   seals and crofts           90
# 12799          85          sly and robbie        sly  robbie           88
# 12880          89     angels and airwaves   angels  airwaves           91
#
#                        Artist2_Key          Spotify2_Key  \
# 76                    [the, faces]               [faces]
# 92     [the, trash, can, sinatras]  [trashcan, sinatras]
# 154                    [vibrators]      [the, vibrators]
# 379                     [spaniels]       [the, spaniels]
# 665                    [honeydogs]      [the, honeydogs]
# ...                            ...                   ...
# 9551           [chris, and, cosey]        [chris, cosey]
# 10807                    [barkays]        [the, barkays]
# 12629              [seals, crofts]  [seals, and, crofts]
# 12799           [sly, and, robbie]         [sly, robbie]
# 12880      [angels, and, airwaves]    [angels, airwaves]
#
#        Longest_Consecutive_Words Artist2_Key_NoStopWords  \
# 76                             1                   faces
# 92                             1        trashcansinatras
# 154                            1               vibrators
# 379                            1                spaniels
# 665                            1               honeydogs
# ...                          ...                     ...
# 9551                           1              chriscosey
# 10807                          1                 barkays
# 12629                          1             sealscrofts
# 12799                          1               slyrobbie
# 12880                          1          angelsairwaves
#
#       Spotify2_Key_NoStopWords
# 76                       faces
# 92            trashcansinatras
# 154                  vibrators
# 379                   spaniels
# 665                  honeydogs
# ...                        ...
# 9551                chriscosey
# 10807                  barkays
# 12629              sealscrofts
# 12799                slyrobbie
# 12880           angelsairwaves
#
# [81 rows x 13 columns]

# %%
df_leftover4_r = df_leftover4[~df_leftover4.isin(df_filtered4)].dropna()
print(len(df_leftover4), len(df_leftover4_r), len(df_filtered4))
# Out:
# 1409 1328 81

# %%
df_result = pd.concat([df_filtered, df_filtered2, df_filtered3, df_filtered4])
print(len(df), len(df_result))
df_result = df_result.iloc[:, :4]
df_result
# Out:
# 13661 11194
#                     Artist        Spotify Name  \
# 1                Motörhead           Motörhead
# 2       Nils Petter Molvær  Nils Petter Molvær
# 3            Color Me Badd       Color Me Badd
# 4            Trumans Water       Trumans Water
# 5          Cliff Eberhardt     Cliff Eberhardt
# ...                    ...                 ...
# 9551       Chris And Cosey       Chris & Cosey
# 10807              Barkays        The Bar-Kays
# 12629       Seals & Crofts    Seals and Crofts
# 12799       Sly And Robbie        Sly & Robbie
# 12880  Angels and Airwaves   Angels & Airwaves
#
#                                                   Genres  Popularity
# 1      [album rock, hard rock, metal, rock, speed metal]        68.0
# 2      [contemporary jazz, ecm-style jazz, fourth wor...        39.0
# 3      [boy band, contemporary r&b, new jack swing, r...        53.0
# 4                                           [noise rock]         7.0
# 5                                    [contemporary folk]        10.0
# ...                                                  ...         ...
# 9551   [british experimental, british industrial, ebm...        29.0
# 10807  [classic soul, disco, electro, funk, memphis s...        46.0
# 12629  [adult standards, album rock, bubblegum pop, c...        58.0
# 12799                        [dub, reggae, roots reggae]        46.0
# 12880                         [pop punk, socal pop punk]        59.0
#
# [11194 rows x 4 columns]

# %%
df_result.to_parquet("filtered_artists_with_infos.parquet")
